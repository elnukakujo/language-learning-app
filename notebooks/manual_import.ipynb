# %%
import json
import pandas as pd
import os
import re
from lapp.dbms import init_db, inserts, modify, delete, find_by_attr, insert
from lapp.tables import Unit, Vocabulary, GrammarRule, Language, CalligraphyCharacter

# %%
language_id = "zh"

# %% [markdown]
# ## Create a Language

# %%
# Check if the db folder exists, if not create it
if not os.path.exists("../db"):
    os.makedirs("../db")
    print(f"Created directory for database: ../db")

engine, session = init_db()

language = Language(
    id=language_id.upper(),
    name="Chinois",
    native_name="中文",
    level="A1",
    flag="🇨🇳"
)
insert(session, language)

session.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3297, in Engine.raw_connection(self)
#    3276 """Return a "raw" DBAPI connection from the connection pool.
#    3277
#    3278 The returned object is a proxied version of the DBAPI
#    (...)   3295
#    3296 """
# -> 3297 return self.pool.connect()
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
#     444 The connection is instrumented such that when its
#    (...)    447
#     448 """
# --> 449 return _ConnectionFairy._checkout(self)
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\pool\base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1263 if not fairy:
# -> 1264     fairy = _ConnectionRecord.checkout(pool)
#    1266     if threadconns is not None:
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\pool\base.py:713, in _ConnectionRecord.checkout(cls, pool)
#     712 else:
# --> 713     rec = pool._do_get()
#     715 try:
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:179, in QueuePool._do_get(self)
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     176 try:
# --> 177     return self._create_connection()
#     178 except:
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\pool\base.py:390, in Pool._create_connection(self)
#     388 """Called by subclasses to create a new ConnectionRecord."""
# --> 390 return _ConnectionRecord(self)
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\pool\base.py:675, in _ConnectionRecord.__init__(self, pool, connect)
#     674 if connect:
# --> 675     self.__connect()
#     676 self.finalize_callback = deque()
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\pool\base.py:901, in _ConnectionRecord.__connect(self)
#     900 except BaseException as e:
# --> 901     with util.safe_reraise():
#     902         pool.logger.debug("Error on connect(): %s", e)
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\pool\base.py:897, in _ConnectionRecord.__connect(self)
#     896 self.starttime = time.time()
# --> 897 self.dbapi_connection = connection = pool._invoke_creator(self)
#     898 pool.logger.debug("Created new connection %r", connection)
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\engine\create.py:646, in create_engine.<locals>.connect(connection_record)
#     644             return connection
# --> 646 return dialect.connect(*cargs, **cparams)
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\engine\default.py:625, in DefaultDialect.connect(self, *cargs, **cparams)
#     623 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     624     # inherits the docstring from interfaces.Dialect.connect
# --> 625     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# OperationalError: unable to open database file
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 engine, session = init_db()
#       3 if not os.path.exists("../db"):
#       4     os.makedirs("../db")
#
# File ~\Desktop\Github_Projet\language-learning-app\src\lapp\dbms.py:43, in init_db()
#      40 session = sessionmaker(bind=engine)
#      41 session = session()
# ---> 43 Base.metadata.create_all(engine)
#      44 logger.info(f"Database languages.db initialized successfully.")
#      46 return engine, session
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\sql\schema.py:5924, in MetaData.create_all(self, bind, tables, checkfirst)
#    5900 def create_all(
#    5901     self,
#    5902     bind: _CreateDropBind,
#    5903     tables: Optional[_typing_Sequence[Table]] = None,
#    5904     checkfirst: bool = True,
#    5905 ) -> None:
#    5906     """Create all tables stored in this metadata.
#    5907
#    5908     Conditional by default, will not attempt to recreate tables already
#    (...)   5922
#    5923     """
# -> 5924     bind._run_ddl_visitor(
#    5925         ddl.SchemaGenerator, self, checkfirst=checkfirst, tables=tables
#    5926     )
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3247, in Engine._run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    3241 def _run_ddl_visitor(
#    3242     self,
#    3243     visitorcallable: Type[InvokeDDLBase],
#    3244     element: SchemaVisitable,
#    3245     **kwargs: Any,
#    3246 ) -> None:
# -> 3247     with self.begin() as conn:
#    3248         conn._run_ddl_visitor(visitorcallable, element, **kwargs)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3237, in Engine.begin(self)
#    3212 @contextlib.contextmanager
#    3213 def begin(self) -> Iterator[Connection]:
#    3214     """Return a context manager delivering a :class:`_engine.Connection`
#    3215     with a :class:`.Transaction` established.
#    3216
#    (...)   3235
#    3236     """  # noqa: E501
# -> 3237     with self.connect() as conn:
#    3238         with conn.begin():
#    3239             yield conn
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3273, in Engine.connect(self)
#    3250 def connect(self) -> Connection:
#    3251     """Return a new :class:`_engine.Connection` object.
#    3252
#    3253     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)   3270
#    3271     """
# -> 3273     return self._connection_cls(self)
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\engine\base.py:147, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
# --> 147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#     150         raise
#     151 else:
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\engine\base.py:2436, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2434 elif should_wrap:
#    2435     assert sqlalchemy_exception is not None
# -> 2436     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2437 else:
#    2438     assert exc_info[1] is not None
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 if connection is None:
#     144     try:
# --> 145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
#     147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3297, in Engine.raw_connection(self)
#    3275 def raw_connection(self) -> PoolProxiedConnection:
#    3276     """Return a "raw" DBAPI connection from the connection pool.
#    3277
#    3278     The returned object is a proxied version of the DBAPI
#    (...)   3295
#    3296     """
# -> 3297     return self.pool.connect()
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     441 def connect(self) -> PoolProxiedConnection:
#     442     """Return a DBAPI connection from the pool.
#     443
#     444     The connection is instrumented such that when its
#    (...)    447
#     448     """
# --> 449     return _ConnectionFairy._checkout(self)
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\pool\base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1256 @classmethod
#    1257 def _checkout(
#    1258     cls,
#    (...)   1261     fairy: Optional[_ConnectionFairy] = None,
#    1262 ) -> _ConnectionFairy:
#    1263     if not fairy:
# -> 1264         fairy = _ConnectionRecord.checkout(pool)
#    1266         if threadconns is not None:
#    1267             threadconns.current = weakref.ref(fairy)
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\pool\base.py:713, in _ConnectionRecord.checkout(cls, pool)
#     711     rec = cast(_ConnectionRecord, pool._do_get())
#     712 else:
# --> 713     rec = pool._do_get()
#     715 try:
#     716     dbapi_connection = rec.get_connection()
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:179, in QueuePool._do_get(self)
#     177     return self._create_connection()
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#     181     raise
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     175 if self._inc_overflow():
#     176     try:
# --> 177         return self._create_connection()
#     178     except:
#     179         with util.safe_reraise():
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\pool\base.py:390, in Pool._create_connection(self)
#     387 def _create_connection(self) -> ConnectionPoolEntry:
#     388     """Called by subclasses to create a new ConnectionRecord."""
# --> 390     return _ConnectionRecord(self)
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\pool\base.py:675, in _ConnectionRecord.__init__(self, pool, connect)
#     673 self.__pool = pool
#     674 if connect:
# --> 675     self.__connect()
#     676 self.finalize_callback = deque()
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\pool\base.py:901, in _ConnectionRecord.__connect(self)
#     899     self.fresh = True
#     900 except BaseException as e:
# --> 901     with util.safe_reraise():
#     902         pool.logger.debug("Error on connect(): %s", e)
#     903 else:
#     904     # in SQLAlchemy 1.4 the first_connect event is not used by
#     905     # the engine, so this will usually not be set
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\pool\base.py:897, in _ConnectionRecord.__connect(self)
#     895 try:
#     896     self.starttime = time.time()
# --> 897     self.dbapi_connection = connection = pool._invoke_creator(self)
#     898     pool.logger.debug("Created new connection %r", connection)
#     899     self.fresh = True
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\engine\create.py:646, in create_engine.<locals>.connect(connection_record)
#     643         if connection is not None:
#     644             return connection
# --> 646 return dialect.connect(*cargs, **cparams)
#
# File c:\Users\Elliot\Desktop\Github_Projet\language-learning-app\.venv\Lib\site-packages\sqlalchemy\engine\default.py:625, in DefaultDialect.connect(self, *cargs, **cparams)
#     623 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     624     # inherits the docstring from interfaces.Dialect.connect
# --> 625     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# OperationalError: (sqlite3.OperationalError) unable to open database file
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# ## Add Units

# %%
# Initialize the database connection and create db file if it doesn't exist
engine, session = init_db()

# Initialize the database
with open(f'../data/{language_id}/units.json', 'r', encoding="utf8") as f:
    units_array = json.load(f)
    
units = []
for idx, unit_data in enumerate(units_array):
    units.append(
        Unit(
            id = f"{language_id.upper()}_{idx}",
            title = unit_data['title'],
            description = unit_data['description'],
            level = unit_data['level'],
            parent = language,
        )
    )
inserts(session, units)
session.close()
# Out:
# 2025-07-10 10:18:02,543 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:02,544 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("language")
# 2025-07-10 10:18:02,544 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-10 10:18:02,544 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-10 10:18:02,544 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-10 10:18:02,545 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-10 10:18:02,545 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-10 10:18:02,545 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-10 10:18:02,545 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-10 10:18:02,545 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-10 10:18:02,545 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-10 10:18:02,545 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-10 10:18:02,546 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-10 10:18:02,546 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:02,548 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:02,549 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-10 10:18:02,549 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('ZH',)
# 2025-07-10 10:18:02,550 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:02,550 INFO sqlalchemy.engine.Engine [generated in 0.00016s] ('ZH_0', 'Lecon introductive: Bonjour!', "A l'oral: Connaitre les salutations de base. \n\nA l'ecrit: 5 caracteres", 'A1', 0, '2025-07-10', 'ZH')
# 2025-07-10 10:18:02,550 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:02,551 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:02,551 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-10 10:18:02,552 INFO sqlalchemy.engine.Engine [generated in 0.00014s] ('ZH',)
# 2025-07-10 10:18:02,552 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:02,552 INFO sqlalchemy.engine.Engine [cached since 0.002146s ago] ('ZH_1', "Unite 1: Comment t'appelles-tu?", "A l'oral: Savoir se presenter et presenter quelqu'un. \n\nParler de sa nationalite. \n\nA l'ecrit: 19 caracteres", 'A1', 0, '2025-07-10', 'ZH')
# 2025-07-10 10:18:02,552 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:02,553 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:02,553 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-10 10:18:02,553 INFO sqlalchemy.engine.Engine [cached since 0.001637s ago] ('ZH',)
# 2025-07-10 10:18:02,553 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:02,553 INFO sqlalchemy.engine.Engine [cached since 0.003657s ago] ('ZH_2', 'Unite 2: Un, deux, trois', "A l'oral: Compter de 1 a 9999. \n\nSavoir enumerer des objets. \n\nA l'ecrit: 19 caracteres", 'A1', 0, '2025-07-10', 'ZH')
# 2025-07-10 10:18:02,554 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:02,554 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:02,555 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-10 10:18:02,555 INFO sqlalchemy.engine.Engine [cached since 0.003353s ago] ('ZH',)
# 2025-07-10 10:18:02,555 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:02,555 INFO sqlalchemy.engine.Engine [cached since 0.005297s ago] ('ZH_3', "Unite 3: Aujourd'hui", "A l'oral: Savoir annoncer la date. \n\nParler des moments de la journee et de l'heure. \n\nA l'ecrit: 17 caracteres", 'A1', 0, '2025-07-10', 'ZH')
# 2025-07-10 10:18:02,555 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:02,556 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:02,556 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-10 10:18:02,556 INFO sqlalchemy.engine.Engine [cached since 0.004774s ago] ('ZH',)
# 2025-07-10 10:18:02,556 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:02,557 INFO sqlalchemy.engine.Engine [cached since 0.006688s ago] ('ZH_4', 'Unite 4: Ou allons-nous?', "A l'oral: Parler d'un evenement passe, d'une experience. \n\nPouvoir se situer, parler ou l'on est, ou l'on va. \n\nA l'ecrit: 17 caracteres", 'A1', 0, '2025-07-10', 'ZH')
# 2025-07-10 10:18:02,557 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:02,557 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:02,558 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-10 10:18:02,558 INFO sqlalchemy.engine.Engine [cached since 0.00638s ago] ('ZH',)
# 2025-07-10 10:18:02,558 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:02,558 INFO sqlalchemy.engine.Engine [cached since 0.008312s ago] ('ZH_5', 'Unite 5: Je ne suis pas vieux', "A l'oral: Decrire quelqu'un ou quelque chose. \n\nUtilise les adjectifs. \n\nA l'ecrit: 17 caracteres", 'A1', 0, '2025-07-10', 'ZH')
# 2025-07-10 10:18:02,558 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:02,559 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:02,559 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-10 10:18:02,559 INFO sqlalchemy.engine.Engine [cached since 0.00769s ago] ('ZH',)
# 2025-07-10 10:18:02,559 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:02,559 INFO sqlalchemy.engine.Engine [cached since 0.009599s ago] ('ZH_6', 'Unite 6: Ma famille', "A l'oral: Pouvoir presenter sa famille. \n\nUtilise les demonstratifs. \n\nA l'ecrit: 22 caracteres", 'A1', 0, '2025-07-10', 'ZH')
# 2025-07-10 10:18:02,560 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:02,560 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:02,560 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-10 10:18:02,560 INFO sqlalchemy.engine.Engine [cached since 0.009011s ago] ('ZH',)
# 2025-07-10 10:18:02,561 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:02,561 INFO sqlalchemy.engine.Engine [cached since 0.01097s ago] ('ZH_7', 'Unite 7: Mes amis', "A l'oral: Parler des ses amis. \n\nParler des langues etrangeres. \n\nComparer des gens ou des objets. \n\nA l'ecrit: 18 caracteres", 'A1', 0, '2025-07-10', 'ZH')
# 2025-07-10 10:18:02,561 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:02,561 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:02,562 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-10 10:18:02,562 INFO sqlalchemy.engine.Engine [cached since 0.01034s ago] ('ZH',)
# 2025-07-10 10:18:02,562 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:02,562 INFO sqlalchemy.engine.Engine [cached since 0.01223s ago] ('ZH_8', "Unite 8: Qu'aimes-tu faire?", "A l'oral: Parler de ses activites favorites. \n\nInterroger sur la maniere. \n\nA l'ecrit: 16 caracteres", 'A2', 0, '2025-07-10', 'ZH')
# 2025-07-10 10:18:02,562 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:02,563 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:02,563 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-10 10:18:02,563 INFO sqlalchemy.engine.Engine [cached since 0.01159s ago] ('ZH',)
# 2025-07-10 10:18:02,563 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:02,563 INFO sqlalchemy.engine.Engine [cached since 0.01349s ago] ('ZH_9', 'Unite 9: Une journee classique', "A l'oral: Raconter sa journee. \n\nParler des differents moyens de transport. \n\nA l'ecrit: 16 caracteres", 'A2', 0, '2025-07-10', 'ZH')
# 2025-07-10 10:18:02,564 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:02,564 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:02,564 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-10 10:18:02,565 INFO sqlalchemy.engine.Engine [cached since 0.01321s ago] ('ZH',)
# 2025-07-10 10:18:02,565 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:02,565 INFO sqlalchemy.engine.Engine [cached since 0.01519s ago] ('ZH_10', 'Unite 10: Au travail', "A l'oral: Parler du monde du travail. \n\nA l'ecrit: 18 caracteres", 'A2', 0, '2025-07-10', 'ZH')
# 2025-07-10 10:18:02,565 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:02,566 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:02,566 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-10 10:18:02,566 INFO sqlalchemy.engine.Engine [cached since 0.01469s ago] ('ZH',)
# 2025-07-10 10:18:02,566 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:02,567 INFO sqlalchemy.engine.Engine [cached since 0.01672s ago] ('ZH_11', 'Unite 11: Dans une grande ville', "A l'oral: Pouvoir demander son chemin. \n\nSe reperer en ville. \n\nA l'ecrit: 18 caracteres", 'A2', 0, '2025-07-10', 'ZH')
# 2025-07-10 10:18:02,567 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:02,567 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:02,567 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-10 10:18:02,568 INFO sqlalchemy.engine.Engine [cached since 0.01619s ago] ('ZH',)
# 2025-07-10 10:18:02,568 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:02,568 INFO sqlalchemy.engine.Engine [cached since 0.01813s ago] ('ZH_12', 'Unite 12: Faire des achats', "A l'oral: Negocier un prix. \n\nFaire des achats. \n\nA l'ecrit: 18 caracteres", 'A2', 0, '2025-07-10', 'ZH')
# 2025-07-10 10:18:02,568 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:02,569 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:02,569 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-10 10:18:02,569 INFO sqlalchemy.engine.Engine [cached since 0.01754s ago] ('ZH',)
# 2025-07-10 10:18:02,569 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:02,569 INFO sqlalchemy.engine.Engine [cached since 0.01946s ago] ('ZH_13', "Unite 13: En voyage a l'etranger", "A l'oral: Pouvoir raconter ou prevoir un voyage. \n\nUtiliser 'Avant, apres, pendant'. \n\nA l'ecrit: 17 caracteres", 'A2', 0, '2025-07-10', 'ZH')
# 2025-07-10 10:18:02,570 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:02,570 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:02,570 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-10 10:18:02,570 INFO sqlalchemy.engine.Engine [cached since 0.01886s ago] ('ZH',)
# 2025-07-10 10:18:02,570 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:02,571 INFO sqlalchemy.engine.Engine [cached since 0.02078s ago] ('ZH_14', 'Unite 14: La culture chinoise', "A l'oral: Decouvrir la culture chinoise. \n\nParler des fetes et des vacances. \n\nA l'ecrit: 19 caracteres", 'A2', 0, '2025-07-10', 'ZH')
# 2025-07-10 10:18:02,571 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:02,571 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:02,571 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-10 10:18:02,572 INFO sqlalchemy.engine.Engine [cached since 0.02021s ago] ('ZH',)
# 2025-07-10 10:18:02,572 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:02,572 INFO sqlalchemy.engine.Engine [cached since 0.02214s ago] ('ZH_15', 'Unite 15: A la maison', "A l'oral: Decrire une maison, un appartement. \n\nUtiliser 吧 et les directionnels. \n\nA l'ecrit: 17 caracteres", 'A2', 0, '2025-07-10', 'ZH')
# 2025-07-10 10:18:02,572 INFO sqlalchemy.engine.Engine COMMIT
# /Users/noe_jager/Documents/GitHub/vocabulary-dbms/src/lapp/dbms.py:80: SAWarning: Object of type <Unit> not in session, add operation along 'Language.units' will not proceed
#   session.commit()

# %% [markdown]
# ## Add Vocabulary

# %%
# Initialize the database connection and create db file if it doesn't exist
engine, session = init_db()

directory_path = f'../data/{language_id}/vocabulary'

if not os.path.exists(directory_path):
    raise FileNotFoundError(f"No vocabulary found for {language_id}.")

vocs = []

# List all elements (files and directories) in the specified directory and get their full paths
elements_paths = [os.path.join(directory_path, element) for element in os.listdir(directory_path)]
for voc_file in elements_paths:
    if os.path.isfile(voc_file) and voc_file.endswith('.csv'):
        unit_id = re.sub("[^0-9]", "", os.path.basename(voc_file))
        df = pd.read_csv(voc_file)
        for idx, row in df.iterrows():
            vocs.append( 
                Vocabulary(
                    id=f"{language_id.upper()}_{unit_id}_V{idx}",
                    word = row['word'],
                    translation = row["translation"],
                    phonetic = row["pinyin"],
                    example_sentence = row.get("example_sentence", ""),
                    type = row["type"],
                    parent=session.query(Unit).filter(Unit.id == f"{language_id.upper()}_{unit_id}").first()
                )
            )
inserts(session, vocs)
session.close()
# Out:
# 2025-07-10 10:18:02,577 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:02,577 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("language")
# 2025-07-10 10:18:02,577 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-10 10:18:02,578 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-10 10:18:02,578 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-10 10:18:02,578 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-10 10:18:02,578 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-10 10:18:02,579 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-10 10:18:02,579 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-10 10:18:02,579 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-10 10:18:02,579 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-10 10:18:02,579 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-10 10:18:02,579 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-10 10:18:02,580 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:02,584 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:02,585 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,585 INFO sqlalchemy.engine.Engine [generated in 0.00016s] ('ZH_2', 1, 0)
# 2025-07-10 10:18:02,586 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,586 INFO sqlalchemy.engine.Engine [cached since 0.001097s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:02,586 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,586 INFO sqlalchemy.engine.Engine [cached since 0.001796s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:02,587 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,587 INFO sqlalchemy.engine.Engine [cached since 0.002454s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:02,588 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,588 INFO sqlalchemy.engine.Engine [cached since 0.003274s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:02,588 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,589 INFO sqlalchemy.engine.Engine [cached since 0.003949s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:02,589 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,589 INFO sqlalchemy.engine.Engine [cached since 0.004621s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:02,590 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,590 INFO sqlalchemy.engine.Engine [cached since 0.005252s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:02,590 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,590 INFO sqlalchemy.engine.Engine [cached since 0.005853s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:02,591 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,591 INFO sqlalchemy.engine.Engine [cached since 0.006433s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:02,592 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,592 INFO sqlalchemy.engine.Engine [cached since 0.007058s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:02,592 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,592 INFO sqlalchemy.engine.Engine [cached since 0.007625s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:02,593 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,593 INFO sqlalchemy.engine.Engine [cached since 0.008217s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:02,593 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,593 INFO sqlalchemy.engine.Engine [cached since 0.008771s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:02,594 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,594 INFO sqlalchemy.engine.Engine [cached since 0.009388s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:02,594 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,595 INFO sqlalchemy.engine.Engine [cached since 0.00995s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:02,595 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,595 INFO sqlalchemy.engine.Engine [cached since 0.01058s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:02,596 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,596 INFO sqlalchemy.engine.Engine [cached since 0.0111s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:02,596 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,596 INFO sqlalchemy.engine.Engine [cached since 0.01167s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:02,597 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,597 INFO sqlalchemy.engine.Engine [cached since 0.01226s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:02,597 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,597 INFO sqlalchemy.engine.Engine [cached since 0.01292s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:02,598 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,598 INFO sqlalchemy.engine.Engine [cached since 0.01374s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:02,599 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,599 INFO sqlalchemy.engine.Engine [cached since 0.01435s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:02,600 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,600 INFO sqlalchemy.engine.Engine [cached since 0.01581s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,601 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,601 INFO sqlalchemy.engine.Engine [cached since 0.01637s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,601 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,602 INFO sqlalchemy.engine.Engine [cached since 0.01699s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,602 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,602 INFO sqlalchemy.engine.Engine [cached since 0.01756s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,603 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,603 INFO sqlalchemy.engine.Engine [cached since 0.01812s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,603 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,603 INFO sqlalchemy.engine.Engine [cached since 0.01873s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,604 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,604 INFO sqlalchemy.engine.Engine [cached since 0.01934s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,604 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,605 INFO sqlalchemy.engine.Engine [cached since 0.01994s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,605 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,605 INFO sqlalchemy.engine.Engine [cached since 0.02057s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,606 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,606 INFO sqlalchemy.engine.Engine [cached since 0.02111s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,606 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,606 INFO sqlalchemy.engine.Engine [cached since 0.0217s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,607 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,607 INFO sqlalchemy.engine.Engine [cached since 0.02226s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,607 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,607 INFO sqlalchemy.engine.Engine [cached since 0.02282s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,608 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,608 INFO sqlalchemy.engine.Engine [cached since 0.0234s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,608 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,609 INFO sqlalchemy.engine.Engine [cached since 0.02399s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,609 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,609 INFO sqlalchemy.engine.Engine [cached since 0.02455s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,610 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,610 INFO sqlalchemy.engine.Engine [cached since 0.02517s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,610 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,610 INFO sqlalchemy.engine.Engine [cached since 0.0258s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,611 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,611 INFO sqlalchemy.engine.Engine [cached since 0.02641s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,611 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,612 INFO sqlalchemy.engine.Engine [cached since 0.02698s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,612 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,612 INFO sqlalchemy.engine.Engine [cached since 0.02758s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,613 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,613 INFO sqlalchemy.engine.Engine [cached since 0.02814s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,613 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,613 INFO sqlalchemy.engine.Engine [cached since 0.02877s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,614 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,614 INFO sqlalchemy.engine.Engine [cached since 0.02934s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,614 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,615 INFO sqlalchemy.engine.Engine [cached since 0.02995s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,615 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,615 INFO sqlalchemy.engine.Engine [cached since 0.03057s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,616 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,616 INFO sqlalchemy.engine.Engine [cached since 0.03115s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,616 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,616 INFO sqlalchemy.engine.Engine [cached since 0.03174s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,617 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,617 INFO sqlalchemy.engine.Engine [cached since 0.03232s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,617 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,617 INFO sqlalchemy.engine.Engine [cached since 0.03289s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,618 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,618 INFO sqlalchemy.engine.Engine [cached since 0.0336s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:02,619 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,620 INFO sqlalchemy.engine.Engine [cached since 0.03509s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:02,620 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,620 INFO sqlalchemy.engine.Engine [cached since 0.03567s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:02,621 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,621 INFO sqlalchemy.engine.Engine [cached since 0.03622s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:02,621 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,621 INFO sqlalchemy.engine.Engine [cached since 0.03675s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:02,622 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,622 INFO sqlalchemy.engine.Engine [cached since 0.03732s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:02,622 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,622 INFO sqlalchemy.engine.Engine [cached since 0.03787s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:02,623 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,623 INFO sqlalchemy.engine.Engine [cached since 0.03846s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:02,623 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,624 INFO sqlalchemy.engine.Engine [cached since 0.03905s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:02,624 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,624 INFO sqlalchemy.engine.Engine [cached since 0.03963s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:02,625 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,625 INFO sqlalchemy.engine.Engine [cached since 0.04018s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:02,625 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,625 INFO sqlalchemy.engine.Engine [cached since 0.04071s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:02,626 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,626 INFO sqlalchemy.engine.Engine [cached since 0.04127s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:02,626 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,626 INFO sqlalchemy.engine.Engine [cached since 0.04181s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:02,627 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,627 INFO sqlalchemy.engine.Engine [cached since 0.04235s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:02,627 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,627 INFO sqlalchemy.engine.Engine [cached since 0.04291s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:02,628 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,628 INFO sqlalchemy.engine.Engine [cached since 0.04349s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:02,629 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,629 INFO sqlalchemy.engine.Engine [cached since 0.04411s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:02,629 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,629 INFO sqlalchemy.engine.Engine [cached since 0.04471s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:02,630 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,630 INFO sqlalchemy.engine.Engine [cached since 0.04532s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:02,630 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,630 INFO sqlalchemy.engine.Engine [cached since 0.04591s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:02,631 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,631 INFO sqlalchemy.engine.Engine [cached since 0.04646s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:02,632 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,632 INFO sqlalchemy.engine.Engine [cached since 0.04715s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:02,632 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,632 INFO sqlalchemy.engine.Engine [cached since 0.04771s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:02,633 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,633 INFO sqlalchemy.engine.Engine [cached since 0.0483s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:02,634 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,634 INFO sqlalchemy.engine.Engine [cached since 0.04969s ago] ('ZH_0', 1, 0)
# 2025-07-10 10:18:02,635 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,635 INFO sqlalchemy.engine.Engine [cached since 0.05025s ago] ('ZH_0', 1, 0)
# 2025-07-10 10:18:02,635 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,635 INFO sqlalchemy.engine.Engine [cached since 0.05089s ago] ('ZH_0', 1, 0)
# 2025-07-10 10:18:02,636 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,636 INFO sqlalchemy.engine.Engine [cached since 0.05142s ago] ('ZH_0', 1, 0)
# 2025-07-10 10:18:02,636 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,637 INFO sqlalchemy.engine.Engine [cached since 0.05196s ago] ('ZH_0', 1, 0)
# 2025-07-10 10:18:02,637 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,637 INFO sqlalchemy.engine.Engine [cached since 0.05247s ago] ('ZH_0', 1, 0)
# 2025-07-10 10:18:02,637 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,638 INFO sqlalchemy.engine.Engine [cached since 0.05297s ago] ('ZH_0', 1, 0)
# 2025-07-10 10:18:02,638 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,638 INFO sqlalchemy.engine.Engine [cached since 0.05354s ago] ('ZH_0', 1, 0)
# 2025-07-10 10:18:02,639 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,641 INFO sqlalchemy.engine.Engine [cached since 0.0566s ago] ('ZH_0', 1, 0)
# 2025-07-10 10:18:02,643 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,644 INFO sqlalchemy.engine.Engine [cached since 0.059s ago] ('ZH_0', 1, 0)
# 2025-07-10 10:18:02,645 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,645 INFO sqlalchemy.engine.Engine [cached since 0.06091s ago] ('ZH_0', 1, 0)
# 2025-07-10 10:18:02,648 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,648 INFO sqlalchemy.engine.Engine [cached since 0.0636s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:02,650 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,650 INFO sqlalchemy.engine.Engine [cached since 0.06591s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:02,652 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,652 INFO sqlalchemy.engine.Engine [cached since 0.06771s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:02,654 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,654 INFO sqlalchemy.engine.Engine [cached since 0.06929s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:02,655 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,655 INFO sqlalchemy.engine.Engine [cached since 0.07088s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:02,656 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,656 INFO sqlalchemy.engine.Engine [cached since 0.07175s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:02,657 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,657 INFO sqlalchemy.engine.Engine [cached since 0.07256s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:02,658 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,658 INFO sqlalchemy.engine.Engine [cached since 0.07325s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:02,659 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,659 INFO sqlalchemy.engine.Engine [cached since 0.0742s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:02,661 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,661 INFO sqlalchemy.engine.Engine [cached since 0.07665s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:02,663 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,663 INFO sqlalchemy.engine.Engine [cached since 0.07846s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:02,664 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,664 INFO sqlalchemy.engine.Engine [cached since 0.0795s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:02,665 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,665 INFO sqlalchemy.engine.Engine [cached since 0.08033s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:02,665 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,666 INFO sqlalchemy.engine.Engine [cached since 0.08102s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:02,666 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,666 INFO sqlalchemy.engine.Engine [cached since 0.08162s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:02,667 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,667 INFO sqlalchemy.engine.Engine [cached since 0.08235s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:02,667 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,668 INFO sqlalchemy.engine.Engine [cached since 0.08295s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:02,668 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,668 INFO sqlalchemy.engine.Engine [cached since 0.08358s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:02,670 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,670 INFO sqlalchemy.engine.Engine [cached since 0.08519s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:02,670 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,670 INFO sqlalchemy.engine.Engine [cached since 0.08593s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:02,671 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,671 INFO sqlalchemy.engine.Engine [cached since 0.08656s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:02,672 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,672 INFO sqlalchemy.engine.Engine [cached since 0.08715s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:02,672 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,672 INFO sqlalchemy.engine.Engine [cached since 0.08771s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:02,673 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:02,673 INFO sqlalchemy.engine.Engine [cached since 0.08839s ago] ('ZH_5', 1, 0)
# ...
# 2025-07-10 10:18:04,392 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,394 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,395 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,396 INFO sqlalchemy.engine.Engine [cached since 1.409s ago] ('ZH_9',)
# 2025-07-10 10:18:04,397 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,397 INFO sqlalchemy.engine.Engine [cached since 1.416s ago] ('ZH_9_V6', '骑', 'Chevaucher', 'Qí', '', 'Verbes', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:04,398 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,399 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,400 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,401 INFO sqlalchemy.engine.Engine [cached since 1.415s ago] ('ZH_9',)
# 2025-07-10 10:18:04,402 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,402 INFO sqlalchemy.engine.Engine [cached since 1.421s ago] ('ZH_9_V7', '上班', 'Commencer le travail', 'Shàngbān', '', 'Verbes', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:04,404 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,406 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,407 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,409 INFO sqlalchemy.engine.Engine [cached since 1.422s ago] ('ZH_9',)
# 2025-07-10 10:18:04,409 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,410 INFO sqlalchemy.engine.Engine [cached since 1.429s ago] ('ZH_9_V8', '下班', 'Finir le travail', 'Xiàbān', '', 'Verbes', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:04,411 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,415 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,417 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,418 INFO sqlalchemy.engine.Engine [cached since 1.431s ago] ('ZH_9',)
# 2025-07-10 10:18:04,419 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,421 INFO sqlalchemy.engine.Engine [cached since 1.439s ago] ('ZH_9_V9', '走路', 'Marcher', 'Zǒulù', '', 'Verbes', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:04,422 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,424 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,424 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,425 INFO sqlalchemy.engine.Engine [cached since 1.438s ago] ('ZH_9',)
# 2025-07-10 10:18:04,426 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,426 INFO sqlalchemy.engine.Engine [cached since 1.445s ago] ('ZH_9_V10', '坐', "S'asseoir/prendre (véhicule)", 'Zuò', '', 'Verbes', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:04,426 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,427 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,427 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,428 INFO sqlalchemy.engine.Engine [cached since 1.441s ago] ('ZH_9',)
# 2025-07-10 10:18:04,428 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,428 INFO sqlalchemy.engine.Engine [cached since 1.447s ago] ('ZH_9_V11', '游泳', 'Nager', 'Yóuyǒng', '', 'Verbes', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:04,428 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,429 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,430 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,430 INFO sqlalchemy.engine.Engine [cached since 1.443s ago] ('ZH_9',)
# 2025-07-10 10:18:04,431 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,431 INFO sqlalchemy.engine.Engine [cached since 1.45s ago] ('ZH_9_V12', '无聊', 'Ennuyeux', 'Wúliáo', '', 'Adjectifs', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:04,432 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,434 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,435 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,435 INFO sqlalchemy.engine.Engine [cached since 1.449s ago] ('ZH_9',)
# 2025-07-10 10:18:04,436 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,437 INFO sqlalchemy.engine.Engine [cached since 1.456s ago] ('ZH_9_V13', '有意思', 'Intéressant (polite)', 'Yǒu yìsi', '', 'Adjectifs', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:04,438 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,440 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,441 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,441 INFO sqlalchemy.engine.Engine [cached since 1.455s ago] ('ZH_9',)
# 2025-07-10 10:18:04,442 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,443 INFO sqlalchemy.engine.Engine [cached since 1.462s ago] ('ZH_9_V14', '没意思', 'Inintéressant (polite)', 'Méi yìsi', '', 'Adjectifs', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:04,444 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,450 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,451 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,451 INFO sqlalchemy.engine.Engine [cached since 1.464s ago] ('ZH_9',)
# 2025-07-10 10:18:04,452 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,453 INFO sqlalchemy.engine.Engine [cached since 1.471s ago] ('ZH_9_V15', '啊', "Particule modale d'exclamation", 'A', '', 'Divers', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:04,454 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,456 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,462 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,463 INFO sqlalchemy.engine.Engine [cached since 1.476s ago] ('ZH_9',)
# 2025-07-10 10:18:04,463 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,463 INFO sqlalchemy.engine.Engine [cached since 1.482s ago] ('ZH_9_V16', '每', 'Chaque', 'Měi', '', 'Divers', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:04,464 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,466 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,467 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,467 INFO sqlalchemy.engine.Engine [cached since 1.481s ago] ('ZH_9',)
# 2025-07-10 10:18:04,469 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,470 INFO sqlalchemy.engine.Engine [cached since 1.489s ago] ('ZH_9_V17', '然后', 'Ensuite', 'Ránhòu', '', 'Divers', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:04,470 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,471 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,472 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,472 INFO sqlalchemy.engine.Engine [cached since 1.485s ago] ('ZH_9',)
# 2025-07-10 10:18:04,472 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,473 INFO sqlalchemy.engine.Engine [cached since 1.492s ago] ('ZH_9_V18', '同意', "Être d'accord", 'Tóngyì', '', 'Divers', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:04,473 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,474 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,474 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,475 INFO sqlalchemy.engine.Engine [cached since 1.488s ago] ('ZH_9',)
# 2025-07-10 10:18:04,475 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,475 INFO sqlalchemy.engine.Engine [cached since 1.494s ago] ('ZH_9_V19', '先', "D'abord", 'Xiān', '', 'Divers', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:04,476 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,477 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,477 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,477 INFO sqlalchemy.engine.Engine [cached since 1.49s ago] ('ZH_9',)
# 2025-07-10 10:18:04,477 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,478 INFO sqlalchemy.engine.Engine [cached since 1.496s ago] ('ZH_9_V20', '有点儿', 'Un petit peu', 'Yǒu diǎnr', '', 'Divers', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:04,478 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,479 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,479 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,479 INFO sqlalchemy.engine.Engine [cached since 1.493s ago] ('ZH_9',)
# 2025-07-10 10:18:04,480 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,480 INFO sqlalchemy.engine.Engine [cached since 1.499s ago] ('ZH_9_V21', '公园', 'Parc public', 'Gōngyuán', '', 'Noms et expressions', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:04,480 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,481 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,481 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,481 INFO sqlalchemy.engine.Engine [cached since 1.494s ago] ('ZH_9',)
# 2025-07-10 10:18:04,481 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,482 INFO sqlalchemy.engine.Engine [cached since 1.5s ago] ('ZH_9_V22', '看法', 'Point de vue', 'Kànfǎ', '', 'Noms et expressions', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:04,482 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,483 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,483 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,483 INFO sqlalchemy.engine.Engine [cached since 1.496s ago] ('ZH_9',)
# 2025-07-10 10:18:04,483 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,483 INFO sqlalchemy.engine.Engine [cached since 1.502s ago] ('ZH_9_V23', '游泳池', 'Piscine', 'Yóuyǒngchí', '', 'Noms et expressions', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:04,484 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Add Grammar Rules

# %%
# Initialize the database connection and create db file if it doesn't exist
engine, session = init_db()

directory_path = f'../data/{language_id}/grammar'

if not os.path.exists(directory_path):
    raise FileNotFoundError(f"No grammar files found for {language_id}.")

grammars = []

# List all elements (files and directories) in the specified directory and get their full paths
elements_paths = [os.path.join(directory_path, element) for element in os.listdir(directory_path)]
for grammar_file in elements_paths:
    if os.path.isfile(grammar_file) and grammar_file.endswith('.json'):
        unit_id = re.sub("[^0-9]", "", os.path.basename(grammar_file))
        with open(grammar_file, 'r', encoding="utf8") as f:
            grammar_data = json.load(f)
        for idx, row in enumerate(grammar_data):
            grammars.append( 
                GrammarRule(
                    id=f"{language_id.upper()}_{unit_id}_G{idx + 1}",
                    title=row['title'],
                    explanation=row["content"],
                    parent=session.query(Unit).filter(Unit.id == f"{language_id.upper()}_{unit_id}").first()
                )
            )
inserts(session, grammars)
session.close()
# Out:
# 2025-07-10 10:18:04,489 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,489 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("language")
# 2025-07-10 10:18:04,489 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-10 10:18:04,489 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-10 10:18:04,490 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-10 10:18:04,490 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-10 10:18:04,490 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-10 10:18:04,490 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-10 10:18:04,490 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-10 10:18:04,490 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-10 10:18:04,491 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-10 10:18:04,491 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-10 10:18:04,491 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-10 10:18:04,491 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,492 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,493 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,493 INFO sqlalchemy.engine.Engine [generated in 0.00013s] ('ZH_11', 1, 0)
# 2025-07-10 10:18:04,494 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,494 INFO sqlalchemy.engine.Engine [cached since 0.001301s ago] ('ZH_11', 1, 0)
# 2025-07-10 10:18:04,495 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,495 INFO sqlalchemy.engine.Engine [cached since 0.002299s ago] ('ZH_11', 1, 0)
# 2025-07-10 10:18:04,499 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,499 INFO sqlalchemy.engine.Engine [cached since 0.006503s ago] ('ZH_11', 1, 0)
# 2025-07-10 10:18:04,502 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,503 INFO sqlalchemy.engine.Engine [cached since 0.00986s ago] ('ZH_6', 1, 0)
# 2025-07-10 10:18:04,504 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,505 INFO sqlalchemy.engine.Engine [cached since 0.01196s ago] ('ZH_6', 1, 0)
# 2025-07-10 10:18:04,506 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,507 INFO sqlalchemy.engine.Engine [cached since 0.01441s ago] ('ZH_6', 1, 0)
# 2025-07-10 10:18:04,510 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,510 INFO sqlalchemy.engine.Engine [cached since 0.01741s ago] ('ZH_6', 1, 0)
# 2025-07-10 10:18:04,513 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,513 INFO sqlalchemy.engine.Engine [cached since 0.02049s ago] ('ZH_7', 1, 0)
# 2025-07-10 10:18:04,514 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,514 INFO sqlalchemy.engine.Engine [cached since 0.02147s ago] ('ZH_7', 1, 0)
# 2025-07-10 10:18:04,515 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,515 INFO sqlalchemy.engine.Engine [cached since 0.02232s ago] ('ZH_7', 1, 0)
# 2025-07-10 10:18:04,516 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,517 INFO sqlalchemy.engine.Engine [cached since 0.02439s ago] ('ZH_7', 1, 0)
# 2025-07-10 10:18:04,519 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,519 INFO sqlalchemy.engine.Engine [cached since 0.02651s ago] ('ZH_7', 1, 0)
# 2025-07-10 10:18:04,521 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,521 INFO sqlalchemy.engine.Engine [cached since 0.02824s ago] ('ZH_7', 1, 0)
# 2025-07-10 10:18:04,522 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,523 INFO sqlalchemy.engine.Engine [cached since 0.02963s ago] ('ZH_10', 1, 0)
# 2025-07-10 10:18:04,523 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,523 INFO sqlalchemy.engine.Engine [cached since 0.03027s ago] ('ZH_10', 1, 0)
# 2025-07-10 10:18:04,524 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,524 INFO sqlalchemy.engine.Engine [cached since 0.03088s ago] ('ZH_10', 1, 0)
# 2025-07-10 10:18:04,524 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,525 INFO sqlalchemy.engine.Engine [cached since 0.03156s ago] ('ZH_10', 1, 0)
# 2025-07-10 10:18:04,525 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,525 INFO sqlalchemy.engine.Engine [cached since 0.03224s ago] ('ZH_10', 1, 0)
# 2025-07-10 10:18:04,526 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,526 INFO sqlalchemy.engine.Engine [cached since 0.03287s ago] ('ZH_10', 1, 0)
# 2025-07-10 10:18:04,527 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,527 INFO sqlalchemy.engine.Engine [cached since 0.03385s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:04,527 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,527 INFO sqlalchemy.engine.Engine [cached since 0.03441s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:04,528 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,528 INFO sqlalchemy.engine.Engine [cached since 0.03495s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:04,529 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,529 INFO sqlalchemy.engine.Engine [cached since 0.03578s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:04,529 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,529 INFO sqlalchemy.engine.Engine [cached since 0.03639s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:04,530 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,530 INFO sqlalchemy.engine.Engine [cached since 0.03696s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:04,530 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,530 INFO sqlalchemy.engine.Engine [cached since 0.03751s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:04,531 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,531 INFO sqlalchemy.engine.Engine [cached since 0.03806s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:04,532 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,532 INFO sqlalchemy.engine.Engine [cached since 0.03903s ago] ('ZH_15', 1, 0)
# 2025-07-10 10:18:04,532 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,533 INFO sqlalchemy.engine.Engine [cached since 0.03957s ago] ('ZH_15', 1, 0)
# 2025-07-10 10:18:04,533 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,533 INFO sqlalchemy.engine.Engine [cached since 0.0401s ago] ('ZH_15', 1, 0)
# 2025-07-10 10:18:04,533 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,534 INFO sqlalchemy.engine.Engine [cached since 0.04063s ago] ('ZH_15', 1, 0)
# 2025-07-10 10:18:04,534 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,534 INFO sqlalchemy.engine.Engine [cached since 0.04149s ago] ('ZH_14', 1, 0)
# 2025-07-10 10:18:04,535 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,535 INFO sqlalchemy.engine.Engine [cached since 0.04208s ago] ('ZH_14', 1, 0)
# 2025-07-10 10:18:04,535 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,536 INFO sqlalchemy.engine.Engine [cached since 0.04262s ago] ('ZH_14', 1, 0)
# 2025-07-10 10:18:04,536 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,536 INFO sqlalchemy.engine.Engine [cached since 0.04314s ago] ('ZH_14', 1, 0)
# 2025-07-10 10:18:04,536 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,537 INFO sqlalchemy.engine.Engine [cached since 0.04364s ago] ('ZH_14', 1, 0)
# 2025-07-10 10:18:04,537 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,537 INFO sqlalchemy.engine.Engine [cached since 0.04451s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:04,538 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,538 INFO sqlalchemy.engine.Engine [cached since 0.04509s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:04,539 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,539 INFO sqlalchemy.engine.Engine [cached since 0.046s ago] ('ZH_8', 1, 0)
# 2025-07-10 10:18:04,539 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,540 INFO sqlalchemy.engine.Engine [cached since 0.04655s ago] ('ZH_8', 1, 0)
# 2025-07-10 10:18:04,540 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,540 INFO sqlalchemy.engine.Engine [cached since 0.04709s ago] ('ZH_8', 1, 0)
# 2025-07-10 10:18:04,540 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,541 INFO sqlalchemy.engine.Engine [cached since 0.04763s ago] ('ZH_8', 1, 0)
# 2025-07-10 10:18:04,541 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,541 INFO sqlalchemy.engine.Engine [cached since 0.04815s ago] ('ZH_8', 1, 0)
# 2025-07-10 10:18:04,542 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,542 INFO sqlalchemy.engine.Engine [cached since 0.04905s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:04,542 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,543 INFO sqlalchemy.engine.Engine [cached since 0.04959s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:04,543 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,543 INFO sqlalchemy.engine.Engine [cached since 0.05012s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:04,543 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,544 INFO sqlalchemy.engine.Engine [cached since 0.05063s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:04,544 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,544 INFO sqlalchemy.engine.Engine [cached since 0.05123s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:04,545 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,545 INFO sqlalchemy.engine.Engine [cached since 0.0521s ago] ('ZH_13', 1, 0)
# 2025-07-10 10:18:04,545 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,546 INFO sqlalchemy.engine.Engine [cached since 0.05263s ago] ('ZH_13', 1, 0)
# 2025-07-10 10:18:04,546 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,546 INFO sqlalchemy.engine.Engine [cached since 0.05318s ago] ('ZH_13', 1, 0)
# 2025-07-10 10:18:04,547 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,547 INFO sqlalchemy.engine.Engine [cached since 0.05373s ago] ('ZH_13', 1, 0)
# 2025-07-10 10:18:04,547 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,547 INFO sqlalchemy.engine.Engine [cached since 0.05435s ago] ('ZH_13', 1, 0)
# 2025-07-10 10:18:04,548 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,548 INFO sqlalchemy.engine.Engine [cached since 0.05516s ago] ('ZH_12', 1, 0)
# 2025-07-10 10:18:04,549 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,549 INFO sqlalchemy.engine.Engine [cached since 0.05571s ago] ('ZH_12', 1, 0)
# 2025-07-10 10:18:04,549 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,549 INFO sqlalchemy.engine.Engine [cached since 0.05623s ago] ('ZH_12', 1, 0)
# 2025-07-10 10:18:04,550 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,550 INFO sqlalchemy.engine.Engine [cached since 0.05677s ago] ('ZH_12', 1, 0)
# 2025-07-10 10:18:04,550 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,550 INFO sqlalchemy.engine.Engine [cached since 0.05733s ago] ('ZH_12', 1, 0)
# 2025-07-10 10:18:04,551 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,551 INFO sqlalchemy.engine.Engine [cached since 0.05827s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:04,552 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,552 INFO sqlalchemy.engine.Engine [cached since 0.05879s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:04,553 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,553 INFO sqlalchemy.engine.Engine [cached since 0.05976s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:04,553 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,553 INFO sqlalchemy.engine.Engine [cached since 0.06028s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:04,554 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,554 INFO sqlalchemy.engine.Engine [cached since 0.06113s ago] ('ZH_9', 1, 0)
# 2025-07-10 10:18:04,555 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,555 INFO sqlalchemy.engine.Engine [cached since 0.06168s ago] ('ZH_9', 1, 0)
# 2025-07-10 10:18:04,555 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,555 INFO sqlalchemy.engine.Engine [cached since 0.06221s ago] ('ZH_9', 1, 0)
# 2025-07-10 10:18:04,556 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,556 INFO sqlalchemy.engine.Engine [cached since 0.06274s ago] ('ZH_9', 1, 0)
# 2025-07-10 10:18:04,556 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,556 INFO sqlalchemy.engine.Engine [cached since 0.06326s ago] ('ZH_9', 1, 0)
# 2025-07-10 10:18:04,557 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,557 INFO sqlalchemy.engine.Engine [cached since 0.06378s ago] ('ZH_9', 1, 0)
# 2025-07-10 10:18:04,557 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,558 INFO sqlalchemy.engine.Engine [generated in 0.00015s] ('ZH_11_G1', 'Énumérer avec 第 dì', "第 dì permet de former des chiffres et nombres ordinaux.\nIl s'emploie de la façon suivante :\n\n第 + chiffre/nombre ( + Classificateur )\n\n* 第一 dì yī ... (918 characters truncated) ... s deux mots suivants signifient « étage » et peuvent s'employer sans 第 dì :\n\n* 三楼 sān lóu : « Troisième étage »\n* 四层 sì céng : « Quatrième étage »", 0, '2025-07-10', 'ZH_11')
# 2025-07-10 10:18:04,558 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,558 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,559 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,559 INFO sqlalchemy.engine.Engine [generated in 0.00015s] ('ZH_11',)
# 2025-07-10 10:18:04,559 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,559 INFO sqlalchemy.engine.Engine [cached since 0.001902s ago] ('ZH_11_G2', 'Exprimer une distance avec 离 lí', "离 lí est utilisé lorsqu'on souhaite exprimer une distance entre deux points. Il peut se traduire par « par rapport à ». La structure à employer, très ... (589 characters truncated) ... ē zhàn lí zhèr tài yuǎn le : « La gare est trop éloignée d’ici »\n* 酒吧离我的家比较远 jiǔbā lí wǒ de jiā bǐjiào yuǎn : « Le bar est plutôt loin de chez moi »", 0, '2025-07-10', 'ZH_11')
# 2025-07-10 10:18:04,560 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,560 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,560 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,560 INFO sqlalchemy.engine.Engine [cached since 0.001517s ago] ('ZH_11',)
# 2025-07-10 10:18:04,561 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,561 INFO sqlalchemy.engine.Engine [cached since 0.003231s ago] ('ZH_11_G3', 'Se diriger, suivre un itinéraire', 'Savoir utiliser les termes « droite », « gauche » et « tout droit » suffit pour se repérer, demander son chemin et comprendre un itinéraire. Lorsqu’o ... (238 characters truncated) ... tout droit »\n* 你先往前走一百米，然后往左拐 nǐ xiān wǎng qián zǒu yī bǎi mǐ, ránhòu wǎng zuǒ guǎi : « Va d’abord tout droit sur 100 mètres, puis tourne à gauche »', 0, '2025-07-10', 'ZH_11')
# 2025-07-10 10:18:04,561 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,561 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,561 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,562 INFO sqlalchemy.engine.Engine [cached since 0.002843s ago] ('ZH_11',)
# 2025-07-10 10:18:04,562 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,562 INFO sqlalchemy.engine.Engine [cached since 0.004564s ago] ('ZH_11_G4', "À l'intérieur de quelque chose", 'Pour indiquer que quelque chose se situe à l’intérieur de quelque chose d’autre, on utilise la structure suivante :\n\nNom 1 + 在 + Nom 2 + 里面\n\n* 你在 ... (240 characters truncated) ...  shàng ma ? : « Es-tu dans le bus ? »\n* 我在车上 wǒ zài chē shàng : « Je suis dans la voiture »\n* 我在火车上 wǒ zài huǒchē shàng : « Je suis dans le train »', 0, '2025-07-10', 'ZH_11')
# 2025-07-10 10:18:04,562 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,563 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,563 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,563 INFO sqlalchemy.engine.Engine [cached since 0.004142s ago] ('ZH_6',)
# 2025-07-10 10:18:04,563 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,563 INFO sqlalchemy.engine.Engine [cached since 0.005905s ago] ('ZH_6_G1', 'Les démonstratifs 这 zhè et 那 nà', "Le démonstratif le plus couramment utilisé en chinois est 这 zhè.\n这 zhè va rarement être utilisé tout seul, il est souvent couplé avec d'autres carac ... (1057 characters truncated) ... à-bas, c'est... »\n* 那个/那个人 nà ge rén : « Cette personne-là »\n* 那里是我的朋友的家 nà lǐ shì wǒ de péngyou de jiā : « Là-bas se trouve la maison de mon ami »", 0, '2025-07-10', 'ZH_6')
# 2025-07-10 10:18:04,564 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,564 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,564 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,564 INFO sqlalchemy.engine.Engine [cached since 0.00559s ago] ('ZH_6',)
# 2025-07-10 10:18:04,565 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,565 INFO sqlalchemy.engine.Engine [cached since 0.007384s ago] ('ZH_6_G2', 'Autres utilisations du caractère 的 de', "的 de, le caractère permettant de marquer la possession, peut s'utiliser à la suite d'un pronom personnel (ex. 我的 wǒ de « mon ») ou d'un nom (ex. 老师的书 ... (937 characters truncated) ... ncài : « C'est le plat que j'aime faire/préparer »\n* 这是我去年去的地方 zhè shì wǒ qùnián qù de dìfang : « C'est l'endroit où je suis allé l'année dernière »", 0, '2025-07-10', 'ZH_6')
# 2025-07-10 10:18:04,565 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,566 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,566 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,566 INFO sqlalchemy.engine.Engine [cached since 0.007104s ago] ('ZH_6',)
# 2025-07-10 10:18:04,566 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,566 INFO sqlalchemy.engine.Engine [cached since 0.008806s ago] ('ZH_6_G3', 'Exprimer "avec" à l\'aide de 跟 gēn et 一起 yīqǐ', "La préposition 跟 gēn, souvent utilisée avec 一起 yīqǐ (signifiant « ensemble »), permet de marquer l'accompagnement :\n\n* 我跟你去 wǒ gēn nǐ qù : « J'y va ... (142 characters truncated) ... gēn tā yīqǐ qù le gōngyuán : « Je suis allé au parc avec lui hier »\n* 我跟我的女朋友一起住 wǒ gēn wǒ de nǚ péngyou yīqǐ zhù : « J'habite avec ma petite amie »", 0, '2025-07-10', 'ZH_6')
# 2025-07-10 10:18:04,567 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,567 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,567 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,567 INFO sqlalchemy.engine.Engine [cached since 0.008387s ago] ('ZH_6',)
# 2025-07-10 10:18:04,567 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,568 INFO sqlalchemy.engine.Engine [cached since 0.01011s ago] ('ZH_6_G4', 'Les caractères ayant plusieurs prononciations', "Vous aurez certainement remarqué que certains caractères peuvent avoir plusieurs prononciations. Le changement de prononciation peut faire varier ou  ... (198 characters truncated) ...  : trouver que\n* 睡觉 shuìjiào : dormir\n\nCertains caractères comme le 都 de 首都 « la capitale » peuvent changer à la fois de prononciation et de sens.", 0, '2025-07-10', 'ZH_6')
# 2025-07-10 10:18:04,568 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,568 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,568 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,568 INFO sqlalchemy.engine.Engine [cached since 0.009672s ago] ('ZH_7',)
# 2025-07-10 10:18:04,569 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,569 INFO sqlalchemy.engine.Engine [cached since 0.01137s ago] ('ZH_7_G1', 'Comparer avec 比 bi ou 没有 méiyǒu', "**Utilisation de 比 bi**\nLe caractère 比 bǐ est utilisé en tant que comparatif de supériorité ou d'infériorité (et non d'égalité). Il peut être tradui ... (740 characters truncated) ...  : « Il est plus petit que moi » (littéralement « Il n'a pas ma taille »)\n* 妈妈没有爸爸高 māma méiyǒu bàba gāo : « Maman n'est pas aussi grande que papa »", 0, '2025-07-10', 'ZH_7')
# 2025-07-10 10:18:04,569 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,569 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,570 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,570 INFO sqlalchemy.engine.Engine [cached since 0.01095s ago] ('ZH_7',)
# 2025-07-10 10:18:04,570 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,570 INFO sqlalchemy.engine.Engine [cached since 0.01277s ago] ('ZH_7_G2', 'Interrogatif 谁 shéi/shuí', "谁 shéi est l'interrogatif signifiant « Qui ? ». Comme tous les mots interrogatifs, il se place à l'endroit où se trouvera la réponse :\n\n* 你是谁？ Nǐ s ... (401 characters truncated) ...  » et ne doit pas traduire le pronom relatif « qui » dans des phrases comme « La personne qui habite ici ». Pour cela, on utilise 的 de (cf. Leçon 6).", 0, '2025-07-10', 'ZH_7')
# 2025-07-10 10:18:04,570 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,571 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,571 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,571 INFO sqlalchemy.engine.Engine [cached since 0.01236s ago] ('ZH_7',)
# 2025-07-10 10:18:04,571 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,571 INFO sqlalchemy.engine.Engine [cached since 0.01405s ago] ('ZH_7_G3', 'Quelle(s) langue(s) sais-tu parler ?', "En général, on forme le nom d'une langue en ajoutant 语 yǔ (ou 文 wén) au nom du pays.\n\nPour les pays finissant par 国 guó, on remplace 国 guó par 语 yǔ ... (342 characters truncated) ... :\n\n* 中国 Zhōngguó (Chine) → 中文 Zhōngwén (chinois)\n* 汉语 Hànyǔ (chinois)\n\nNote : 汉语 Hànyǔ (chinois) et 韩语 Hányǔ (coréen) se prononcent très proche.", 0, '2025-07-10', 'ZH_7')
# 2025-07-10 10:18:04,572 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,572 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,572 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,572 INFO sqlalchemy.engine.Engine [cached since 0.01359s ago] ('ZH_7',)
# 2025-07-10 10:18:04,573 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,573 INFO sqlalchemy.engine.Engine [cached since 0.01529s ago] ('ZH_7_G4', 'Les adverbes 最 zuì et 太 ... 了 tài...le', "Les adverbes 最 zuì et 太 ... 了 tài...le s'emploient comme 很 hěn devant un adjectif, mais nuancent ou renforcent le propos :\n\n* 我很累 wǒ hěn lèi : « Je ... (11 characters truncated) ... ué »\n* 最累 zuì lèi : « Le plus fatigué »\n* 我太累了 wǒ tài lèi le : « Je suis trop fatigué »\n* 我不太累了 wǒ bù tài lèi le : « Je ne suis pas trop fatigué »", 0, '2025-07-10', 'ZH_7')
# 2025-07-10 10:18:04,573 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,573 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,573 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,574 INFO sqlalchemy.engine.Engine [cached since 0.01478s ago] ('ZH_7',)
# 2025-07-10 10:18:04,574 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,574 INFO sqlalchemy.engine.Engine [cached since 0.0165s ago] ('ZH_7_G5', 'Tout, toutes et tous avec 都 dōu', 'Le caractère 都 peut se prononcer « dū » (dans 首都 shǒudū « capitale ») ou « dōu » quand il signifie « tout, tous ». Il se place directement après le n ... (122 characters truncated) ... ōu xiǎng qù Zhōngguó : « Nous voulons tous aller en Chine »\n* 我的朋友都 wǒ de péngyou dōu : « Tous mes amis »\n* 女生都 nǚshēng dōu : « Toutes les filles »', 0, '2025-07-10', 'ZH_7')
# 2025-07-10 10:18:04,574 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,575 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,575 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,575 INFO sqlalchemy.engine.Engine [cached since 0.01608s ago] ('ZH_7',)
# 2025-07-10 10:18:04,575 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,575 INFO sqlalchemy.engine.Engine [cached since 0.01781s ago] ('ZH_7_G6', 'Ensemble avec 一起 yīqǐ', '一起 yīqǐ a déjà été vu dans la structure 跟 gēn ... + 一起 yīqǐ (page 109) pour dire « avec ». 一起 yīqǐ peut aussi être utilisé seul et signifie « ensembl ... (50 characters truncated) ...  Elles vont regarder un film ensemble »\n* 我们一起去北京 wǒmen yīqǐ qù Běijīng : « Nous allons ensemble à Pékin »\n\nStructure : Sujet + 一起 + Verbe + Objet', 0, '2025-07-10', 'ZH_7')
# 2025-07-10 10:18:04,575 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,576 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,576 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,576 INFO sqlalchemy.engine.Engine [cached since 0.01735s ago] ('ZH_10',)
# 2025-07-10 10:18:04,576 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,576 INFO sqlalchemy.engine.Engine [cached since 0.01908s ago] ('ZH_10_G1', 'Indiquer le destinataire avec 给 gěi', "给 gěi, signifiant « donner », permet d'indiquer la cible d'une action.\n\nStructure : Sujet + 给 + cible + action\n\n* 你给我打电话 nǐ gěi wǒ dǎ diànhuà : « ... (45 characters truncated) ... i tā dǎ diànhuà : « Tu dois lui téléphoner »\n* 你给他写信 nǐ gěi tā xiěxìn : « Écris-lui une lettre »\n* 我给你做饭 wǒ gěi nǐ zuòfàn : « Je te fais à manger »", 0, '2025-07-10', 'ZH_10')
# 2025-07-10 10:18:04,577 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,577 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,577 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,577 INFO sqlalchemy.engine.Engine [cached since 0.01867s ago] ('ZH_10',)
# 2025-07-10 10:18:04,578 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,578 INFO sqlalchemy.engine.Engine [cached since 0.02041s ago] ('ZH_10_G2', '"Pouvoir" avec 能 néng ou 可以 kěyǐ', "Plusieurs verbes existent pour exprimer la possibilité, cependant ils ne peuvent pas s'employer de la même manière. Nous avons déjà étudié le verbe 会 ... (795 characters truncated) ... 停车吗？wǒ zài zhèr kěyǐ tíngchē ma ? : « Puis-je garer ma voiture ici ? »\n* 妈妈，我可以出去吗？māma, wǒ kěyǐ chūqù ma ? : « Maman, est-ce que je peux sortir ? »", 0, '2025-07-10', 'ZH_10')
# 2025-07-10 10:18:04,578 INFO sqlalchemy.engine.Engine COMMIT
# ...
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,708 INFO sqlalchemy.engine.Engine [cached since 0.1496s ago] ('ZH_12',)
# 2025-07-10 10:18:04,709 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,709 INFO sqlalchemy.engine.Engine [cached since 0.152s ago] ('ZH_12_G2', 'Classificateurs ne pouvant pas être remplacés par 个 gè', "Certains classificateurs ne peuvent pas être remplacés par 个 gè (qui est, pour rappel, le classificateur universel), car ils apportent un sens partic ... (274 characters truncated) ...  gè niǎo : « Un oiseau »\n* 一群鸟 yī qún niǎo : « Un vol d’oiseaux »\n* 一些人 yī xiē rén : « Quelques personnes »\n* 一杯水 yī bēi shuǐ : « Un verre d’eau »", 0, '2025-07-10', 'ZH_12')
# 2025-07-10 10:18:04,710 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,711 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,711 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,711 INFO sqlalchemy.engine.Engine [cached since 0.1527s ago] ('ZH_12',)
# 2025-07-10 10:18:04,713 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,713 INFO sqlalchemy.engine.Engine [cached since 0.1553s ago] ('ZH_12_G3', 'Permettre quelque chose avec 让 ràng', "让 ràng est un verbe dit « causatif », qui peut être traduit par « laisser » ou « permettre » en français.\n\nStructure : Sujet + 让 + Personne/Objet + ... (128 characters truncated) ...  papa ne te laisse-t-il pas y aller ? »\n* 看 Titanic 电影让我很感动 kàn Titanic diànyǐng ràng wǒ hěn gǎndòng : « Regarder le film Titanic m'a beaucoup ému »", 0, '2025-07-10', 'ZH_12')
# 2025-07-10 10:18:04,713 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,714 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,714 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,714 INFO sqlalchemy.engine.Engine [cached since 0.1554s ago] ('ZH_12',)
# 2025-07-10 10:18:04,715 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,716 INFO sqlalchemy.engine.Engine [cached since 0.1588s ago] ('ZH_12_G4', 'Demander « combien » avec 多少 duōshǎo ou 几 jǐ', "Il existe deux façons principales de demander « combien » : 多少 duōshǎo et 几 jǐ. Voici leurs différences :\n\n* 几 jǐ est utilisé pour des quantités gé ... (695 characters truncated) ...  ici »\n* 我有十多元 wǒ yǒu shí duō yuán : « J’ai un peu plus de dix yuans »\n* 我有三十多块钱 wǒ yǒu sānshí duō kuài qián : « J’ai un peu plus de trente kuais »", 0, '2025-07-10', 'ZH_12')
# 2025-07-10 10:18:04,717 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,717 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,717 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,718 INFO sqlalchemy.engine.Engine [cached since 0.1589s ago] ('ZH_12',)
# 2025-07-10 10:18:04,718 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,719 INFO sqlalchemy.engine.Engine [cached since 0.1616s ago] ('ZH_12_G5', '« Quelques » avec 一些 yīxiē', "一些 yīxiē signifie « quelques » ou « certains » et désigne une quantité indéterminée. Il s'utilise selon le schéma suivant :\n\n一些 + Nom\n\n* 有一些人 yǒu yīxiē rén : « Il y a quelques personnes »\n* 爸爸买了一些书 bàba mǎi le yīxiē shū : « Papa a acheté quelques livres »", 0, '2025-07-10', 'ZH_12')
# 2025-07-10 10:18:04,720 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,721 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,721 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,721 INFO sqlalchemy.engine.Engine [cached since 0.1626s ago] ('ZH_5',)
# 2025-07-10 10:18:04,722 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,722 INFO sqlalchemy.engine.Engine [cached since 0.1643s ago] ('ZH_5_G1', 'Les adjectifs', "**Affirmation avec 很 hěn**\nLes noms doivent être liés aux autres noms à l'aide du verbe « être » 是 shì.\n\n* 妈妈 是 老师 māma shì lǎoshī : « Maman est p ... (1844 characters truncated) ... ǐhuan : « j'aime »\n* 我 讨厌 wǒ tǎoyàn : « je déteste »\n* 我 很 喜欢 wǒ hěn xǐhuan : « j'aime beaucoup »\n* 我 很 讨厌 wǒ hěn tǎoyàn : « je déteste vraiment »", 0, '2025-07-10', 'ZH_5')
# 2025-07-10 10:18:04,722 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,722 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,723 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,723 INFO sqlalchemy.engine.Engine [cached since 0.1639s ago] ('ZH_5',)
# 2025-07-10 10:18:04,723 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,723 INFO sqlalchemy.engine.Engine [cached since 0.1657s ago] ('ZH_5_G2', 'Énumérer avec 和 hé', "Le caractère 和 hé permet d'énumérer des noms communs. Nous pouvons traduire par « ainsi que », son emploi diffère donc du « et » français.\n\n* 我 的 妈 ... (132 characters truncated) ... n papa et moi »\n\n和 hé ne peut pas être utilisé pour lier deux phrases comme en français (ex. Ce matin je travaille et cet après-midi je me repose).", 0, '2025-07-10', 'ZH_5')
# 2025-07-10 10:18:04,723 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,724 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,724 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,724 INFO sqlalchemy.engine.Engine [cached since 0.1654s ago] ('ZH_5',)
# 2025-07-10 10:18:04,724 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,724 INFO sqlalchemy.engine.Engine [cached since 0.1671s ago] ('ZH_5_G3', 'Le caractère 的 de', "Le premier sens de 的 de est le possessif. L'ajout du caractère 的 de aux pronoms personnels permet de former les pronoms possessifs :\n\nPronom person ... (638 characters truncated) ...  de Chine »\n\nDéterminant + 的 + déterminé\n\nLe contexte est indispensable pour comprendre le sens qu'il a dans une phrase, un texte ou un dialogue.", 0, '2025-07-10', 'ZH_5')
# 2025-07-10 10:18:04,725 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,725 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,725 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,726 INFO sqlalchemy.engine.Engine [cached since 0.1668s ago] ('ZH_5',)
# 2025-07-10 10:18:04,726 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,726 INFO sqlalchemy.engine.Engine [cached since 0.1685s ago] ('ZH_5_G4', 'Les différentes utilisations de 要 yào', "Le premier sens de 要 yào est le verbe « vouloir ».\n\n* 我 要 工作 wǒ yào gōngzuò : « Je veux travailler »\n* 我 要 吃饭 wǒ yào chīfàn : « Je veux manger »\n ... (31 characters truncated) ... enir est la suivante :\n\nIl peut également avoir d'autres sens, tels que « devoir », « falloir » ou encore « aller faire/être sur le point de ... ».", 0, '2025-07-10', 'ZH_5')
# 2025-07-10 10:18:04,726 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,727 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,727 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,727 INFO sqlalchemy.engine.Engine [cached since 0.1681s ago] ('ZH_9',)
# 2025-07-10 10:18:04,727 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,727 INFO sqlalchemy.engine.Engine [cached since 0.1698s ago] ('ZH_9_G1', 'Moyens de transport', "Si en français nous employons généralement le verbe « prendre » lorsqu'il s'agit des moyens de transport, il convient d'utiliser le verbe 坐 zuò « s'a ... (471 characters truncated) ...  véhicule, il faut employer 开 kāi « conduire, ouvrir » :\n\n* 我开车 wǒ kāi chē : « Je conduis la voiture »\n* 我开飞机 wǒ kāi fēijī : « Je pilote l'avion »", 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:04,727 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,728 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,728 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,728 INFO sqlalchemy.engine.Engine [cached since 0.1695s ago] ('ZH_9',)
# 2025-07-10 10:18:04,729 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,729 INFO sqlalchemy.engine.Engine [cached since 0.1712s ago] ('ZH_9_G2', '"Chaque" avec 每 měi', '每 měi est employé dans la majorité des cas avec un classificateur derrière :\n\n* 每个人 měi gè rén : « Chaque personne »\n* 每个月 měi gè yuè : « Chaque m ... (100 characters truncated) ... it pas être employé dans les trois cas suivants :\n\n* 每年 měi nián : « Chaque année »\n* 每天 měi tiān : « Chaque jour »\n* 每日 měi rì : « Chaque jour »', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:04,729 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,729 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,729 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,730 INFO sqlalchemy.engine.Engine [cached since 0.1708s ago] ('ZH_9',)
# 2025-07-10 10:18:04,730 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,730 INFO sqlalchemy.engine.Engine [cached since 0.1726s ago] ('ZH_9_G3', '"D\'abord... ensuite..." avec 先 xiān et 然后 ránhòu', "先 xiān « premièrement », et 然后 ránhòu « ensuite » peuvent être utilisés ensemble pour indiquer que deux événements se succèdent :\n\n* 我们先吃饭，然后看电视 wǒ ... (220 characters truncated) ... emièrement » peut également être utilisé seul :\n\n* 他先到了 tā xiān dào le : « Il est arrivé en premier »\n* 我先说 wǒ xiān shuō : « Je parle en premier »", 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:04,730 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,731 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,731 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,731 INFO sqlalchemy.engine.Engine [cached since 0.1722s ago] ('ZH_9',)
# 2025-07-10 10:18:04,731 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,731 INFO sqlalchemy.engine.Engine [cached since 0.174s ago] ('ZH_9_G4', '"Un petit peu" avec 有点儿 yǒu diǎnr ou 一点儿 yī diǎnr', "**有点儿 yǒu diǎnr**\n有点儿 yǒu diǎnr ou simplement 有点 yǒu diǎn est utilisé avant un adjectif. Il est généralement employé dans des phrases négatives, pou ... (499 characters truncated) ... 宜一点儿 nǐ piányi yī diǎnr : « Baisse un peu le prix »\n* 你快一点儿 nǐ kuài yī diǎnr : « Dépêche-toi un peu »\n* 你慢一点儿 nǐ màn yī diǎnr : « Ralentis un peu »", 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:04,732 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,732 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,732 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,732 INFO sqlalchemy.engine.Engine [cached since 0.1736s ago] ('ZH_9',)
# 2025-07-10 10:18:04,733 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,733 INFO sqlalchemy.engine.Engine [cached since 0.1753s ago] ('ZH_9_G5', 'Utiliser 比较 bǐjiào devant un verbe', "Nous avons vu dans la leçon précédente que l'adverbe 比较 bǐjiào signifie « relativement, plutôt » et qu'il était employé devant un adjectif afin de le ... (162 characters truncated) ... iào xǐhuan : « Je préfère »\n* 我不喜欢坐车，我比较喜欢走路 wǒ bù xǐhuan zuò chē, wǒ bǐjiào xǐhuan zǒulù : « Je n'aime pas prendre la voiture, je préfère marcher »", 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:04,733 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:04,733 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,734 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:04,734 INFO sqlalchemy.engine.Engine [cached since 0.175s ago] ('ZH_9',)
# 2025-07-10 10:18:04,734 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:04,734 INFO sqlalchemy.engine.Engine [cached since 0.1767s ago] ('ZH_9_G6', 'Les particules modales placées en fin de phrase', 'Quelques particules modales sont habituellement rajoutées en fin de phrase pour donner un ton particulier à la phrase, en voici quelques exemples :\n ... (334 characters truncated) ... .\n\nIl existe également des interjections placées en début de phrase :\n\n* 嗯 en : équivalent du « hum... » français\n* 哎呀 āiyā : marque la surprise', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:04,734 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Add Characters

# %%
engine, session = init_db()

directory_path = f'../data/{language_id}/character'

if not os.path.exists(directory_path):
    raise FileNotFoundError(f"No character files found for {language_id}.")

characters = []

# List all elements (files and directories) in the specified directory and get their full paths
elements_paths = [os.path.join(directory_path, element) for element in os.listdir(directory_path)]
for character_file in elements_paths:
    if os.path.isfile(character_file) and character_file.endswith('.csv'):
        unit_id = re.sub("[^0-9]", "", os.path.basename(character_file))
        print(f"Processing: {unit_id}")
        df = pd.read_csv(character_file)
        for idx, row in enumerate(df.itertuples(index=False)):
            characters.append(
                CalligraphyCharacter(
                    id=f"{language_id.upper()}_{unit_id}_C{idx + 1}",
                    character=row.character,
                    components=row.components,
                    phonetic=row.phonetic,
                    meaning=row.meaning,
                    example_word=row.example_word,
                    parent=session.query(Unit).filter(Unit.id == f"{language_id.upper()}_{unit_id}").first()
                )
            )
inserts(session, characters)
session.close()
# Out:
# 2025-07-10 10:18:04,741 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,743 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("language")
# 2025-07-10 10:18:04,743 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-10 10:18:04,744 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-10 10:18:04,745 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-10 10:18:04,746 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-10 10:18:04,746 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-10 10:18:04,747 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-10 10:18:04,748 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-10 10:18:04,749 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-10 10:18:04,750 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-10 10:18:04,751 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-10 10:18:04,754 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-10 10:18:04,756 INFO sqlalchemy.engine.Engine COMMIT
# Processing: 2
# 2025-07-10 10:18:04,761 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:04,762 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,763 INFO sqlalchemy.engine.Engine [generated in 0.00155s] ('ZH_2', 1, 0)
# 2025-07-10 10:18:04,767 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,767 INFO sqlalchemy.engine.Engine [cached since 0.005357s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:04,768 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,768 INFO sqlalchemy.engine.Engine [cached since 0.006145s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:04,769 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,769 INFO sqlalchemy.engine.Engine [cached since 0.00686s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:04,769 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,769 INFO sqlalchemy.engine.Engine [cached since 0.00749s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:04,770 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,770 INFO sqlalchemy.engine.Engine [cached since 0.008183s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:04,771 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,771 INFO sqlalchemy.engine.Engine [cached since 0.008944s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:04,771 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,772 INFO sqlalchemy.engine.Engine [cached since 0.009706s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:04,772 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,772 INFO sqlalchemy.engine.Engine [cached since 0.01034s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:04,773 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,773 INFO sqlalchemy.engine.Engine [cached since 0.01092s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:04,773 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,773 INFO sqlalchemy.engine.Engine [cached since 0.0116s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:04,774 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,774 INFO sqlalchemy.engine.Engine [cached since 0.01224s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:04,775 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,775 INFO sqlalchemy.engine.Engine [cached since 0.01285s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:04,775 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,775 INFO sqlalchemy.engine.Engine [cached since 0.0135s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:04,776 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,776 INFO sqlalchemy.engine.Engine [cached since 0.01408s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:04,776 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,777 INFO sqlalchemy.engine.Engine [cached since 0.01473s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:04,777 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,777 INFO sqlalchemy.engine.Engine [cached since 0.0153s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:04,778 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,778 INFO sqlalchemy.engine.Engine [cached since 0.0159s ago] ('ZH_2', 1, 0)
# 2025-07-10 10:18:04,778 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,778 INFO sqlalchemy.engine.Engine [cached since 0.01651s ago] ('ZH_2', 1, 0)
# Processing: 3
# 2025-07-10 10:18:04,780 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,780 INFO sqlalchemy.engine.Engine [cached since 0.01828s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:04,781 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,781 INFO sqlalchemy.engine.Engine [cached since 0.01882s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:04,782 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,782 INFO sqlalchemy.engine.Engine [cached since 0.02059s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:04,783 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,783 INFO sqlalchemy.engine.Engine [cached since 0.02141s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:04,784 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,784 INFO sqlalchemy.engine.Engine [cached since 0.02199s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:04,784 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,784 INFO sqlalchemy.engine.Engine [cached since 0.02253s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:04,785 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,785 INFO sqlalchemy.engine.Engine [cached since 0.02304s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:04,785 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,785 INFO sqlalchemy.engine.Engine [cached since 0.02361s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:04,786 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,786 INFO sqlalchemy.engine.Engine [cached since 0.02446s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:04,787 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,787 INFO sqlalchemy.engine.Engine [cached since 0.02506s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:04,787 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,787 INFO sqlalchemy.engine.Engine [cached since 0.02563s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:04,788 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,788 INFO sqlalchemy.engine.Engine [cached since 0.02617s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:04,788 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,789 INFO sqlalchemy.engine.Engine [cached since 0.0267s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:04,789 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,789 INFO sqlalchemy.engine.Engine [cached since 0.02723s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:04,790 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,790 INFO sqlalchemy.engine.Engine [cached since 0.02797s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:04,790 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,790 INFO sqlalchemy.engine.Engine [cached since 0.02852s ago] ('ZH_3', 1, 0)
# 2025-07-10 10:18:04,791 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,791 INFO sqlalchemy.engine.Engine [cached since 0.02909s ago] ('ZH_3', 1, 0)
# Processing: 1
# 2025-07-10 10:18:04,793 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,793 INFO sqlalchemy.engine.Engine [cached since 0.03121s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:04,794 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,794 INFO sqlalchemy.engine.Engine [cached since 0.03185s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:04,794 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,794 INFO sqlalchemy.engine.Engine [cached since 0.03242s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:04,795 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,795 INFO sqlalchemy.engine.Engine [cached since 0.033s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:04,795 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,795 INFO sqlalchemy.engine.Engine [cached since 0.03355s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:04,796 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,796 INFO sqlalchemy.engine.Engine [cached since 0.03409s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:04,796 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,797 INFO sqlalchemy.engine.Engine [cached since 0.03472s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:04,797 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,797 INFO sqlalchemy.engine.Engine [cached since 0.0353s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:04,798 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,798 INFO sqlalchemy.engine.Engine [cached since 0.03597s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:04,799 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,799 INFO sqlalchemy.engine.Engine [cached since 0.03687s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:04,799 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,800 INFO sqlalchemy.engine.Engine [cached since 0.03784s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:04,800 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,800 INFO sqlalchemy.engine.Engine [cached since 0.03847s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:04,801 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,801 INFO sqlalchemy.engine.Engine [cached since 0.03907s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:04,801 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,802 INFO sqlalchemy.engine.Engine [cached since 0.03975s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:04,802 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,802 INFO sqlalchemy.engine.Engine [cached since 0.04042s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:04,803 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,803 INFO sqlalchemy.engine.Engine [cached since 0.04114s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:04,803 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,804 INFO sqlalchemy.engine.Engine [cached since 0.04177s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:04,804 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,804 INFO sqlalchemy.engine.Engine [cached since 0.04239s ago] ('ZH_1', 1, 0)
# 2025-07-10 10:18:04,805 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,805 INFO sqlalchemy.engine.Engine [cached since 0.04296s ago] ('ZH_1', 1, 0)
# Processing: 4
# 2025-07-10 10:18:04,806 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,807 INFO sqlalchemy.engine.Engine [cached since 0.04467s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:04,807 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,807 INFO sqlalchemy.engine.Engine [cached since 0.04527s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:04,808 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,808 INFO sqlalchemy.engine.Engine [cached since 0.04582s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:04,808 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,808 INFO sqlalchemy.engine.Engine [cached since 0.0464s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:04,809 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,809 INFO sqlalchemy.engine.Engine [cached since 0.04703s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:04,809 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,809 INFO sqlalchemy.engine.Engine [cached since 0.04753s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:04,810 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,810 INFO sqlalchemy.engine.Engine [cached since 0.04831s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:04,811 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,811 INFO sqlalchemy.engine.Engine [cached since 0.04888s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:04,811 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,811 INFO sqlalchemy.engine.Engine [cached since 0.04936s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:04,812 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,812 INFO sqlalchemy.engine.Engine [cached since 0.04989s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:04,812 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,812 INFO sqlalchemy.engine.Engine [cached since 0.05052s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:04,813 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,813 INFO sqlalchemy.engine.Engine [cached since 0.05112s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:04,813 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,814 INFO sqlalchemy.engine.Engine [cached since 0.05166s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:04,814 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,814 INFO sqlalchemy.engine.Engine [cached since 0.05217s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:04,814 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,815 INFO sqlalchemy.engine.Engine [cached since 0.05271s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:04,815 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,815 INFO sqlalchemy.engine.Engine [cached since 0.05344s ago] ('ZH_4', 1, 0)
# 2025-07-10 10:18:04,816 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,816 INFO sqlalchemy.engine.Engine [cached since 0.05415s ago] ('ZH_4', 1, 0)
# Processing: 5
# 2025-07-10 10:18:04,818 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,818 INFO sqlalchemy.engine.Engine [cached since 0.05578s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:04,818 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,818 INFO sqlalchemy.engine.Engine [cached since 0.05635s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:04,819 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,819 INFO sqlalchemy.engine.Engine [cached since 0.05691s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:04,819 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,819 INFO sqlalchemy.engine.Engine [cached since 0.05747s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:04,820 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,820 INFO sqlalchemy.engine.Engine [cached since 0.05798s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:04,820 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,820 INFO sqlalchemy.engine.Engine [cached since 0.05853s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:04,821 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,821 INFO sqlalchemy.engine.Engine [cached since 0.05903s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:04,821 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,821 INFO sqlalchemy.engine.Engine [cached since 0.05955s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:04,822 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,822 INFO sqlalchemy.engine.Engine [cached since 0.06008s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:04,822 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,823 INFO sqlalchemy.engine.Engine [cached since 0.06065s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:04,823 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,823 INFO sqlalchemy.engine.Engine [cached since 0.06123s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:04,823 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,824 INFO sqlalchemy.engine.Engine [cached since 0.06174s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:04,824 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,824 INFO sqlalchemy.engine.Engine [cached since 0.06225s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:04,824 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,825 INFO sqlalchemy.engine.Engine [cached since 0.06278s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:04,825 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,825 INFO sqlalchemy.engine.Engine [cached since 0.06331s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:04,826 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,826 INFO sqlalchemy.engine.Engine [cached since 0.06383s ago] ('ZH_5', 1, 0)
# 2025-07-10 10:18:04,826 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,826 INFO sqlalchemy.engine.Engine [cached since 0.06436s ago] ('ZH_5', 1, 0)
# Processing: 7
# 2025-07-10 10:18:04,828 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,828 INFO sqlalchemy.engine.Engine [cached since 0.06616s ago] ('ZH_7', 1, 0)
# 2025-07-10 10:18:04,828 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,829 INFO sqlalchemy.engine.Engine [cached since 0.06668s ago] ('ZH_7', 1, 0)
# 2025-07-10 10:18:04,829 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,829 INFO sqlalchemy.engine.Engine [cached since 0.06735s ago] ('ZH_7', 1, 0)
# 2025-07-10 10:18:04,830 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,830 INFO sqlalchemy.engine.Engine [cached since 0.0679s ago] ('ZH_7', 1, 0)
# 2025-07-10 10:18:04,830 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,830 INFO sqlalchemy.engine.Engine [cached since 0.06842s ago] ('ZH_7', 1, 0)
# 2025-07-10 10:18:04,831 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,831 INFO sqlalchemy.engine.Engine [cached since 0.06893s ago] ('ZH_7', 1, 0)
# 2025-07-10 10:18:04,831 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,831 INFO sqlalchemy.engine.Engine [cached since 0.06943s ago] ('ZH_7', 1, 0)
# 2025-07-10 10:18:04,832 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,832 INFO sqlalchemy.engine.Engine [cached since 0.06992s ago] ('ZH_7', 1, 0)
# 2025-07-10 10:18:04,834 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,834 INFO sqlalchemy.engine.Engine [cached since 0.07191s ago] ('ZH_7', 1, 0)
# 2025-07-10 10:18:04,834 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,834 INFO sqlalchemy.engine.Engine [cached since 0.07261s ago] ('ZH_7', 1, 0)
# 2025-07-10 10:18:04,835 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,835 INFO sqlalchemy.engine.Engine [cached since 0.07316s ago] ('ZH_7', 1, 0)
# 2025-07-10 10:18:04,835 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,836 INFO sqlalchemy.engine.Engine [cached since 0.07372s ago] ('ZH_7', 1, 0)
# 2025-07-10 10:18:04,836 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,836 INFO sqlalchemy.engine.Engine [cached since 0.07424s ago] ('ZH_7', 1, 0)
# 2025-07-10 10:18:04,837 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,837 INFO sqlalchemy.engine.Engine [cached since 0.07483s ago] ('ZH_7', 1, 0)
# 2025-07-10 10:18:04,837 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,837 INFO sqlalchemy.engine.Engine [cached since 0.07537s ago] ('ZH_7', 1, 0)
# 2025-07-10 10:18:04,838 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,838 INFO sqlalchemy.engine.Engine [cached since 0.07593s ago] ('ZH_7', 1, 0)
# 2025-07-10 10:18:04,838 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,838 INFO sqlalchemy.engine.Engine [cached since 0.07646s ago] ('ZH_7', 1, 0)
# 2025-07-10 10:18:04,839 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,839 INFO sqlalchemy.engine.Engine [cached since 0.07702s ago] ('ZH_7', 1, 0)
# Processing: 6
# 2025-07-10 10:18:04,840 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,841 INFO sqlalchemy.engine.Engine [cached since 0.07867s ago] ('ZH_6', 1, 0)
# 2025-07-10 10:18:04,841 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,841 INFO sqlalchemy.engine.Engine [cached since 0.07924s ago] ('ZH_6', 1, 0)
# 2025-07-10 10:18:04,841 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,842 INFO sqlalchemy.engine.Engine [cached since 0.07977s ago] ('ZH_6', 1, 0)
# 2025-07-10 10:18:04,842 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,842 INFO sqlalchemy.engine.Engine [cached since 0.0803s ago] ('ZH_6', 1, 0)
# 2025-07-10 10:18:04,843 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,843 INFO sqlalchemy.engine.Engine [cached since 0.08099s ago] ('ZH_6', 1, 0)
# 2025-07-10 10:18:04,843 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-10 10:18:04,843 INFO sqlalchemy.engine.Engine [cached since 0.08153s ago] ('ZH_6', 1, 0)
# ...
# 2025-07-10 10:18:05,649 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:05,650 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:05,650 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:05,650 INFO sqlalchemy.engine.Engine [cached since 0.6552s ago] ('ZH_8',)
# 2025-07-10 10:18:05,651 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:05,651 INFO sqlalchemy.engine.Engine [cached since 0.6578s ago] ('ZH_8_C16', '做', '亻 (clef : homme) + 故', 'zuò', 'Faire', '你做什么 ? Nǐ zuò shénme ? Que fais-tu ?', 0, '2025-07-10', 'ZH_8')
# 2025-07-10 10:18:05,651 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:05,652 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:05,652 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:05,652 INFO sqlalchemy.engine.Engine [cached since 0.6574s ago] ('ZH_9',)
# 2025-07-10 10:18:05,652 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:05,653 INFO sqlalchemy.engine.Engine [cached since 0.6594s ago] ('ZH_9_C1', '班', '王 (clef : jade) + 6 traits', 'bān', 'Groupe', '上班 shàngbān : Aller au travail', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:05,653 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:05,653 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:05,654 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:05,654 INFO sqlalchemy.engine.Engine [cached since 0.659s ago] ('ZH_9',)
# 2025-07-10 10:18:05,654 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:05,654 INFO sqlalchemy.engine.Engine [cached since 0.6611s ago] ('ZH_9_C2', '车', 'Pictogramme', 'chē', 'Véhicule', '火车 huǒchē : Train', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:05,655 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:05,655 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:05,655 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:05,655 INFO sqlalchemy.engine.Engine [cached since 0.6606s ago] ('ZH_9',)
# 2025-07-10 10:18:05,656 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:05,656 INFO sqlalchemy.engine.Engine [cached since 0.6627s ago] ('ZH_9_C3', '公', '八 (clef : huit) + 2 traits', 'gōng', 'Public', '公交车 gōngjiāochē : Bus', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:05,656 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:05,657 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:05,657 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:05,657 INFO sqlalchemy.engine.Engine [cached since 0.6623s ago] ('ZH_9',)
# 2025-07-10 10:18:05,657 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:05,658 INFO sqlalchemy.engine.Engine [cached since 0.6644s ago] ('ZH_9_C4', '后', '厂 + 口 (clef : bouche)', 'hòu', 'Après/ensuite', '以后 yǐhòu : Après', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:05,658 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:05,658 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:05,659 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:05,659 INFO sqlalchemy.engine.Engine [cached since 0.6639s ago] ('ZH_9',)
# 2025-07-10 10:18:05,659 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:05,659 INFO sqlalchemy.engine.Engine [cached since 0.6659s ago] ('ZH_9_C5', '火', 'Pictogramme', 'huǒ', 'Feu', '火车 huǒchē : Train', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:05,659 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:05,660 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:05,660 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:05,660 INFO sqlalchemy.engine.Engine [cached since 0.6654s ago] ('ZH_9',)
# 2025-07-10 10:18:05,660 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:05,661 INFO sqlalchemy.engine.Engine [cached since 0.6674s ago] ('ZH_9_C6', '交', '亠 (clef : tête) + 4 traits', 'jiāo', 'Échange', '公交车 gōngjiāochē : Bus', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:05,661 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:05,661 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:05,662 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:05,662 INFO sqlalchemy.engine.Engine [cached since 0.6669s ago] ('ZH_9',)
# 2025-07-10 10:18:05,662 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:05,662 INFO sqlalchemy.engine.Engine [cached since 0.6689s ago] ('ZH_9_C7', '开', '廾 (clef : mains) + 1 trait', 'kāi', 'Ouvrir', '开车 kāichē : Conduire', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:05,662 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:05,663 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:05,663 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:05,663 INFO sqlalchemy.engine.Engine [cached since 0.6684s ago] ('ZH_9',)
# 2025-07-10 10:18:05,663 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:05,664 INFO sqlalchemy.engine.Engine [cached since 0.6704s ago] ('ZH_9_C8', '每', '母 (clef : mère) + 2 traits', 'měi', 'Chaque', '每天 měitiān : Tous les jours', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:05,664 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:05,664 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:05,665 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:05,665 INFO sqlalchemy.engine.Engine [cached since 0.6701s ago] ('ZH_9',)
# 2025-07-10 10:18:05,665 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:05,665 INFO sqlalchemy.engine.Engine [cached since 0.6721s ago] ('ZH_9_C9', '然', '月 + 犬 + 灬 (clef : feu)', 'rán', 'Cependant', '然后 ránhòu : Ensuite', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:05,666 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:05,666 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:05,667 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:05,667 INFO sqlalchemy.engine.Engine [cached since 0.6722s ago] ('ZH_9',)
# 2025-07-10 10:18:05,669 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:05,670 INFO sqlalchemy.engine.Engine [cached since 0.6768s ago] ('ZH_9_C10', '始', '女 (clef : femme) + 台', 'shǐ', 'Débuter', '开始 kāishǐ : Commencer', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:05,671 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:05,672 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:05,673 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:05,673 INFO sqlalchemy.engine.Engine [cached since 0.6783s ago] ('ZH_9',)
# 2025-07-10 10:18:05,674 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:05,674 INFO sqlalchemy.engine.Engine [cached since 0.6809s ago] ('ZH_9_C11', '同', '口 (clef : bouche) + 门', 'tóng', 'Identique', "同意 tóngyì : Être d'accord", 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:05,675 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:05,676 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:05,677 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:05,677 INFO sqlalchemy.engine.Engine [cached since 0.6825s ago] ('ZH_9',)
# 2025-07-10 10:18:05,678 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:05,678 INFO sqlalchemy.engine.Engine [cached since 0.6851s ago] ('ZH_9_C12', '先', '儿 (clef : fils) + 4 traits', 'xiān', 'Premièrement', "你先吃饭吧 nǐ xiān chīfàn ba : Mange d'abord !", 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:05,679 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:05,680 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:05,681 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:05,682 INFO sqlalchemy.engine.Engine [cached since 0.6868s ago] ('ZH_9',)
# 2025-07-10 10:18:05,682 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:05,683 INFO sqlalchemy.engine.Engine [cached since 0.6896s ago] ('ZH_9_C13', '意', '心 (clef : cœur) + 音', 'yì', 'Signification', "同意 tóngyì : Être d'accord", 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:05,684 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:05,685 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:05,685 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:05,686 INFO sqlalchemy.engine.Engine [cached since 0.6911s ago] ('ZH_9',)
# 2025-07-10 10:18:05,687 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:05,687 INFO sqlalchemy.engine.Engine [cached since 0.694s ago] ('ZH_9_C14', '园', '囗 (clef : enceinte) + 元', 'yuán', 'Jardin', '公园 gōngyuán : Parc public', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:05,688 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:05,689 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:05,689 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:05,690 INFO sqlalchemy.engine.Engine [cached since 0.6951s ago] ('ZH_9',)
# 2025-07-10 10:18:05,691 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:05,691 INFO sqlalchemy.engine.Engine [cached since 0.6982s ago] ('ZH_9_C15', '自', '自 (clef : personnel)', 'zì', 'Soi-même', '自行车 zìxíngchē : Vélo', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:05,692 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-10 10:18:05,696 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-10 10:18:05,697 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-10 10:18:05,697 INFO sqlalchemy.engine.Engine [cached since 0.7026s ago] ('ZH_9',)
# 2025-07-10 10:18:05,698 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-10 10:18:05,699 INFO sqlalchemy.engine.Engine [cached since 0.7054s ago] ('ZH_9_C16', '坐', '土 (clef : sol) + 从', 'zuò', "S'asseoir", '坐车 zuò chē : Prendre un véhicule', 0, '2025-07-10', 'ZH_9')
# 2025-07-10 10:18:05,699 INFO sqlalchemy.engine.Engine COMMIT
