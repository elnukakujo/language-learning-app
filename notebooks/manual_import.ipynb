# %%
import json
import pandas as pd
import os
import re
from lapp.dbms import init_db, inserts, modify, delete, find_by_attr, insert
from lapp.tables import Unit, Vocabulary, GrammarRule, Language

# %%
language_id = "zh"

# %% [markdown]
# ## Create a Language

# %%
engine, session = init_db()

if not os.path.exists("../db"):
    os.makedirs("../db")
    print(f"Created directory for database: ../db")

language = Language(
    id=language_id.upper(),
    name="Chinois",
    native_name="中文",
    level="A1",
    flag="🇨🇳"
)
insert(session, language)

session.close()
# Out:
# 2025-07-07 18:21:51,582 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:51,582 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("language")
# 2025-07-07 18:21:51,582 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:51,582 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("language")
# 2025-07-07 18:21:51,582 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:51,583 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-07 18:21:51,583 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:51,583 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("unit")
# 2025-07-07 18:21:51,583 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:51,583 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-07 18:21:51,583 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:51,584 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("calligraphy_character")
# 2025-07-07 18:21:51,584 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:51,584 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-07 18:21:51,584 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:51,584 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("grammar_rule")
# 2025-07-07 18:21:51,584 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:51,584 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-07 18:21:51,584 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:51,585 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("vocabulary")
# 2025-07-07 18:21:51,585 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:51,585 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-07 18:21:51,585 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:51,585 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("exercises")
# 2025-07-07 18:21:51,585 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:51,586 INFO sqlalchemy.engine.Engine
# CREATE TABLE language (
# 	id VARCHAR NOT NULL,
# 	name VARCHAR,
# 	native_name VARCHAR,
# 	level VARCHAR,
# 	description VARCHAR,
# 	score INTEGER,
# 	last_seen DATE,
# 	flag VARCHAR,
# 	current_unit VARCHAR,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(current_unit) REFERENCES unit (id)
# )
#
#
# 2025-07-07 18:21:51,586 INFO sqlalchemy.engine.Engine [no key 0.00013s] ()
# 2025-07-07 18:21:51,586 INFO sqlalchemy.engine.Engine CREATE INDEX ix_language_name ON language (name)
# 2025-07-07 18:21:51,587 INFO sqlalchemy.engine.Engine [no key 0.00010s] ()
# 2025-07-07 18:21:51,587 INFO sqlalchemy.engine.Engine CREATE INDEX ix_language_id ON language (id)
# 2025-07-07 18:21:51,587 INFO sqlalchemy.engine.Engine [no key 0.00012s] ()
# 2025-07-07 18:21:51,588 INFO sqlalchemy.engine.Engine
# CREATE TABLE unit (
# 	id VARCHAR NOT NULL,
# 	title VARCHAR,
# 	description VARCHAR,
# 	level VARCHAR,
# 	score INTEGER,
# 	language_id VARCHAR NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(language_id) REFERENCES language (id)
# )
#
#
# 2025-07-07 18:21:51,588 INFO sqlalchemy.engine.Engine [no key 0.00012s] ()
# 2025-07-07 18:21:51,588 INFO sqlalchemy.engine.Engine CREATE INDEX ix_unit_title ON unit (title)
# 2025-07-07 18:21:51,588 INFO sqlalchemy.engine.Engine [no key 0.00010s] ()
# 2025-07-07 18:21:51,589 INFO sqlalchemy.engine.Engine CREATE INDEX ix_unit_id ON unit (id)
# 2025-07-07 18:21:51,589 INFO sqlalchemy.engine.Engine [no key 0.00012s] ()
# 2025-07-07 18:21:51,589 INFO sqlalchemy.engine.Engine
# CREATE TABLE calligraphy_character (
# 	id VARCHAR NOT NULL,
# 	character VARCHAR,
# 	translation VARCHAR,
# 	components VARCHAR,
# 	score INTEGER,
# 	last_seen DATE,
# 	unit_id VARCHAR NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(unit_id) REFERENCES unit (id)
# )
#
#
# 2025-07-07 18:21:51,590 INFO sqlalchemy.engine.Engine [no key 0.00012s] ()
# 2025-07-07 18:21:51,590 INFO sqlalchemy.engine.Engine CREATE INDEX ix_calligraphy_character_id ON calligraphy_character (id)
# 2025-07-07 18:21:51,590 INFO sqlalchemy.engine.Engine [no key 0.00009s] ()
# 2025-07-07 18:21:51,590 INFO sqlalchemy.engine.Engine CREATE INDEX ix_calligraphy_character_character ON calligraphy_character (character)
# 2025-07-07 18:21:51,591 INFO sqlalchemy.engine.Engine [no key 0.00011s] ()
# 2025-07-07 18:21:51,591 INFO sqlalchemy.engine.Engine
# CREATE TABLE grammar_rule (
# 	id VARCHAR NOT NULL,
# 	title VARCHAR,
# 	explanation VARCHAR,
# 	score INTEGER,
# 	last_seen DATE,
# 	unit_id VARCHAR NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(unit_id) REFERENCES unit (id)
# )
#
#
# 2025-07-07 18:21:51,591 INFO sqlalchemy.engine.Engine [no key 0.00016s] ()
# 2025-07-07 18:21:51,592 INFO sqlalchemy.engine.Engine CREATE INDEX ix_grammar_rule_title ON grammar_rule (title)
# 2025-07-07 18:21:51,592 INFO sqlalchemy.engine.Engine [no key 0.00009s] ()
# 2025-07-07 18:21:51,592 INFO sqlalchemy.engine.Engine CREATE INDEX ix_grammar_rule_id ON grammar_rule (id)
# 2025-07-07 18:21:51,592 INFO sqlalchemy.engine.Engine [no key 0.00016s] ()
# 2025-07-07 18:21:51,593 INFO sqlalchemy.engine.Engine
# CREATE TABLE vocabulary (
# 	id VARCHAR NOT NULL,
# 	word VARCHAR,
# 	translation VARCHAR,
# 	phonetic VARCHAR,
# 	example_sentence VARCHAR,
# 	type VARCHAR,
# 	score INTEGER,
# 	last_seen DATE,
# 	unit_id VARCHAR NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(unit_id) REFERENCES unit (id)
# )
#
#
# 2025-07-07 18:21:51,593 INFO sqlalchemy.engine.Engine [no key 0.00011s] ()
# 2025-07-07 18:21:51,593 INFO sqlalchemy.engine.Engine CREATE INDEX ix_vocabulary_id ON vocabulary (id)
# 2025-07-07 18:21:51,593 INFO sqlalchemy.engine.Engine [no key 0.00011s] ()
# 2025-07-07 18:21:51,594 INFO sqlalchemy.engine.Engine CREATE INDEX ix_vocabulary_word ON vocabulary (word)
# 2025-07-07 18:21:51,594 INFO sqlalchemy.engine.Engine [no key 0.00010s] ()
# 2025-07-07 18:21:51,594 INFO sqlalchemy.engine.Engine
# CREATE TABLE exercises (
# 	id VARCHAR NOT NULL,
# 	exercise_type VARCHAR,
# 	question VARCHAR,
# 	support VARCHAR,
# 	answer VARCHAR,
# 	score INTEGER,
# 	last_seen DATE,
# 	unit_id VARCHAR NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(unit_id) REFERENCES unit (id)
# )
#
#
# 2025-07-07 18:21:51,594 INFO sqlalchemy.engine.Engine [no key 0.00016s] ()
# 2025-07-07 18:21:51,595 INFO sqlalchemy.engine.Engine CREATE INDEX ix_exercises_exercise_type ON exercises (exercise_type)
# 2025-07-07 18:21:51,595 INFO sqlalchemy.engine.Engine [no key 0.00012s] ()
# 2025-07-07 18:21:51,596 INFO sqlalchemy.engine.Engine CREATE INDEX ix_exercises_question ON exercises (question)
# 2025-07-07 18:21:51,596 INFO sqlalchemy.engine.Engine [no key 0.00008s] ()
# 2025-07-07 18:21:51,596 INFO sqlalchemy.engine.Engine CREATE INDEX ix_exercises_id ON exercises (id)
# 2025-07-07 18:21:51,596 INFO sqlalchemy.engine.Engine [no key 0.00011s] ()
# 2025-07-07 18:21:51,597 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:51,601 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:51,602 INFO sqlalchemy.engine.Engine INSERT INTO language (id, name, native_name, level, description, score, last_seen, flag, current_unit) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:51,602 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('ZH', 'Chinois', '中文', 'A1', '', 0, '2025-07-07', '🇨🇳', None)
# 2025-07-07 18:21:51,603 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Add Units

# %%
# Initialize the database connection and create db file if it doesn't exist
engine, session = init_db()

# Initialize the database
with open(f'../data/{language_id}/units.json', 'r', encoding="utf8") as f:
    units_array = json.load(f)
    
units = []
for idx, unit_data in enumerate(units_array):
    units.append(
        Unit(
            id = f"{language_id.upper()}_{idx}",
            title = unit_data['title'],
            description = unit_data['description'],
            level = unit_data['level'],
            parent = language,
        )
    )
inserts(session, units)
session.close()
# Out:
# 2025-07-07 18:21:51,607 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:51,607 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("language")
# 2025-07-07 18:21:51,608 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:51,609 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-07 18:21:51,609 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:51,609 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-07 18:21:51,609 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:51,610 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-07 18:21:51,610 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:51,610 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-07 18:21:51,610 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:51,610 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-07 18:21:51,610 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:51,611 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:51,613 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:51,614 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-07 18:21:51,614 INFO sqlalchemy.engine.Engine [generated in 0.00019s] ('ZH',)
# 2025-07-07 18:21:51,615 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:51,615 INFO sqlalchemy.engine.Engine [generated in 0.00014s] ('ZH_0', 'Lecon introductive: Bonjour!', "A l'oral: Connaitre les salutations de base. \n\nA l'ecrit: 5 caracteres", 'A1', 0, 'ZH')
# 2025-07-07 18:21:51,616 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:51,616 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:51,617 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-07 18:21:51,617 INFO sqlalchemy.engine.Engine [generated in 0.00014s] ('ZH',)
# 2025-07-07 18:21:51,617 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:51,617 INFO sqlalchemy.engine.Engine [cached since 0.002077s ago] ('ZH_1', "Unite 1: Comment t'appelles-tu?", "A l'oral: Savoir se presenter et presenter quelqu'un. \n\nParler de sa nationalite. \n\nA l'ecrit: 19 caracteres", 'A1', 0, 'ZH')
# 2025-07-07 18:21:51,617 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:51,618 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:51,618 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-07 18:21:51,619 INFO sqlalchemy.engine.Engine [cached since 0.002094s ago] ('ZH',)
# 2025-07-07 18:21:51,619 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:51,619 INFO sqlalchemy.engine.Engine [cached since 0.004358s ago] ('ZH_2', 'Unite 2: Un, deux, trois', "A l'oral: Compter de 1 a 9999. \n\nSavoir enumerer des objets. \n\nA l'ecrit: 19 caracteres", 'A1', 0, 'ZH')
# 2025-07-07 18:21:51,620 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:51,620 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:51,621 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-07 18:21:51,621 INFO sqlalchemy.engine.Engine [cached since 0.004478s ago] ('ZH',)
# 2025-07-07 18:21:51,621 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:51,621 INFO sqlalchemy.engine.Engine [cached since 0.006404s ago] ('ZH_3', "Unite 3: Aujourd'hui", "A l'oral: Savoir annoncer la date. \n\nParler des moments de la journee et de l'heure. \n\nA l'ecrit: 17 caracteres", 'A1', 0, 'ZH')
# 2025-07-07 18:21:51,622 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:51,622 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:51,622 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-07 18:21:51,622 INFO sqlalchemy.engine.Engine [cached since 0.005985s ago] ('ZH',)
# 2025-07-07 18:21:51,623 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:51,623 INFO sqlalchemy.engine.Engine [cached since 0.007902s ago] ('ZH_4', 'Unite 4: Ou allons-nous?', "A l'oral: Parler d'un evenement passe, d'une experience. \n\nPouvoir se situer, parler ou l'on est, ou l'on va. \n\nA l'ecrit: 17 caracteres", 'A1', 0, 'ZH')
# 2025-07-07 18:21:51,623 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:51,624 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:51,624 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-07 18:21:51,624 INFO sqlalchemy.engine.Engine [cached since 0.007621s ago] ('ZH',)
# 2025-07-07 18:21:51,624 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:51,624 INFO sqlalchemy.engine.Engine [cached since 0.009535s ago] ('ZH_5', 'Unite 5: Je ne suis pas vieux', "A l'oral: Decrire quelqu'un ou quelque chose. \n\nUtilise les adjectifs. \n\nA l'ecrit: 17 caracteres", 'A1', 0, 'ZH')
# 2025-07-07 18:21:51,625 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:51,625 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:51,626 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-07 18:21:51,626 INFO sqlalchemy.engine.Engine [cached since 0.009168s ago] ('ZH',)
# 2025-07-07 18:21:51,626 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:51,626 INFO sqlalchemy.engine.Engine [cached since 0.01107s ago] ('ZH_6', 'Unite 6: Ma famille', "A l'oral: Pouvoir presenter sa famille. \n\nUtilise les demonstratifs. \n\nA l'ecrit: 22 caracteres", 'A1', 0, 'ZH')
# 2025-07-07 18:21:51,626 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:51,627 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:51,627 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-07 18:21:51,627 INFO sqlalchemy.engine.Engine [cached since 0.01082s ago] ('ZH',)
# 2025-07-07 18:21:51,628 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:51,628 INFO sqlalchemy.engine.Engine [cached since 0.0133s ago] ('ZH_7', 'Unite 7: Mes amis', "A l'oral: Parler des ses amis. \n\nParler des langues etrangeres. \n\nComparer des gens ou des objets. \n\nA l'ecrit: 18 caracteres", 'A1', 0, 'ZH')
# 2025-07-07 18:21:51,629 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:51,630 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:51,630 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-07 18:21:51,630 INFO sqlalchemy.engine.Engine [cached since 0.01383s ago] ('ZH',)
# 2025-07-07 18:21:51,631 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:51,631 INFO sqlalchemy.engine.Engine [cached since 0.01581s ago] ('ZH_8', "Unite 8: Qu'aimes-tu faire?", "A l'oral: Parler de ses activites favorites. \n\nInterroger sur la maniere. \n\nA l'ecrit: 16 caracteres", 'A2', 0, 'ZH')
# 2025-07-07 18:21:51,631 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:51,632 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:51,632 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-07 18:21:51,632 INFO sqlalchemy.engine.Engine [cached since 0.01555s ago] ('ZH',)
# 2025-07-07 18:21:51,632 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:51,632 INFO sqlalchemy.engine.Engine [cached since 0.0175s ago] ('ZH_9', 'Unite 9: Une journee classique', "A l'oral: Raconter sa journee. \n\nParler des differents moyens de transport. \n\nA l'ecrit: 16 caracteres", 'A2', 0, 'ZH')
# 2025-07-07 18:21:51,633 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:51,633 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:51,634 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-07 18:21:51,634 INFO sqlalchemy.engine.Engine [cached since 0.01712s ago] ('ZH',)
# 2025-07-07 18:21:51,634 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:51,634 INFO sqlalchemy.engine.Engine [cached since 0.019s ago] ('ZH_10', 'Unite 10: Au travail', "A l'oral: Parler du monde du travail. \n\nA l'ecrit: 18 caracteres", 'A2', 0, 'ZH')
# 2025-07-07 18:21:51,634 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:51,635 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:51,635 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-07 18:21:51,635 INFO sqlalchemy.engine.Engine [cached since 0.01864s ago] ('ZH',)
# 2025-07-07 18:21:51,635 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:51,635 INFO sqlalchemy.engine.Engine [cached since 0.02053s ago] ('ZH_11', 'Unite 11: Dans une grande ville', "A l'oral: Pouvoir demander son chemin. \n\nSe reperer en ville. \n\nA l'ecrit: 18 caracteres", 'A2', 0, 'ZH')
# 2025-07-07 18:21:51,636 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:51,636 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:51,636 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-07 18:21:51,636 INFO sqlalchemy.engine.Engine [cached since 0.01997s ago] ('ZH',)
# 2025-07-07 18:21:51,637 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:51,637 INFO sqlalchemy.engine.Engine [cached since 0.02191s ago] ('ZH_12', 'Unite 12: Faire des achats', "A l'oral: Negocier un prix. \n\nFaire des achats. \n\nA l'ecrit: 18 caracteres", 'A2', 0, 'ZH')
# 2025-07-07 18:21:51,637 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:51,638 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:51,638 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-07 18:21:51,638 INFO sqlalchemy.engine.Engine [cached since 0.0219s ago] ('ZH',)
# 2025-07-07 18:21:51,639 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:51,639 INFO sqlalchemy.engine.Engine [cached since 0.0239s ago] ('ZH_13', "Unite 13: En voyage a l'etranger", "A l'oral: Pouvoir raconter ou prevoir un voyage. \n\nUtiliser 'Avant, apres, pendant'. \n\nA l'ecrit: 17 caracteres", 'A2', 0, 'ZH')
# 2025-07-07 18:21:51,639 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:51,640 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:51,640 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-07 18:21:51,640 INFO sqlalchemy.engine.Engine [cached since 0.02361s ago] ('ZH',)
# 2025-07-07 18:21:51,640 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:51,640 INFO sqlalchemy.engine.Engine [cached since 0.02548s ago] ('ZH_14', 'Unite 14: La culture chinoise', "A l'oral: Decouvrir la culture chinoise. \n\nParler des fetes et des vacances. \n\nA l'ecrit: 19 caracteres", 'A2', 0, 'ZH')
# 2025-07-07 18:21:51,641 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:51,641 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:51,641 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-07 18:21:51,641 INFO sqlalchemy.engine.Engine [cached since 0.02498s ago] ('ZH',)
# 2025-07-07 18:21:51,642 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:51,642 INFO sqlalchemy.engine.Engine [cached since 0.0269s ago] ('ZH_15', 'Unite 15: A la maison', "A l'oral: Decrire une maison, un appartement. \n\nUtiliser 吧 et les directionnels. \n\nA l'ecrit: 17 caracteres", 'A2', 0, 'ZH')
# 2025-07-07 18:21:51,642 INFO sqlalchemy.engine.Engine COMMIT
# /Users/noe_jager/Documents/GitHub/vocabulary-dbms/src/lapp/dbms.py:80: SAWarning: Object of type <Unit> not in session, add operation along 'Language.units' will not proceed
#   session.commit()

# %% [markdown]
# ## Add Vocabulary

# %%
# Initialize the database connection and create db file if it doesn't exist
engine, session = init_db()

directory_path = f'../data/{language_id}/vocabulary'

if not os.path.exists(directory_path):
    raise FileNotFoundError(f"No vocabulary found for {language_id}.")

vocs = []

# List all elements (files and directories) in the specified directory and get their full paths
elements_paths = [os.path.join(directory_path, element) for element in os.listdir(directory_path)]
for voc_file in elements_paths:
    if os.path.isfile(voc_file) and voc_file.endswith('.csv'):
        unit_id = re.sub("[^0-9]", "", os.path.basename(voc_file))
        df = pd.read_csv(voc_file)
        for idx, row in df.iterrows():
            vocs.append( 
                Vocabulary(
                    id=f"{language_id.upper()}_{unit_id}_V{idx}",
                    word = row['word'],
                    translation = row["translation"],
                    phonetic = row["pinyin"],
                    example_sentence = row.get("example_sentence", ""),
                    type = row["type"],
                    parent=session.query(Unit).filter(Unit.id == f"{language_id.upper()}_{unit_id}").first()
                )
            )
inserts(session, vocs)
session.close()
# Out:
# 2025-07-07 18:21:51,647 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:51,647 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("language")
# 2025-07-07 18:21:51,647 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:51,649 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-07 18:21:51,649 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:51,650 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-07 18:21:51,651 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:51,651 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-07 18:21:51,652 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:51,652 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-07 18:21:51,652 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:51,652 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-07 18:21:51,652 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:51,653 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:51,656 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:51,656 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,656 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('ZH_2', 1, 0)
# 2025-07-07 18:21:51,658 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,658 INFO sqlalchemy.engine.Engine [cached since 0.00137s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:51,658 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,658 INFO sqlalchemy.engine.Engine [cached since 0.002019s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:51,659 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,659 INFO sqlalchemy.engine.Engine [cached since 0.002734s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:51,660 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,660 INFO sqlalchemy.engine.Engine [cached since 0.003369s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:51,660 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,660 INFO sqlalchemy.engine.Engine [cached since 0.004172s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:51,661 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,661 INFO sqlalchemy.engine.Engine [cached since 0.005169s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:51,662 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,662 INFO sqlalchemy.engine.Engine [cached since 0.005901s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:51,663 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,664 INFO sqlalchemy.engine.Engine [cached since 0.007422s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:51,665 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,665 INFO sqlalchemy.engine.Engine [cached since 0.008525s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:51,665 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,665 INFO sqlalchemy.engine.Engine [cached since 0.009184s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:51,666 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,666 INFO sqlalchemy.engine.Engine [cached since 0.00982s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:51,667 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,667 INFO sqlalchemy.engine.Engine [cached since 0.01055s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:51,667 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,667 INFO sqlalchemy.engine.Engine [cached since 0.0112s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:51,668 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,668 INFO sqlalchemy.engine.Engine [cached since 0.01177s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:51,668 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,669 INFO sqlalchemy.engine.Engine [cached since 0.01233s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:51,669 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,669 INFO sqlalchemy.engine.Engine [cached since 0.01291s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:51,670 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,670 INFO sqlalchemy.engine.Engine [cached since 0.0136s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:51,670 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,671 INFO sqlalchemy.engine.Engine [cached since 0.01425s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:51,671 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,671 INFO sqlalchemy.engine.Engine [cached since 0.01487s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:51,672 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,672 INFO sqlalchemy.engine.Engine [cached since 0.01549s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:51,672 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,672 INFO sqlalchemy.engine.Engine [cached since 0.01607s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:51,673 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,673 INFO sqlalchemy.engine.Engine [cached since 0.01666s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:51,674 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,674 INFO sqlalchemy.engine.Engine [cached since 0.01818s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,675 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,675 INFO sqlalchemy.engine.Engine [cached since 0.01879s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,676 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,676 INFO sqlalchemy.engine.Engine [cached since 0.01936s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,676 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,676 INFO sqlalchemy.engine.Engine [cached since 0.01996s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,677 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,677 INFO sqlalchemy.engine.Engine [cached since 0.02051s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,677 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,677 INFO sqlalchemy.engine.Engine [cached since 0.0212s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,678 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,678 INFO sqlalchemy.engine.Engine [cached since 0.02216s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,679 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,679 INFO sqlalchemy.engine.Engine [cached since 0.0229s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,680 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,680 INFO sqlalchemy.engine.Engine [cached since 0.02345s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,680 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,680 INFO sqlalchemy.engine.Engine [cached since 0.02397s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,681 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,681 INFO sqlalchemy.engine.Engine [cached since 0.02452s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,681 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,681 INFO sqlalchemy.engine.Engine [cached since 0.02514s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,682 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,682 INFO sqlalchemy.engine.Engine [cached since 0.02569s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,682 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,683 INFO sqlalchemy.engine.Engine [cached since 0.02626s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,683 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,683 INFO sqlalchemy.engine.Engine [cached since 0.0268s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,684 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,684 INFO sqlalchemy.engine.Engine [cached since 0.02735s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,684 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,684 INFO sqlalchemy.engine.Engine [cached since 0.02788s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,685 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,685 INFO sqlalchemy.engine.Engine [cached since 0.02851s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,685 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,685 INFO sqlalchemy.engine.Engine [cached since 0.02908s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,686 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,686 INFO sqlalchemy.engine.Engine [cached since 0.02964s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,686 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,686 INFO sqlalchemy.engine.Engine [cached since 0.03021s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,687 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,687 INFO sqlalchemy.engine.Engine [cached since 0.03075s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,688 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,688 INFO sqlalchemy.engine.Engine [cached since 0.03136s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,688 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,688 INFO sqlalchemy.engine.Engine [cached since 0.03195s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,689 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,689 INFO sqlalchemy.engine.Engine [cached since 0.03253s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,689 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,689 INFO sqlalchemy.engine.Engine [cached since 0.03313s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,690 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,690 INFO sqlalchemy.engine.Engine [cached since 0.03372s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,690 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,691 INFO sqlalchemy.engine.Engine [cached since 0.0343s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,691 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,691 INFO sqlalchemy.engine.Engine [cached since 0.03486s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,692 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,692 INFO sqlalchemy.engine.Engine [cached since 0.03542s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,692 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,692 INFO sqlalchemy.engine.Engine [cached since 0.03605s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:51,694 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,694 INFO sqlalchemy.engine.Engine [cached since 0.0377s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:51,695 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,695 INFO sqlalchemy.engine.Engine [cached since 0.03845s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:51,695 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,695 INFO sqlalchemy.engine.Engine [cached since 0.03914s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:51,696 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,696 INFO sqlalchemy.engine.Engine [cached since 0.03972s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:51,696 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,697 INFO sqlalchemy.engine.Engine [cached since 0.04027s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:51,697 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,697 INFO sqlalchemy.engine.Engine [cached since 0.04104s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:51,698 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,698 INFO sqlalchemy.engine.Engine [cached since 0.04164s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:51,698 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,698 INFO sqlalchemy.engine.Engine [cached since 0.04216s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:51,699 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,699 INFO sqlalchemy.engine.Engine [cached since 0.04269s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:51,699 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,700 INFO sqlalchemy.engine.Engine [cached since 0.04326s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:51,700 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,700 INFO sqlalchemy.engine.Engine [cached since 0.0438s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:51,700 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,701 INFO sqlalchemy.engine.Engine [cached since 0.04433s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:51,701 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,701 INFO sqlalchemy.engine.Engine [cached since 0.04484s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:51,702 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,702 INFO sqlalchemy.engine.Engine [cached since 0.04534s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:51,702 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,702 INFO sqlalchemy.engine.Engine [cached since 0.04599s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:51,703 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,703 INFO sqlalchemy.engine.Engine [cached since 0.04658s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:51,703 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,703 INFO sqlalchemy.engine.Engine [cached since 0.0471s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:51,704 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,704 INFO sqlalchemy.engine.Engine [cached since 0.04766s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:51,704 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,705 INFO sqlalchemy.engine.Engine [cached since 0.04823s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:51,705 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,705 INFO sqlalchemy.engine.Engine [cached since 0.04887s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:51,706 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,706 INFO sqlalchemy.engine.Engine [cached since 0.04941s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:51,706 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,706 INFO sqlalchemy.engine.Engine [cached since 0.04999s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:51,707 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,707 INFO sqlalchemy.engine.Engine [cached since 0.05058s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:51,707 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,708 INFO sqlalchemy.engine.Engine [cached since 0.05124s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:51,709 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,709 INFO sqlalchemy.engine.Engine [cached since 0.0526s ago] ('ZH_0', 1, 0)
# 2025-07-07 18:21:51,709 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,710 INFO sqlalchemy.engine.Engine [cached since 0.05325s ago] ('ZH_0', 1, 0)
# 2025-07-07 18:21:51,710 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,710 INFO sqlalchemy.engine.Engine [cached since 0.05408s ago] ('ZH_0', 1, 0)
# 2025-07-07 18:21:51,711 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,711 INFO sqlalchemy.engine.Engine [cached since 0.05465s ago] ('ZH_0', 1, 0)
# 2025-07-07 18:21:51,711 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,712 INFO sqlalchemy.engine.Engine [cached since 0.05522s ago] ('ZH_0', 1, 0)
# 2025-07-07 18:21:51,712 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,712 INFO sqlalchemy.engine.Engine [cached since 0.0558s ago] ('ZH_0', 1, 0)
# 2025-07-07 18:21:51,712 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,713 INFO sqlalchemy.engine.Engine [cached since 0.05632s ago] ('ZH_0', 1, 0)
# 2025-07-07 18:21:51,713 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,713 INFO sqlalchemy.engine.Engine [cached since 0.05684s ago] ('ZH_0', 1, 0)
# 2025-07-07 18:21:51,714 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,714 INFO sqlalchemy.engine.Engine [cached since 0.05747s ago] ('ZH_0', 1, 0)
# 2025-07-07 18:21:51,714 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,714 INFO sqlalchemy.engine.Engine [cached since 0.058s ago] ('ZH_0', 1, 0)
# 2025-07-07 18:21:51,715 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,715 INFO sqlalchemy.engine.Engine [cached since 0.05854s ago] ('ZH_0', 1, 0)
# 2025-07-07 18:21:51,716 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,716 INFO sqlalchemy.engine.Engine [cached since 0.05999s ago] ('ZH_4', 1, 0)
# 2025-07-07 18:21:51,717 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,717 INFO sqlalchemy.engine.Engine [cached since 0.06053s ago] ('ZH_4', 1, 0)
# 2025-07-07 18:21:51,717 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,717 INFO sqlalchemy.engine.Engine [cached since 0.061s ago] ('ZH_4', 1, 0)
# 2025-07-07 18:21:51,718 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,718 INFO sqlalchemy.engine.Engine [cached since 0.0616s ago] ('ZH_4', 1, 0)
# 2025-07-07 18:21:51,718 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,718 INFO sqlalchemy.engine.Engine [cached since 0.06214s ago] ('ZH_4', 1, 0)
# 2025-07-07 18:21:51,719 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,719 INFO sqlalchemy.engine.Engine [cached since 0.06262s ago] ('ZH_4', 1, 0)
# 2025-07-07 18:21:51,719 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,719 INFO sqlalchemy.engine.Engine [cached since 0.06317s ago] ('ZH_4', 1, 0)
# 2025-07-07 18:21:51,720 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,720 INFO sqlalchemy.engine.Engine [cached since 0.06376s ago] ('ZH_4', 1, 0)
# 2025-07-07 18:21:51,720 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,721 INFO sqlalchemy.engine.Engine [cached since 0.0643s ago] ('ZH_4', 1, 0)
# 2025-07-07 18:21:51,721 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,721 INFO sqlalchemy.engine.Engine [cached since 0.06482s ago] ('ZH_4', 1, 0)
# 2025-07-07 18:21:51,722 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,722 INFO sqlalchemy.engine.Engine [cached since 0.06535s ago] ('ZH_4', 1, 0)
# 2025-07-07 18:21:51,722 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,722 INFO sqlalchemy.engine.Engine [cached since 0.06585s ago] ('ZH_4', 1, 0)
# 2025-07-07 18:21:51,723 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,723 INFO sqlalchemy.engine.Engine [cached since 0.06636s ago] ('ZH_4', 1, 0)
# 2025-07-07 18:21:51,723 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,723 INFO sqlalchemy.engine.Engine [cached since 0.06691s ago] ('ZH_4', 1, 0)
# 2025-07-07 18:21:51,724 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,724 INFO sqlalchemy.engine.Engine [cached since 0.06744s ago] ('ZH_4', 1, 0)
# 2025-07-07 18:21:51,724 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,724 INFO sqlalchemy.engine.Engine [cached since 0.06809s ago] ('ZH_4', 1, 0)
# 2025-07-07 18:21:51,725 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,725 INFO sqlalchemy.engine.Engine [cached since 0.06863s ago] ('ZH_4', 1, 0)
# 2025-07-07 18:21:51,725 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,726 INFO sqlalchemy.engine.Engine [cached since 0.06924s ago] ('ZH_4', 1, 0)
# 2025-07-07 18:21:51,727 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,727 INFO sqlalchemy.engine.Engine [cached since 0.07066s ago] ('ZH_5', 1, 0)
# 2025-07-07 18:21:51,728 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,728 INFO sqlalchemy.engine.Engine [cached since 0.07134s ago] ('ZH_5', 1, 0)
# 2025-07-07 18:21:51,728 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,728 INFO sqlalchemy.engine.Engine [cached since 0.07194s ago] ('ZH_5', 1, 0)
# 2025-07-07 18:21:51,729 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,729 INFO sqlalchemy.engine.Engine [cached since 0.07265s ago] ('ZH_5', 1, 0)
# 2025-07-07 18:21:51,729 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,729 INFO sqlalchemy.engine.Engine [cached since 0.07321s ago] ('ZH_5', 1, 0)
# 2025-07-07 18:21:51,730 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,730 INFO sqlalchemy.engine.Engine [cached since 0.07388s ago] ('ZH_5', 1, 0)
# 2025-07-07 18:21:51,731 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,731 INFO sqlalchemy.engine.Engine [cached since 0.07468s ago] ('ZH_5', 1, 0)
# 2025-07-07 18:21:51,732 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,732 INFO sqlalchemy.engine.Engine [cached since 0.07539s ago] ('ZH_5', 1, 0)
# 2025-07-07 18:21:51,732 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,733 INFO sqlalchemy.engine.Engine [cached since 0.07623s ago] ('ZH_5', 1, 0)
# 2025-07-07 18:21:51,733 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,733 INFO sqlalchemy.engine.Engine [cached since 0.07709s ago] ('ZH_5', 1, 0)
# 2025-07-07 18:21:51,734 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,734 INFO sqlalchemy.engine.Engine [cached since 0.07778s ago] ('ZH_5', 1, 0)
# 2025-07-07 18:21:51,734 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,735 INFO sqlalchemy.engine.Engine [cached since 0.07837s ago] ('ZH_5', 1, 0)
# 2025-07-07 18:21:51,735 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,735 INFO sqlalchemy.engine.Engine [cached since 0.07904s ago] ('ZH_5', 1, 0)
# 2025-07-07 18:21:51,736 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,736 INFO sqlalchemy.engine.Engine [cached since 0.07979s ago] ('ZH_5', 1, 0)
# 2025-07-07 18:21:51,737 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,737 INFO sqlalchemy.engine.Engine [cached since 0.08062s ago] ('ZH_5', 1, 0)
# 2025-07-07 18:21:51,738 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:51,738 INFO sqlalchemy.engine.Engine [cached since 0.08133s ago] ('ZH_5', 1, 0)
# 2025-07-07 18:21:51,738 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# ...
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,399 INFO sqlalchemy.engine.Engine [cached since 1.375s ago] ('ZH_9',)
# 2025-07-07 18:21:53,399 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,399 INFO sqlalchemy.engine.Engine [cached since 1.379s ago] ('ZH_9_V5', '开始', 'Commencer', 'Kāishǐ', '', 'Verbes', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,399 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,400 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,400 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,400 INFO sqlalchemy.engine.Engine [cached since 1.377s ago] ('ZH_9',)
# 2025-07-07 18:21:53,401 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,401 INFO sqlalchemy.engine.Engine [cached since 1.381s ago] ('ZH_9_V6', '骑', 'Chevaucher', 'Qí', '', 'Verbes', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,401 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,402 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,402 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,403 INFO sqlalchemy.engine.Engine [cached since 1.379s ago] ('ZH_9',)
# 2025-07-07 18:21:53,403 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,403 INFO sqlalchemy.engine.Engine [cached since 1.383s ago] ('ZH_9_V7', '上班', 'Commencer le travail', 'Shàngbān', '', 'Verbes', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,404 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,405 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,405 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,405 INFO sqlalchemy.engine.Engine [cached since 1.382s ago] ('ZH_9',)
# 2025-07-07 18:21:53,405 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,406 INFO sqlalchemy.engine.Engine [cached since 1.385s ago] ('ZH_9_V8', '下班', 'Finir le travail', 'Xiàbān', '', 'Verbes', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,406 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,407 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,407 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,407 INFO sqlalchemy.engine.Engine [cached since 1.384s ago] ('ZH_9',)
# 2025-07-07 18:21:53,407 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,407 INFO sqlalchemy.engine.Engine [cached since 1.387s ago] ('ZH_9_V9', '走路', 'Marcher', 'Zǒulù', '', 'Verbes', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,408 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,409 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,409 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,409 INFO sqlalchemy.engine.Engine [cached since 1.386s ago] ('ZH_9',)
# 2025-07-07 18:21:53,410 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,410 INFO sqlalchemy.engine.Engine [cached since 1.389s ago] ('ZH_9_V10', '坐', "S'asseoir/prendre (véhicule)", 'Zuò', '', 'Verbes', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,410 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,411 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,411 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,411 INFO sqlalchemy.engine.Engine [cached since 1.388s ago] ('ZH_9',)
# 2025-07-07 18:21:53,412 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,412 INFO sqlalchemy.engine.Engine [cached since 1.392s ago] ('ZH_9_V11', '游泳', 'Nager', 'Yóuyǒng', '', 'Verbes', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,413 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,413 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,414 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,414 INFO sqlalchemy.engine.Engine [cached since 1.39s ago] ('ZH_9',)
# 2025-07-07 18:21:53,414 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,414 INFO sqlalchemy.engine.Engine [cached since 1.394s ago] ('ZH_9_V12', '无聊', 'Ennuyeux', 'Wúliáo', '', 'Adjectifs', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,415 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,415 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,416 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,416 INFO sqlalchemy.engine.Engine [cached since 1.393s ago] ('ZH_9',)
# 2025-07-07 18:21:53,416 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,417 INFO sqlalchemy.engine.Engine [cached since 1.396s ago] ('ZH_9_V13', '有意思', 'Intéressant (polite)', 'Yǒu yìsi', '', 'Adjectifs', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,417 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,418 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,418 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,427 INFO sqlalchemy.engine.Engine [cached since 1.404s ago] ('ZH_9',)
# 2025-07-07 18:21:53,430 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,433 INFO sqlalchemy.engine.Engine [cached since 1.413s ago] ('ZH_9_V14', '没意思', 'Inintéressant (polite)', 'Méi yìsi', '', 'Adjectifs', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,439 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,441 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,443 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,444 INFO sqlalchemy.engine.Engine [cached since 1.421s ago] ('ZH_9',)
# 2025-07-07 18:21:53,446 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,446 INFO sqlalchemy.engine.Engine [cached since 1.426s ago] ('ZH_9_V15', '啊', "Particule modale d'exclamation", 'A', '', 'Divers', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,446 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,447 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,448 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,448 INFO sqlalchemy.engine.Engine [cached since 1.425s ago] ('ZH_9',)
# 2025-07-07 18:21:53,449 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,451 INFO sqlalchemy.engine.Engine [cached since 1.43s ago] ('ZH_9_V16', '每', 'Chaque', 'Měi', '', 'Divers', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,453 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,455 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,456 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,456 INFO sqlalchemy.engine.Engine [cached since 1.433s ago] ('ZH_9',)
# 2025-07-07 18:21:53,457 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,457 INFO sqlalchemy.engine.Engine [cached since 1.436s ago] ('ZH_9_V17', '然后', 'Ensuite', 'Ránhòu', '', 'Divers', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,457 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,458 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,458 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,458 INFO sqlalchemy.engine.Engine [cached since 1.435s ago] ('ZH_9',)
# 2025-07-07 18:21:53,459 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,459 INFO sqlalchemy.engine.Engine [cached since 1.438s ago] ('ZH_9_V18', '同意', "Être d'accord", 'Tóngyì', '', 'Divers', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,459 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,460 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,460 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,461 INFO sqlalchemy.engine.Engine [cached since 1.437s ago] ('ZH_9',)
# 2025-07-07 18:21:53,461 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,461 INFO sqlalchemy.engine.Engine [cached since 1.44s ago] ('ZH_9_V19', '先', "D'abord", 'Xiān', '', 'Divers', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,461 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,462 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,462 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,462 INFO sqlalchemy.engine.Engine [cached since 1.439s ago] ('ZH_9',)
# 2025-07-07 18:21:53,463 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,463 INFO sqlalchemy.engine.Engine [cached since 1.443s ago] ('ZH_9_V20', '有点儿', 'Un petit peu', 'Yǒu diǎnr', '', 'Divers', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,463 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,464 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,465 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,465 INFO sqlalchemy.engine.Engine [cached since 1.442s ago] ('ZH_9',)
# 2025-07-07 18:21:53,466 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,467 INFO sqlalchemy.engine.Engine [cached since 1.446s ago] ('ZH_9_V21', '公园', 'Parc public', 'Gōngyuán', '', 'Noms et expressions', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,468 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,469 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,470 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,471 INFO sqlalchemy.engine.Engine [cached since 1.448s ago] ('ZH_9',)
# 2025-07-07 18:21:53,472 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,472 INFO sqlalchemy.engine.Engine [cached since 1.452s ago] ('ZH_9_V22', '看法', 'Point de vue', 'Kànfǎ', '', 'Noms et expressions', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,473 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,475 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,476 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,477 INFO sqlalchemy.engine.Engine [cached since 1.453s ago] ('ZH_9',)
# 2025-07-07 18:21:53,478 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,479 INFO sqlalchemy.engine.Engine [cached since 1.458s ago] ('ZH_9_V23', '游泳池', 'Piscine', 'Yóuyǒngchí', '', 'Noms et expressions', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,480 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Add Grammar Rules

# %%
# Initialize the database connection and create db file if it doesn't exist
engine, session = init_db()

directory_path = f'../data/{language_id}/grammar'

if not os.path.exists(directory_path):
    raise FileNotFoundError(f"No grammar files found for {language_id}.")

grammars = []

# List all elements (files and directories) in the specified directory and get their full paths
elements_paths = [os.path.join(directory_path, element) for element in os.listdir(directory_path)]
for grammar_file in elements_paths:
    if os.path.isfile(grammar_file) and grammar_file.endswith('.json'):
        unit_id = re.sub("[^0-9]", "", os.path.basename(grammar_file))
        with open(grammar_file, 'r', encoding="utf8") as f:
            grammar_data = json.load(f)
        for idx, row in enumerate(grammar_data):
            grammars.append( 
                GrammarRule(
                    id=f"{language_id.upper()}_{unit_id}_G{idx + 1}",
                    title=row['title'],
                    explanation=row["content"],
                    parent=session.query(Unit).filter(Unit.id == f"{language_id.upper()}_{unit_id}").first()
                )
            )
inserts(session, grammars)
session.close()
# Out:
# 2025-07-07 18:21:53,491 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,492 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("language")
# 2025-07-07 18:21:53,492 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:53,493 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-07 18:21:53,493 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:53,494 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-07 18:21:53,494 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:53,495 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-07 18:21:53,521 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:53,522 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-07 18:21:53,522 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:53,523 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-07 18:21:53,523 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 18:21:53,524 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,529 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,533 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,533 INFO sqlalchemy.engine.Engine [generated in 0.00059s] ('ZH_11', 1, 0)
# 2025-07-07 18:21:53,536 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,537 INFO sqlalchemy.engine.Engine [cached since 0.004071s ago] ('ZH_11', 1, 0)
# 2025-07-07 18:21:53,539 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,539 INFO sqlalchemy.engine.Engine [cached since 0.006373s ago] ('ZH_11', 1, 0)
# 2025-07-07 18:21:53,541 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,542 INFO sqlalchemy.engine.Engine [cached since 0.008657s ago] ('ZH_11', 1, 0)
# 2025-07-07 18:21:53,544 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,544 INFO sqlalchemy.engine.Engine [cached since 0.01146s ago] ('ZH_6', 1, 0)
# 2025-07-07 18:21:53,546 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,546 INFO sqlalchemy.engine.Engine [cached since 0.01311s ago] ('ZH_6', 1, 0)
# 2025-07-07 18:21:53,547 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,548 INFO sqlalchemy.engine.Engine [cached since 0.01537s ago] ('ZH_6', 1, 0)
# 2025-07-07 18:21:53,549 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,550 INFO sqlalchemy.engine.Engine [cached since 0.01667s ago] ('ZH_6', 1, 0)
# 2025-07-07 18:21:53,552 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,553 INFO sqlalchemy.engine.Engine [cached since 0.01989s ago] ('ZH_7', 1, 0)
# 2025-07-07 18:21:53,554 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,554 INFO sqlalchemy.engine.Engine [cached since 0.02115s ago] ('ZH_7', 1, 0)
# 2025-07-07 18:21:53,555 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,555 INFO sqlalchemy.engine.Engine [cached since 0.02204s ago] ('ZH_7', 1, 0)
# 2025-07-07 18:21:53,556 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,556 INFO sqlalchemy.engine.Engine [cached since 0.02306s ago] ('ZH_7', 1, 0)
# 2025-07-07 18:21:53,557 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,557 INFO sqlalchemy.engine.Engine [cached since 0.02389s ago] ('ZH_7', 1, 0)
# 2025-07-07 18:21:53,557 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,558 INFO sqlalchemy.engine.Engine [cached since 0.02467s ago] ('ZH_7', 1, 0)
# 2025-07-07 18:21:53,560 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,561 INFO sqlalchemy.engine.Engine [cached since 0.02824s ago] ('ZH_10', 1, 0)
# 2025-07-07 18:21:53,563 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,564 INFO sqlalchemy.engine.Engine [cached since 0.03139s ago] ('ZH_10', 1, 0)
# 2025-07-07 18:21:53,566 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,567 INFO sqlalchemy.engine.Engine [cached since 0.03385s ago] ('ZH_10', 1, 0)
# 2025-07-07 18:21:53,568 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,569 INFO sqlalchemy.engine.Engine [cached since 0.03566s ago] ('ZH_10', 1, 0)
# 2025-07-07 18:21:53,571 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,572 INFO sqlalchemy.engine.Engine [cached since 0.03898s ago] ('ZH_10', 1, 0)
# 2025-07-07 18:21:53,574 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,575 INFO sqlalchemy.engine.Engine [cached since 0.04165s ago] ('ZH_10', 1, 0)
# 2025-07-07 18:21:53,577 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,577 INFO sqlalchemy.engine.Engine [cached since 0.04463s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:53,578 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,578 INFO sqlalchemy.engine.Engine [cached since 0.04535s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:53,579 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,579 INFO sqlalchemy.engine.Engine [cached since 0.04599s ago] ('ZH_1', 1, 0)
# 2025-07-07 18:21:53,580 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,580 INFO sqlalchemy.engine.Engine [cached since 0.04714s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:53,580 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,581 INFO sqlalchemy.engine.Engine [cached since 0.04775s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:53,581 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,581 INFO sqlalchemy.engine.Engine [cached since 0.04837s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:53,582 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,582 INFO sqlalchemy.engine.Engine [cached since 0.04896s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:53,582 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,582 INFO sqlalchemy.engine.Engine [cached since 0.0495s ago] ('ZH_2', 1, 0)
# 2025-07-07 18:21:53,583 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,583 INFO sqlalchemy.engine.Engine [cached since 0.0504s ago] ('ZH_15', 1, 0)
# 2025-07-07 18:21:53,584 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,584 INFO sqlalchemy.engine.Engine [cached since 0.051s ago] ('ZH_15', 1, 0)
# 2025-07-07 18:21:53,584 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,584 INFO sqlalchemy.engine.Engine [cached since 0.05155s ago] ('ZH_15', 1, 0)
# 2025-07-07 18:21:53,585 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,585 INFO sqlalchemy.engine.Engine [cached since 0.05221s ago] ('ZH_15', 1, 0)
# 2025-07-07 18:21:53,586 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,586 INFO sqlalchemy.engine.Engine [cached since 0.053s ago] ('ZH_14', 1, 0)
# 2025-07-07 18:21:53,586 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,586 INFO sqlalchemy.engine.Engine [cached since 0.05357s ago] ('ZH_14', 1, 0)
# 2025-07-07 18:21:53,587 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,587 INFO sqlalchemy.engine.Engine [cached since 0.05413s ago] ('ZH_14', 1, 0)
# 2025-07-07 18:21:53,587 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,588 INFO sqlalchemy.engine.Engine [cached since 0.05467s ago] ('ZH_14', 1, 0)
# 2025-07-07 18:21:53,588 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,588 INFO sqlalchemy.engine.Engine [cached since 0.05521s ago] ('ZH_14', 1, 0)
# 2025-07-07 18:21:53,589 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,589 INFO sqlalchemy.engine.Engine [cached since 0.05614s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:53,589 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,590 INFO sqlalchemy.engine.Engine [cached since 0.05665s ago] ('ZH_3', 1, 0)
# 2025-07-07 18:21:53,590 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,590 INFO sqlalchemy.engine.Engine [cached since 0.0575s ago] ('ZH_8', 1, 0)
# 2025-07-07 18:21:53,591 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,591 INFO sqlalchemy.engine.Engine [cached since 0.0581s ago] ('ZH_8', 1, 0)
# 2025-07-07 18:21:53,591 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,591 INFO sqlalchemy.engine.Engine [cached since 0.05862s ago] ('ZH_8', 1, 0)
# 2025-07-07 18:21:53,592 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,592 INFO sqlalchemy.engine.Engine [cached since 0.05911s ago] ('ZH_8', 1, 0)
# 2025-07-07 18:21:53,592 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,592 INFO sqlalchemy.engine.Engine [cached since 0.05962s ago] ('ZH_8', 1, 0)
# 2025-07-07 18:21:53,593 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,593 INFO sqlalchemy.engine.Engine [cached since 0.06053s ago] ('ZH_4', 1, 0)
# 2025-07-07 18:21:53,594 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,594 INFO sqlalchemy.engine.Engine [cached since 0.06104s ago] ('ZH_4', 1, 0)
# 2025-07-07 18:21:53,594 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,595 INFO sqlalchemy.engine.Engine [cached since 0.06169s ago] ('ZH_4', 1, 0)
# 2025-07-07 18:21:53,595 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,595 INFO sqlalchemy.engine.Engine [cached since 0.06228s ago] ('ZH_4', 1, 0)
# 2025-07-07 18:21:53,596 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,596 INFO sqlalchemy.engine.Engine [cached since 0.06286s ago] ('ZH_4', 1, 0)
# 2025-07-07 18:21:53,597 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,597 INFO sqlalchemy.engine.Engine [cached since 0.06376s ago] ('ZH_13', 1, 0)
# 2025-07-07 18:21:53,597 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,597 INFO sqlalchemy.engine.Engine [cached since 0.0643s ago] ('ZH_13', 1, 0)
# 2025-07-07 18:21:53,598 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,598 INFO sqlalchemy.engine.Engine [cached since 0.06485s ago] ('ZH_13', 1, 0)
# 2025-07-07 18:21:53,598 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,598 INFO sqlalchemy.engine.Engine [cached since 0.06538s ago] ('ZH_13', 1, 0)
# 2025-07-07 18:21:53,599 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,599 INFO sqlalchemy.engine.Engine [cached since 0.06596s ago] ('ZH_13', 1, 0)
# 2025-07-07 18:21:53,600 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,600 INFO sqlalchemy.engine.Engine [cached since 0.06679s ago] ('ZH_12', 1, 0)
# 2025-07-07 18:21:53,600 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,600 INFO sqlalchemy.engine.Engine [cached since 0.06733s ago] ('ZH_12', 1, 0)
# 2025-07-07 18:21:53,601 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,601 INFO sqlalchemy.engine.Engine [cached since 0.06791s ago] ('ZH_12', 1, 0)
# 2025-07-07 18:21:53,601 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,601 INFO sqlalchemy.engine.Engine [cached since 0.06844s ago] ('ZH_12', 1, 0)
# 2025-07-07 18:21:53,602 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,602 INFO sqlalchemy.engine.Engine [cached since 0.06894s ago] ('ZH_12', 1, 0)
# 2025-07-07 18:21:53,603 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,603 INFO sqlalchemy.engine.Engine [cached since 0.06983s ago] ('ZH_5', 1, 0)
# 2025-07-07 18:21:53,603 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,603 INFO sqlalchemy.engine.Engine [cached since 0.07036s ago] ('ZH_5', 1, 0)
# 2025-07-07 18:21:53,604 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,604 INFO sqlalchemy.engine.Engine [cached since 0.07095s ago] ('ZH_5', 1, 0)
# 2025-07-07 18:21:53,604 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,604 INFO sqlalchemy.engine.Engine [cached since 0.07149s ago] ('ZH_5', 1, 0)
# 2025-07-07 18:21:53,605 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,605 INFO sqlalchemy.engine.Engine [cached since 0.07234s ago] ('ZH_9', 1, 0)
# 2025-07-07 18:21:53,606 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,606 INFO sqlalchemy.engine.Engine [cached since 0.07283s ago] ('ZH_9', 1, 0)
# 2025-07-07 18:21:53,606 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,606 INFO sqlalchemy.engine.Engine [cached since 0.07336s ago] ('ZH_9', 1, 0)
# 2025-07-07 18:21:53,607 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,607 INFO sqlalchemy.engine.Engine [cached since 0.07386s ago] ('ZH_9', 1, 0)
# 2025-07-07 18:21:53,607 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,607 INFO sqlalchemy.engine.Engine [cached since 0.0744s ago] ('ZH_9', 1, 0)
# 2025-07-07 18:21:53,608 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 18:21:53,608 INFO sqlalchemy.engine.Engine [cached since 0.07492s ago] ('ZH_9', 1, 0)
# 2025-07-07 18:21:53,609 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,609 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('ZH_11_G1', 'Énumérer avec 第 dì', "第 dì permet de former des chiffres et nombres ordinaux.\nIl s'emploie de la façon suivante :\n\n第 + chiffre/nombre ( + Classificateur )\n\n* 第一 dì yī ... (918 characters truncated) ... s deux mots suivants signifient « étage » et peuvent s'employer sans 第 dì :\n\n* 三楼 sān lóu : « Troisième étage »\n* 四层 sì céng : « Quatrième étage »", 0, '2025-07-07', 'ZH_11')
# 2025-07-07 18:21:53,609 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,610 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,610 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,610 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('ZH_11',)
# 2025-07-07 18:21:53,611 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,611 INFO sqlalchemy.engine.Engine [cached since 0.002129s ago] ('ZH_11_G2', 'Exprimer une distance avec 离 lí', "离 lí est utilisé lorsqu'on souhaite exprimer une distance entre deux points. Il peut se traduire par « par rapport à ». La structure à employer, très ... (589 characters truncated) ... ē zhàn lí zhèr tài yuǎn le : « La gare est trop éloignée d’ici »\n* 酒吧离我的家比较远 jiǔbā lí wǒ de jiā bǐjiào yuǎn : « Le bar est plutôt loin de chez moi »", 0, '2025-07-07', 'ZH_11')
# 2025-07-07 18:21:53,611 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,611 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,612 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,612 INFO sqlalchemy.engine.Engine [cached since 0.00168s ago] ('ZH_11',)
# 2025-07-07 18:21:53,612 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,612 INFO sqlalchemy.engine.Engine [cached since 0.003522s ago] ('ZH_11_G3', 'Se diriger, suivre un itinéraire', 'Savoir utiliser les termes « droite », « gauche » et « tout droit » suffit pour se repérer, demander son chemin et comprendre un itinéraire. Lorsqu’o ... (238 characters truncated) ... tout droit »\n* 你先往前走一百米，然后往左拐 nǐ xiān wǎng qián zǒu yī bǎi mǐ, ránhòu wǎng zuǒ guǎi : « Va d’abord tout droit sur 100 mètres, puis tourne à gauche »', 0, '2025-07-07', 'ZH_11')
# 2025-07-07 18:21:53,612 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,613 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,613 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,613 INFO sqlalchemy.engine.Engine [cached since 0.003092s ago] ('ZH_11',)
# 2025-07-07 18:21:53,613 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,613 INFO sqlalchemy.engine.Engine [cached since 0.004969s ago] ('ZH_11_G4', "À l'intérieur de quelque chose", 'Pour indiquer que quelque chose se situe à l’intérieur de quelque chose d’autre, on utilise la structure suivante :\n\nNom 1 + 在 + Nom 2 + 里面\n\n* 你在 ... (240 characters truncated) ...  shàng ma ? : « Es-tu dans le bus ? »\n* 我在车上 wǒ zài chē shàng : « Je suis dans la voiture »\n* 我在火车上 wǒ zài huǒchē shàng : « Je suis dans le train »', 0, '2025-07-07', 'ZH_11')
# 2025-07-07 18:21:53,614 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,614 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,614 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,614 INFO sqlalchemy.engine.Engine [cached since 0.004458s ago] ('ZH_6',)
# 2025-07-07 18:21:53,615 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,615 INFO sqlalchemy.engine.Engine [cached since 0.006322s ago] ('ZH_6_G1', 'Les démonstratifs 这 zhè et 那 nà', "Le démonstratif le plus couramment utilisé en chinois est 这 zhè.\n这 zhè va rarement être utilisé tout seul, il est souvent couplé avec d'autres carac ... (1057 characters truncated) ... à-bas, c'est... »\n* 那个/那个人 nà ge rén : « Cette personne-là »\n* 那里是我的朋友的家 nà lǐ shì wǒ de péngyou de jiā : « Là-bas se trouve la maison de mon ami »", 0, '2025-07-07', 'ZH_6')
# 2025-07-07 18:21:53,615 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,615 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,616 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,616 INFO sqlalchemy.engine.Engine [cached since 0.005786s ago] ('ZH_6',)
# 2025-07-07 18:21:53,616 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,616 INFO sqlalchemy.engine.Engine [cached since 0.007647s ago] ('ZH_6_G2', 'Autres utilisations du caractère 的 de', "的 de, le caractère permettant de marquer la possession, peut s'utiliser à la suite d'un pronom personnel (ex. 我的 wǒ de « mon ») ou d'un nom (ex. 老师的书 ... (937 characters truncated) ... ncài : « C'est le plat que j'aime faire/préparer »\n* 这是我去年去的地方 zhè shì wǒ qùnián qù de dìfang : « C'est l'endroit où je suis allé l'année dernière »", 0, '2025-07-07', 'ZH_6')
# 2025-07-07 18:21:53,616 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,617 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,617 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,617 INFO sqlalchemy.engine.Engine [cached since 0.007109s ago] ('ZH_6',)
# 2025-07-07 18:21:53,617 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,617 INFO sqlalchemy.engine.Engine [cached since 0.00895s ago] ('ZH_6_G3', 'Exprimer "avec" à l\'aide de 跟 gēn et 一起 yīqǐ', "La préposition 跟 gēn, souvent utilisée avec 一起 yīqǐ (signifiant « ensemble »), permet de marquer l'accompagnement :\n\n* 我跟你去 wǒ gēn nǐ qù : « J'y va ... (142 characters truncated) ... gēn tā yīqǐ qù le gōngyuán : « Je suis allé au parc avec lui hier »\n* 我跟我的女朋友一起住 wǒ gēn wǒ de nǚ péngyou yīqǐ zhù : « J'habite avec ma petite amie »", 0, '2025-07-07', 'ZH_6')
# 2025-07-07 18:21:53,618 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,618 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,618 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,618 INFO sqlalchemy.engine.Engine [cached since 0.008324s ago] ('ZH_6',)
# 2025-07-07 18:21:53,619 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,619 INFO sqlalchemy.engine.Engine [cached since 0.01025s ago] ('ZH_6_G4', 'Les caractères ayant plusieurs prononciations', "Vous aurez certainement remarqué que certains caractères peuvent avoir plusieurs prononciations. Le changement de prononciation peut faire varier ou  ... (198 characters truncated) ...  : trouver que\n* 睡觉 shuìjiào : dormir\n\nCertains caractères comme le 都 de 首都 « la capitale » peuvent changer à la fois de prononciation et de sens.", 0, '2025-07-07', 'ZH_6')
# 2025-07-07 18:21:53,619 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,619 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,620 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,620 INFO sqlalchemy.engine.Engine [cached since 0.009689s ago] ('ZH_7',)
# 2025-07-07 18:21:53,620 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,620 INFO sqlalchemy.engine.Engine [cached since 0.01154s ago] ('ZH_7_G1', 'Comparer avec 比 bi ou 没有 méiyǒu', "**Utilisation de 比 bi**\nLe caractère 比 bǐ est utilisé en tant que comparatif de supériorité ou d'infériorité (et non d'égalité). Il peut être tradui ... (740 characters truncated) ...  : « Il est plus petit que moi » (littéralement « Il n'a pas ma taille »)\n* 妈妈没有爸爸高 māma méiyǒu bàba gāo : « Maman n'est pas aussi grande que papa »", 0, '2025-07-07', 'ZH_7')
# 2025-07-07 18:21:53,620 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,621 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,621 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,621 INFO sqlalchemy.engine.Engine [cached since 0.01098s ago] ('ZH_7',)
# 2025-07-07 18:21:53,621 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,621 INFO sqlalchemy.engine.Engine [cached since 0.01291s ago] ('ZH_7_G2', 'Interrogatif 谁 shéi/shuí', "谁 shéi est l'interrogatif signifiant « Qui ? ». Comme tous les mots interrogatifs, il se place à l'endroit où se trouvera la réponse :\n\n* 你是谁？ Nǐ s ... (401 characters truncated) ...  » et ne doit pas traduire le pronom relatif « qui » dans des phrases comme « La personne qui habite ici ». Pour cela, on utilise 的 de (cf. Leçon 6).", 0, '2025-07-07', 'ZH_7')
# 2025-07-07 18:21:53,622 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,622 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,622 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,622 INFO sqlalchemy.engine.Engine [cached since 0.01243s ago] ('ZH_7',)
# 2025-07-07 18:21:53,623 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,623 INFO sqlalchemy.engine.Engine [cached since 0.01431s ago] ('ZH_7_G3', 'Quelle(s) langue(s) sais-tu parler ?', "En général, on forme le nom d'une langue en ajoutant 语 yǔ (ou 文 wén) au nom du pays.\n\nPour les pays finissant par 国 guó, on remplace 国 guó par 语 yǔ ... (342 characters truncated) ... :\n\n* 中国 Zhōngguó (Chine) → 中文 Zhōngwén (chinois)\n* 汉语 Hànyǔ (chinois)\n\nNote : 汉语 Hànyǔ (chinois) et 韩语 Hányǔ (coréen) se prononcent très proche.", 0, '2025-07-07', 'ZH_7')
# 2025-07-07 18:21:53,623 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,623 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,624 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,624 INFO sqlalchemy.engine.Engine [cached since 0.01374s ago] ('ZH_7',)
# 2025-07-07 18:21:53,624 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,624 INFO sqlalchemy.engine.Engine [cached since 0.01557s ago] ('ZH_7_G4', 'Les adverbes 最 zuì et 太 ... 了 tài...le', "Les adverbes 最 zuì et 太 ... 了 tài...le s'emploient comme 很 hěn devant un adjectif, mais nuancent ou renforcent le propos :\n\n* 我很累 wǒ hěn lèi : « Je ... (11 characters truncated) ... ué »\n* 最累 zuì lèi : « Le plus fatigué »\n* 我太累了 wǒ tài lèi le : « Je suis trop fatigué »\n* 我不太累了 wǒ bù tài lèi le : « Je ne suis pas trop fatigué »", 0, '2025-07-07', 'ZH_7')
# 2025-07-07 18:21:53,624 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,625 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,625 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,625 INFO sqlalchemy.engine.Engine [cached since 0.01502s ago] ('ZH_7',)
# 2025-07-07 18:21:53,625 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,625 INFO sqlalchemy.engine.Engine [cached since 0.01688s ago] ('ZH_7_G5', 'Tout, toutes et tous avec 都 dōu', 'Le caractère 都 peut se prononcer « dū » (dans 首都 shǒudū « capitale ») ou « dōu » quand il signifie « tout, tous ». Il se place directement après le n ... (122 characters truncated) ... ōu xiǎng qù Zhōngguó : « Nous voulons tous aller en Chine »\n* 我的朋友都 wǒ de péngyou dōu : « Tous mes amis »\n* 女生都 nǚshēng dōu : « Toutes les filles »', 0, '2025-07-07', 'ZH_7')
# 2025-07-07 18:21:53,626 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,626 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,626 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,626 INFO sqlalchemy.engine.Engine [cached since 0.01631s ago] ('ZH_7',)
# 2025-07-07 18:21:53,627 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,627 INFO sqlalchemy.engine.Engine [cached since 0.01818s ago] ('ZH_7_G6', 'Ensemble avec 一起 yīqǐ', '一起 yīqǐ a déjà été vu dans la structure 跟 gēn ... + 一起 yīqǐ (page 109) pour dire « avec ». 一起 yīqǐ peut aussi être utilisé seul et signifie « ensembl ... (50 characters truncated) ...  Elles vont regarder un film ensemble »\n* 我们一起去北京 wǒmen yīqǐ qù Běijīng : « Nous allons ensemble à Pékin »\n\nStructure : Sujet + 一起 + Verbe + Objet', 0, '2025-07-07', 'ZH_7')
# 2025-07-07 18:21:53,627 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,627 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,627 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,628 INFO sqlalchemy.engine.Engine [cached since 0.0176s ago] ('ZH_10',)
# 2025-07-07 18:21:53,628 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,628 INFO sqlalchemy.engine.Engine [cached since 0.01951s ago] ('ZH_10_G1', 'Indiquer le destinataire avec 给 gěi', "给 gěi, signifiant « donner », permet d'indiquer la cible d'une action.\n\nStructure : Sujet + 给 + cible + action\n\n* 你给我打电话 nǐ gěi wǒ dǎ diànhuà : « ... (45 characters truncated) ... i tā dǎ diànhuà : « Tu dois lui téléphoner »\n* 你给他写信 nǐ gěi tā xiěxìn : « Écris-lui une lettre »\n* 我给你做饭 wǒ gěi nǐ zuòfàn : « Je te fais à manger »", 0, '2025-07-07', 'ZH_10')
# 2025-07-07 18:21:53,628 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,629 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,629 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,629 INFO sqlalchemy.engine.Engine [cached since 0.01891s ago] ('ZH_10',)
# 2025-07-07 18:21:53,629 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,629 INFO sqlalchemy.engine.Engine [cached since 0.02073s ago] ('ZH_10_G2', '"Pouvoir" avec 能 néng ou 可以 kěyǐ', "Plusieurs verbes existent pour exprimer la possibilité, cependant ils ne peuvent pas s'employer de la même manière. Nous avons déjà étudié le verbe 会 ... (795 characters truncated) ... 停车吗？wǒ zài zhèr kěyǐ tíngchē ma ? : « Puis-je garer ma voiture ici ? »\n* 妈妈，我可以出去吗？māma, wǒ kěyǐ chūqù ma ? : « Maman, est-ce que je peux sortir ? »", 0, '2025-07-07', 'ZH_10')
# 2025-07-07 18:21:53,630 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,630 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,630 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,630 INFO sqlalchemy.engine.Engine [cached since 0.02019s ago] ('ZH_10',)
# 2025-07-07 18:21:53,631 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,631 INFO sqlalchemy.engine.Engine [cached since 0.02259s ago] ('ZH_10_G3', 'La condition avec 如果 ... 的话 rúguǒ ... de huà et 就 jiù', "如果 ... 的话 rúguǒ ... de huà et 就 jiù sont utilisés, ensemble ou séparément, afin d'introduire une condition et sa conséquence.\n\nStructure : 如果 + Suj ... (135 characters truncated) ... , appelle le médecin »\n* 如果他生病的话，他就不能去工作 rúguǒ tā shēngbìng de huà, tā jiù bù néng qù gōngzuò : « S'il est malade, il ne peut pas aller travailler »", 0, '2025-07-07', 'ZH_10')
# 2025-07-07 18:21:53,631 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,632 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,632 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,632 INFO sqlalchemy.engine.Engine [cached since 0.0221s ago] ('ZH_10',)
# 2025-07-07 18:21:53,632 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,632 INFO sqlalchemy.engine.Engine [cached since 0.02395s ago] ('ZH_10_G4', "Le comparatif d'égalité", "Nous avons étudié dans la leçon 7 les comparatifs de supériorité ou d'infériorité en utilisant le caractère 比 bǐ. Il ne faut pas employer 比 pour intr ... (338 characters truncated) ... la mienne »\n* 今天的会议和昨天的会议一样无聊 jīntiān de huìyì hé zuótiān de huìyì yīyàng wúliáo : « La réunion d'aujourd'hui est aussi ennuyeuse que celle d'hier »", 0, '2025-07-07', 'ZH_10')
# 2025-07-07 18:21:53,633 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,633 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,633 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,633 INFO sqlalchemy.engine.Engine [cached since 0.0234s ago] ('ZH_10',)
# ...
# 2025-07-07 18:21:53,703 INFO sqlalchemy.engine.Engine [cached since 0.09448s ago] ('ZH_12_G2', 'Classificateurs ne pouvant pas être remplacés par 个 gè', "Certains classificateurs ne peuvent pas être remplacés par 个 gè (qui est, pour rappel, le classificateur universel), car ils apportent un sens partic ... (274 characters truncated) ...  gè niǎo : « Un oiseau »\n* 一群鸟 yī qún niǎo : « Un vol d’oiseaux »\n* 一些人 yī xiē rén : « Quelques personnes »\n* 一杯水 yī bēi shuǐ : « Un verre d’eau »", 0, '2025-07-07', 'ZH_12')
# 2025-07-07 18:21:53,703 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,705 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,706 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,706 INFO sqlalchemy.engine.Engine [cached since 0.096s ago] ('ZH_12',)
# 2025-07-07 18:21:53,707 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,707 INFO sqlalchemy.engine.Engine [cached since 0.09862s ago] ('ZH_12_G3', 'Permettre quelque chose avec 让 ràng', "让 ràng est un verbe dit « causatif », qui peut être traduit par « laisser » ou « permettre » en français.\n\nStructure : Sujet + 让 + Personne/Objet + ... (128 characters truncated) ...  papa ne te laisse-t-il pas y aller ? »\n* 看 Titanic 电影让我很感动 kàn Titanic diànyǐng ràng wǒ hěn gǎndòng : « Regarder le film Titanic m'a beaucoup ému »", 0, '2025-07-07', 'ZH_12')
# 2025-07-07 18:21:53,708 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,709 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,710 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,710 INFO sqlalchemy.engine.Engine [cached since 0.09992s ago] ('ZH_12',)
# 2025-07-07 18:21:53,710 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,711 INFO sqlalchemy.engine.Engine [cached since 0.102s ago] ('ZH_12_G4', 'Demander « combien » avec 多少 duōshǎo ou 几 jǐ', "Il existe deux façons principales de demander « combien » : 多少 duōshǎo et 几 jǐ. Voici leurs différences :\n\n* 几 jǐ est utilisé pour des quantités gé ... (695 characters truncated) ...  ici »\n* 我有十多元 wǒ yǒu shí duō yuán : « J’ai un peu plus de dix yuans »\n* 我有三十多块钱 wǒ yǒu sānshí duō kuài qián : « J’ai un peu plus de trente kuais »", 0, '2025-07-07', 'ZH_12')
# 2025-07-07 18:21:53,711 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,711 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,712 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,712 INFO sqlalchemy.engine.Engine [cached since 0.1017s ago] ('ZH_12',)
# 2025-07-07 18:21:53,712 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,712 INFO sqlalchemy.engine.Engine [cached since 0.1037s ago] ('ZH_12_G5', '« Quelques » avec 一些 yīxiē', "一些 yīxiē signifie « quelques » ou « certains » et désigne une quantité indéterminée. Il s'utilise selon le schéma suivant :\n\n一些 + Nom\n\n* 有一些人 yǒu yīxiē rén : « Il y a quelques personnes »\n* 爸爸买了一些书 bàba mǎi le yīxiē shū : « Papa a acheté quelques livres »", 0, '2025-07-07', 'ZH_12')
# 2025-07-07 18:21:53,713 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,713 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,713 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,713 INFO sqlalchemy.engine.Engine [cached since 0.1034s ago] ('ZH_5',)
# 2025-07-07 18:21:53,714 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,714 INFO sqlalchemy.engine.Engine [cached since 0.1052s ago] ('ZH_5_G1', 'Les adjectifs', "**Affirmation avec 很 hěn**\nLes noms doivent être liés aux autres noms à l'aide du verbe « être » 是 shì.\n\n* 妈妈 是 老师 māma shì lǎoshī : « Maman est p ... (1844 characters truncated) ... ǐhuan : « j'aime »\n* 我 讨厌 wǒ tǎoyàn : « je déteste »\n* 我 很 喜欢 wǒ hěn xǐhuan : « j'aime beaucoup »\n* 我 很 讨厌 wǒ hěn tǎoyàn : « je déteste vraiment »", 0, '2025-07-07', 'ZH_5')
# 2025-07-07 18:21:53,714 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,714 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,715 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,715 INFO sqlalchemy.engine.Engine [cached since 0.1047s ago] ('ZH_5',)
# 2025-07-07 18:21:53,715 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,715 INFO sqlalchemy.engine.Engine [cached since 0.1066s ago] ('ZH_5_G2', 'Énumérer avec 和 hé', "Le caractère 和 hé permet d'énumérer des noms communs. Nous pouvons traduire par « ainsi que », son emploi diffère donc du « et » français.\n\n* 我 的 妈 ... (132 characters truncated) ... n papa et moi »\n\n和 hé ne peut pas être utilisé pour lier deux phrases comme en français (ex. Ce matin je travaille et cet après-midi je me repose).", 0, '2025-07-07', 'ZH_5')
# 2025-07-07 18:21:53,715 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,716 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,716 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,716 INFO sqlalchemy.engine.Engine [cached since 0.1061s ago] ('ZH_5',)
# 2025-07-07 18:21:53,716 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,716 INFO sqlalchemy.engine.Engine [cached since 0.108s ago] ('ZH_5_G3', 'Le caractère 的 de', "Le premier sens de 的 de est le possessif. L'ajout du caractère 的 de aux pronoms personnels permet de former les pronoms possessifs :\n\nPronom person ... (638 characters truncated) ...  de Chine »\n\nDéterminant + 的 + déterminé\n\nLe contexte est indispensable pour comprendre le sens qu'il a dans une phrase, un texte ou un dialogue.", 0, '2025-07-07', 'ZH_5')
# 2025-07-07 18:21:53,717 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,717 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,717 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,717 INFO sqlalchemy.engine.Engine [cached since 0.1075s ago] ('ZH_5',)
# 2025-07-07 18:21:53,718 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,718 INFO sqlalchemy.engine.Engine [cached since 0.1094s ago] ('ZH_5_G4', 'Les différentes utilisations de 要 yào', "Le premier sens de 要 yào est le verbe « vouloir ».\n\n* 我 要 工作 wǒ yào gōngzuò : « Je veux travailler »\n* 我 要 吃饭 wǒ yào chīfàn : « Je veux manger »\n ... (31 characters truncated) ... enir est la suivante :\n\nIl peut également avoir d'autres sens, tels que « devoir », « falloir » ou encore « aller faire/être sur le point de ... ».", 0, '2025-07-07', 'ZH_5')
# 2025-07-07 18:21:53,718 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,719 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,719 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,719 INFO sqlalchemy.engine.Engine [cached since 0.1089s ago] ('ZH_9',)
# 2025-07-07 18:21:53,719 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,719 INFO sqlalchemy.engine.Engine [cached since 0.1107s ago] ('ZH_9_G1', 'Moyens de transport', "Si en français nous employons généralement le verbe « prendre » lorsqu'il s'agit des moyens de transport, il convient d'utiliser le verbe 坐 zuò « s'a ... (471 characters truncated) ...  véhicule, il faut employer 开 kāi « conduire, ouvrir » :\n\n* 我开车 wǒ kāi chē : « Je conduis la voiture »\n* 我开飞机 wǒ kāi fēijī : « Je pilote l'avion »", 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,719 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,720 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,720 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,720 INFO sqlalchemy.engine.Engine [cached since 0.1102s ago] ('ZH_9',)
# 2025-07-07 18:21:53,721 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,721 INFO sqlalchemy.engine.Engine [cached since 0.1123s ago] ('ZH_9_G2', '"Chaque" avec 每 měi', '每 měi est employé dans la majorité des cas avec un classificateur derrière :\n\n* 每个人 měi gè rén : « Chaque personne »\n* 每个月 měi gè yuè : « Chaque m ... (100 characters truncated) ... it pas être employé dans les trois cas suivants :\n\n* 每年 měi nián : « Chaque année »\n* 每天 měi tiān : « Chaque jour »\n* 每日 měi rì : « Chaque jour »', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,721 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,721 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,722 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,722 INFO sqlalchemy.engine.Engine [cached since 0.1117s ago] ('ZH_9',)
# 2025-07-07 18:21:53,722 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,722 INFO sqlalchemy.engine.Engine [cached since 0.1136s ago] ('ZH_9_G3', '"D\'abord... ensuite..." avec 先 xiān et 然后 ránhòu', "先 xiān « premièrement », et 然后 ránhòu « ensuite » peuvent être utilisés ensemble pour indiquer que deux événements se succèdent :\n\n* 我们先吃饭，然后看电视 wǒ ... (220 characters truncated) ... emièrement » peut également être utilisé seul :\n\n* 他先到了 tā xiān dào le : « Il est arrivé en premier »\n* 我先说 wǒ xiān shuō : « Je parle en premier »", 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,722 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,723 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,723 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,723 INFO sqlalchemy.engine.Engine [cached since 0.113s ago] ('ZH_9',)
# 2025-07-07 18:21:53,723 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,723 INFO sqlalchemy.engine.Engine [cached since 0.1149s ago] ('ZH_9_G4', '"Un petit peu" avec 有点儿 yǒu diǎnr ou 一点儿 yī diǎnr', "**有点儿 yǒu diǎnr**\n有点儿 yǒu diǎnr ou simplement 有点 yǒu diǎn est utilisé avant un adjectif. Il est généralement employé dans des phrases négatives, pou ... (499 characters truncated) ... 宜一点儿 nǐ piányi yī diǎnr : « Baisse un peu le prix »\n* 你快一点儿 nǐ kuài yī diǎnr : « Dépêche-toi un peu »\n* 你慢一点儿 nǐ màn yī diǎnr : « Ralentis un peu »", 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,724 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,724 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,724 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,724 INFO sqlalchemy.engine.Engine [cached since 0.1144s ago] ('ZH_9',)
# 2025-07-07 18:21:53,725 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,725 INFO sqlalchemy.engine.Engine [cached since 0.1162s ago] ('ZH_9_G5', 'Utiliser 比较 bǐjiào devant un verbe', "Nous avons vu dans la leçon précédente que l'adverbe 比较 bǐjiào signifie « relativement, plutôt » et qu'il était employé devant un adjectif afin de le ... (162 characters truncated) ... iào xǐhuan : « Je préfère »\n* 我不喜欢坐车，我比较喜欢走路 wǒ bù xǐhuan zuò chē, wǒ bǐjiào xǐhuan zǒulù : « Je n'aime pas prendre la voiture, je préfère marcher »", 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,725 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 18:21:53,725 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 18:21:53,726 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-07 18:21:53,726 INFO sqlalchemy.engine.Engine [cached since 0.1157s ago] ('ZH_9',)
# 2025-07-07 18:21:53,726 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 18:21:53,726 INFO sqlalchemy.engine.Engine [cached since 0.1175s ago] ('ZH_9_G6', 'Les particules modales placées en fin de phrase', 'Quelques particules modales sont habituellement rajoutées en fin de phrase pour donner un ton particulier à la phrase, en voici quelques exemples :\n ... (334 characters truncated) ... .\n\nIl existe également des interjections placées en début de phrase :\n\n* 嗯 en : équivalent du « hum... » français\n* 哎呀 āiyā : marque la surprise', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 18:21:53,726 INFO sqlalchemy.engine.Engine COMMIT
# /var/folders/5p/bjh6crbn6fv0vtxy5sqmmxh00000gn/T/ipykernel_22672/1242808380.py:24: SAWarning: Object of type <GrammarRule> not in session, add operation along 'Unit.grammars' will not proceed (This warning originated from the Session 'autoflush' process, which was invoked automatically in response to a user-initiated operation. Consider using ``no_autoflush`` context manager if this warning happended while initializing objects.)
#   parent=session.query(Unit).filter(Unit.id == f"{language_id.upper()}_{unit_id}").first()
# /Users/noe_jager/Documents/GitHub/vocabulary-dbms/src/lapp/dbms.py:80: SAWarning: Object of type <GrammarRule> not in session, add operation along 'Unit.grammars' will not proceed
#   session.commit()
