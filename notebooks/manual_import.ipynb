# %%
import json
import pandas as pd
import os
import re
from lapp.dbms import init_db, inserts, modify, delete, find_by_attr
from lapp.tables import Unit, Vocabulary, GrammarRule

# %%
language_name = "zh"

# %% [markdown]
# ## Add Units

# %%
# Initialize the database connection and create db file if it doesn't exist
engine, session = init_db(language_name)

if not os.path.exists(f'../data/{language_name}'):
    raise FileNotFoundError(f"Dataset for {language_name} not found.")

# Initialize the database
with open(f'../data/{language_name}/units.json', 'r', encoding="utf8") as f:
    units_array = json.load(f)
    
units = []
for idx, unit_data in enumerate(units_array):
    units.append(
        Unit(
            unit_id = f"{language_name.upper()}_{idx}",
            title = unit_data['title'],
            description = unit_data['description'],
            level = unit_data['level']
        )
    )
inserts(session, units)
session.close()
# Out:
# 2025-07-07 10:44:10,184 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:10,184 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-07 10:44:10,184 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 10:44:10,185 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-07 10:44:10,186 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 10:44:10,186 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-07 10:44:10,186 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 10:44:10,187 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-07 10:44:10,187 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 10:44:10,188 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-07 10:44:10,188 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 10:44:10,188 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:10,195 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:10,197 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-07 10:44:10,198 INFO sqlalchemy.engine.Engine [generated in 0.00080s] ('ZH_0', 'Lecon introductive: Bonjour!', "A l'oral: Connaitre les salutations de base\nA l'ecrit: 5 caracteres", 'A1')
# 2025-07-07 10:44:10,200 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:10,203 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:10,204 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-07 10:44:10,204 INFO sqlalchemy.engine.Engine [cached since 0.006934s ago] ('ZH_1', "Unite 1: Comment t'appelles-tu?", "A l'oral: Savoir se presenter et presenter quelqu'un\nParler de sa nationalite\nA l'ecrit: 19 caracteres", 'A1')
# 2025-07-07 10:44:10,205 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:10,208 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:10,209 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-07 10:44:10,209 INFO sqlalchemy.engine.Engine [cached since 0.01299s ago] ('ZH_2', 'Unite 2: Un, deux, trois', "A l'oral: Compter de 1 a 9999\nSavoir enumerer des objets\nA l'ecrit: 19 caracteres", 'A1')
# 2025-07-07 10:44:10,212 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:10,214 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:10,215 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-07 10:44:10,215 INFO sqlalchemy.engine.Engine [cached since 0.01795s ago] ('ZH_3', "Unite 3: Aujourd'hui", "A l'oral: Savoir annoncer la date\nParler des moments de la journee et de l'heure\nA l'ecrit: 17 caracteres", 'A1')
# 2025-07-07 10:44:10,216 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:10,218 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:10,219 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-07 10:44:10,219 INFO sqlalchemy.engine.Engine [cached since 0.02228s ago] ('ZH_4', 'Unite 4: Ou allons-nous?', "A l'oral: Parler d'un evenement passe, d'une experience\nPouvoir se situer, parler ou l'on est, ou l'on va\nA l'ecrit: 17 caracteres", 'A1')
# 2025-07-07 10:44:10,220 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:10,223 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:10,224 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-07 10:44:10,224 INFO sqlalchemy.engine.Engine [cached since 0.02668s ago] ('ZH_5', 'Unite 5: Je ne suis pas vieux', "A l'oral: Decrire quelqu'un ou quelque chose\nUtilise les adjectifs\nA l'ecrit: 17 caracteres", 'A1')
# 2025-07-07 10:44:10,226 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:10,228 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:10,229 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-07 10:44:10,230 INFO sqlalchemy.engine.Engine [cached since 0.03315s ago] ('ZH_6', 'Unite 6: Ma famille', "A l'oral: Pouvoir presenter sa famille\nUtilise les demonstratifs\nA l'ecrit: 22 caracteres", 'A1')
# 2025-07-07 10:44:10,232 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:10,233 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:10,234 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-07 10:44:10,234 INFO sqlalchemy.engine.Engine [cached since 0.0372s ago] ('ZH_7', 'Unite 7: Mes amis', "A l'oral: Parler des ses amis\nParler des langues etrangeres\nComparer des gens ou des objets\nA l'ecrit: 18 caracteres", 'A1')
# 2025-07-07 10:44:10,234 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:10,237 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:10,238 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-07 10:44:10,238 INFO sqlalchemy.engine.Engine [cached since 0.04106s ago] ('ZH_8', "Unite 8: Qu'aimes-tu faire?", "A l'oral: Parler de ses activites favorites\nInterroger sur la maniere\nA l'ecrit: 16 caracteres", 'A2')
# 2025-07-07 10:44:10,239 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:10,241 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:10,242 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-07 10:44:10,242 INFO sqlalchemy.engine.Engine [cached since 0.04504s ago] ('ZH_9', 'Unite 9: Une journee classique', "A l'oral: Raconter sa journee\nParler des differents moyens de transport\nA l'ecrit: 16 caracteres", 'A2')
# 2025-07-07 10:44:10,243 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:10,245 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:10,246 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-07 10:44:10,246 INFO sqlalchemy.engine.Engine [cached since 0.04856s ago] ('ZH_10', 'Unite 10: Au travail', "A l'oral: Parler du monde du travail\nA l'ecrit: 18 caracteres", 'A2')
# 2025-07-07 10:44:10,247 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:10,249 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:10,250 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-07 10:44:10,250 INFO sqlalchemy.engine.Engine [cached since 0.05232s ago] ('ZH_11', 'Unite 11: Dans une grande ville', "A l'oral: Pouvoir demander son chemin\nSe reperer en ville\nA l'ecrit: 18 caracteres", 'A2')
# 2025-07-07 10:44:10,251 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:10,252 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:10,252 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-07 10:44:10,253 INFO sqlalchemy.engine.Engine [cached since 0.05594s ago] ('ZH_12', 'Unite 12: Faire des achats', "A l'oral: Negocier un prix\nFaire des achats\nA l'ecrit: 18 caracteres", 'A2')
# 2025-07-07 10:44:10,254 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:10,257 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:10,257 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-07 10:44:10,257 INFO sqlalchemy.engine.Engine [cached since 0.05992s ago] ('ZH_13', "Unite 13: En voyage a l'etranger", "A l'oral: Pouvoir raconter ou prevoir un voyage\nUtiliser 'Avant, apres, pendant'\nA l'ecrit: 17 caracteres", 'A2')
# 2025-07-07 10:44:10,258 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:10,260 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:10,261 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-07 10:44:10,261 INFO sqlalchemy.engine.Engine [cached since 0.06349s ago] ('ZH_14', 'Unite 14: La culture chinoise', "A l'oral: Decouvrir la culture chinoise\nParler des fetes et des vacances\nA l'ecrit: 19 caracteres", 'A2')
# 2025-07-07 10:44:10,262 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:10,263 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:10,264 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-07 10:44:10,264 INFO sqlalchemy.engine.Engine [cached since 0.06693s ago] ('ZH_15', 'Unite 15: A la maison', "A l'oral: Decrire une maison, un appartement\nUtiliser 吧 et les directionnels\nA l'ecrit: 17 caracteres", 'A2')
# 2025-07-07 10:44:10,265 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Add Vocabulary

# %%
# Initialize the database connection and create db file if it doesn't exist
engine, session = init_db(language_name)

directory_path = f'../data/{language_name}/vocabulary'

if not os.path.exists(directory_path):
    raise FileNotFoundError(f"No vocabulary found for {language_name}.")

vocs = []

# List all elements (files and directories) in the specified directory and get their full paths
elements_paths = [os.path.join(directory_path, element) for element in os.listdir(directory_path)]
for voc_file in elements_paths:
    if os.path.isfile(voc_file) and voc_file.endswith('.csv'):
        unit_id = re.sub("[^0-9]", "", os.path.basename(voc_file))
        df = pd.read_csv(voc_file)
        for idx, row in df.iterrows():
            vocs.append( 
                Vocabulary(
                    learn_id=f"{language_name.upper()}_{unit_id}_V{idx}",
                    word = row['word'],
                    translation = row["translation"],
                    phonetic = row["pinyin"],
                    example_sentence = row.get("example_sentence", ""),
                    type = row["type"],
                    parent=session.query(Unit).filter(Unit.unit_id == f"{language_name.upper()}_{unit_id}").first()
                )
            )
inserts(session, vocs)
session.close()
# Out:
# 2025-07-07 10:44:10,275 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:10,275 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-07 10:44:10,276 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 10:44:10,276 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-07 10:44:10,276 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 10:44:10,277 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-07 10:44:10,277 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 10:44:10,278 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-07 10:44:10,278 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 10:44:10,279 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-07 10:44:10,279 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 10:44:10,280 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:10,292 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:10,293 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,294 INFO sqlalchemy.engine.Engine [generated in 0.00044s] ('ZH_0', 1, 0)
# 2025-07-07 10:44:10,295 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,296 INFO sqlalchemy.engine.Engine [cached since 0.002675s ago] ('ZH_0', 1, 0)
# 2025-07-07 10:44:10,297 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,297 INFO sqlalchemy.engine.Engine [cached since 0.004242s ago] ('ZH_0', 1, 0)
# 2025-07-07 10:44:10,298 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,298 INFO sqlalchemy.engine.Engine [cached since 0.00542s ago] ('ZH_0', 1, 0)
# 2025-07-07 10:44:10,300 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,300 INFO sqlalchemy.engine.Engine [cached since 0.006699s ago] ('ZH_0', 1, 0)
# 2025-07-07 10:44:10,301 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,301 INFO sqlalchemy.engine.Engine [cached since 0.008029s ago] ('ZH_0', 1, 0)
# 2025-07-07 10:44:10,303 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,303 INFO sqlalchemy.engine.Engine [cached since 0.009807s ago] ('ZH_0', 1, 0)
# 2025-07-07 10:44:10,304 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,304 INFO sqlalchemy.engine.Engine [cached since 0.01126s ago] ('ZH_0', 1, 0)
# 2025-07-07 10:44:10,305 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,306 INFO sqlalchemy.engine.Engine [cached since 0.01254s ago] ('ZH_0', 1, 0)
# 2025-07-07 10:44:10,307 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,307 INFO sqlalchemy.engine.Engine [cached since 0.01372s ago] ('ZH_0', 1, 0)
# 2025-07-07 10:44:10,308 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,308 INFO sqlalchemy.engine.Engine [cached since 0.01482s ago] ('ZH_0', 1, 0)
# 2025-07-07 10:44:10,314 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,314 INFO sqlalchemy.engine.Engine [cached since 0.02182s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:10,316 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,316 INFO sqlalchemy.engine.Engine [cached since 0.02315s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:10,317 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,318 INFO sqlalchemy.engine.Engine [cached since 0.02441s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:10,319 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,319 INFO sqlalchemy.engine.Engine [cached since 0.02562s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:10,320 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,320 INFO sqlalchemy.engine.Engine [cached since 0.02662s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:10,321 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,321 INFO sqlalchemy.engine.Engine [cached since 0.02792s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:10,322 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,322 INFO sqlalchemy.engine.Engine [cached since 0.02902s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:10,323 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,323 INFO sqlalchemy.engine.Engine [cached since 0.02997s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:10,324 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,324 INFO sqlalchemy.engine.Engine [cached since 0.03107s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:10,325 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,326 INFO sqlalchemy.engine.Engine [cached since 0.03233s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:10,326 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,327 INFO sqlalchemy.engine.Engine [cached since 0.03356s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:10,328 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,328 INFO sqlalchemy.engine.Engine [cached since 0.03462s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:10,329 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,329 INFO sqlalchemy.engine.Engine [cached since 0.03568s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:10,330 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,330 INFO sqlalchemy.engine.Engine [cached since 0.03674s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:10,331 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,331 INFO sqlalchemy.engine.Engine [cached since 0.03803s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:10,332 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,332 INFO sqlalchemy.engine.Engine [cached since 0.03911s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:10,333 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,333 INFO sqlalchemy.engine.Engine [cached since 0.04054s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:10,334 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,334 INFO sqlalchemy.engine.Engine [cached since 0.04195s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:10,337 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,337 INFO sqlalchemy.engine.Engine [cached since 0.04373s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:10,338 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,338 INFO sqlalchemy.engine.Engine [cached since 0.04506s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:10,339 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,340 INFO sqlalchemy.engine.Engine [cached since 0.04649s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:10,341 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,341 INFO sqlalchemy.engine.Engine [cached since 0.04759s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:10,342 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,342 INFO sqlalchemy.engine.Engine [cached since 0.04888s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:10,343 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,343 INFO sqlalchemy.engine.Engine [cached since 0.05008s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:10,357 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,358 INFO sqlalchemy.engine.Engine [cached since 0.06505s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,359 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,359 INFO sqlalchemy.engine.Engine [cached since 0.06625s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,360 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,360 INFO sqlalchemy.engine.Engine [cached since 0.06745s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,360 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,362 INFO sqlalchemy.engine.Engine [cached since 0.06869s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,363 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,363 INFO sqlalchemy.engine.Engine [cached since 0.06988s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,364 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,364 INFO sqlalchemy.engine.Engine [cached since 0.07106s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,365 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,365 INFO sqlalchemy.engine.Engine [cached since 0.0723s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,366 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,367 INFO sqlalchemy.engine.Engine [cached since 0.07341s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,367 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,368 INFO sqlalchemy.engine.Engine [cached since 0.07463s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,369 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,369 INFO sqlalchemy.engine.Engine [cached since 0.07612s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,370 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,371 INFO sqlalchemy.engine.Engine [cached since 0.07735s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,371 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,371 INFO sqlalchemy.engine.Engine [cached since 0.07858s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,372 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,372 INFO sqlalchemy.engine.Engine [cached since 0.07962s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,373 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,374 INFO sqlalchemy.engine.Engine [cached since 0.08098s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,374 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,375 INFO sqlalchemy.engine.Engine [cached since 0.08205s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,375 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,377 INFO sqlalchemy.engine.Engine [cached since 0.08313s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,378 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,378 INFO sqlalchemy.engine.Engine [cached since 0.08445s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,379 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,379 INFO sqlalchemy.engine.Engine [cached since 0.08554s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,380 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,380 INFO sqlalchemy.engine.Engine [cached since 0.08667s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,381 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,381 INFO sqlalchemy.engine.Engine [cached since 0.0879s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,382 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,383 INFO sqlalchemy.engine.Engine [cached since 0.08912s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,383 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,384 INFO sqlalchemy.engine.Engine [cached since 0.09009s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,384 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,385 INFO sqlalchemy.engine.Engine [cached since 0.09109s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,386 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,386 INFO sqlalchemy.engine.Engine [cached since 0.09225s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,387 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,387 INFO sqlalchemy.engine.Engine [cached since 0.09361s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,388 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,388 INFO sqlalchemy.engine.Engine [cached since 0.09493s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,389 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,390 INFO sqlalchemy.engine.Engine [cached since 0.09613s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,391 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,391 INFO sqlalchemy.engine.Engine [cached since 0.09747s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,392 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,392 INFO sqlalchemy.engine.Engine [cached since 0.09865s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,393 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,393 INFO sqlalchemy.engine.Engine [cached since 0.09991s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,394 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,395 INFO sqlalchemy.engine.Engine [cached since 0.1011s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,396 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,396 INFO sqlalchemy.engine.Engine [cached since 0.1025s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,397 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,397 INFO sqlalchemy.engine.Engine [cached since 0.1038s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:10,408 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,408 INFO sqlalchemy.engine.Engine [cached since 0.1148s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,409 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,409 INFO sqlalchemy.engine.Engine [cached since 0.1161s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,410 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,411 INFO sqlalchemy.engine.Engine [cached since 0.1173s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,411 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,412 INFO sqlalchemy.engine.Engine [cached since 0.1186s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,413 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,413 INFO sqlalchemy.engine.Engine [cached since 0.1197s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,414 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,414 INFO sqlalchemy.engine.Engine [cached since 0.1207s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,415 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,415 INFO sqlalchemy.engine.Engine [cached since 0.122s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,416 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,416 INFO sqlalchemy.engine.Engine [cached since 0.1231s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,417 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,417 INFO sqlalchemy.engine.Engine [cached since 0.1243s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,418 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,418 INFO sqlalchemy.engine.Engine [cached since 0.1254s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,419 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,419 INFO sqlalchemy.engine.Engine [cached since 0.1266s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,420 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,420 INFO sqlalchemy.engine.Engine [cached since 0.128s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,422 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,422 INFO sqlalchemy.engine.Engine [cached since 0.1291s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,423 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,423 INFO sqlalchemy.engine.Engine [cached since 0.1303s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,424 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,424 INFO sqlalchemy.engine.Engine [cached since 0.1316s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,425 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,425 INFO sqlalchemy.engine.Engine [cached since 0.1327s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,426 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,426 INFO sqlalchemy.engine.Engine [cached since 0.1338s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,427 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,427 INFO sqlalchemy.engine.Engine [cached since 0.1347s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,428 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,429 INFO sqlalchemy.engine.Engine [cached since 0.136s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,430 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,430 INFO sqlalchemy.engine.Engine [cached since 0.138s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,432 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,432 INFO sqlalchemy.engine.Engine [cached since 0.1393s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,433 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,433 INFO sqlalchemy.engine.Engine [cached since 0.1406s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,434 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,435 INFO sqlalchemy.engine.Engine [cached since 0.142s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,436 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,436 INFO sqlalchemy.engine.Engine [cached since 0.1435s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,437 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,437 INFO sqlalchemy.engine.Engine [cached since 0.1446s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,438 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,438 INFO sqlalchemy.engine.Engine [cached since 0.1458s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,439 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,440 INFO sqlalchemy.engine.Engine [cached since 0.1469s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:10,451 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,452 INFO sqlalchemy.engine.Engine [cached since 0.1592s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,453 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,454 INFO sqlalchemy.engine.Engine [cached since 0.1609s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,455 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,455 INFO sqlalchemy.engine.Engine [cached since 0.1623s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,457 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,457 INFO sqlalchemy.engine.Engine [cached since 0.1634s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,458 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,458 INFO sqlalchemy.engine.Engine [cached since 0.1643s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,459 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,459 INFO sqlalchemy.engine.Engine [cached since 0.1655s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,460 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,460 INFO sqlalchemy.engine.Engine [cached since 0.1668s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,461 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,462 INFO sqlalchemy.engine.Engine [cached since 0.1682s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,463 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,463 INFO sqlalchemy.engine.Engine [cached since 0.1694s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,464 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,464 INFO sqlalchemy.engine.Engine [cached since 0.1706s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,465 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,466 INFO sqlalchemy.engine.Engine [cached since 0.1722s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,466 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,467 INFO sqlalchemy.engine.Engine [cached since 0.1735s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,468 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,468 INFO sqlalchemy.engine.Engine [cached since 0.1748s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,469 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,469 INFO sqlalchemy.engine.Engine [cached since 0.1759s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,470 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,470 INFO sqlalchemy.engine.Engine [cached since 0.177s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,471 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,472 INFO sqlalchemy.engine.Engine [cached since 0.1782s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,472 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,473 INFO sqlalchemy.engine.Engine [cached since 0.1794s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,474 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,474 INFO sqlalchemy.engine.Engine [cached since 0.1806s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,475 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,475 INFO sqlalchemy.engine.Engine [cached since 0.1818s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,476 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,476 INFO sqlalchemy.engine.Engine [cached since 0.1829s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,476 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,477 INFO sqlalchemy.engine.Engine [cached since 0.184s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,478 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,478 INFO sqlalchemy.engine.Engine [cached since 0.1851s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,479 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# C:\Users\Elliot\AppData\Local\Temp\ipykernel_2016\721160772.py:26: SAWarning: Object of type <Vocabulary> not in session, add operation along 'Unit.vocs' will not proceed (This warning originated from the Session 'autoflush' process, which was invoked automatically in response to a user-initiated operation. Consider using ``no_autoflush`` context manager if this warning happended while initializing objects.)
#   parent=session.query(Unit).filter(Unit.unit_id == f"{language_name.upper()}_{unit_id}").first()
# C:\Users\Elliot\AppData\Local\Temp\ipykernel_2016\721160772.py:26: SAWarning: Object of type <Vocabulary> not in session, add operation along 'Unit.vocs' will not proceed (This warning originated from the Session 'autoflush' process, which was invoked automatically in response to a user-initiated operation. Consider using ``no_autoflush`` context manager if this warning happended while initializing objects.)
#   parent=session.query(Unit).filter(Unit.unit_id == f"{language_name.upper()}_{unit_id}").first()
# C:\Users\Elliot\AppData\Local\Temp\ipykernel_2016\721160772.py:26: SAWarning: Object of type <Vocabulary> not in session, add operation along 'Unit.vocs' will not proceed (This warning originated from the Session 'autoflush' process, which was invoked automatically in response to a user-initiated operation. Consider using ``no_autoflush`` context manager if this warning happended while initializing objects.)
#   parent=session.query(Unit).filter(Unit.unit_id == f"{language_name.upper()}_{unit_id}").first()
# C:\Users\Elliot\AppData\Local\Temp\ipykernel_2016\721160772.py:26: SAWarning: Object of type <Vocabulary> not in session, add operation along 'Unit.vocs' will not proceed (This warning originated from the Session 'autoflush' process, which was invoked automatically in response to a user-initiated operation. Consider using ``no_autoflush`` context manager if this warning happended while initializing objects.)
#   parent=session.query(Unit).filter(Unit.unit_id == f"{language_name.upper()}_{unit_id}").first()
# C:\Users\Elliot\AppData\Local\Temp\ipykernel_2016\721160772.py:26: SAWarning: Object of type <Vocabulary> not in session, add operation along 'Unit.vocs' will not proceed (This warning originated from the Session 'autoflush' process, which was invoked automatically in response to a user-initiated operation. Consider using ``no_autoflush`` context manager if this warning happended while initializing objects.)
#   parent=session.query(Unit).filter(Unit.unit_id == f"{language_name.upper()}_{unit_id}").first()
# 2025-07-07 10:44:10,479 INFO sqlalchemy.engine.Engine [cached since 0.1866s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,480 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,480 INFO sqlalchemy.engine.Engine [cached since 0.188s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,482 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,482 INFO sqlalchemy.engine.Engine [cached since 0.1892s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,484 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,484 INFO sqlalchemy.engine.Engine [cached since 0.1907s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,485 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,485 INFO sqlalchemy.engine.Engine [cached since 0.1922s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,487 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,487 INFO sqlalchemy.engine.Engine [cached since 0.1939s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:10,500 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,501 INFO sqlalchemy.engine.Engine [cached since 0.2073s ago] ('ZH_13', 1, 0)
# 2025-07-07 10:44:10,502 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,502 INFO sqlalchemy.engine.Engine [cached since 0.2088s ago] ('ZH_13', 1, 0)
# 2025-07-07 10:44:10,503 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,503 INFO sqlalchemy.engine.Engine [cached since 0.21s ago] ('ZH_13', 1, 0)
# 2025-07-07 10:44:10,504 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,504 INFO sqlalchemy.engine.Engine [cached since 0.211s ago] ('ZH_13', 1, 0)
# 2025-07-07 10:44:10,505 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,505 INFO sqlalchemy.engine.Engine [cached since 0.2122s ago] ('ZH_13', 1, 0)
# 2025-07-07 10:44:10,506 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,506 INFO sqlalchemy.engine.Engine [cached since 0.2133s ago] ('ZH_13', 1, 0)
# 2025-07-07 10:44:10,507 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,508 INFO sqlalchemy.engine.Engine [cached since 0.2146s ago] ('ZH_13', 1, 0)
# 2025-07-07 10:44:10,509 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,509 INFO sqlalchemy.engine.Engine [cached since 0.2158s ago] ('ZH_13', 1, 0)
# 2025-07-07 10:44:10,510 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,510 INFO sqlalchemy.engine.Engine [cached since 0.2171s ago] ('ZH_13', 1, 0)
# 2025-07-07 10:44:10,511 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,511 INFO sqlalchemy.engine.Engine [cached since 0.2183s ago] ('ZH_13', 1, 0)
# 2025-07-07 10:44:10,513 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:10,513 INFO sqlalchemy.engine.Engine [cached since 0.2193s ago] ('ZH_13', 1, 0)
# 2025-07-07 10:44:10,514 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# ...
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:13,864 INFO sqlalchemy.engine.Engine [cached since 2.779s ago] ('ZH_9',)
# 2025-07-07 10:44:13,865 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:13,865 INFO sqlalchemy.engine.Engine [cached since 2.787s ago] ('ZH_9_V4', '开', 'Conduire', 'Kāi', '', 'Verbes', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:13,866 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:13,870 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:13,872 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:13,872 INFO sqlalchemy.engine.Engine [cached since 2.788s ago] ('ZH_9',)
# 2025-07-07 10:44:13,874 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:13,874 INFO sqlalchemy.engine.Engine [cached since 2.797s ago] ('ZH_9_V5', '开始', 'Commencer', 'Kāishǐ', '', 'Verbes', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:13,876 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:13,879 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:13,880 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:13,881 INFO sqlalchemy.engine.Engine [cached since 2.796s ago] ('ZH_9',)
# 2025-07-07 10:44:13,881 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:13,882 INFO sqlalchemy.engine.Engine [cached since 2.804s ago] ('ZH_9_V6', '骑', 'Chevaucher', 'Qí', '', 'Verbes', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:13,883 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:13,887 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:13,888 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:13,888 INFO sqlalchemy.engine.Engine [cached since 2.804s ago] ('ZH_9',)
# 2025-07-07 10:44:13,889 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:13,890 INFO sqlalchemy.engine.Engine [cached since 2.812s ago] ('ZH_9_V7', '上班', 'Commencer le travail', 'Shàngbān', '', 'Verbes', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:13,891 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:13,894 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:13,895 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:13,896 INFO sqlalchemy.engine.Engine [cached since 2.812s ago] ('ZH_9',)
# 2025-07-07 10:44:13,897 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:13,897 INFO sqlalchemy.engine.Engine [cached since 2.82s ago] ('ZH_9_V8', '下班', 'Finir le travail', 'Xiàbān', '', 'Verbes', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:13,899 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:13,902 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:13,903 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:13,903 INFO sqlalchemy.engine.Engine [cached since 2.819s ago] ('ZH_9',)
# 2025-07-07 10:44:13,905 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:13,906 INFO sqlalchemy.engine.Engine [cached since 2.828s ago] ('ZH_9_V9', '走路', 'Marcher', 'Zǒulù', '', 'Verbes', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:13,907 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:13,911 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:13,912 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:13,912 INFO sqlalchemy.engine.Engine [cached since 2.828s ago] ('ZH_9',)
# 2025-07-07 10:44:13,913 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:13,913 INFO sqlalchemy.engine.Engine [cached since 2.835s ago] ('ZH_9_V10', '坐', "S'asseoir/prendre (véhicule)", 'Zuò', '', 'Verbes', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:13,914 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:13,916 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:13,917 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:13,918 INFO sqlalchemy.engine.Engine [cached since 2.834s ago] ('ZH_9',)
# 2025-07-07 10:44:13,918 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:13,919 INFO sqlalchemy.engine.Engine [cached since 2.842s ago] ('ZH_9_V11', '游泳', 'Nager', 'Yóuyǒng', '', 'Verbes', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:13,920 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:13,924 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:13,925 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:13,926 INFO sqlalchemy.engine.Engine [cached since 2.841s ago] ('ZH_9',)
# 2025-07-07 10:44:13,927 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:13,927 INFO sqlalchemy.engine.Engine [cached since 2.85s ago] ('ZH_9_V12', '无聊', 'Ennuyeux', 'Wúliáo', '', 'Adjectifs', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:13,930 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:13,933 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:13,935 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:13,936 INFO sqlalchemy.engine.Engine [cached since 2.852s ago] ('ZH_9',)
# 2025-07-07 10:44:13,938 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:13,939 INFO sqlalchemy.engine.Engine [cached since 2.861s ago] ('ZH_9_V13', '有意思', 'Intéressant (polite)', 'Yǒu yìsi', '', 'Adjectifs', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:13,940 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:13,947 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:13,949 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:13,950 INFO sqlalchemy.engine.Engine [cached since 2.865s ago] ('ZH_9',)
# 2025-07-07 10:44:13,951 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:13,952 INFO sqlalchemy.engine.Engine [cached since 2.874s ago] ('ZH_9_V14', '没意思', 'Inintéressant (polite)', 'Méi yìsi', '', 'Adjectifs', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:13,954 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:13,958 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:13,959 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:13,960 INFO sqlalchemy.engine.Engine [cached since 2.876s ago] ('ZH_9',)
# 2025-07-07 10:44:13,962 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:13,963 INFO sqlalchemy.engine.Engine [cached since 2.885s ago] ('ZH_9_V15', '啊', "Particule modale d'exclamation", 'A', '', 'Divers', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:13,964 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:13,969 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:13,970 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:13,972 INFO sqlalchemy.engine.Engine [cached since 2.887s ago] ('ZH_9',)
# 2025-07-07 10:44:13,973 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:13,973 INFO sqlalchemy.engine.Engine [cached since 2.895s ago] ('ZH_9_V16', '每', 'Chaque', 'Měi', '', 'Divers', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:13,975 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:13,979 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:13,980 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:13,981 INFO sqlalchemy.engine.Engine [cached since 2.897s ago] ('ZH_9',)
# 2025-07-07 10:44:13,982 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:13,983 INFO sqlalchemy.engine.Engine [cached since 2.905s ago] ('ZH_9_V17', '然后', 'Ensuite', 'Ránhòu', '', 'Divers', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:13,985 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:13,988 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:13,990 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:13,990 INFO sqlalchemy.engine.Engine [cached since 2.906s ago] ('ZH_9',)
# 2025-07-07 10:44:13,990 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:13,992 INFO sqlalchemy.engine.Engine [cached since 2.914s ago] ('ZH_9_V18', '同意', "Être d'accord", 'Tóngyì', '', 'Divers', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:13,994 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:13,997 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:13,998 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:13,998 INFO sqlalchemy.engine.Engine [cached since 2.915s ago] ('ZH_9',)
# 2025-07-07 10:44:14,000 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:14,001 INFO sqlalchemy.engine.Engine [cached since 2.923s ago] ('ZH_9_V19', '先', "D'abord", 'Xiān', '', 'Divers', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:14,002 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:14,006 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:14,006 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:14,007 INFO sqlalchemy.engine.Engine [cached since 2.923s ago] ('ZH_9',)
# 2025-07-07 10:44:14,008 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:14,008 INFO sqlalchemy.engine.Engine [cached since 2.931s ago] ('ZH_9_V20', '有点儿', 'Un petit peu', 'Yǒu diǎnr', '', 'Divers', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:14,010 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:14,014 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:14,014 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:14,015 INFO sqlalchemy.engine.Engine [cached since 2.931s ago] ('ZH_9',)
# 2025-07-07 10:44:14,016 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:14,016 INFO sqlalchemy.engine.Engine [cached since 2.939s ago] ('ZH_9_V21', '公园', 'Parc public', 'Gōngyuán', '', 'Noms et expressions', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:14,019 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:14,022 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:14,023 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:14,024 INFO sqlalchemy.engine.Engine [cached since 2.94s ago] ('ZH_9',)
# 2025-07-07 10:44:14,025 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:14,026 INFO sqlalchemy.engine.Engine [cached since 2.948s ago] ('ZH_9_V22', '看法', 'Point de vue', 'Kànfǎ', '', 'Noms et expressions', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:14,027 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:14,031 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:14,031 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:14,032 INFO sqlalchemy.engine.Engine [cached since 2.948s ago] ('ZH_9',)
# 2025-07-07 10:44:14,033 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:14,034 INFO sqlalchemy.engine.Engine [cached since 2.957s ago] ('ZH_9_V23', '游泳池', 'Piscine', 'Yóuyǒngchí', '', 'Noms et expressions', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:14,037 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Add Grammar Rules

# %%
# Initialize the database connection and create db file if it doesn't exist
engine, session = init_db(language_name)

directory_path = f'../data/{language_name}/grammar'

if not os.path.exists(directory_path):
    raise FileNotFoundError(f"No grammar files found for {language_name}.")

grammars = []

# List all elements (files and directories) in the specified directory and get their full paths
elements_paths = [os.path.join(directory_path, element) for element in os.listdir(directory_path)]
for grammar_file in elements_paths:
    if os.path.isfile(grammar_file) and grammar_file.endswith('.json'):
        unit_id = re.sub("[^0-9]", "", os.path.basename(grammar_file))
        with open(grammar_file, 'r', encoding="utf8") as f:
            grammar_data = json.load(f)
        for idx, row in enumerate(grammar_data):
            grammars.append( 
                GrammarRule(
                    learn_id=f"{language_name.upper()}_{unit_id}_G{idx + 1}",
                    title=row['title'],
                    explanation=row["content"],
                    parent=session.query(Unit).filter(Unit.unit_id == f"{language_name.upper()}_{unit_id}").first()
                )
            )
inserts(session, grammars)
session.close()
# Out:
# 2025-07-07 10:44:32,760 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:32,760 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-07 10:44:32,762 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 10:44:32,763 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-07 10:44:32,763 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 10:44:32,764 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-07 10:44:32,764 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 10:44:32,764 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-07 10:44:32,765 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 10:44:32,765 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-07 10:44:32,766 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 10:44:32,766 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:32,768 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:32,769 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,769 INFO sqlalchemy.engine.Engine [generated in 0.00040s] ('ZH_1', 1, 0)
# 2025-07-07 10:44:32,771 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,771 INFO sqlalchemy.engine.Engine [cached since 0.002103s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:32,772 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,772 INFO sqlalchemy.engine.Engine [cached since 0.003422s ago] ('ZH_1', 1, 0)
# 2025-07-07 10:44:32,779 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,779 INFO sqlalchemy.engine.Engine [cached since 0.01077s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:32,780 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,780 INFO sqlalchemy.engine.Engine [cached since 0.01196s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:32,782 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,782 INFO sqlalchemy.engine.Engine [cached since 0.01312s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:32,783 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,783 INFO sqlalchemy.engine.Engine [cached since 0.01451s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:32,784 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,785 INFO sqlalchemy.engine.Engine [cached since 0.01595s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:32,786 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,786 INFO sqlalchemy.engine.Engine [cached since 0.01752s ago] ('ZH_10', 1, 0)
# 2025-07-07 10:44:32,793 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,793 INFO sqlalchemy.engine.Engine [cached since 0.02448s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:32,794 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,795 INFO sqlalchemy.engine.Engine [cached since 0.02577s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:32,795 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,796 INFO sqlalchemy.engine.Engine [cached since 0.0269s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:32,797 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,797 INFO sqlalchemy.engine.Engine [cached since 0.02871s ago] ('ZH_11', 1, 0)
# 2025-07-07 10:44:32,805 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,805 INFO sqlalchemy.engine.Engine [cached since 0.03621s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:32,806 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,806 INFO sqlalchemy.engine.Engine [cached since 0.03762s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:32,807 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,808 INFO sqlalchemy.engine.Engine [cached since 0.03911s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:32,809 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,809 INFO sqlalchemy.engine.Engine [cached since 0.04049s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:32,810 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,810 INFO sqlalchemy.engine.Engine [cached since 0.04156s ago] ('ZH_12', 1, 0)
# 2025-07-07 10:44:32,817 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,818 INFO sqlalchemy.engine.Engine [cached since 0.04957s ago] ('ZH_13', 1, 0)
# 2025-07-07 10:44:32,819 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,819 INFO sqlalchemy.engine.Engine [cached since 0.05129s ago] ('ZH_13', 1, 0)
# 2025-07-07 10:44:32,820 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,820 INFO sqlalchemy.engine.Engine [cached since 0.05275s ago] ('ZH_13', 1, 0)
# 2025-07-07 10:44:32,822 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,822 INFO sqlalchemy.engine.Engine [cached since 0.05386s ago] ('ZH_13', 1, 0)
# 2025-07-07 10:44:32,823 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,823 INFO sqlalchemy.engine.Engine [cached since 0.05485s ago] ('ZH_13', 1, 0)
# 2025-07-07 10:44:32,834 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,835 INFO sqlalchemy.engine.Engine [cached since 0.06606s ago] ('ZH_14', 1, 0)
# 2025-07-07 10:44:32,836 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,836 INFO sqlalchemy.engine.Engine [cached since 0.06746s ago] ('ZH_14', 1, 0)
# 2025-07-07 10:44:32,837 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,837 INFO sqlalchemy.engine.Engine [cached since 0.06862s ago] ('ZH_14', 1, 0)
# 2025-07-07 10:44:32,838 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,839 INFO sqlalchemy.engine.Engine [cached since 0.06991s ago] ('ZH_14', 1, 0)
# 2025-07-07 10:44:32,839 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,840 INFO sqlalchemy.engine.Engine [cached since 0.07119s ago] ('ZH_14', 1, 0)
# 2025-07-07 10:44:32,854 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,855 INFO sqlalchemy.engine.Engine [cached since 0.08622s ago] ('ZH_15', 1, 0)
# 2025-07-07 10:44:32,856 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,856 INFO sqlalchemy.engine.Engine [cached since 0.08744s ago] ('ZH_15', 1, 0)
# 2025-07-07 10:44:32,856 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,857 INFO sqlalchemy.engine.Engine [cached since 0.08855s ago] ('ZH_15', 1, 0)
# 2025-07-07 10:44:32,858 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,858 INFO sqlalchemy.engine.Engine [cached since 0.08997s ago] ('ZH_15', 1, 0)
# 2025-07-07 10:44:32,874 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,874 INFO sqlalchemy.engine.Engine [cached since 0.1057s ago] ('ZH_2', 1, 0)
# 2025-07-07 10:44:32,876 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,876 INFO sqlalchemy.engine.Engine [cached since 0.1073s ago] ('ZH_2', 1, 0)
# 2025-07-07 10:44:32,877 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,877 INFO sqlalchemy.engine.Engine [cached since 0.1085s ago] ('ZH_2', 1, 0)
# 2025-07-07 10:44:32,878 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,878 INFO sqlalchemy.engine.Engine [cached since 0.1096s ago] ('ZH_2', 1, 0)
# 2025-07-07 10:44:32,879 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,879 INFO sqlalchemy.engine.Engine [cached since 0.1107s ago] ('ZH_2', 1, 0)
# 2025-07-07 10:44:32,894 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,894 INFO sqlalchemy.engine.Engine [cached since 0.1255s ago] ('ZH_3', 1, 0)
# 2025-07-07 10:44:32,895 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,896 INFO sqlalchemy.engine.Engine [cached since 0.1268s ago] ('ZH_3', 1, 0)
# 2025-07-07 10:44:32,908 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,908 INFO sqlalchemy.engine.Engine [cached since 0.1394s ago] ('ZH_4', 1, 0)
# 2025-07-07 10:44:32,909 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,909 INFO sqlalchemy.engine.Engine [cached since 0.1405s ago] ('ZH_4', 1, 0)
# 2025-07-07 10:44:32,910 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,910 INFO sqlalchemy.engine.Engine [cached since 0.1415s ago] ('ZH_4', 1, 0)
# 2025-07-07 10:44:32,911 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,911 INFO sqlalchemy.engine.Engine [cached since 0.1426s ago] ('ZH_4', 1, 0)
# 2025-07-07 10:44:32,912 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,913 INFO sqlalchemy.engine.Engine [cached since 0.1438s ago] ('ZH_4', 1, 0)
# 2025-07-07 10:44:32,925 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,926 INFO sqlalchemy.engine.Engine [cached since 0.1576s ago] ('ZH_5', 1, 0)
# 2025-07-07 10:44:32,927 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,928 INFO sqlalchemy.engine.Engine [cached since 0.1595s ago] ('ZH_5', 1, 0)
# 2025-07-07 10:44:32,929 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,929 INFO sqlalchemy.engine.Engine [cached since 0.1608s ago] ('ZH_5', 1, 0)
# 2025-07-07 10:44:32,930 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,930 INFO sqlalchemy.engine.Engine [cached since 0.1621s ago] ('ZH_5', 1, 0)
# 2025-07-07 10:44:32,941 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,942 INFO sqlalchemy.engine.Engine [cached since 0.1729s ago] ('ZH_6', 1, 0)
# 2025-07-07 10:44:32,943 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,943 INFO sqlalchemy.engine.Engine [cached since 0.1743s ago] ('ZH_6', 1, 0)
# 2025-07-07 10:44:32,944 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,945 INFO sqlalchemy.engine.Engine [cached since 0.1759s ago] ('ZH_6', 1, 0)
# 2025-07-07 10:44:32,946 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,946 INFO sqlalchemy.engine.Engine [cached since 0.1771s ago] ('ZH_6', 1, 0)
# 2025-07-07 10:44:32,956 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# C:\Users\Elliot\AppData\Local\Temp\ipykernel_2016\3651024739.py:24: SAWarning: Object of type <GrammarRule> not in session, add operation along 'Unit.grammars' will not proceed (This warning originated from the Session 'autoflush' process, which was invoked automatically in response to a user-initiated operation. Consider using ``no_autoflush`` context manager if this warning happended while initializing objects.)
#   parent=session.query(Unit).filter(Unit.unit_id == f"{language_name.upper()}_{unit_id}").first()
# 2025-07-07 10:44:32,956 INFO sqlalchemy.engine.Engine [cached since 0.1881s ago] ('ZH_7', 1, 0)
# 2025-07-07 10:44:32,957 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,957 INFO sqlalchemy.engine.Engine [cached since 0.1894s ago] ('ZH_7', 1, 0)
# 2025-07-07 10:44:32,958 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,959 INFO sqlalchemy.engine.Engine [cached since 0.1904s ago] ('ZH_7', 1, 0)
# 2025-07-07 10:44:32,959 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,960 INFO sqlalchemy.engine.Engine [cached since 0.1916s ago] ('ZH_7', 1, 0)
# 2025-07-07 10:44:32,960 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,962 INFO sqlalchemy.engine.Engine [cached since 0.1929s ago] ('ZH_7', 1, 0)
# 2025-07-07 10:44:32,962 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,962 INFO sqlalchemy.engine.Engine [cached since 0.1939s ago] ('ZH_7', 1, 0)
# 2025-07-07 10:44:32,976 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,976 INFO sqlalchemy.engine.Engine [cached since 0.2074s ago] ('ZH_8', 1, 0)
# 2025-07-07 10:44:32,978 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,978 INFO sqlalchemy.engine.Engine [cached since 0.2089s ago] ('ZH_8', 1, 0)
# 2025-07-07 10:44:32,979 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,979 INFO sqlalchemy.engine.Engine [cached since 0.2101s ago] ('ZH_8', 1, 0)
# 2025-07-07 10:44:32,980 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,980 INFO sqlalchemy.engine.Engine [cached since 0.2112s ago] ('ZH_8', 1, 0)
# 2025-07-07 10:44:32,981 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,981 INFO sqlalchemy.engine.Engine [cached since 0.2124s ago] ('ZH_8', 1, 0)
# 2025-07-07 10:44:32,993 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,994 INFO sqlalchemy.engine.Engine [cached since 0.2247s ago] ('ZH_9', 1, 0)
# 2025-07-07 10:44:32,995 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,995 INFO sqlalchemy.engine.Engine [cached since 0.2261s ago] ('ZH_9', 1, 0)
# 2025-07-07 10:44:32,996 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,996 INFO sqlalchemy.engine.Engine [cached since 0.2276s ago] ('ZH_9', 1, 0)
# 2025-07-07 10:44:32,997 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,998 INFO sqlalchemy.engine.Engine [cached since 0.229s ago] ('ZH_9', 1, 0)
# 2025-07-07 10:44:32,998 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:32,998 INFO sqlalchemy.engine.Engine [cached since 0.2301s ago] ('ZH_9', 1, 0)
# 2025-07-07 10:44:32,999 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 10:44:33,000 INFO sqlalchemy.engine.Engine [cached since 0.2311s ago] ('ZH_9', 1, 0)
# 2025-07-07 10:44:33,000 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,002 INFO sqlalchemy.engine.Engine [generated in 0.00037s] ('ZH_1_G1', 'Conjuguer', 'Une des facilités de la langue chinoise est qu’elle ne contient pas de conjugaison. Conjuguer le verbe être se résume à :\n\n- 我是 (wǒ shì) : Je suis\ ... (318 characters truncated) ... . Si les verbes chinois ne se conjuguent pas, il existe tout de même quelques particules et suffixes verbaux permettant de contextualiser une phrase.', 0, '2025-07-07', 'ZH_1')
# 2025-07-07 10:44:33,004 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,006 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,007 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,007 INFO sqlalchemy.engine.Engine [generated in 0.00042s] ('ZH_1',)
# 2025-07-07 10:44:33,008 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,008 INFO sqlalchemy.engine.Engine [cached since 0.00709s ago] ('ZH_1_G2', 'Affirmation et négation', 'La construction de base est `Sujet/Verbe/Objet`. Pour dire « Je suis français », nous dirons simplement :\n\n- 我是法国人 (wǒ shì fǎguórén) (je/être/franç ... (459 characters truncated) ... e ton, mais 不 bú shì car 是 shì est au quatrième ton. Cette modification se fait uniquement à l’oral et n’est généralement pas inscrite sur le pinyin.', 0, '2025-07-07', 'ZH_1')
# 2025-07-07 10:44:33,009 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,011 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,012 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,012 INFO sqlalchemy.engine.Engine [cached since 0.005453s ago] ('ZH_1',)
# 2025-07-07 10:44:33,013 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,013 INFO sqlalchemy.engine.Engine [cached since 0.01197s ago] ('ZH_1_G3', "L'interrogation", '## Interroger avec 吗 (ma)\nEn règle générale, l’interrogation se forme avec le caractère 吗 (ma) que l’on place en fin de phrase. Il est l’équivalent  ... (1658 characters truncated) ... shénme ?) : « Quel est leur nom de famille ? »\n- 你叫什么？(Nǐ jiào shénme ?) : « Comment t’appelles-tu ? »\n- 他做什么？(Tā zuò shénme ?) : « Que fait-il ? »', 0, '2025-07-07', 'ZH_1')
# 2025-07-07 10:44:33,014 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,016 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,017 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,017 INFO sqlalchemy.engine.Engine [cached since 0.0102s ago] ('ZH_10',)
# 2025-07-07 10:44:33,017 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,018 INFO sqlalchemy.engine.Engine [cached since 0.01655s ago] ('ZH_10_G1', 'Indiquer le destinataire avec 给 gěi', "给 gěi, signifiant « donner », permet d'indiquer la cible d'une action.\n\nStructure : Sujet + 给 + cible + action\n\n* 你给我打电话 nǐ gěi wǒ dǎ diànhuà : « ... (45 characters truncated) ... i tā dǎ diànhuà : « Tu dois lui téléphoner »\n* 你给他写信 nǐ gěi tā xiěxìn : « Écris-lui une lettre »\n* 我给你做饭 wǒ gěi nǐ zuòfàn : « Je te fais à manger »", 0, '2025-07-07', 'ZH_10')
# 2025-07-07 10:44:33,018 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,021 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,021 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,022 INFO sqlalchemy.engine.Engine [cached since 0.01484s ago] ('ZH_10',)
# 2025-07-07 10:44:33,022 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,022 INFO sqlalchemy.engine.Engine [cached since 0.02152s ago] ('ZH_10_G2', '"Pouvoir" avec 能 néng ou 可以 kěyǐ', "Plusieurs verbes existent pour exprimer la possibilité, cependant ils ne peuvent pas s'employer de la même manière. Nous avons déjà étudié le verbe 会 ... (795 characters truncated) ... 停车吗？wǒ zài zhèr kěyǐ tíngchē ma ? : « Puis-je garer ma voiture ici ? »\n* 妈妈，我可以出去吗？māma, wǒ kěyǐ chūqù ma ? : « Maman, est-ce que je peux sortir ? »", 0, '2025-07-07', 'ZH_10')
# 2025-07-07 10:44:33,023 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,025 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,026 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,026 INFO sqlalchemy.engine.Engine [cached since 0.01949s ago] ('ZH_10',)
# 2025-07-07 10:44:33,027 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,027 INFO sqlalchemy.engine.Engine [cached since 0.02619s ago] ('ZH_10_G3', 'La condition avec 如果 ... 的话 rúguǒ ... de huà et 就 jiù', "如果 ... 的话 rúguǒ ... de huà et 就 jiù sont utilisés, ensemble ou séparément, afin d'introduire une condition et sa conséquence.\n\nStructure : 如果 + Suj ... (135 characters truncated) ... , appelle le médecin »\n* 如果他生病的话，他就不能去工作 rúguǒ tā shēngbìng de huà, tā jiù bù néng qù gōngzuò : « S'il est malade, il ne peut pas aller travailler »", 0, '2025-07-07', 'ZH_10')
# 2025-07-07 10:44:33,028 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,030 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,031 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,031 INFO sqlalchemy.engine.Engine [cached since 0.02443s ago] ('ZH_10',)
# 2025-07-07 10:44:33,032 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,033 INFO sqlalchemy.engine.Engine [cached since 0.03218s ago] ('ZH_10_G4', "Le comparatif d'égalité", "Nous avons étudié dans la leçon 7 les comparatifs de supériorité ou d'infériorité en utilisant le caractère 比 bǐ. Il ne faut pas employer 比 pour intr ... (338 characters truncated) ... la mienne »\n* 今天的会议和昨天的会议一样无聊 jīntiān de huìyì hé zuótiān de huìyì yīyàng wúliáo : « La réunion d'aujourd'hui est aussi ennuyeuse que celle d'hier »", 0, '2025-07-07', 'ZH_10')
# 2025-07-07 10:44:33,034 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,036 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,036 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,037 INFO sqlalchemy.engine.Engine [cached since 0.03004s ago] ('ZH_10',)
# 2025-07-07 10:44:33,037 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,037 INFO sqlalchemy.engine.Engine [cached since 0.03654s ago] ('ZH_10_G5', '"Encore, toujours" avec 还 hái', "还 hái peut être utilisé seul ou bien accompagné de 在 zài pour marquer qu'une action est « encore, toujours » en cours. On peut aussi l'utiliser avec  ... (391 characters truncated) ... »\n* 我还不会说中文 wǒ hái bù huì shuō zhōngwén : « Je ne sais toujours pas parler chinois »\n* 我还没有吃饭 wǒ hái méiyǒu chīfàn : « Je n'ai toujours pas mangé »", 0, '2025-07-07', 'ZH_10')
# 2025-07-07 10:44:33,038 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,040 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,041 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,041 INFO sqlalchemy.engine.Engine [cached since 0.03494s ago] ('ZH_10',)
# 2025-07-07 10:44:33,041 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,043 INFO sqlalchemy.engine.Engine [cached since 0.04161s ago] ('ZH_10_G6', '"Venir" avec 来 lái', "Le verbe 来 lái signifie « venir » et doit être utilisé lorsque l'on se rapproche de son interlocuteur.\n\n* 你来饭馆吃饭吗？nǐ lái fànguǎn chīfàn ma ? : « Vi ... (214 characters truncated) ... inverse, si l'interlocuteur s'éloigne, on utilisera le verbe 去 qù (« aller »), car il indique un déplacement vers un lieu éloigné de celui qui parle.", 0, '2025-07-07', 'ZH_10')
# 2025-07-07 10:44:33,044 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,047 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,047 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,048 INFO sqlalchemy.engine.Engine [cached since 0.0408s ago] ('ZH_11',)
# 2025-07-07 10:44:33,048 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,048 INFO sqlalchemy.engine.Engine [cached since 0.04734s ago] ('ZH_11_G1', 'Énumérer avec 第 dì', "第 dì permet de former des chiffres et nombres ordinaux.\nIl s'emploie de la façon suivante :\n\n第 + chiffre/nombre ( + Classificateur )\n\n* 第一 dì yī ... (918 characters truncated) ... s deux mots suivants signifient « étage » et peuvent s'employer sans 第 dì :\n\n* 三楼 sān lóu : « Troisième étage »\n* 四层 sì céng : « Quatrième étage »", 0, '2025-07-07', 'ZH_11')
# 2025-07-07 10:44:33,049 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,051 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,052 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,052 INFO sqlalchemy.engine.Engine [cached since 0.04508s ago] ('ZH_11',)
# 2025-07-07 10:44:33,052 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,053 INFO sqlalchemy.engine.Engine [cached since 0.05166s ago] ('ZH_11_G2', 'Exprimer une distance avec 离 lí', "离 lí est utilisé lorsqu'on souhaite exprimer une distance entre deux points. Il peut se traduire par « par rapport à ». La structure à employer, très ... (589 characters truncated) ... ē zhàn lí zhèr tài yuǎn le : « La gare est trop éloignée d’ici »\n* 酒吧离我的家比较远 jiǔbā lí wǒ de jiā bǐjiào yuǎn : « Le bar est plutôt loin de chez moi »", 0, '2025-07-07', 'ZH_11')
# 2025-07-07 10:44:33,053 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,055 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,056 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,056 INFO sqlalchemy.engine.Engine [cached since 0.049s ago] ('ZH_11',)
# 2025-07-07 10:44:33,056 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,057 INFO sqlalchemy.engine.Engine [cached since 0.05555s ago] ('ZH_11_G3', 'Se diriger, suivre un itinéraire', 'Savoir utiliser les termes « droite », « gauche » et « tout droit » suffit pour se repérer, demander son chemin et comprendre un itinéraire. Lorsqu’o ... (238 characters truncated) ... tout droit »\n* 你先往前走一百米，然后往左拐 nǐ xiān wǎng qián zǒu yī bǎi mǐ, ránhòu wǎng zuǒ guǎi : « Va d’abord tout droit sur 100 mètres, puis tourne à gauche »', 0, '2025-07-07', 'ZH_11')
# 2025-07-07 10:44:33,058 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,060 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,060 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,061 INFO sqlalchemy.engine.Engine [cached since 0.05367s ago] ('ZH_11',)
# 2025-07-07 10:44:33,061 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,062 INFO sqlalchemy.engine.Engine [cached since 0.06044s ago] ('ZH_11_G4', "À l'intérieur de quelque chose", 'Pour indiquer que quelque chose se situe à l’intérieur de quelque chose d’autre, on utilise la structure suivante :\n\nNom 1 + 在 + Nom 2 + 里面\n\n* 你在 ... (240 characters truncated) ...  shàng ma ? : « Es-tu dans le bus ? »\n* 我在车上 wǒ zài chē shàng : « Je suis dans la voiture »\n* 我在火车上 wǒ zài huǒchē shàng : « Je suis dans le train »', 0, '2025-07-07', 'ZH_11')
# 2025-07-07 10:44:33,062 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,064 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,065 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,065 INFO sqlalchemy.engine.Engine [cached since 0.05812s ago] ('ZH_12',)
# 2025-07-07 10:44:33,065 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,066 INFO sqlalchemy.engine.Engine [cached since 0.0648s ago] ('ZH_12_G1', 'Atténuation avec ou sans 一 yī', "Il est possible de redoubler un verbe afin d'atténuer son propos :\n\n* 你看看 nǐ kàn kan : « Regarde un peu »\n* 你试试 nǐ shì shi : « Essaye un peu »\n*  ... (349 characters truncated) ... n* 给我说一说 gěi wǒ shuō yī shuō : « Dis-moi un peu »\n* 我可以用一用你的手机吗？wǒ kěyǐ yòng yī yòng nǐ de shǒujī ma ? : « Puis-je utiliser un peu ton téléphone ? »", 0, '2025-07-07', 'ZH_12')
# 2025-07-07 10:44:33,067 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,069 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,069 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,070 INFO sqlalchemy.engine.Engine [cached since 0.06293s ago] ('ZH_12',)
# 2025-07-07 10:44:33,070 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,071 INFO sqlalchemy.engine.Engine [cached since 0.07033s ago] ('ZH_12_G2', 'Classificateurs ne pouvant pas être remplacés par 个 gè', "Certains classificateurs ne peuvent pas être remplacés par 个 gè (qui est, pour rappel, le classificateur universel), car ils apportent un sens partic ... (274 characters truncated) ...  gè niǎo : « Un oiseau »\n* 一群鸟 yī qún niǎo : « Un vol d’oiseaux »\n* 一些人 yī xiē rén : « Quelques personnes »\n* 一杯水 yī bēi shuǐ : « Un verre d’eau »", 0, '2025-07-07', 'ZH_12')
# 2025-07-07 10:44:33,072 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,074 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,075 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,076 INFO sqlalchemy.engine.Engine [cached since 0.06879s ago] ('ZH_12',)
# 2025-07-07 10:44:33,076 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,076 INFO sqlalchemy.engine.Engine [cached since 0.07542s ago] ('ZH_12_G3', 'Permettre quelque chose avec 让 ràng', "让 ràng est un verbe dit « causatif », qui peut être traduit par « laisser » ou « permettre » en français.\n\nStructure : Sujet + 让 + Personne/Objet + ... (128 characters truncated) ...  papa ne te laisse-t-il pas y aller ? »\n* 看 Titanic 电影让我很感动 kàn Titanic diànyǐng ràng wǒ hěn gǎndòng : « Regarder le film Titanic m'a beaucoup ému »", 0, '2025-07-07', 'ZH_12')
# 2025-07-07 10:44:33,077 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,080 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,080 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,080 INFO sqlalchemy.engine.Engine [cached since 0.07374s ago] ('ZH_12',)
# 2025-07-07 10:44:33,081 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,082 INFO sqlalchemy.engine.Engine [cached since 0.08066s ago] ('ZH_12_G4', 'Demander « combien » avec 多少 duōshǎo ou 几 jǐ', "Il existe deux façons principales de demander « combien » : 多少 duōshǎo et 几 jǐ. Voici leurs différences :\n\n* 几 jǐ est utilisé pour des quantités gé ... (695 characters truncated) ...  ici »\n* 我有十多元 wǒ yǒu shí duō yuán : « J’ai un peu plus de dix yuans »\n* 我有三十多块钱 wǒ yǒu sānshí duō kuài qián : « J’ai un peu plus de trente kuais »", 0, '2025-07-07', 'ZH_12')
# 2025-07-07 10:44:33,083 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,085 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,086 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,086 INFO sqlalchemy.engine.Engine [cached since 0.07911s ago] ('ZH_12',)
# 2025-07-07 10:44:33,087 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,087 INFO sqlalchemy.engine.Engine [cached since 0.08581s ago] ('ZH_12_G5', '« Quelques » avec 一些 yīxiē', "一些 yīxiē signifie « quelques » ou « certains » et désigne une quantité indéterminée. Il s'utilise selon le schéma suivant :\n\n一些 + Nom\n\n* 有一些人 yǒu yīxiē rén : « Il y a quelques personnes »\n* 爸爸买了一些书 bàba mǎi le yīxiē shū : « Papa a acheté quelques livres »", 0, '2025-07-07', 'ZH_12')
# 2025-07-07 10:44:33,088 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,090 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,091 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,091 INFO sqlalchemy.engine.Engine [cached since 0.08372s ago] ('ZH_13',)
# 2025-07-07 10:44:33,091 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,092 INFO sqlalchemy.engine.Engine [cached since 0.09044s ago] ('ZH_13_G1', 'Action révolue avec 了 le', "Vous aurez sûrement remarqué l'utilisation du caractère 了 le, notamment dans les exemples des différentes parties grammaire et méthodologie. Le carac ... (1114 characters truncated) ... e voulais avant)\n\n了 le a d'autres utilisations, il est par exemple employé lorsqu'une action est sur le point de se produire (cf. 快要...了 ci-après).", 0, '2025-07-07', 'ZH_13')
# 2025-07-07 10:44:33,093 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,095 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,095 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,096 INFO sqlalchemy.engine.Engine [cached since 0.0887s ago] ('ZH_13',)
# 2025-07-07 10:44:33,096 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,097 INFO sqlalchemy.engine.Engine [cached since 0.09548s ago] ('ZH_13_G2', '"Pendant" avec 的时候 de shíhòu', "的时候 de shíhòu est utilisé en fin de proposition et signifie « quand », « pendant que », « lors de... ». Son placement en fin de proposition mérite un ... (588 characters truncated) ... ger pendant qu'elles travaillent »\n* 你在市中心的时候给我打电话 nǐ zài shìzhōngxīn de shíhòu gěi wǒ dǎ diànhuà : « Appelle-moi quand tu es dans le centre-ville »", 0, '2025-07-07', 'ZH_13')
# 2025-07-07 10:44:33,097 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,099 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,099 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,100 INFO sqlalchemy.engine.Engine [cached since 0.09349s ago] ('ZH_13',)
# 2025-07-07 10:44:33,100 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,100 INFO sqlalchemy.engine.Engine [cached since 0.1003s ago] ('ZH_13_G3', '"Avant" et "après" avec 以前 yǐqián et 以后 yǐhòu', "以前 yǐqián et 以后 yǐhòu s'emploient également en fin de proposition et permettent de décrire quelque chose qui se passe avant ou après un moment donné. ... (811 characters truncated) ...  plus tard ? »\n* 我以前住在巴黎 wǒ yǐqián zhù zài Bālí : « Avant, j'habitais à Paris »\n* 他以前没有钱 tā yǐqián méiyǒu qián : « Avant, il n'avait pas d'argent »", 0, '2025-07-07', 'ZH_13')
# 2025-07-07 10:44:33,102 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,104 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,105 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,105 INFO sqlalchemy.engine.Engine [cached since 0.09872s ago] ('ZH_13',)
# 2025-07-07 10:44:33,106 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,106 INFO sqlalchemy.engine.Engine [cached since 0.1055s ago] ('ZH_13_G4', '"Être sur le point de" avec 快要 ... 了 kuài yào ... le', 'La structure 快要...了 kuài yào... le est employée pour signifier que quelque chose va bientôt arriver.\n\nSujet + 快要 + Verbe/action + 了\n\n* 天快要黑了 tiān ... (90 characters truncated) ...  bientôt arriver »\n* 快要下雨了 kuài yào xià yǔ le : « Il va bientôt pleuvoir »\n* 我快要回家了 wǒ kuài yào huíjiā le : « Je vais bientôt rentrer à la maison »', 0, '2025-07-07', 'ZH_13')
# 2025-07-07 10:44:33,107 INFO sqlalchemy.engine.Engine COMMIT
# ...
# 2025-07-07 10:44:33,325 INFO sqlalchemy.engine.Engine [cached since 0.3243s ago] ('ZH_7_G3', 'Quelle(s) langue(s) sais-tu parler ?', "En général, on forme le nom d'une langue en ajoutant 语 yǔ (ou 文 wén) au nom du pays.\n\nPour les pays finissant par 国 guó, on remplace 国 guó par 语 yǔ ... (342 characters truncated) ... :\n\n* 中国 Zhōngguó (Chine) → 中文 Zhōngwén (chinois)\n* 汉语 Hànyǔ (chinois)\n\nNote : 汉语 Hànyǔ (chinois) et 韩语 Hányǔ (coréen) se prononcent très proche.", 0, '2025-07-07', 'ZH_7')
# 2025-07-07 10:44:33,326 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,329 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,329 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,330 INFO sqlalchemy.engine.Engine [cached since 0.3231s ago] ('ZH_7',)
# 2025-07-07 10:44:33,331 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,331 INFO sqlalchemy.engine.Engine [cached since 0.3299s ago] ('ZH_7_G4', 'Les adverbes 最 zuì et 太 ... 了 tài...le', "Les adverbes 最 zuì et 太 ... 了 tài...le s'emploient comme 很 hěn devant un adjectif, mais nuancent ou renforcent le propos :\n\n* 我很累 wǒ hěn lèi : « Je ... (11 characters truncated) ... ué »\n* 最累 zuì lèi : « Le plus fatigué »\n* 我太累了 wǒ tài lèi le : « Je suis trop fatigué »\n* 我不太累了 wǒ bù tài lèi le : « Je ne suis pas trop fatigué »", 0, '2025-07-07', 'ZH_7')
# 2025-07-07 10:44:33,331 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,334 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,335 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,336 INFO sqlalchemy.engine.Engine [cached since 0.3289s ago] ('ZH_7',)
# 2025-07-07 10:44:33,336 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,336 INFO sqlalchemy.engine.Engine [cached since 0.3358s ago] ('ZH_7_G5', 'Tout, toutes et tous avec 都 dōu', 'Le caractère 都 peut se prononcer « dū » (dans 首都 shǒudū « capitale ») ou « dōu » quand il signifie « tout, tous ». Il se place directement après le n ... (122 characters truncated) ... ōu xiǎng qù Zhōngguó : « Nous voulons tous aller en Chine »\n* 我的朋友都 wǒ de péngyou dōu : « Tous mes amis »\n* 女生都 nǚshēng dōu : « Toutes les filles »', 0, '2025-07-07', 'ZH_7')
# 2025-07-07 10:44:33,337 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,340 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,340 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,340 INFO sqlalchemy.engine.Engine [cached since 0.3343s ago] ('ZH_7',)
# 2025-07-07 10:44:33,342 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,342 INFO sqlalchemy.engine.Engine [cached since 0.3414s ago] ('ZH_7_G6', 'Ensemble avec 一起 yīqǐ', '一起 yīqǐ a déjà été vu dans la structure 跟 gēn ... + 一起 yīqǐ (page 109) pour dire « avec ». 一起 yīqǐ peut aussi être utilisé seul et signifie « ensembl ... (50 characters truncated) ...  Elles vont regarder un film ensemble »\n* 我们一起去北京 wǒmen yīqǐ qù Běijīng : « Nous allons ensemble à Pékin »\n\nStructure : Sujet + 一起 + Verbe + Objet', 0, '2025-07-07', 'ZH_7')
# 2025-07-07 10:44:33,344 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,346 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,347 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,347 INFO sqlalchemy.engine.Engine [cached since 0.3405s ago] ('ZH_8',)
# 2025-07-07 10:44:33,348 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,348 INFO sqlalchemy.engine.Engine [cached since 0.3474s ago] ('ZH_8_G1', "Le complément d'appréciation 得 de", "L'utilisation du caractère 得 de en tant que complément d'appréciation est relativement difficile car elle ne comporte pas d'équivalent en français. 得 ... (1124 characters truncated) ... 打网球打得不好 nǐ dǎ wǎngqiú dǎ de bù hǎo : « Tu ne joues pas bien au tennis »\n\nLa prononciation du 得 d'appréciation est identique à celle du 的 possessif.", 0, '2025-07-07', 'ZH_8')
# 2025-07-07 10:44:33,349 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,352 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,352 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,353 INFO sqlalchemy.engine.Engine [cached since 0.346s ago] ('ZH_8',)
# 2025-07-07 10:44:33,354 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,354 INFO sqlalchemy.engine.Engine [cached since 0.3532s ago] ('ZH_8_G2', '"Depuis... jusqu\'à..." avec 从 cóng et 到 dào', "从 cóng et 到 dào fonctionnent de la même façon que « depuis » et « jusqu'à » en français et peuvent être utilisés dans les mêmes contextes :\n\n* 从这里到 ... (67 characters truncated) ...  diǎn dào shí diǎn : « De huit heures à dix heures »\n* 从我的家到我的朋友的家 cóng wǒ de jiā dào wǒ de péngyou de jiā : « De ma maison à la maison de mon ami »", 0, '2025-07-07', 'ZH_8')
# 2025-07-07 10:44:33,355 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,357 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,358 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,358 INFO sqlalchemy.engine.Engine [cached since 0.3517s ago] ('ZH_8',)
# 2025-07-07 10:44:33,359 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,359 INFO sqlalchemy.engine.Engine [cached since 0.3584s ago] ('ZH_8_G3', '"Comment ?" avec 怎么 zěnme et 怎么样 zěnmeyàng', "**怎么 zěnme**\n怎么 zěnme est généralement utilisé avec un verbe.\n\n* 怎么说？ zěnme shuō? : « Comment dire ? »\n* 我怎么去？ wǒ zěnme qù? : « Comment y vais-je ... (414 characters truncated) ... 么样？ nǐ de māma zěnmeyàng? : « Comment va ta mère ? »\n* 我们一起去吃饭，怎么样？ wǒmen yīqǐ qù chīfàn, zěnmeyàng? : « Allons manger ensemble, qu'en penses-tu ? »", 0, '2025-07-07', 'ZH_8')
# 2025-07-07 10:44:33,361 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,363 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,363 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,364 INFO sqlalchemy.engine.Engine [cached since 0.3571s ago] ('ZH_8',)
# 2025-07-07 10:44:33,364 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,364 INFO sqlalchemy.engine.Engine [cached since 0.3639s ago] ('ZH_8_G4', '"Alors" avec 那 nà', "Nous avons déjà vu le caractère 那 nà en tant que démonstratif avec des mots comme 那里 nàlǐ signifiant « là-bas » ou encore 那个人 nà ge rén pour « cette  ... (131 characters truncated) ... ànyǐng : « Je ne souhaite pas aller regarder un film »\n\n那，我们不去看电影 nà, wǒmen bù qù kàn diànyǐng : « Dans ce cas, nous n'irons pas regarder un film »", 0, '2025-07-07', 'ZH_8')
# 2025-07-07 10:44:33,366 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,368 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,369 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,370 INFO sqlalchemy.engine.Engine [cached since 0.3629s ago] ('ZH_8',)
# 2025-07-07 10:44:33,370 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,370 INFO sqlalchemy.engine.Engine [cached since 0.3697s ago] ('ZH_8_G5', '"Seulement" avec 才 cái', "L'adverbe 才 cái est généralement utilisé pour les petits nombres ou les petites fréquences.\n\n* 这里才四个人 zhèlǐ cái sì gè rén : « Il n'y a que 4 person ... (71 characters truncated) ... que deux personnes »\n* 我喜欢踢足球，可是我星期六才踢 wǒ xǐhuan tī zúqiú, kěshì wǒ xīngqīliù cái tī : « J'aime faire du football, mais je n'en fais que le samedi »", 0, '2025-07-07', 'ZH_8')
# 2025-07-07 10:44:33,372 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,375 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,375 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,376 INFO sqlalchemy.engine.Engine [cached since 0.3686s ago] ('ZH_9',)
# 2025-07-07 10:44:33,376 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,377 INFO sqlalchemy.engine.Engine [cached since 0.3754s ago] ('ZH_9_G1', 'Moyens de transport', "Si en français nous employons généralement le verbe « prendre » lorsqu'il s'agit des moyens de transport, il convient d'utiliser le verbe 坐 zuò « s'a ... (471 characters truncated) ...  véhicule, il faut employer 开 kāi « conduire, ouvrir » :\n\n* 我开车 wǒ kāi chē : « Je conduis la voiture »\n* 我开飞机 wǒ kāi fēijī : « Je pilote l'avion »", 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:33,378 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,380 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,381 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,381 INFO sqlalchemy.engine.Engine [cached since 0.3739s ago] ('ZH_9',)
# 2025-07-07 10:44:33,382 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,382 INFO sqlalchemy.engine.Engine [cached since 0.3808s ago] ('ZH_9_G2', '"Chaque" avec 每 měi', '每 měi est employé dans la majorité des cas avec un classificateur derrière :\n\n* 每个人 měi gè rén : « Chaque personne »\n* 每个月 měi gè yuè : « Chaque m ... (100 characters truncated) ... it pas être employé dans les trois cas suivants :\n\n* 每年 měi nián : « Chaque année »\n* 每天 měi tiān : « Chaque jour »\n* 每日 měi rì : « Chaque jour »', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:33,383 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,385 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,386 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,386 INFO sqlalchemy.engine.Engine [cached since 0.379s ago] ('ZH_9',)
# 2025-07-07 10:44:33,386 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,387 INFO sqlalchemy.engine.Engine [cached since 0.3857s ago] ('ZH_9_G3', '"D\'abord... ensuite..." avec 先 xiān et 然后 ránhòu', "先 xiān « premièrement », et 然后 ránhòu « ensuite » peuvent être utilisés ensemble pour indiquer que deux événements se succèdent :\n\n* 我们先吃饭，然后看电视 wǒ ... (220 characters truncated) ... emièrement » peut également être utilisé seul :\n\n* 他先到了 tā xiān dào le : « Il est arrivé en premier »\n* 我先说 wǒ xiān shuō : « Je parle en premier »", 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:33,388 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,390 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,390 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,391 INFO sqlalchemy.engine.Engine [cached since 0.3838s ago] ('ZH_9',)
# 2025-07-07 10:44:33,391 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,391 INFO sqlalchemy.engine.Engine [cached since 0.3903s ago] ('ZH_9_G4', '"Un petit peu" avec 有点儿 yǒu diǎnr ou 一点儿 yī diǎnr', "**有点儿 yǒu diǎnr**\n有点儿 yǒu diǎnr ou simplement 有点 yǒu diǎn est utilisé avant un adjectif. Il est généralement employé dans des phrases négatives, pou ... (499 characters truncated) ... 宜一点儿 nǐ piányi yī diǎnr : « Baisse un peu le prix »\n* 你快一点儿 nǐ kuài yī diǎnr : « Dépêche-toi un peu »\n* 你慢一点儿 nǐ màn yī diǎnr : « Ralentis un peu »", 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:33,392 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,394 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,394 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,395 INFO sqlalchemy.engine.Engine [cached since 0.3881s ago] ('ZH_9',)
# 2025-07-07 10:44:33,395 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,395 INFO sqlalchemy.engine.Engine [cached since 0.3945s ago] ('ZH_9_G5', 'Utiliser 比较 bǐjiào devant un verbe', "Nous avons vu dans la leçon précédente que l'adverbe 比较 bǐjiào signifie « relativement, plutôt » et qu'il était employé devant un adjectif afin de le ... (162 characters truncated) ... iào xǐhuan : « Je préfère »\n* 我不喜欢坐车，我比较喜欢走路 wǒ bù xǐhuan zuò chē, wǒ bǐjiào xǐhuan zǒulù : « Je n'aime pas prendre la voiture, je préfère marcher »", 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:33,397 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 10:44:33,398 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 10:44:33,399 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 10:44:33,399 INFO sqlalchemy.engine.Engine [cached since 0.3927s ago] ('ZH_9',)
# 2025-07-07 10:44:33,400 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 10:44:33,400 INFO sqlalchemy.engine.Engine [cached since 0.3996s ago] ('ZH_9_G6', 'Les particules modales placées en fin de phrase', 'Quelques particules modales sont habituellement rajoutées en fin de phrase pour donner un ton particulier à la phrase, en voici quelques exemples :\n ... (334 characters truncated) ... .\n\nIl existe également des interjections placées en début de phrase :\n\n* 嗯 en : équivalent du « hum... » français\n* 哎呀 āiyā : marque la surprise', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 10:44:33,402 INFO sqlalchemy.engine.Engine COMMIT
