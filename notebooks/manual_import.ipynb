# %%
import json
import pandas as pd
import os
import re
from lapp.dbms import init_db, inserts, modify, delete, find_by_attr, insert
from lapp.tables import Unit, Vocabulary, GrammarRule, Language, CalligraphyCharacter

# %%
language_id = "de"

# %% [markdown]
# ## Create a Language

# %%
# Check if the db folder exists, if not create it
if not os.path.exists("../db"):
    os.makedirs("../db")
    print(f"Created directory for database: ../db")

engine, session = init_db()

language = Language(
    id=language_id.upper(),
    name="German",
    native_name="Deutsch",
    level="A1",
    flag="🇩🇪"
)
insert(session, language)

session.close()
# Out:
# 2025-07-23 23:27:54,854 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:54,854 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("language")
# 2025-07-23 23:27:54,855 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:54,855 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("language")
# 2025-07-23 23:27:54,856 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:54,856 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-23 23:27:54,857 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:54,857 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("unit")
# 2025-07-23 23:27:54,857 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:54,858 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-23 23:27:54,858 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:54,858 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("calligraphy_character")
# 2025-07-23 23:27:54,858 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:54,859 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-23 23:27:54,859 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:54,859 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("grammar_rule")
# 2025-07-23 23:27:54,859 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:54,859 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-23 23:27:54,860 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:54,860 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("vocabulary")
# 2025-07-23 23:27:54,860 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:54,861 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-23 23:27:54,861 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:54,861 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("exercises")
# 2025-07-23 23:27:54,861 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:54,862 INFO sqlalchemy.engine.Engine
# CREATE TABLE language (
# 	id VARCHAR NOT NULL,
# 	name VARCHAR,
# 	native_name VARCHAR,
# 	level VARCHAR,
# 	description VARCHAR,
# 	score INTEGER,
# 	last_seen DATE,
# 	flag VARCHAR,
# 	current_unit VARCHAR,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(current_unit) REFERENCES unit (id)
# )
#
#
# 2025-07-23 23:27:54,862 INFO sqlalchemy.engine.Engine [no key 0.00035s] ()
# 2025-07-23 23:27:54,863 INFO sqlalchemy.engine.Engine CREATE INDEX ix_language_id ON language (id)
# 2025-07-23 23:27:54,863 INFO sqlalchemy.engine.Engine [no key 0.00018s] ()
# 2025-07-23 23:27:54,864 INFO sqlalchemy.engine.Engine CREATE INDEX ix_language_name ON language (name)
# 2025-07-23 23:27:54,864 INFO sqlalchemy.engine.Engine [no key 0.00012s] ()
# 2025-07-23 23:27:54,865 INFO sqlalchemy.engine.Engine
# CREATE TABLE unit (
# 	id VARCHAR NOT NULL,
# 	title VARCHAR,
# 	description VARCHAR,
# 	level VARCHAR,
# 	score INTEGER,
# 	last_seen DATE,
# 	language_id VARCHAR NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(language_id) REFERENCES language (id)
# )
#
#
# 2025-07-23 23:27:54,865 INFO sqlalchemy.engine.Engine [no key 0.00014s] ()
# 2025-07-23 23:27:54,865 INFO sqlalchemy.engine.Engine CREATE INDEX ix_unit_id ON unit (id)
# 2025-07-23 23:27:54,865 INFO sqlalchemy.engine.Engine [no key 0.00012s] ()
# 2025-07-23 23:27:54,866 INFO sqlalchemy.engine.Engine CREATE INDEX ix_unit_title ON unit (title)
# 2025-07-23 23:27:54,866 INFO sqlalchemy.engine.Engine [no key 0.00013s] ()
# 2025-07-23 23:27:54,867 INFO sqlalchemy.engine.Engine
# CREATE TABLE calligraphy_character (
# 	id VARCHAR NOT NULL,
# 	character VARCHAR,
# 	components VARCHAR,
# 	phonetic VARCHAR,
# 	meaning VARCHAR,
# 	example_word VARCHAR,
# 	score INTEGER,
# 	last_seen DATE,
# 	unit_id VARCHAR NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(unit_id) REFERENCES unit (id)
# )
#
#
# 2025-07-23 23:27:54,867 INFO sqlalchemy.engine.Engine [no key 0.00019s] ()
# 2025-07-23 23:27:54,867 INFO sqlalchemy.engine.Engine CREATE INDEX ix_calligraphy_character_character ON calligraphy_character (character)
# 2025-07-23 23:27:54,868 INFO sqlalchemy.engine.Engine [no key 0.00047s] ()
# 2025-07-23 23:27:54,869 INFO sqlalchemy.engine.Engine CREATE INDEX ix_calligraphy_character_id ON calligraphy_character (id)
# 2025-07-23 23:27:54,869 INFO sqlalchemy.engine.Engine [no key 0.00054s] ()
# 2025-07-23 23:27:54,870 INFO sqlalchemy.engine.Engine
# CREATE TABLE grammar_rule (
# 	id VARCHAR NOT NULL,
# 	title VARCHAR,
# 	explanation VARCHAR,
# 	score INTEGER,
# 	last_seen DATE,
# 	unit_id VARCHAR NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(unit_id) REFERENCES unit (id)
# )
#
#
# 2025-07-23 23:27:54,871 INFO sqlalchemy.engine.Engine [no key 0.00024s] ()
# 2025-07-23 23:27:54,871 INFO sqlalchemy.engine.Engine CREATE INDEX ix_grammar_rule_title ON grammar_rule (title)
# 2025-07-23 23:27:54,871 INFO sqlalchemy.engine.Engine [no key 0.00013s] ()
# 2025-07-23 23:27:54,872 INFO sqlalchemy.engine.Engine CREATE INDEX ix_grammar_rule_id ON grammar_rule (id)
# 2025-07-23 23:27:54,872 INFO sqlalchemy.engine.Engine [no key 0.00012s] ()
# 2025-07-23 23:27:54,873 INFO sqlalchemy.engine.Engine
# CREATE TABLE vocabulary (
# 	id VARCHAR NOT NULL,
# 	word VARCHAR,
# 	translation VARCHAR,
# 	phonetic VARCHAR,
# 	example_sentence VARCHAR,
# 	type VARCHAR,
# 	score INTEGER,
# 	last_seen DATE,
# 	unit_id VARCHAR NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(unit_id) REFERENCES unit (id)
# )
#
#
# 2025-07-23 23:27:54,873 INFO sqlalchemy.engine.Engine [no key 0.00013s] ()
# 2025-07-23 23:27:54,873 INFO sqlalchemy.engine.Engine CREATE INDEX ix_vocabulary_id ON vocabulary (id)
# 2025-07-23 23:27:54,874 INFO sqlalchemy.engine.Engine [no key 0.00016s] ()
# 2025-07-23 23:27:54,874 INFO sqlalchemy.engine.Engine CREATE INDEX ix_vocabulary_word ON vocabulary (word)
# 2025-07-23 23:27:54,874 INFO sqlalchemy.engine.Engine [no key 0.00013s] ()
# 2025-07-23 23:27:54,875 INFO sqlalchemy.engine.Engine
# CREATE TABLE exercises (
# 	id VARCHAR NOT NULL,
# 	exercise_type VARCHAR,
# 	question VARCHAR,
# 	support VARCHAR,
# 	answer VARCHAR,
# 	score INTEGER,
# 	last_seen DATE,
# 	unit_id VARCHAR NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(unit_id) REFERENCES unit (id)
# )
#
#
# 2025-07-23 23:27:54,875 INFO sqlalchemy.engine.Engine [no key 0.00013s] ()
# 2025-07-23 23:27:54,877 INFO sqlalchemy.engine.Engine CREATE INDEX ix_exercises_exercise_type ON exercises (exercise_type)
# 2025-07-23 23:27:54,878 INFO sqlalchemy.engine.Engine [no key 0.00116s] ()
# 2025-07-23 23:27:54,881 INFO sqlalchemy.engine.Engine CREATE INDEX ix_exercises_id ON exercises (id)
# 2025-07-23 23:27:54,881 INFO sqlalchemy.engine.Engine [no key 0.00031s] ()
# 2025-07-23 23:27:54,883 INFO sqlalchemy.engine.Engine CREATE INDEX ix_exercises_question ON exercises (question)
# 2025-07-23 23:27:54,883 INFO sqlalchemy.engine.Engine [no key 0.00040s] ()
# 2025-07-23 23:27:54,884 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:54,885 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:54,886 INFO sqlalchemy.engine.Engine INSERT INTO language (id, name, native_name, level, description, score, last_seen, flag, current_unit) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:54,886 INFO sqlalchemy.engine.Engine [generated in 0.00029s] ('ZH', 'Chinois', '中文', 'A1', '', 0, '2025-07-23', '🇨🇳', None)
# 2025-07-23 23:27:54,888 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Add Units

# %%
# Initialize the database connection and create db file if it doesn't exist
engine, session = init_db()

# Initialize the database
with open(f'../assets/data/{language_id}/units.json', 'r', encoding="utf8") as f:
    units_array = json.load(f)
    
units = []
for idx, unit_data in enumerate(units_array):
    units.append(
        Unit(
            id = f"{language_id.upper()}_{idx}",
            title = unit_data['title'],
            description = unit_data['description'],
            level = unit_data['level'],
            parent = language,
        )
    )
inserts(session, units)
session.close()
# Out:
# 2025-07-23 23:27:54,893 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:54,894 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("language")
# 2025-07-23 23:27:54,894 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:54,894 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-23 23:27:54,897 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:54,898 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-23 23:27:54,898 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:54,899 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-23 23:27:54,899 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:54,899 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-23 23:27:54,900 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:54,900 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-23 23:27:54,901 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:54,902 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:54,907 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:54,909 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-23 23:27:54,910 INFO sqlalchemy.engine.Engine [generated in 0.00122s] ('ZH',)
# 2025-07-23 23:27:54,913 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:54,914 INFO sqlalchemy.engine.Engine [generated in 0.00087s] ('ZH_0', 'Lecon introductive: Bonjour!', "A l'oral: Connaitre les salutations de base. \n\nA l'ecrit: 5 caracteres", 'A1', 0, '2025-07-23', 'ZH')
# 2025-07-23 23:27:54,915 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:54,915 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:54,917 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-23 23:27:54,920 INFO sqlalchemy.engine.Engine [generated in 0.00385s] ('ZH',)
# 2025-07-23 23:27:54,921 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:54,922 INFO sqlalchemy.engine.Engine [cached since 0.009066s ago] ('ZH_1', "Unite 1: Comment t'appelles-tu?", "A l'oral: Savoir se presenter et presenter quelqu'un. \n\nParler de sa nationalite. \n\nA l'ecrit: 19 caracteres", 'A1', 0, '2025-07-23', 'ZH')
# 2025-07-23 23:27:54,923 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:54,924 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:54,925 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-23 23:27:54,925 INFO sqlalchemy.engine.Engine [cached since 0.008258s ago] ('ZH',)
# 2025-07-23 23:27:54,925 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:54,926 INFO sqlalchemy.engine.Engine [cached since 0.01285s ago] ('ZH_2', 'Unite 2: Un, deux, trois', "A l'oral: Compter de 1 a 9999. \n\nSavoir enumerer des objets. \n\nA l'ecrit: 19 caracteres", 'A1', 0, '2025-07-23', 'ZH')
# 2025-07-23 23:27:54,926 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:54,926 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:54,927 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-23 23:27:54,927 INFO sqlalchemy.engine.Engine [cached since 0.01029s ago] ('ZH',)
# 2025-07-23 23:27:54,928 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:54,928 INFO sqlalchemy.engine.Engine [cached since 0.01511s ago] ('ZH_3', "Unite 3: Aujourd'hui", "A l'oral: Savoir annoncer la date. \n\nParler des moments de la journee et de l'heure. \n\nA l'ecrit: 17 caracteres", 'A1', 0, '2025-07-23', 'ZH')
# 2025-07-23 23:27:54,928 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:54,929 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:54,929 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-23 23:27:54,929 INFO sqlalchemy.engine.Engine [cached since 0.01279s ago] ('ZH',)
# 2025-07-23 23:27:54,931 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:54,931 INFO sqlalchemy.engine.Engine [cached since 0.01821s ago] ('ZH_4', 'Unite 4: Ou allons-nous?', "A l'oral: Parler d'un evenement passe, d'une experience. \n\nPouvoir se situer, parler ou l'on est, ou l'on va. \n\nA l'ecrit: 17 caracteres", 'A1', 0, '2025-07-23', 'ZH')
# 2025-07-23 23:27:54,932 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:54,933 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:54,934 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-23 23:27:54,934 INFO sqlalchemy.engine.Engine [cached since 0.01768s ago] ('ZH',)
# 2025-07-23 23:27:54,936 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:54,936 INFO sqlalchemy.engine.Engine [cached since 0.02355s ago] ('ZH_5', 'Unite 5: Je ne suis pas vieux', "A l'oral: Decrire quelqu'un ou quelque chose. \n\nUtilise les adjectifs. \n\nA l'ecrit: 17 caracteres", 'A1', 0, '2025-07-23', 'ZH')
# 2025-07-23 23:27:54,937 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:54,938 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:54,938 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-23 23:27:54,938 INFO sqlalchemy.engine.Engine [cached since 0.02153s ago] ('ZH',)
# 2025-07-23 23:27:54,938 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:54,939 INFO sqlalchemy.engine.Engine [cached since 0.02585s ago] ('ZH_6', 'Unite 6: Ma famille', "A l'oral: Pouvoir presenter sa famille. \n\nUtilise les demonstratifs. \n\nA l'ecrit: 22 caracteres", 'A1', 0, '2025-07-23', 'ZH')
# 2025-07-23 23:27:54,939 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:54,939 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:54,939 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-23 23:27:54,940 INFO sqlalchemy.engine.Engine [cached since 0.02299s ago] ('ZH',)
# 2025-07-23 23:27:54,940 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:54,940 INFO sqlalchemy.engine.Engine [cached since 0.02728s ago] ('ZH_7', 'Unite 7: Mes amis', "A l'oral: Parler des ses amis. \n\nParler des langues etrangeres. \n\nComparer des gens ou des objets. \n\nA l'ecrit: 18 caracteres", 'A1', 0, '2025-07-23', 'ZH')
# 2025-07-23 23:27:54,941 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:54,941 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:54,941 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-23 23:27:54,942 INFO sqlalchemy.engine.Engine [cached since 0.02494s ago] ('ZH',)
# 2025-07-23 23:27:54,942 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:54,942 INFO sqlalchemy.engine.Engine [cached since 0.02926s ago] ('ZH_8', "Unite 8: Qu'aimes-tu faire?", "A l'oral: Parler de ses activites favorites. \n\nInterroger sur la maniere. \n\nA l'ecrit: 16 caracteres", 'A2', 0, '2025-07-23', 'ZH')
# 2025-07-23 23:27:54,942 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:54,943 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:54,943 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-23 23:27:54,943 INFO sqlalchemy.engine.Engine [cached since 0.02653s ago] ('ZH',)
# 2025-07-23 23:27:54,943 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:54,943 INFO sqlalchemy.engine.Engine [cached since 0.03077s ago] ('ZH_9', 'Unite 9: Une journee classique', "A l'oral: Raconter sa journee. \n\nParler des differents moyens de transport. \n\nA l'ecrit: 16 caracteres", 'A2', 0, '2025-07-23', 'ZH')
# 2025-07-23 23:27:54,944 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:54,944 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:54,944 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-23 23:27:54,945 INFO sqlalchemy.engine.Engine [cached since 0.02796s ago] ('ZH',)
# 2025-07-23 23:27:54,945 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:54,945 INFO sqlalchemy.engine.Engine [cached since 0.03226s ago] ('ZH_10', 'Unite 10: Au travail', "A l'oral: Parler du monde du travail. \n\nA l'ecrit: 18 caracteres", 'A2', 0, '2025-07-23', 'ZH')
# 2025-07-23 23:27:54,945 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:54,946 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:54,946 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-23 23:27:54,946 INFO sqlalchemy.engine.Engine [cached since 0.02943s ago] ('ZH',)
# 2025-07-23 23:27:54,946 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:54,946 INFO sqlalchemy.engine.Engine [cached since 0.03364s ago] ('ZH_11', 'Unite 11: Dans une grande ville', "A l'oral: Pouvoir demander son chemin. \n\nSe reperer en ville. \n\nA l'ecrit: 18 caracteres", 'A2', 0, '2025-07-23', 'ZH')
# 2025-07-23 23:27:54,947 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:54,947 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:54,947 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-23 23:27:54,947 INFO sqlalchemy.engine.Engine [cached since 0.03082s ago] ('ZH',)
# 2025-07-23 23:27:54,948 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:54,948 INFO sqlalchemy.engine.Engine [cached since 0.03506s ago] ('ZH_12', 'Unite 12: Faire des achats', "A l'oral: Negocier un prix. \n\nFaire des achats. \n\nA l'ecrit: 18 caracteres", 'A2', 0, '2025-07-23', 'ZH')
# 2025-07-23 23:27:54,948 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:54,948 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:54,949 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-23 23:27:54,949 INFO sqlalchemy.engine.Engine [cached since 0.03214s ago] ('ZH',)
# 2025-07-23 23:27:54,949 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:54,949 INFO sqlalchemy.engine.Engine [cached since 0.03638s ago] ('ZH_13', "Unite 13: En voyage a l'etranger", "A l'oral: Pouvoir raconter ou prevoir un voyage. \n\nUtiliser 'Avant, apres, pendant'. \n\nA l'ecrit: 17 caracteres", 'A2', 0, '2025-07-23', 'ZH')
# 2025-07-23 23:27:54,949 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:54,950 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:54,950 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-23 23:27:54,950 INFO sqlalchemy.engine.Engine [cached since 0.03348s ago] ('ZH',)
# 2025-07-23 23:27:54,950 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:54,950 INFO sqlalchemy.engine.Engine [cached since 0.03771s ago] ('ZH_14', 'Unite 14: La culture chinoise', "A l'oral: Decouvrir la culture chinoise. \n\nParler des fetes et des vacances. \n\nA l'ecrit: 19 caracteres", 'A2', 0, '2025-07-23', 'ZH')
# 2025-07-23 23:27:54,951 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:54,951 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:54,951 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-23 23:27:54,952 INFO sqlalchemy.engine.Engine [cached since 0.03503s ago] ('ZH',)
# 2025-07-23 23:27:54,952 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, last_seen, language_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:54,952 INFO sqlalchemy.engine.Engine [cached since 0.0394s ago] ('ZH_15', 'Unite 15: A la maison', "A l'oral: Decrire une maison, un appartement. \n\nUtiliser 吧 et les directionnels. \n\nA l'ecrit: 17 caracteres", 'A2', 0, '2025-07-23', 'ZH')
# 2025-07-23 23:27:54,952 INFO sqlalchemy.engine.Engine COMMIT
# /Users/noe_jager/Documents/GitHub/vocabulary-dbms/src/lapp/dbms.py:80: SAWarning: Object of type <Unit> not in session, add operation along 'Language.units' will not proceed
#   session.commit()

# %% [markdown]
# ## Add Vocabulary

# %%
# Initialize the database connection and create db file if it doesn't exist
engine, session = init_db()

directory_path = f'../assets/data/{language_id}/vocabulary'

if not os.path.exists(directory_path):
    raise FileNotFoundError(f"No vocabulary found for {language_id}.")

vocs = []

# List all elements (files and directories) in the specified directory and get their full paths
elements_paths = [os.path.join(directory_path, element) for element in os.listdir(directory_path)]
for voc_file in elements_paths:
    if os.path.isfile(voc_file) and voc_file.endswith('.csv'):
        unit_id = re.sub("[^0-9]", "", os.path.basename(voc_file))
        df = pd.read_csv(voc_file)
        for idx, row in df.iterrows():
            vocs.append( 
                Vocabulary(
                    id=f"{language_id.upper()}_{unit_id}_V{idx}",
                    word = row['word'],
                    translation = row["translation"],
                    phonetic = row["pinyin"],
                    example_sentence = row.get("example_sentence", ""),
                    type = row["type"],
                    parent=session.query(Unit).filter(Unit.id == f"{language_id.upper()}_{unit_id}").first()
                )
            )
inserts(session, vocs)
session.close()
# Out:
# 2025-07-23 23:27:54,958 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:54,958 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("language")
# 2025-07-23 23:27:54,958 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:54,959 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-23 23:27:54,959 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:54,959 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-23 23:27:54,959 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:54,959 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-23 23:27:54,960 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:54,960 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-23 23:27:54,960 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:54,960 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-23 23:27:54,960 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:54,960 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:54,962 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:54,963 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,963 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('ZH_2', 1, 0)
# 2025-07-23 23:27:54,964 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,964 INFO sqlalchemy.engine.Engine [cached since 0.001067s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:54,964 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,964 INFO sqlalchemy.engine.Engine [cached since 0.001733s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:54,965 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,965 INFO sqlalchemy.engine.Engine [cached since 0.002375s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:54,966 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,966 INFO sqlalchemy.engine.Engine [cached since 0.003088s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:54,966 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,966 INFO sqlalchemy.engine.Engine [cached since 0.003685s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:54,967 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,967 INFO sqlalchemy.engine.Engine [cached since 0.004251s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:54,967 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,968 INFO sqlalchemy.engine.Engine [cached since 0.004854s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:54,969 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,969 INFO sqlalchemy.engine.Engine [cached since 0.006202s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:54,970 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,970 INFO sqlalchemy.engine.Engine [cached since 0.006983s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:54,970 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,970 INFO sqlalchemy.engine.Engine [cached since 0.007752s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:54,971 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,971 INFO sqlalchemy.engine.Engine [cached since 0.008369s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:54,972 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,972 INFO sqlalchemy.engine.Engine [cached since 0.009281s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:54,972 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,973 INFO sqlalchemy.engine.Engine [cached since 0.009906s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:54,973 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,973 INFO sqlalchemy.engine.Engine [cached since 0.01044s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:54,974 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,974 INFO sqlalchemy.engine.Engine [cached since 0.01101s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:54,974 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,974 INFO sqlalchemy.engine.Engine [cached since 0.01157s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:54,975 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,975 INFO sqlalchemy.engine.Engine [cached since 0.01216s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:54,975 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,976 INFO sqlalchemy.engine.Engine [cached since 0.01283s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:54,976 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,976 INFO sqlalchemy.engine.Engine [cached since 0.01348s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:54,977 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,977 INFO sqlalchemy.engine.Engine [cached since 0.01409s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:54,977 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,977 INFO sqlalchemy.engine.Engine [cached since 0.0147s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:54,978 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,978 INFO sqlalchemy.engine.Engine [cached since 0.01536s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:54,980 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,980 INFO sqlalchemy.engine.Engine [cached since 0.01692s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,980 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,980 INFO sqlalchemy.engine.Engine [cached since 0.01754s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,981 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,981 INFO sqlalchemy.engine.Engine [cached since 0.01814s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,981 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,981 INFO sqlalchemy.engine.Engine [cached since 0.01873s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,982 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,982 INFO sqlalchemy.engine.Engine [cached since 0.01929s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,982 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,983 INFO sqlalchemy.engine.Engine [cached since 0.01982s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,983 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,983 INFO sqlalchemy.engine.Engine [cached since 0.02043s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,984 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,984 INFO sqlalchemy.engine.Engine [cached since 0.021s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,984 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,984 INFO sqlalchemy.engine.Engine [cached since 0.02165s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,985 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,985 INFO sqlalchemy.engine.Engine [cached since 0.02237s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,986 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,986 INFO sqlalchemy.engine.Engine [cached since 0.02301s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,986 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,986 INFO sqlalchemy.engine.Engine [cached since 0.02359s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,987 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,987 INFO sqlalchemy.engine.Engine [cached since 0.02412s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,987 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,987 INFO sqlalchemy.engine.Engine [cached since 0.02469s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,988 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,988 INFO sqlalchemy.engine.Engine [cached since 0.02556s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,989 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,989 INFO sqlalchemy.engine.Engine [cached since 0.02616s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,989 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,989 INFO sqlalchemy.engine.Engine [cached since 0.02679s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,990 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,990 INFO sqlalchemy.engine.Engine [cached since 0.02756s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,991 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,991 INFO sqlalchemy.engine.Engine [cached since 0.02834s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,992 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,992 INFO sqlalchemy.engine.Engine [cached since 0.02896s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,992 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,992 INFO sqlalchemy.engine.Engine [cached since 0.02955s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,993 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,993 INFO sqlalchemy.engine.Engine [cached since 0.03019s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,993 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,993 INFO sqlalchemy.engine.Engine [cached since 0.03076s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,994 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,994 INFO sqlalchemy.engine.Engine [cached since 0.03149s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,995 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,995 INFO sqlalchemy.engine.Engine [cached since 0.0321s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,995 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,995 INFO sqlalchemy.engine.Engine [cached since 0.03267s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,996 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,996 INFO sqlalchemy.engine.Engine [cached since 0.03335s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,997 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,997 INFO sqlalchemy.engine.Engine [cached since 0.03393s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,997 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,997 INFO sqlalchemy.engine.Engine [cached since 0.03455s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,998 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,998 INFO sqlalchemy.engine.Engine [cached since 0.03539s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:54,999 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:54,999 INFO sqlalchemy.engine.Engine [cached since 0.03605s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:55,000 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,000 INFO sqlalchemy.engine.Engine [cached since 0.0376s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:55,001 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,001 INFO sqlalchemy.engine.Engine [cached since 0.03828s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:55,001 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,002 INFO sqlalchemy.engine.Engine [cached since 0.03895s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:55,002 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,002 INFO sqlalchemy.engine.Engine [cached since 0.03961s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:55,003 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,003 INFO sqlalchemy.engine.Engine [cached since 0.04043s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:55,004 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,004 INFO sqlalchemy.engine.Engine [cached since 0.04113s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:55,004 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,004 INFO sqlalchemy.engine.Engine [cached since 0.04168s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:55,005 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,005 INFO sqlalchemy.engine.Engine [cached since 0.04226s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:55,005 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,006 INFO sqlalchemy.engine.Engine [cached since 0.04285s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:55,006 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,006 INFO sqlalchemy.engine.Engine [cached since 0.04342s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:55,007 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,007 INFO sqlalchemy.engine.Engine [cached since 0.044s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:55,007 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,007 INFO sqlalchemy.engine.Engine [cached since 0.04454s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:55,008 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,008 INFO sqlalchemy.engine.Engine [cached since 0.04517s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:55,008 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,009 INFO sqlalchemy.engine.Engine [cached since 0.04587s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:55,009 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,009 INFO sqlalchemy.engine.Engine [cached since 0.04646s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:55,010 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,010 INFO sqlalchemy.engine.Engine [cached since 0.04703s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:55,010 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,010 INFO sqlalchemy.engine.Engine [cached since 0.0476s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:55,011 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,011 INFO sqlalchemy.engine.Engine [cached since 0.04827s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:55,011 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,012 INFO sqlalchemy.engine.Engine [cached since 0.04886s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:55,012 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,012 INFO sqlalchemy.engine.Engine [cached since 0.04943s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:55,013 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,013 INFO sqlalchemy.engine.Engine [cached since 0.05001s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:55,013 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,013 INFO sqlalchemy.engine.Engine [cached since 0.05065s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:55,014 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,014 INFO sqlalchemy.engine.Engine [cached since 0.05129s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:55,014 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,015 INFO sqlalchemy.engine.Engine [cached since 0.05189s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:55,016 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,016 INFO sqlalchemy.engine.Engine [cached since 0.05332s ago] ('ZH_0', 1, 0)
# 2025-07-23 23:27:55,016 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,017 INFO sqlalchemy.engine.Engine [cached since 0.0539s ago] ('ZH_0', 1, 0)
# 2025-07-23 23:27:55,017 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,017 INFO sqlalchemy.engine.Engine [cached since 0.05453s ago] ('ZH_0', 1, 0)
# 2025-07-23 23:27:55,018 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,018 INFO sqlalchemy.engine.Engine [cached since 0.0551s ago] ('ZH_0', 1, 0)
# 2025-07-23 23:27:55,018 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,018 INFO sqlalchemy.engine.Engine [cached since 0.0557s ago] ('ZH_0', 1, 0)
# 2025-07-23 23:27:55,019 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,019 INFO sqlalchemy.engine.Engine [cached since 0.0567s ago] ('ZH_0', 1, 0)
# 2025-07-23 23:27:55,020 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,021 INFO sqlalchemy.engine.Engine [cached since 0.05796s ago] ('ZH_0', 1, 0)
# 2025-07-23 23:27:55,021 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,021 INFO sqlalchemy.engine.Engine [cached since 0.0588s ago] ('ZH_0', 1, 0)
# 2025-07-23 23:27:55,022 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,022 INFO sqlalchemy.engine.Engine [cached since 0.05963s ago] ('ZH_0', 1, 0)
# 2025-07-23 23:27:55,023 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,023 INFO sqlalchemy.engine.Engine [cached since 0.0604s ago] ('ZH_0', 1, 0)
# 2025-07-23 23:27:55,024 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,024 INFO sqlalchemy.engine.Engine [cached since 0.0612s ago] ('ZH_0', 1, 0)
# 2025-07-23 23:27:55,025 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,025 INFO sqlalchemy.engine.Engine [cached since 0.06274s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:55,026 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,026 INFO sqlalchemy.engine.Engine [cached since 0.06331s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:55,026 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,027 INFO sqlalchemy.engine.Engine [cached since 0.06388s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:55,027 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,027 INFO sqlalchemy.engine.Engine [cached since 0.06445s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:55,028 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,028 INFO sqlalchemy.engine.Engine [cached since 0.06518s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:55,028 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,029 INFO sqlalchemy.engine.Engine [cached since 0.06594s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:55,029 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,029 INFO sqlalchemy.engine.Engine [cached since 0.06665s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:55,030 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,030 INFO sqlalchemy.engine.Engine [cached since 0.06739s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:55,031 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,031 INFO sqlalchemy.engine.Engine [cached since 0.06798s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:55,031 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,031 INFO sqlalchemy.engine.Engine [cached since 0.06854s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:55,032 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,032 INFO sqlalchemy.engine.Engine [cached since 0.06917s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:55,032 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,032 INFO sqlalchemy.engine.Engine [cached since 0.06973s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:55,033 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,033 INFO sqlalchemy.engine.Engine [cached since 0.07025s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:55,033 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,034 INFO sqlalchemy.engine.Engine [cached since 0.07082s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:55,034 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,034 INFO sqlalchemy.engine.Engine [cached since 0.07139s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:55,035 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,035 INFO sqlalchemy.engine.Engine [cached since 0.07202s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:55,035 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,035 INFO sqlalchemy.engine.Engine [cached since 0.07268s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:55,036 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,036 INFO sqlalchemy.engine.Engine [cached since 0.07345s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:55,037 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,038 INFO sqlalchemy.engine.Engine [cached since 0.07485s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:55,038 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,038 INFO sqlalchemy.engine.Engine [cached since 0.07554s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:55,039 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,039 INFO sqlalchemy.engine.Engine [cached since 0.07618s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:55,039 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,040 INFO sqlalchemy.engine.Engine [cached since 0.07687s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:55,040 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,040 INFO sqlalchemy.engine.Engine [cached since 0.07745s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:55,041 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:55,041 INFO sqlalchemy.engine.Engine [cached since 0.07804s ago] ('ZH_5', 1, 0)
# ...
# 2025-07-23 23:27:56,748 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,751 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,752 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,753 INFO sqlalchemy.engine.Engine [cached since 1.45s ago] ('ZH_9',)
# 2025-07-23 23:27:56,757 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,762 INFO sqlalchemy.engine.Engine [cached since 1.461s ago] ('ZH_9_V6', '骑', 'Chevaucher', 'Qí', '', 'Verbes', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:56,763 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,766 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,767 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,768 INFO sqlalchemy.engine.Engine [cached since 1.465s ago] ('ZH_9',)
# 2025-07-23 23:27:56,770 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,771 INFO sqlalchemy.engine.Engine [cached since 1.47s ago] ('ZH_9_V7', '上班', 'Commencer le travail', 'Shàngbān', '', 'Verbes', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:56,772 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,775 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,777 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,778 INFO sqlalchemy.engine.Engine [cached since 1.475s ago] ('ZH_9',)
# 2025-07-23 23:27:56,779 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,780 INFO sqlalchemy.engine.Engine [cached since 1.479s ago] ('ZH_9_V8', '下班', 'Finir le travail', 'Xiàbān', '', 'Verbes', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:56,781 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,782 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,783 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,783 INFO sqlalchemy.engine.Engine [cached since 1.48s ago] ('ZH_9',)
# 2025-07-23 23:27:56,784 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,784 INFO sqlalchemy.engine.Engine [cached since 1.483s ago] ('ZH_9_V9', '走路', 'Marcher', 'Zǒulù', '', 'Verbes', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:56,784 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,786 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,787 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,788 INFO sqlalchemy.engine.Engine [cached since 1.485s ago] ('ZH_9',)
# 2025-07-23 23:27:56,789 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,789 INFO sqlalchemy.engine.Engine [cached since 1.488s ago] ('ZH_9_V10', '坐', "S'asseoir/prendre (véhicule)", 'Zuò', '', 'Verbes', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:56,790 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,793 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,793 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,794 INFO sqlalchemy.engine.Engine [cached since 1.491s ago] ('ZH_9',)
# 2025-07-23 23:27:56,794 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,794 INFO sqlalchemy.engine.Engine [cached since 1.493s ago] ('ZH_9_V11', '游泳', 'Nager', 'Yóuyǒng', '', 'Verbes', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:56,795 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,796 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,796 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,796 INFO sqlalchemy.engine.Engine [cached since 1.494s ago] ('ZH_9',)
# 2025-07-23 23:27:56,797 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,797 INFO sqlalchemy.engine.Engine [cached since 1.496s ago] ('ZH_9_V12', '无聊', 'Ennuyeux', 'Wúliáo', '', 'Adjectifs', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:56,798 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,799 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,799 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,799 INFO sqlalchemy.engine.Engine [cached since 1.496s ago] ('ZH_9',)
# 2025-07-23 23:27:56,799 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,800 INFO sqlalchemy.engine.Engine [cached since 1.499s ago] ('ZH_9_V13', '有意思', 'Intéressant (polite)', 'Yǒu yìsi', '', 'Adjectifs', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:56,800 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,801 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,801 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,801 INFO sqlalchemy.engine.Engine [cached since 1.498s ago] ('ZH_9',)
# 2025-07-23 23:27:56,801 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,801 INFO sqlalchemy.engine.Engine [cached since 1.5s ago] ('ZH_9_V14', '没意思', 'Inintéressant (polite)', 'Méi yìsi', '', 'Adjectifs', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:56,802 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,802 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,803 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,803 INFO sqlalchemy.engine.Engine [cached since 1.5s ago] ('ZH_9',)
# 2025-07-23 23:27:56,803 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,803 INFO sqlalchemy.engine.Engine [cached since 1.502s ago] ('ZH_9_V15', '啊', "Particule modale d'exclamation", 'A', '', 'Divers', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:56,804 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,805 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,805 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,805 INFO sqlalchemy.engine.Engine [cached since 1.502s ago] ('ZH_9',)
# 2025-07-23 23:27:56,805 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,806 INFO sqlalchemy.engine.Engine [cached since 1.505s ago] ('ZH_9_V16', '每', 'Chaque', 'Měi', '', 'Divers', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:56,806 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,807 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,807 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,807 INFO sqlalchemy.engine.Engine [cached since 1.505s ago] ('ZH_9',)
# 2025-07-23 23:27:56,808 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,808 INFO sqlalchemy.engine.Engine [cached since 1.507s ago] ('ZH_9_V17', '然后', 'Ensuite', 'Ránhòu', '', 'Divers', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:56,808 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,809 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,809 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,809 INFO sqlalchemy.engine.Engine [cached since 1.507s ago] ('ZH_9',)
# 2025-07-23 23:27:56,810 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,810 INFO sqlalchemy.engine.Engine [cached since 1.509s ago] ('ZH_9_V18', '同意', "Être d'accord", 'Tóngyì', '', 'Divers', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:56,810 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,811 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,811 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,812 INFO sqlalchemy.engine.Engine [cached since 1.509s ago] ('ZH_9',)
# 2025-07-23 23:27:56,812 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,812 INFO sqlalchemy.engine.Engine [cached since 1.511s ago] ('ZH_9_V19', '先', "D'abord", 'Xiān', '', 'Divers', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:56,813 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,813 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,814 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,814 INFO sqlalchemy.engine.Engine [cached since 1.511s ago] ('ZH_9',)
# 2025-07-23 23:27:56,814 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,814 INFO sqlalchemy.engine.Engine [cached since 1.513s ago] ('ZH_9_V20', '有点儿', 'Un petit peu', 'Yǒu diǎnr', '', 'Divers', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:56,815 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,815 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,816 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,816 INFO sqlalchemy.engine.Engine [cached since 1.513s ago] ('ZH_9',)
# 2025-07-23 23:27:56,816 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,817 INFO sqlalchemy.engine.Engine [cached since 1.516s ago] ('ZH_9_V21', '公园', 'Parc public', 'Gōngyuán', '', 'Noms et expressions', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:56,817 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,818 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,818 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,819 INFO sqlalchemy.engine.Engine [cached since 1.516s ago] ('ZH_9',)
# 2025-07-23 23:27:56,819 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,819 INFO sqlalchemy.engine.Engine [cached since 1.518s ago] ('ZH_9_V22', '看法', 'Point de vue', 'Kànfǎ', '', 'Noms et expressions', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:56,819 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,820 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,820 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,821 INFO sqlalchemy.engine.Engine [cached since 1.518s ago] ('ZH_9',)
# 2025-07-23 23:27:56,821 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,821 INFO sqlalchemy.engine.Engine [cached since 1.52s ago] ('ZH_9_V23', '游泳池', 'Piscine', 'Yóuyǒngchí', '', 'Noms et expressions', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:56,822 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Add Grammar Rules

# %%
# Initialize the database connection and create db file if it doesn't exist
engine, session = init_db()

directory_path = f'../assets/data/{language_id}/grammar'

if not os.path.exists(directory_path):
    raise FileNotFoundError(f"No grammar files found for {language_id}.")

grammars = []

# List all elements (files and directories) in the specified directory and get their full paths
elements_paths = [os.path.join(directory_path, element) for element in os.listdir(directory_path)]
for grammar_file in elements_paths:
    if os.path.isfile(grammar_file) and grammar_file.endswith('.json'):
        unit_id = re.sub("[^0-9]", "", os.path.basename(grammar_file))
        with open(grammar_file, 'r', encoding="utf8") as f:
            grammar_data = json.load(f)
        for idx, row in enumerate(grammar_data):
            grammars.append( 
                GrammarRule(
                    id=f"{language_id.upper()}_{unit_id}_G{idx + 1}",
                    title=row['title'],
                    explanation=row["content"],
                    parent=session.query(Unit).filter(Unit.id == f"{language_id.upper()}_{unit_id}").first()
                )
            )
inserts(session, grammars)
session.close()
# Out:
# 2025-07-23 23:27:56,832 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,838 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("language")
# 2025-07-23 23:27:56,840 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:56,841 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-23 23:27:56,846 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:56,855 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-23 23:27:56,855 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:56,856 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-23 23:27:56,856 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:56,857 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-23 23:27:56,857 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:56,858 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-23 23:27:56,858 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:56,859 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,865 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,866 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,867 INFO sqlalchemy.engine.Engine [generated in 0.00052s] ('ZH_11', 1, 0)
# 2025-07-23 23:27:56,869 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,870 INFO sqlalchemy.engine.Engine [cached since 0.003264s ago] ('ZH_11', 1, 0)
# 2025-07-23 23:27:56,871 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,872 INFO sqlalchemy.engine.Engine [cached since 0.005213s ago] ('ZH_11', 1, 0)
# 2025-07-23 23:27:56,873 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,874 INFO sqlalchemy.engine.Engine [cached since 0.007289s ago] ('ZH_11', 1, 0)
# 2025-07-23 23:27:56,876 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,876 INFO sqlalchemy.engine.Engine [cached since 0.00988s ago] ('ZH_6', 1, 0)
# 2025-07-23 23:27:56,878 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,878 INFO sqlalchemy.engine.Engine [cached since 0.01201s ago] ('ZH_6', 1, 0)
# 2025-07-23 23:27:56,880 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,881 INFO sqlalchemy.engine.Engine [cached since 0.01421s ago] ('ZH_6', 1, 0)
# 2025-07-23 23:27:56,882 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,882 INFO sqlalchemy.engine.Engine [cached since 0.01596s ago] ('ZH_6', 1, 0)
# 2025-07-23 23:27:56,884 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,885 INFO sqlalchemy.engine.Engine [cached since 0.01851s ago] ('ZH_7', 1, 0)
# 2025-07-23 23:27:56,886 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,887 INFO sqlalchemy.engine.Engine [cached since 0.02038s ago] ('ZH_7', 1, 0)
# 2025-07-23 23:27:56,888 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,889 INFO sqlalchemy.engine.Engine [cached since 0.02248s ago] ('ZH_7', 1, 0)
# 2025-07-23 23:27:56,890 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,890 INFO sqlalchemy.engine.Engine [cached since 0.02394s ago] ('ZH_7', 1, 0)
# 2025-07-23 23:27:56,892 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,893 INFO sqlalchemy.engine.Engine [cached since 0.0261s ago] ('ZH_7', 1, 0)
# 2025-07-23 23:27:56,895 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,895 INFO sqlalchemy.engine.Engine [cached since 0.02858s ago] ('ZH_7', 1, 0)
# 2025-07-23 23:27:56,897 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,898 INFO sqlalchemy.engine.Engine [cached since 0.03153s ago] ('ZH_10', 1, 0)
# 2025-07-23 23:27:56,899 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,900 INFO sqlalchemy.engine.Engine [cached since 0.03346s ago] ('ZH_10', 1, 0)
# 2025-07-23 23:27:56,902 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,902 INFO sqlalchemy.engine.Engine [cached since 0.03555s ago] ('ZH_10', 1, 0)
# 2025-07-23 23:27:56,903 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,904 INFO sqlalchemy.engine.Engine [cached since 0.0378s ago] ('ZH_10', 1, 0)
# 2025-07-23 23:27:56,905 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,906 INFO sqlalchemy.engine.Engine [cached since 0.03932s ago] ('ZH_10', 1, 0)
# 2025-07-23 23:27:56,907 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,908 INFO sqlalchemy.engine.Engine [cached since 0.04165s ago] ('ZH_10', 1, 0)
# 2025-07-23 23:27:56,910 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,911 INFO sqlalchemy.engine.Engine [cached since 0.04454s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:56,912 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,912 INFO sqlalchemy.engine.Engine [cached since 0.04572s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:56,913 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,914 INFO sqlalchemy.engine.Engine [cached since 0.0471s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:56,916 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,916 INFO sqlalchemy.engine.Engine [cached since 0.04938s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:56,917 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,917 INFO sqlalchemy.engine.Engine [cached since 0.05032s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:56,918 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,918 INFO sqlalchemy.engine.Engine [cached since 0.05129s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:56,918 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,919 INFO sqlalchemy.engine.Engine [cached since 0.05222s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:56,919 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,919 INFO sqlalchemy.engine.Engine [cached since 0.05295s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:56,920 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,921 INFO sqlalchemy.engine.Engine [cached since 0.05454s ago] ('ZH_15', 1, 0)
# 2025-07-23 23:27:56,922 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,923 INFO sqlalchemy.engine.Engine [cached since 0.05634s ago] ('ZH_15', 1, 0)
# 2025-07-23 23:27:56,924 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,925 INFO sqlalchemy.engine.Engine [cached since 0.05833s ago] ('ZH_15', 1, 0)
# 2025-07-23 23:27:56,926 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,927 INFO sqlalchemy.engine.Engine [cached since 0.06011s ago] ('ZH_15', 1, 0)
# 2025-07-23 23:27:56,928 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,929 INFO sqlalchemy.engine.Engine [cached since 0.06223s ago] ('ZH_14', 1, 0)
# 2025-07-23 23:27:56,930 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,931 INFO sqlalchemy.engine.Engine [cached since 0.06417s ago] ('ZH_14', 1, 0)
# 2025-07-23 23:27:56,932 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,932 INFO sqlalchemy.engine.Engine [cached since 0.06598s ago] ('ZH_14', 1, 0)
# 2025-07-23 23:27:56,934 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,934 INFO sqlalchemy.engine.Engine [cached since 0.0678s ago] ('ZH_14', 1, 0)
# 2025-07-23 23:27:56,936 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,936 INFO sqlalchemy.engine.Engine [cached since 0.06997s ago] ('ZH_14', 1, 0)
# 2025-07-23 23:27:56,938 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,938 INFO sqlalchemy.engine.Engine [cached since 0.07183s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:56,939 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,939 INFO sqlalchemy.engine.Engine [cached since 0.07273s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:56,940 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,940 INFO sqlalchemy.engine.Engine [cached since 0.07361s ago] ('ZH_8', 1, 0)
# 2025-07-23 23:27:56,941 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,941 INFO sqlalchemy.engine.Engine [cached since 0.07423s ago] ('ZH_8', 1, 0)
# 2025-07-23 23:27:56,941 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,941 INFO sqlalchemy.engine.Engine [cached since 0.07485s ago] ('ZH_8', 1, 0)
# 2025-07-23 23:27:56,942 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,942 INFO sqlalchemy.engine.Engine [cached since 0.07549s ago] ('ZH_8', 1, 0)
# 2025-07-23 23:27:56,942 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,942 INFO sqlalchemy.engine.Engine [cached since 0.07607s ago] ('ZH_8', 1, 0)
# 2025-07-23 23:27:56,943 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,943 INFO sqlalchemy.engine.Engine [cached since 0.07687s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:56,944 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,944 INFO sqlalchemy.engine.Engine [cached since 0.07737s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:56,944 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,944 INFO sqlalchemy.engine.Engine [cached since 0.07792s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:56,945 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,945 INFO sqlalchemy.engine.Engine [cached since 0.0785s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:56,945 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,946 INFO sqlalchemy.engine.Engine [cached since 0.07908s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:56,946 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,946 INFO sqlalchemy.engine.Engine [cached since 0.07995s ago] ('ZH_13', 1, 0)
# 2025-07-23 23:27:56,947 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,947 INFO sqlalchemy.engine.Engine [cached since 0.0805s ago] ('ZH_13', 1, 0)
# 2025-07-23 23:27:56,947 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,947 INFO sqlalchemy.engine.Engine [cached since 0.08102s ago] ('ZH_13', 1, 0)
# 2025-07-23 23:27:56,948 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,948 INFO sqlalchemy.engine.Engine [cached since 0.08155s ago] ('ZH_13', 1, 0)
# 2025-07-23 23:27:56,948 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,948 INFO sqlalchemy.engine.Engine [cached since 0.08207s ago] ('ZH_13', 1, 0)
# 2025-07-23 23:27:56,949 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,949 INFO sqlalchemy.engine.Engine [cached since 0.08276s ago] ('ZH_12', 1, 0)
# 2025-07-23 23:27:56,950 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,950 INFO sqlalchemy.engine.Engine [cached since 0.08366s ago] ('ZH_12', 1, 0)
# 2025-07-23 23:27:56,950 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,951 INFO sqlalchemy.engine.Engine [cached since 0.08418s ago] ('ZH_12', 1, 0)
# 2025-07-23 23:27:56,951 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,951 INFO sqlalchemy.engine.Engine [cached since 0.08479s ago] ('ZH_12', 1, 0)
# 2025-07-23 23:27:56,952 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,952 INFO sqlalchemy.engine.Engine [cached since 0.0856s ago] ('ZH_12', 1, 0)
# 2025-07-23 23:27:56,953 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,953 INFO sqlalchemy.engine.Engine [cached since 0.08653s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:56,953 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,953 INFO sqlalchemy.engine.Engine [cached since 0.08707s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:56,954 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,954 INFO sqlalchemy.engine.Engine [cached since 0.08799s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:56,955 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,955 INFO sqlalchemy.engine.Engine [cached since 0.08873s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:56,956 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,956 INFO sqlalchemy.engine.Engine [cached since 0.08958s ago] ('ZH_9', 1, 0)
# 2025-07-23 23:27:56,956 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,957 INFO sqlalchemy.engine.Engine [cached since 0.09009s ago] ('ZH_9', 1, 0)
# 2025-07-23 23:27:56,957 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,957 INFO sqlalchemy.engine.Engine [cached since 0.0906s ago] ('ZH_9', 1, 0)
# 2025-07-23 23:27:56,957 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,958 INFO sqlalchemy.engine.Engine [cached since 0.09109s ago] ('ZH_9', 1, 0)
# 2025-07-23 23:27:56,958 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,958 INFO sqlalchemy.engine.Engine [cached since 0.09161s ago] ('ZH_9', 1, 0)
# 2025-07-23 23:27:56,958 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:56,959 INFO sqlalchemy.engine.Engine [cached since 0.09217s ago] ('ZH_9', 1, 0)
# 2025-07-23 23:27:56,959 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,959 INFO sqlalchemy.engine.Engine [generated in 0.00015s] ('ZH_11_G1', 'Énumérer avec 第 dì', "第 dì permet de former des chiffres et nombres ordinaux.\nIl s'emploie de la façon suivante :\n\n第 + chiffre/nombre ( + Classificateur )\n\n* 第一 dì yī ... (918 characters truncated) ... s deux mots suivants signifient « étage » et peuvent s'employer sans 第 dì :\n\n* 三楼 sān lóu : « Troisième étage »\n* 四层 sì céng : « Quatrième étage »", 0, '2025-07-23', 'ZH_11')
# 2025-07-23 23:27:56,960 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,960 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,961 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,961 INFO sqlalchemy.engine.Engine [generated in 0.00013s] ('ZH_11',)
# 2025-07-23 23:27:56,961 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,962 INFO sqlalchemy.engine.Engine [cached since 0.00228s ago] ('ZH_11_G2', 'Exprimer une distance avec 离 lí', "离 lí est utilisé lorsqu'on souhaite exprimer une distance entre deux points. Il peut se traduire par « par rapport à ». La structure à employer, très ... (589 characters truncated) ... ē zhàn lí zhèr tài yuǎn le : « La gare est trop éloignée d’ici »\n* 酒吧离我的家比较远 jiǔbā lí wǒ de jiā bǐjiào yuǎn : « Le bar est plutôt loin de chez moi »", 0, '2025-07-23', 'ZH_11')
# 2025-07-23 23:27:56,962 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,962 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,963 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,963 INFO sqlalchemy.engine.Engine [cached since 0.002054s ago] ('ZH_11',)
# 2025-07-23 23:27:56,963 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,963 INFO sqlalchemy.engine.Engine [cached since 0.003818s ago] ('ZH_11_G3', 'Se diriger, suivre un itinéraire', 'Savoir utiliser les termes « droite », « gauche » et « tout droit » suffit pour se repérer, demander son chemin et comprendre un itinéraire. Lorsqu’o ... (238 characters truncated) ... tout droit »\n* 你先往前走一百米，然后往左拐 nǐ xiān wǎng qián zǒu yī bǎi mǐ, ránhòu wǎng zuǒ guǎi : « Va d’abord tout droit sur 100 mètres, puis tourne à gauche »', 0, '2025-07-23', 'ZH_11')
# 2025-07-23 23:27:56,963 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,964 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,964 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,964 INFO sqlalchemy.engine.Engine [cached since 0.003445s ago] ('ZH_11',)
# 2025-07-23 23:27:56,964 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,965 INFO sqlalchemy.engine.Engine [cached since 0.005207s ago] ('ZH_11_G4', "À l'intérieur de quelque chose", 'Pour indiquer que quelque chose se situe à l’intérieur de quelque chose d’autre, on utilise la structure suivante :\n\nNom 1 + 在 + Nom 2 + 里面\n\n* 你在 ... (240 characters truncated) ...  shàng ma ? : « Es-tu dans le bus ? »\n* 我在车上 wǒ zài chē shàng : « Je suis dans la voiture »\n* 我在火车上 wǒ zài huǒchē shàng : « Je suis dans le train »', 0, '2025-07-23', 'ZH_11')
# 2025-07-23 23:27:56,965 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,965 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,965 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,966 INFO sqlalchemy.engine.Engine [cached since 0.004796s ago] ('ZH_6',)
# 2025-07-23 23:27:56,966 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,966 INFO sqlalchemy.engine.Engine [cached since 0.006653s ago] ('ZH_6_G1', 'Les démonstratifs 这 zhè et 那 nà', "Le démonstratif le plus couramment utilisé en chinois est 这 zhè.\n这 zhè va rarement être utilisé tout seul, il est souvent couplé avec d'autres carac ... (1057 characters truncated) ... à-bas, c'est... »\n* 那个/那个人 nà ge rén : « Cette personne-là »\n* 那里是我的朋友的家 nà lǐ shì wǒ de péngyou de jiā : « Là-bas se trouve la maison de mon ami »", 0, '2025-07-23', 'ZH_6')
# 2025-07-23 23:27:56,966 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,967 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,967 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,967 INFO sqlalchemy.engine.Engine [cached since 0.006174s ago] ('ZH_6',)
# 2025-07-23 23:27:56,967 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,967 INFO sqlalchemy.engine.Engine [cached since 0.007965s ago] ('ZH_6_G2', 'Autres utilisations du caractère 的 de', "的 de, le caractère permettant de marquer la possession, peut s'utiliser à la suite d'un pronom personnel (ex. 我的 wǒ de « mon ») ou d'un nom (ex. 老师的书 ... (937 characters truncated) ... ncài : « C'est le plat que j'aime faire/préparer »\n* 这是我去年去的地方 zhè shì wǒ qùnián qù de dìfang : « C'est l'endroit où je suis allé l'année dernière »", 0, '2025-07-23', 'ZH_6')
# 2025-07-23 23:27:56,968 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,968 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,968 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,969 INFO sqlalchemy.engine.Engine [cached since 0.007888s ago] ('ZH_6',)
# 2025-07-23 23:27:56,969 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,969 INFO sqlalchemy.engine.Engine [cached since 0.009657s ago] ('ZH_6_G3', 'Exprimer "avec" à l\'aide de 跟 gēn et 一起 yīqǐ', "La préposition 跟 gēn, souvent utilisée avec 一起 yīqǐ (signifiant « ensemble »), permet de marquer l'accompagnement :\n\n* 我跟你去 wǒ gēn nǐ qù : « J'y va ... (142 characters truncated) ... gēn tā yīqǐ qù le gōngyuán : « Je suis allé au parc avec lui hier »\n* 我跟我的女朋友一起住 wǒ gēn wǒ de nǚ péngyou yīqǐ zhù : « J'habite avec ma petite amie »", 0, '2025-07-23', 'ZH_6')
# 2025-07-23 23:27:56,969 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,970 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,970 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,970 INFO sqlalchemy.engine.Engine [cached since 0.009254s ago] ('ZH_6',)
# 2025-07-23 23:27:56,970 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,970 INFO sqlalchemy.engine.Engine [cached since 0.01102s ago] ('ZH_6_G4', 'Les caractères ayant plusieurs prononciations', "Vous aurez certainement remarqué que certains caractères peuvent avoir plusieurs prononciations. Le changement de prononciation peut faire varier ou  ... (198 characters truncated) ...  : trouver que\n* 睡觉 shuìjiào : dormir\n\nCertains caractères comme le 都 de 首都 « la capitale » peuvent changer à la fois de prononciation et de sens.", 0, '2025-07-23', 'ZH_6')
# 2025-07-23 23:27:56,971 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,971 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,971 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,971 INFO sqlalchemy.engine.Engine [cached since 0.01066s ago] ('ZH_7',)
# 2025-07-23 23:27:56,972 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,972 INFO sqlalchemy.engine.Engine [cached since 0.0125s ago] ('ZH_7_G1', 'Comparer avec 比 bi ou 没有 méiyǒu', "**Utilisation de 比 bi**\nLe caractère 比 bǐ est utilisé en tant que comparatif de supériorité ou d'infériorité (et non d'égalité). Il peut être tradui ... (740 characters truncated) ...  : « Il est plus petit que moi » (littéralement « Il n'a pas ma taille »)\n* 妈妈没有爸爸高 māma méiyǒu bàba gāo : « Maman n'est pas aussi grande que papa »", 0, '2025-07-23', 'ZH_7')
# 2025-07-23 23:27:56,972 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,973 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,973 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,973 INFO sqlalchemy.engine.Engine [cached since 0.01231s ago] ('ZH_7',)
# 2025-07-23 23:27:56,973 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,974 INFO sqlalchemy.engine.Engine [cached since 0.0142s ago] ('ZH_7_G2', 'Interrogatif 谁 shéi/shuí', "谁 shéi est l'interrogatif signifiant « Qui ? ». Comme tous les mots interrogatifs, il se place à l'endroit où se trouvera la réponse :\n\n* 你是谁？ Nǐ s ... (401 characters truncated) ...  » et ne doit pas traduire le pronom relatif « qui » dans des phrases comme « La personne qui habite ici ». Pour cela, on utilise 的 de (cf. Leçon 6).", 0, '2025-07-23', 'ZH_7')
# 2025-07-23 23:27:56,974 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,974 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,975 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,975 INFO sqlalchemy.engine.Engine [cached since 0.01401s ago] ('ZH_7',)
# 2025-07-23 23:27:56,975 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,975 INFO sqlalchemy.engine.Engine [cached since 0.01586s ago] ('ZH_7_G3', 'Quelle(s) langue(s) sais-tu parler ?', "En général, on forme le nom d'une langue en ajoutant 语 yǔ (ou 文 wén) au nom du pays.\n\nPour les pays finissant par 国 guó, on remplace 国 guó par 语 yǔ ... (342 characters truncated) ... :\n\n* 中国 Zhōngguó (Chine) → 中文 Zhōngwén (chinois)\n* 汉语 Hànyǔ (chinois)\n\nNote : 汉语 Hànyǔ (chinois) et 韩语 Hányǔ (coréen) se prononcent très proche.", 0, '2025-07-23', 'ZH_7')
# 2025-07-23 23:27:56,976 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,976 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,976 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,976 INFO sqlalchemy.engine.Engine [cached since 0.01553s ago] ('ZH_7',)
# 2025-07-23 23:27:56,977 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,977 INFO sqlalchemy.engine.Engine [cached since 0.01739s ago] ('ZH_7_G4', 'Les adverbes 最 zuì et 太 ... 了 tài...le', "Les adverbes 最 zuì et 太 ... 了 tài...le s'emploient comme 很 hěn devant un adjectif, mais nuancent ou renforcent le propos :\n\n* 我很累 wǒ hěn lèi : « Je ... (11 characters truncated) ... ué »\n* 最累 zuì lèi : « Le plus fatigué »\n* 我太累了 wǒ tài lèi le : « Je suis trop fatigué »\n* 我不太累了 wǒ bù tài lèi le : « Je ne suis pas trop fatigué »", 0, '2025-07-23', 'ZH_7')
# 2025-07-23 23:27:56,977 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,977 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,978 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,978 INFO sqlalchemy.engine.Engine [cached since 0.01726s ago] ('ZH_7',)
# 2025-07-23 23:27:56,978 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,978 INFO sqlalchemy.engine.Engine [cached since 0.01914s ago] ('ZH_7_G5', 'Tout, toutes et tous avec 都 dōu', 'Le caractère 都 peut se prononcer « dū » (dans 首都 shǒudū « capitale ») ou « dōu » quand il signifie « tout, tous ». Il se place directement après le n ... (122 characters truncated) ... ōu xiǎng qù Zhōngguó : « Nous voulons tous aller en Chine »\n* 我的朋友都 wǒ de péngyou dōu : « Tous mes amis »\n* 女生都 nǚshēng dōu : « Toutes les filles »', 0, '2025-07-23', 'ZH_7')
# 2025-07-23 23:27:56,979 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,979 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,979 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,980 INFO sqlalchemy.engine.Engine [cached since 0.01895s ago] ('ZH_7',)
# 2025-07-23 23:27:56,980 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,980 INFO sqlalchemy.engine.Engine [cached since 0.02082s ago] ('ZH_7_G6', 'Ensemble avec 一起 yīqǐ', '一起 yīqǐ a déjà été vu dans la structure 跟 gēn ... + 一起 yīqǐ (page 109) pour dire « avec ». 一起 yīqǐ peut aussi être utilisé seul et signifie « ensembl ... (50 characters truncated) ...  Elles vont regarder un film ensemble »\n* 我们一起去北京 wǒmen yīqǐ qù Běijīng : « Nous allons ensemble à Pékin »\n\nStructure : Sujet + 一起 + Verbe + Objet', 0, '2025-07-23', 'ZH_7')
# 2025-07-23 23:27:56,980 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,981 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,981 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,981 INFO sqlalchemy.engine.Engine [cached since 0.02066s ago] ('ZH_10',)
# 2025-07-23 23:27:56,982 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,982 INFO sqlalchemy.engine.Engine [cached since 0.02242s ago] ('ZH_10_G1', 'Indiquer le destinataire avec 给 gěi', "给 gěi, signifiant « donner », permet d'indiquer la cible d'une action.\n\nStructure : Sujet + 给 + cible + action\n\n* 你给我打电话 nǐ gěi wǒ dǎ diànhuà : « ... (45 characters truncated) ... i tā dǎ diànhuà : « Tu dois lui téléphoner »\n* 你给他写信 nǐ gěi tā xiěxìn : « Écris-lui une lettre »\n* 我给你做饭 wǒ gěi nǐ zuòfàn : « Je te fais à manger »", 0, '2025-07-23', 'ZH_10')
# 2025-07-23 23:27:56,982 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:56,982 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:56,983 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:56,983 INFO sqlalchemy.engine.Engine [cached since 0.02215s ago] ('ZH_10',)
# 2025-07-23 23:27:56,983 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:56,983 INFO sqlalchemy.engine.Engine [cached since 0.02406s ago] ('ZH_10_G2', '"Pouvoir" avec 能 néng ou 可以 kěyǐ', "Plusieurs verbes existent pour exprimer la possibilité, cependant ils ne peuvent pas s'employer de la même manière. Nous avons déjà étudié le verbe 会 ... (795 characters truncated) ... 停车吗？wǒ zài zhèr kěyǐ tíngchē ma ? : « Puis-je garer ma voiture ici ? »\n* 妈妈，我可以出去吗？māma, wǒ kěyǐ chūqù ma ? : « Maman, est-ce que je peux sortir ? »", 0, '2025-07-23', 'ZH_10')
# 2025-07-23 23:27:56,984 INFO sqlalchemy.engine.Engine COMMIT
# ...
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:57,085 INFO sqlalchemy.engine.Engine [cached since 0.1241s ago] ('ZH_12',)
# 2025-07-23 23:27:57,085 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:57,085 INFO sqlalchemy.engine.Engine [cached since 0.1259s ago] ('ZH_12_G2', 'Classificateurs ne pouvant pas être remplacés par 个 gè', "Certains classificateurs ne peuvent pas être remplacés par 个 gè (qui est, pour rappel, le classificateur universel), car ils apportent un sens partic ... (274 characters truncated) ...  gè niǎo : « Un oiseau »\n* 一群鸟 yī qún niǎo : « Un vol d’oiseaux »\n* 一些人 yī xiē rén : « Quelques personnes »\n* 一杯水 yī bēi shuǐ : « Un verre d’eau »", 0, '2025-07-23', 'ZH_12')
# 2025-07-23 23:27:57,086 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:57,086 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:57,086 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:57,086 INFO sqlalchemy.engine.Engine [cached since 0.1256s ago] ('ZH_12',)
# 2025-07-23 23:27:57,087 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:57,087 INFO sqlalchemy.engine.Engine [cached since 0.1274s ago] ('ZH_12_G3', 'Permettre quelque chose avec 让 ràng', "让 ràng est un verbe dit « causatif », qui peut être traduit par « laisser » ou « permettre » en français.\n\nStructure : Sujet + 让 + Personne/Objet + ... (128 characters truncated) ...  papa ne te laisse-t-il pas y aller ? »\n* 看 Titanic 电影让我很感动 kàn Titanic diànyǐng ràng wǒ hěn gǎndòng : « Regarder le film Titanic m'a beaucoup ému »", 0, '2025-07-23', 'ZH_12')
# 2025-07-23 23:27:57,087 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:57,088 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:57,088 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:57,088 INFO sqlalchemy.engine.Engine [cached since 0.1275s ago] ('ZH_12',)
# 2025-07-23 23:27:57,089 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:57,089 INFO sqlalchemy.engine.Engine [cached since 0.1294s ago] ('ZH_12_G4', 'Demander « combien » avec 多少 duōshǎo ou 几 jǐ', "Il existe deux façons principales de demander « combien » : 多少 duōshǎo et 几 jǐ. Voici leurs différences :\n\n* 几 jǐ est utilisé pour des quantités gé ... (695 characters truncated) ...  ici »\n* 我有十多元 wǒ yǒu shí duō yuán : « J’ai un peu plus de dix yuans »\n* 我有三十多块钱 wǒ yǒu sānshí duō kuài qián : « J’ai un peu plus de trente kuais »", 0, '2025-07-23', 'ZH_12')
# 2025-07-23 23:27:57,089 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:57,090 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:57,090 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:57,090 INFO sqlalchemy.engine.Engine [cached since 0.1292s ago] ('ZH_12',)
# 2025-07-23 23:27:57,090 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:57,090 INFO sqlalchemy.engine.Engine [cached since 0.1311s ago] ('ZH_12_G5', '« Quelques » avec 一些 yīxiē', "一些 yīxiē signifie « quelques » ou « certains » et désigne une quantité indéterminée. Il s'utilise selon le schéma suivant :\n\n一些 + Nom\n\n* 有一些人 yǒu yīxiē rén : « Il y a quelques personnes »\n* 爸爸买了一些书 bàba mǎi le yīxiē shū : « Papa a acheté quelques livres »", 0, '2025-07-23', 'ZH_12')
# 2025-07-23 23:27:57,091 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:57,091 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:57,091 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:57,091 INFO sqlalchemy.engine.Engine [cached since 0.1307s ago] ('ZH_5',)
# 2025-07-23 23:27:57,092 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:57,092 INFO sqlalchemy.engine.Engine [cached since 0.1325s ago] ('ZH_5_G1', 'Les adjectifs', "**Affirmation avec 很 hěn**\nLes noms doivent être liés aux autres noms à l'aide du verbe « être » 是 shì.\n\n* 妈妈 是 老师 māma shì lǎoshī : « Maman est p ... (1844 characters truncated) ... ǐhuan : « j'aime »\n* 我 讨厌 wǒ tǎoyàn : « je déteste »\n* 我 很 喜欢 wǒ hěn xǐhuan : « j'aime beaucoup »\n* 我 很 讨厌 wǒ hěn tǎoyàn : « je déteste vraiment »", 0, '2025-07-23', 'ZH_5')
# 2025-07-23 23:27:57,092 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:57,093 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:57,093 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:57,093 INFO sqlalchemy.engine.Engine [cached since 0.1322s ago] ('ZH_5',)
# 2025-07-23 23:27:57,093 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:57,093 INFO sqlalchemy.engine.Engine [cached since 0.1341s ago] ('ZH_5_G2', 'Énumérer avec 和 hé', "Le caractère 和 hé permet d'énumérer des noms communs. Nous pouvons traduire par « ainsi que », son emploi diffère donc du « et » français.\n\n* 我 的 妈 ... (132 characters truncated) ... n papa et moi »\n\n和 hé ne peut pas être utilisé pour lier deux phrases comme en français (ex. Ce matin je travaille et cet après-midi je me repose).", 0, '2025-07-23', 'ZH_5')
# 2025-07-23 23:27:57,094 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:57,094 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:57,094 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:57,094 INFO sqlalchemy.engine.Engine [cached since 0.1337s ago] ('ZH_5',)
# 2025-07-23 23:27:57,095 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:57,095 INFO sqlalchemy.engine.Engine [cached since 0.1355s ago] ('ZH_5_G3', 'Le caractère 的 de', "Le premier sens de 的 de est le possessif. L'ajout du caractère 的 de aux pronoms personnels permet de former les pronoms possessifs :\n\nPronom person ... (638 characters truncated) ...  de Chine »\n\nDéterminant + 的 + déterminé\n\nLe contexte est indispensable pour comprendre le sens qu'il a dans une phrase, un texte ou un dialogue.", 0, '2025-07-23', 'ZH_5')
# 2025-07-23 23:27:57,095 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:57,095 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:57,096 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:57,096 INFO sqlalchemy.engine.Engine [cached since 0.135s ago] ('ZH_5',)
# 2025-07-23 23:27:57,096 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:57,096 INFO sqlalchemy.engine.Engine [cached since 0.1368s ago] ('ZH_5_G4', 'Les différentes utilisations de 要 yào', "Le premier sens de 要 yào est le verbe « vouloir ».\n\n* 我 要 工作 wǒ yào gōngzuò : « Je veux travailler »\n* 我 要 吃饭 wǒ yào chīfàn : « Je veux manger »\n ... (31 characters truncated) ... enir est la suivante :\n\nIl peut également avoir d'autres sens, tels que « devoir », « falloir » ou encore « aller faire/être sur le point de ... ».", 0, '2025-07-23', 'ZH_5')
# 2025-07-23 23:27:57,096 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:57,097 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:57,097 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:57,097 INFO sqlalchemy.engine.Engine [cached since 0.1364s ago] ('ZH_9',)
# 2025-07-23 23:27:57,097 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:57,098 INFO sqlalchemy.engine.Engine [cached since 0.1382s ago] ('ZH_9_G1', 'Moyens de transport', "Si en français nous employons généralement le verbe « prendre » lorsqu'il s'agit des moyens de transport, il convient d'utiliser le verbe 坐 zuò « s'a ... (471 characters truncated) ...  véhicule, il faut employer 开 kāi « conduire, ouvrir » :\n\n* 我开车 wǒ kāi chē : « Je conduis la voiture »\n* 我开飞机 wǒ kāi fēijī : « Je pilote l'avion »", 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:57,098 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:57,098 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:57,098 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:57,099 INFO sqlalchemy.engine.Engine [cached since 0.1378s ago] ('ZH_9',)
# 2025-07-23 23:27:57,099 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:57,099 INFO sqlalchemy.engine.Engine [cached since 0.1396s ago] ('ZH_9_G2', '"Chaque" avec 每 měi', '每 měi est employé dans la majorité des cas avec un classificateur derrière :\n\n* 每个人 měi gè rén : « Chaque personne »\n* 每个月 měi gè yuè : « Chaque m ... (100 characters truncated) ... it pas être employé dans les trois cas suivants :\n\n* 每年 měi nián : « Chaque année »\n* 每天 měi tiān : « Chaque jour »\n* 每日 měi rì : « Chaque jour »', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:57,099 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:57,100 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:57,100 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:57,100 INFO sqlalchemy.engine.Engine [cached since 0.1392s ago] ('ZH_9',)
# 2025-07-23 23:27:57,100 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:57,100 INFO sqlalchemy.engine.Engine [cached since 0.141s ago] ('ZH_9_G3', '"D\'abord... ensuite..." avec 先 xiān et 然后 ránhòu', "先 xiān « premièrement », et 然后 ránhòu « ensuite » peuvent être utilisés ensemble pour indiquer que deux événements se succèdent :\n\n* 我们先吃饭，然后看电视 wǒ ... (220 characters truncated) ... emièrement » peut également être utilisé seul :\n\n* 他先到了 tā xiān dào le : « Il est arrivé en premier »\n* 我先说 wǒ xiān shuō : « Je parle en premier »", 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:57,101 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:57,101 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:57,101 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:57,101 INFO sqlalchemy.engine.Engine [cached since 0.1406s ago] ('ZH_9',)
# 2025-07-23 23:27:57,102 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:57,102 INFO sqlalchemy.engine.Engine [cached since 0.1423s ago] ('ZH_9_G4', '"Un petit peu" avec 有点儿 yǒu diǎnr ou 一点儿 yī diǎnr', "**有点儿 yǒu diǎnr**\n有点儿 yǒu diǎnr ou simplement 有点 yǒu diǎn est utilisé avant un adjectif. Il est généralement employé dans des phrases négatives, pou ... (499 characters truncated) ... 宜一点儿 nǐ piányi yī diǎnr : « Baisse un peu le prix »\n* 你快一点儿 nǐ kuài yī diǎnr : « Dépêche-toi un peu »\n* 你慢一点儿 nǐ màn yī diǎnr : « Ralentis un peu »", 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:57,102 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:57,102 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:57,103 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:57,103 INFO sqlalchemy.engine.Engine [cached since 0.1419s ago] ('ZH_9',)
# 2025-07-23 23:27:57,103 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:57,103 INFO sqlalchemy.engine.Engine [cached since 0.1438s ago] ('ZH_9_G5', 'Utiliser 比较 bǐjiào devant un verbe', "Nous avons vu dans la leçon précédente que l'adverbe 比较 bǐjiào signifie « relativement, plutôt » et qu'il était employé devant un adjectif afin de le ... (162 characters truncated) ... iào xǐhuan : « Je préfère »\n* 我不喜欢坐车，我比较喜欢走路 wǒ bù xǐhuan zuò chē, wǒ bǐjiào xǐhuan zǒulù : « Je n'aime pas prendre la voiture, je préfère marcher »", 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:57,103 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:57,104 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:57,104 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:57,104 INFO sqlalchemy.engine.Engine [cached since 0.1435s ago] ('ZH_9',)
# 2025-07-23 23:27:57,104 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:57,105 INFO sqlalchemy.engine.Engine [cached since 0.1453s ago] ('ZH_9_G6', 'Les particules modales placées en fin de phrase', 'Quelques particules modales sont habituellement rajoutées en fin de phrase pour donner un ton particulier à la phrase, en voici quelques exemples :\n ... (334 characters truncated) ... .\n\nIl existe également des interjections placées en début de phrase :\n\n* 嗯 en : équivalent du « hum... » français\n* 哎呀 āiyā : marque la surprise', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:57,105 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Add Characters

# %%
engine, session = init_db()

directory_path = f'../data/{language_id}/character'

if not os.path.exists(directory_path):
    raise FileNotFoundError(f"No character files found for {language_id}.")

characters = []

# List all elements (files and directories) in the specified directory and get their full paths
elements_paths = [os.path.join(directory_path, element) for element in os.listdir(directory_path)]
for character_file in elements_paths:
    if os.path.isfile(character_file) and character_file.endswith('.csv'):
        unit_id = re.sub("[^0-9]", "", os.path.basename(character_file))
        print(f"Processing: {unit_id}")
        df = pd.read_csv(character_file)
        for idx, row in enumerate(df.itertuples(index=False)):
            characters.append(
                CalligraphyCharacter(
                    id=f"{language_id.upper()}_{unit_id}_C{idx + 1}",
                    character=row.character,
                    components=row.components,
                    phonetic=row.phonetic,
                    meaning=row.meaning,
                    example_word=row.example_word,
                    parent=session.query(Unit).filter(Unit.id == f"{language_id.upper()}_{unit_id}").first()
                )
            )
inserts(session, characters)
session.close()
# Out:
# 2025-07-23 23:27:57,110 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:57,110 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("language")
# 2025-07-23 23:27:57,110 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:57,111 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-23 23:27:57,111 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:57,111 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-23 23:27:57,111 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:57,112 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-23 23:27:57,112 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:57,112 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-23 23:27:57,112 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:57,112 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-23 23:27:57,112 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-23 23:27:57,113 INFO sqlalchemy.engine.Engine COMMIT
# Processing: 2
# 2025-07-23 23:27:57,115 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:57,115 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,115 INFO sqlalchemy.engine.Engine [generated in 0.00016s] ('ZH_2', 1, 0)
# 2025-07-23 23:27:57,116 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,116 INFO sqlalchemy.engine.Engine [cached since 0.0009518s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:57,117 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,117 INFO sqlalchemy.engine.Engine [cached since 0.001609s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:57,117 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,118 INFO sqlalchemy.engine.Engine [cached since 0.002261s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:57,118 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,118 INFO sqlalchemy.engine.Engine [cached since 0.002941s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:57,119 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,119 INFO sqlalchemy.engine.Engine [cached since 0.003636s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:57,119 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,120 INFO sqlalchemy.engine.Engine [cached since 0.004213s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:57,120 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,120 INFO sqlalchemy.engine.Engine [cached since 0.00491s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:57,121 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,121 INFO sqlalchemy.engine.Engine [cached since 0.005518s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:57,121 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,121 INFO sqlalchemy.engine.Engine [cached since 0.006106s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:57,122 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,122 INFO sqlalchemy.engine.Engine [cached since 0.006664s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:57,122 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,123 INFO sqlalchemy.engine.Engine [cached since 0.007262s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:57,123 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,123 INFO sqlalchemy.engine.Engine [cached since 0.008004s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:57,124 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,124 INFO sqlalchemy.engine.Engine [cached since 0.008538s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:57,124 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,125 INFO sqlalchemy.engine.Engine [cached since 0.009174s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:57,125 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,125 INFO sqlalchemy.engine.Engine [cached since 0.009704s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:57,125 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,126 INFO sqlalchemy.engine.Engine [cached since 0.01026s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:57,126 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,126 INFO sqlalchemy.engine.Engine [cached since 0.01083s ago] ('ZH_2', 1, 0)
# 2025-07-23 23:27:57,127 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,127 INFO sqlalchemy.engine.Engine [cached since 0.01148s ago] ('ZH_2', 1, 0)
# Processing: 3
# 2025-07-23 23:27:57,128 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,129 INFO sqlalchemy.engine.Engine [cached since 0.01322s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:57,129 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,129 INFO sqlalchemy.engine.Engine [cached since 0.0138s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:57,130 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,130 INFO sqlalchemy.engine.Engine [cached since 0.01434s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:57,130 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,130 INFO sqlalchemy.engine.Engine [cached since 0.01494s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:57,131 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,131 INFO sqlalchemy.engine.Engine [cached since 0.01548s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:57,131 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,131 INFO sqlalchemy.engine.Engine [cached since 0.01602s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:57,132 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,132 INFO sqlalchemy.engine.Engine [cached since 0.01663s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:57,132 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,133 INFO sqlalchemy.engine.Engine [cached since 0.01717s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:57,133 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,133 INFO sqlalchemy.engine.Engine [cached since 0.01769s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:57,133 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,134 INFO sqlalchemy.engine.Engine [cached since 0.01824s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:57,134 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,134 INFO sqlalchemy.engine.Engine [cached since 0.01885s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:57,135 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,135 INFO sqlalchemy.engine.Engine [cached since 0.01937s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:57,135 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,135 INFO sqlalchemy.engine.Engine [cached since 0.01988s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:57,136 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,136 INFO sqlalchemy.engine.Engine [cached since 0.02042s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:57,136 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,136 INFO sqlalchemy.engine.Engine [cached since 0.02094s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:57,137 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,137 INFO sqlalchemy.engine.Engine [cached since 0.02148s ago] ('ZH_3', 1, 0)
# 2025-07-23 23:27:57,137 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,137 INFO sqlalchemy.engine.Engine [cached since 0.02206s ago] ('ZH_3', 1, 0)
# Processing: 1
# 2025-07-23 23:27:57,139 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,139 INFO sqlalchemy.engine.Engine [cached since 0.02366s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:57,139 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,140 INFO sqlalchemy.engine.Engine [cached since 0.02421s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:57,140 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,140 INFO sqlalchemy.engine.Engine [cached since 0.02481s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:57,141 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,141 INFO sqlalchemy.engine.Engine [cached since 0.02539s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:57,141 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,141 INFO sqlalchemy.engine.Engine [cached since 0.02609s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:57,142 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,142 INFO sqlalchemy.engine.Engine [cached since 0.02662s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:57,142 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,142 INFO sqlalchemy.engine.Engine [cached since 0.02716s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:57,143 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,143 INFO sqlalchemy.engine.Engine [cached since 0.02766s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:57,143 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,144 INFO sqlalchemy.engine.Engine [cached since 0.02821s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:57,144 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,144 INFO sqlalchemy.engine.Engine [cached since 0.02875s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:57,144 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,145 INFO sqlalchemy.engine.Engine [cached since 0.02928s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:57,145 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,145 INFO sqlalchemy.engine.Engine [cached since 0.02988s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:57,146 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,146 INFO sqlalchemy.engine.Engine [cached since 0.03042s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:57,146 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,146 INFO sqlalchemy.engine.Engine [cached since 0.03093s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:57,147 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,147 INFO sqlalchemy.engine.Engine [cached since 0.03149s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:57,147 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,147 INFO sqlalchemy.engine.Engine [cached since 0.03204s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:57,148 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,148 INFO sqlalchemy.engine.Engine [cached since 0.03257s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:57,148 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,148 INFO sqlalchemy.engine.Engine [cached since 0.03315s ago] ('ZH_1', 1, 0)
# 2025-07-23 23:27:57,149 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,149 INFO sqlalchemy.engine.Engine [cached since 0.03371s ago] ('ZH_1', 1, 0)
# Processing: 4
# 2025-07-23 23:27:57,151 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,151 INFO sqlalchemy.engine.Engine [cached since 0.03549s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:57,151 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,152 INFO sqlalchemy.engine.Engine [cached since 0.03628s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:57,152 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,152 INFO sqlalchemy.engine.Engine [cached since 0.03688s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:57,153 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,153 INFO sqlalchemy.engine.Engine [cached since 0.03745s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:57,153 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,153 INFO sqlalchemy.engine.Engine [cached since 0.03797s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:57,154 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,154 INFO sqlalchemy.engine.Engine [cached since 0.03855s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:57,154 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,154 INFO sqlalchemy.engine.Engine [cached since 0.03909s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:57,155 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,155 INFO sqlalchemy.engine.Engine [cached since 0.03966s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:57,155 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,156 INFO sqlalchemy.engine.Engine [cached since 0.04022s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:57,156 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,156 INFO sqlalchemy.engine.Engine [cached since 0.04083s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:57,157 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,157 INFO sqlalchemy.engine.Engine [cached since 0.04138s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:57,157 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,157 INFO sqlalchemy.engine.Engine [cached since 0.04192s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:57,158 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,158 INFO sqlalchemy.engine.Engine [cached since 0.04245s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:57,158 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,158 INFO sqlalchemy.engine.Engine [cached since 0.04296s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:57,159 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,159 INFO sqlalchemy.engine.Engine [cached since 0.04345s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:57,159 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,159 INFO sqlalchemy.engine.Engine [cached since 0.04398s ago] ('ZH_4', 1, 0)
# 2025-07-23 23:27:57,160 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,160 INFO sqlalchemy.engine.Engine [cached since 0.04447s ago] ('ZH_4', 1, 0)
# Processing: 5
# 2025-07-23 23:27:57,161 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,161 INFO sqlalchemy.engine.Engine [cached since 0.0461s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:57,162 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,162 INFO sqlalchemy.engine.Engine [cached since 0.04663s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:57,162 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,163 INFO sqlalchemy.engine.Engine [cached since 0.04716s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:57,163 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,163 INFO sqlalchemy.engine.Engine [cached since 0.04766s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:57,163 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,163 INFO sqlalchemy.engine.Engine [cached since 0.04815s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:57,164 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,164 INFO sqlalchemy.engine.Engine [cached since 0.04867s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:57,164 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,165 INFO sqlalchemy.engine.Engine [cached since 0.0492s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:57,165 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,165 INFO sqlalchemy.engine.Engine [cached since 0.04972s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:57,165 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,166 INFO sqlalchemy.engine.Engine [cached since 0.05025s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:57,166 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,166 INFO sqlalchemy.engine.Engine [cached since 0.05077s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:57,167 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,167 INFO sqlalchemy.engine.Engine [cached since 0.05132s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:57,167 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,167 INFO sqlalchemy.engine.Engine [cached since 0.05186s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:57,168 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,168 INFO sqlalchemy.engine.Engine [cached since 0.05247s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:57,168 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,168 INFO sqlalchemy.engine.Engine [cached since 0.053s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:57,169 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,169 INFO sqlalchemy.engine.Engine [cached since 0.05353s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:57,169 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,170 INFO sqlalchemy.engine.Engine [cached since 0.05418s ago] ('ZH_5', 1, 0)
# 2025-07-23 23:27:57,170 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,170 INFO sqlalchemy.engine.Engine [cached since 0.05469s ago] ('ZH_5', 1, 0)
# Processing: 7
# 2025-07-23 23:27:57,171 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,172 INFO sqlalchemy.engine.Engine [cached since 0.05631s ago] ('ZH_7', 1, 0)
# 2025-07-23 23:27:57,172 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,172 INFO sqlalchemy.engine.Engine [cached since 0.05694s ago] ('ZH_7', 1, 0)
# 2025-07-23 23:27:57,173 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,173 INFO sqlalchemy.engine.Engine [cached since 0.0575s ago] ('ZH_7', 1, 0)
# 2025-07-23 23:27:57,173 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,173 INFO sqlalchemy.engine.Engine [cached since 0.05804s ago] ('ZH_7', 1, 0)
# 2025-07-23 23:27:57,174 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,174 INFO sqlalchemy.engine.Engine [cached since 0.05859s ago] ('ZH_7', 1, 0)
# 2025-07-23 23:27:57,174 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,174 INFO sqlalchemy.engine.Engine [cached since 0.05911s ago] ('ZH_7', 1, 0)
# 2025-07-23 23:27:57,175 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,175 INFO sqlalchemy.engine.Engine [cached since 0.05964s ago] ('ZH_7', 1, 0)
# 2025-07-23 23:27:57,175 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,176 INFO sqlalchemy.engine.Engine [cached since 0.0602s ago] ('ZH_7', 1, 0)
# 2025-07-23 23:27:57,176 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,176 INFO sqlalchemy.engine.Engine [cached since 0.06071s ago] ('ZH_7', 1, 0)
# 2025-07-23 23:27:57,176 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,177 INFO sqlalchemy.engine.Engine [cached since 0.06126s ago] ('ZH_7', 1, 0)
# 2025-07-23 23:27:57,177 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,177 INFO sqlalchemy.engine.Engine [cached since 0.06181s ago] ('ZH_7', 1, 0)
# 2025-07-23 23:27:57,178 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,178 INFO sqlalchemy.engine.Engine [cached since 0.06237s ago] ('ZH_7', 1, 0)
# 2025-07-23 23:27:57,178 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,178 INFO sqlalchemy.engine.Engine [cached since 0.06291s ago] ('ZH_7', 1, 0)
# 2025-07-23 23:27:57,179 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,179 INFO sqlalchemy.engine.Engine [cached since 0.06344s ago] ('ZH_7', 1, 0)
# 2025-07-23 23:27:57,179 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,179 INFO sqlalchemy.engine.Engine [cached since 0.0639s ago] ('ZH_7', 1, 0)
# 2025-07-23 23:27:57,180 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,180 INFO sqlalchemy.engine.Engine [cached since 0.06441s ago] ('ZH_7', 1, 0)
# 2025-07-23 23:27:57,180 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,180 INFO sqlalchemy.engine.Engine [cached since 0.06495s ago] ('ZH_7', 1, 0)
# 2025-07-23 23:27:57,181 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,181 INFO sqlalchemy.engine.Engine [cached since 0.06548s ago] ('ZH_7', 1, 0)
# Processing: 6
# 2025-07-23 23:27:57,182 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,182 INFO sqlalchemy.engine.Engine [cached since 0.067s ago] ('ZH_6', 1, 0)
# 2025-07-23 23:27:57,183 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,183 INFO sqlalchemy.engine.Engine [cached since 0.06758s ago] ('ZH_6', 1, 0)
# 2025-07-23 23:27:57,183 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,184 INFO sqlalchemy.engine.Engine [cached since 0.06816s ago] ('ZH_6', 1, 0)
# 2025-07-23 23:27:57,184 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,184 INFO sqlalchemy.engine.Engine [cached since 0.06871s ago] ('ZH_6', 1, 0)
# 2025-07-23 23:27:57,185 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,185 INFO sqlalchemy.engine.Engine [cached since 0.06929s ago] ('ZH_6', 1, 0)
# 2025-07-23 23:27:57,185 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-23 23:27:57,185 INFO sqlalchemy.engine.Engine [cached since 0.06982s ago] ('ZH_6', 1, 0)
# ...
# 2025-07-23 23:27:58,088 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:58,089 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:58,090 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:58,090 INFO sqlalchemy.engine.Engine [cached since 0.786s ago] ('ZH_8',)
# 2025-07-23 23:27:58,091 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:58,092 INFO sqlalchemy.engine.Engine [cached since 0.7892s ago] ('ZH_8_C16', '做', '亻 (clef : homme) + 故', 'zuò', 'Faire', '你做什么 ? Nǐ zuò shénme ? Que fais-tu ?', 0, '2025-07-23', 'ZH_8')
# 2025-07-23 23:27:58,093 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:58,095 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:58,096 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:58,096 INFO sqlalchemy.engine.Engine [cached since 0.7923s ago] ('ZH_9',)
# 2025-07-23 23:27:58,098 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:58,098 INFO sqlalchemy.engine.Engine [cached since 0.7956s ago] ('ZH_9_C1', '班', '王 (clef : jade) + 6 traits', 'bān', 'Groupe', '上班 shàngbān : Aller au travail', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:58,100 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:58,102 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:58,103 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:58,104 INFO sqlalchemy.engine.Engine [cached since 0.7996s ago] ('ZH_9',)
# 2025-07-23 23:27:58,104 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:58,105 INFO sqlalchemy.engine.Engine [cached since 0.8021s ago] ('ZH_9_C2', '车', 'Pictogramme', 'chē', 'Véhicule', '火车 huǒchē : Train', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:58,105 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:58,106 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:58,106 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:58,106 INFO sqlalchemy.engine.Engine [cached since 0.8023s ago] ('ZH_9',)
# 2025-07-23 23:27:58,107 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:58,107 INFO sqlalchemy.engine.Engine [cached since 0.8044s ago] ('ZH_9_C3', '公', '八 (clef : huit) + 2 traits', 'gōng', 'Public', '公交车 gōngjiāochē : Bus', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:58,107 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:58,108 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:58,108 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:58,109 INFO sqlalchemy.engine.Engine [cached since 0.8046s ago] ('ZH_9',)
# 2025-07-23 23:27:58,109 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:58,110 INFO sqlalchemy.engine.Engine [cached since 0.8069s ago] ('ZH_9_C4', '后', '厂 + 口 (clef : bouche)', 'hòu', 'Après/ensuite', '以后 yǐhòu : Après', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:58,110 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:58,110 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:58,111 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:58,111 INFO sqlalchemy.engine.Engine [cached since 0.8068s ago] ('ZH_9',)
# 2025-07-23 23:27:58,112 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:58,112 INFO sqlalchemy.engine.Engine [cached since 0.8093s ago] ('ZH_9_C5', '火', 'Pictogramme', 'huǒ', 'Feu', '火车 huǒchē : Train', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:58,112 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:58,113 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:58,113 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:58,113 INFO sqlalchemy.engine.Engine [cached since 0.8089s ago] ('ZH_9',)
# 2025-07-23 23:27:58,113 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:58,113 INFO sqlalchemy.engine.Engine [cached since 0.8109s ago] ('ZH_9_C6', '交', '亠 (clef : tête) + 4 traits', 'jiāo', 'Échange', '公交车 gōngjiāochē : Bus', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:58,114 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:58,114 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:58,115 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:58,115 INFO sqlalchemy.engine.Engine [cached since 0.8105s ago] ('ZH_9',)
# 2025-07-23 23:27:58,115 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:58,115 INFO sqlalchemy.engine.Engine [cached since 0.8124s ago] ('ZH_9_C7', '开', '廾 (clef : mains) + 1 trait', 'kāi', 'Ouvrir', '开车 kāichē : Conduire', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:58,115 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:58,116 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:58,116 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:58,116 INFO sqlalchemy.engine.Engine [cached since 0.812s ago] ('ZH_9',)
# 2025-07-23 23:27:58,116 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:58,117 INFO sqlalchemy.engine.Engine [cached since 0.814s ago] ('ZH_9_C8', '每', '母 (clef : mère) + 2 traits', 'měi', 'Chaque', '每天 měitiān : Tous les jours', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:58,117 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:58,117 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:58,118 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:58,118 INFO sqlalchemy.engine.Engine [cached since 0.8136s ago] ('ZH_9',)
# 2025-07-23 23:27:58,118 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:58,118 INFO sqlalchemy.engine.Engine [cached since 0.8156s ago] ('ZH_9_C9', '然', '月 + 犬 + 灬 (clef : feu)', 'rán', 'Cependant', '然后 ránhòu : Ensuite', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:58,118 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:58,119 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:58,119 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:58,119 INFO sqlalchemy.engine.Engine [cached since 0.8152s ago] ('ZH_9',)
# 2025-07-23 23:27:58,120 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:58,120 INFO sqlalchemy.engine.Engine [cached since 0.8171s ago] ('ZH_9_C10', '始', '女 (clef : femme) + 台', 'shǐ', 'Débuter', '开始 kāishǐ : Commencer', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:58,120 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:58,121 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:58,121 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:58,121 INFO sqlalchemy.engine.Engine [cached since 0.8167s ago] ('ZH_9',)
# 2025-07-23 23:27:58,121 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:58,121 INFO sqlalchemy.engine.Engine [cached since 0.8187s ago] ('ZH_9_C11', '同', '口 (clef : bouche) + 门', 'tóng', 'Identique', "同意 tóngyì : Être d'accord", 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:58,122 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:58,122 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:58,122 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:58,122 INFO sqlalchemy.engine.Engine [cached since 0.8183s ago] ('ZH_9',)
# 2025-07-23 23:27:58,123 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:58,123 INFO sqlalchemy.engine.Engine [cached since 0.8202s ago] ('ZH_9_C12', '先', '儿 (clef : fils) + 4 traits', 'xiān', 'Premièrement', "你先吃饭吧 nǐ xiān chīfàn ba : Mange d'abord !", 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:58,123 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:58,124 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:58,124 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:58,124 INFO sqlalchemy.engine.Engine [cached since 0.8199s ago] ('ZH_9',)
# 2025-07-23 23:27:58,124 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:58,124 INFO sqlalchemy.engine.Engine [cached since 0.8218s ago] ('ZH_9_C13', '意', '心 (clef : cœur) + 音', 'yì', 'Signification', "同意 tóngyì : Être d'accord", 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:58,125 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:58,125 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:58,125 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:58,125 INFO sqlalchemy.engine.Engine [cached since 0.8213s ago] ('ZH_9',)
# 2025-07-23 23:27:58,126 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:58,126 INFO sqlalchemy.engine.Engine [cached since 0.8233s ago] ('ZH_9_C14', '园', '囗 (clef : enceinte) + 元', 'yuán', 'Jardin', '公园 gōngyuán : Parc public', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:58,126 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:58,127 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:58,127 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:58,127 INFO sqlalchemy.engine.Engine [cached since 0.8229s ago] ('ZH_9',)
# 2025-07-23 23:27:58,127 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:58,128 INFO sqlalchemy.engine.Engine [cached since 0.8249s ago] ('ZH_9_C15', '自', '自 (clef : personnel)', 'zì', 'Soi-même', '自行车 zìxíngchē : Vélo', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:58,128 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-23 23:27:58,128 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-23 23:27:58,129 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.last_seen AS unit_last_seen, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-23 23:27:58,129 INFO sqlalchemy.engine.Engine [cached since 0.8245s ago] ('ZH_9',)
# 2025-07-23 23:27:58,129 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-23 23:27:58,129 INFO sqlalchemy.engine.Engine [cached since 0.8265s ago] ('ZH_9_C16', '坐', '土 (clef : sol) + 从', 'zuò', "S'asseoir", '坐车 zuò chē : Prendre un véhicule', 0, '2025-07-23', 'ZH_9')
# 2025-07-23 23:27:58,129 INFO sqlalchemy.engine.Engine COMMIT
