# %%
import json
import pandas as pd
import os
import re
from lapp.dbms import init_db, inserts, modify, delete, find_by_attr
from lapp.tables import Unit, Vocabulary, GrammarRule

# %%
language_name = "zh"

# %% [markdown]
# ## Add Units

# %%
# Initialize the database connection and create db file if it doesn't exist
engine, session = init_db(language_name)

if not os.path.exists(f'../data/{language_name}'):
    raise FileNotFoundError(f"Dataset for {language_name} not found.")

# Initialize the database
with open(f'../data/{language_name}/units.json', 'r') as f:
    units_array = json.load(f)
    
units = []
for idx, unit_data in enumerate(units_array):
    units.append(
        Unit(
            unit_id = f"{language_name.upper()}_{idx}",
            title = unit_data['title'],
            description = unit_data['description'],
            level = unit_data['level']
        )
    )
inserts(session, units)
session.close()
# Out:
# 2025-07-05 18:42:11,197 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:11,198 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-05 18:42:11,198 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-05 18:42:11,198 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("unit")
# 2025-07-05 18:42:11,198 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-05 18:42:11,198 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-05 18:42:11,199 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-05 18:42:11,199 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("calligraphy_character")
# 2025-07-05 18:42:11,199 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-05 18:42:11,199 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-05 18:42:11,199 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-05 18:42:11,199 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("grammar_rule")
# 2025-07-05 18:42:11,200 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-05 18:42:11,200 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-05 18:42:11,200 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-05 18:42:11,200 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("vocabulary")
# 2025-07-05 18:42:11,200 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-05 18:42:11,200 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-05 18:42:11,200 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-05 18:42:11,201 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("exercises")
# 2025-07-05 18:42:11,201 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-05 18:42:11,201 INFO sqlalchemy.engine.Engine
# CREATE TABLE unit (
# 	unit_id VARCHAR NOT NULL,
# 	title VARCHAR,
# 	description VARCHAR,
# 	level VARCHAR,
# 	PRIMARY KEY (unit_id)
# )
#
#
# 2025-07-05 18:42:11,201 INFO sqlalchemy.engine.Engine [no key 0.00012s] ()
# 2025-07-05 18:42:11,202 INFO sqlalchemy.engine.Engine CREATE INDEX ix_unit_title ON unit (title)
# 2025-07-05 18:42:11,202 INFO sqlalchemy.engine.Engine [no key 0.00010s] ()
# 2025-07-05 18:42:11,202 INFO sqlalchemy.engine.Engine CREATE INDEX ix_unit_unit_id ON unit (unit_id)
# 2025-07-05 18:42:11,203 INFO sqlalchemy.engine.Engine [no key 0.00012s] ()
# 2025-07-05 18:42:11,203 INFO sqlalchemy.engine.Engine
# CREATE TABLE calligraphy_character (
# 	learn_id VARCHAR NOT NULL,
# 	character VARCHAR,
# 	translation VARCHAR,
# 	components VARCHAR,
# 	score INTEGER,
# 	last_seen DATE,
# 	unit_id VARCHAR NOT NULL,
# 	PRIMARY KEY (learn_id),
# 	FOREIGN KEY(unit_id) REFERENCES unit (unit_id)
# )
#
#
# 2025-07-05 18:42:11,203 INFO sqlalchemy.engine.Engine [no key 0.00011s] ()
# 2025-07-05 18:42:11,204 INFO sqlalchemy.engine.Engine CREATE INDEX ix_calligraphy_character_learn_id ON calligraphy_character (learn_id)
# 2025-07-05 18:42:11,204 INFO sqlalchemy.engine.Engine [no key 0.00017s] ()
# 2025-07-05 18:42:11,204 INFO sqlalchemy.engine.Engine CREATE INDEX ix_calligraphy_character_character ON calligraphy_character (character)
# 2025-07-05 18:42:11,204 INFO sqlalchemy.engine.Engine [no key 0.00010s] ()
# 2025-07-05 18:42:11,205 INFO sqlalchemy.engine.Engine
# CREATE TABLE grammar_rule (
# 	learn_id VARCHAR NOT NULL,
# 	title VARCHAR,
# 	explanation VARCHAR,
# 	score INTEGER,
# 	last_seen DATE,
# 	unit_id VARCHAR NOT NULL,
# 	PRIMARY KEY (learn_id),
# 	FOREIGN KEY(unit_id) REFERENCES unit (unit_id)
# )
#
#
# 2025-07-05 18:42:11,205 INFO sqlalchemy.engine.Engine [no key 0.00011s] ()
# 2025-07-05 18:42:11,205 INFO sqlalchemy.engine.Engine CREATE INDEX ix_grammar_rule_title ON grammar_rule (title)
# 2025-07-05 18:42:11,205 INFO sqlalchemy.engine.Engine [no key 0.00010s] ()
# 2025-07-05 18:42:11,206 INFO sqlalchemy.engine.Engine CREATE INDEX ix_grammar_rule_learn_id ON grammar_rule (learn_id)
# 2025-07-05 18:42:11,206 INFO sqlalchemy.engine.Engine [no key 0.00011s] ()
# 2025-07-05 18:42:11,206 INFO sqlalchemy.engine.Engine
# CREATE TABLE vocabulary (
# 	learn_id VARCHAR NOT NULL,
# 	word VARCHAR,
# 	translation VARCHAR,
# 	phonetic VARCHAR,
# 	example_sentence VARCHAR,
# 	type VARCHAR,
# 	score INTEGER,
# 	last_seen DATE,
# 	unit_id VARCHAR NOT NULL,
# 	PRIMARY KEY (learn_id),
# 	FOREIGN KEY(unit_id) REFERENCES unit (unit_id)
# )
#
#
# 2025-07-05 18:42:11,206 INFO sqlalchemy.engine.Engine [no key 0.00010s] ()
# 2025-07-05 18:42:11,207 INFO sqlalchemy.engine.Engine CREATE INDEX ix_vocabulary_word ON vocabulary (word)
# 2025-07-05 18:42:11,208 INFO sqlalchemy.engine.Engine [no key 0.00025s] ()
# 2025-07-05 18:42:11,208 INFO sqlalchemy.engine.Engine CREATE INDEX ix_vocabulary_learn_id ON vocabulary (learn_id)
# 2025-07-05 18:42:11,208 INFO sqlalchemy.engine.Engine [no key 0.00012s] ()
# 2025-07-05 18:42:11,209 INFO sqlalchemy.engine.Engine
# CREATE TABLE exercises (
# 	learn_id VARCHAR NOT NULL,
# 	exercise_type VARCHAR,
# 	question VARCHAR,
# 	support VARCHAR,
# 	answer VARCHAR,
# 	score INTEGER,
# 	last_seen DATE,
# 	unit_id VARCHAR NOT NULL,
# 	PRIMARY KEY (learn_id),
# 	FOREIGN KEY(unit_id) REFERENCES unit (unit_id)
# )
#
#
# 2025-07-05 18:42:11,209 INFO sqlalchemy.engine.Engine [no key 0.00011s] ()
# 2025-07-05 18:42:11,209 INFO sqlalchemy.engine.Engine CREATE INDEX ix_exercises_learn_id ON exercises (learn_id)
# 2025-07-05 18:42:11,209 INFO sqlalchemy.engine.Engine [no key 0.00011s] ()
# 2025-07-05 18:42:11,210 INFO sqlalchemy.engine.Engine CREATE INDEX ix_exercises_exercise_type ON exercises (exercise_type)
# 2025-07-05 18:42:11,210 INFO sqlalchemy.engine.Engine [no key 0.00012s] ()
# 2025-07-05 18:42:11,210 INFO sqlalchemy.engine.Engine CREATE INDEX ix_exercises_question ON exercises (question)
# 2025-07-05 18:42:11,210 INFO sqlalchemy.engine.Engine [no key 0.00011s] ()
# 2025-07-05 18:42:11,211 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:11,215 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:11,216 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-05 18:42:11,216 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('ZH_0', 'Lecon introductive: Bonjour!', "A l'oral: Connaitre les salutations de base\nA l'ecrit: 5 caracteres", 'A1')
# 2025-07-05 18:42:11,216 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:11,217 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:11,217 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-05 18:42:11,217 INFO sqlalchemy.engine.Engine [cached since 0.001459s ago] ('ZH_1', "Unite 1: Comment t'appelles-tu?", "A l'oral: Savoir se presenter et presenter quelqu'un\nParler de sa nationalite\nA l'ecrit: 19 caracteres", 'A1')
# 2025-07-05 18:42:11,217 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:11,218 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:11,218 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-05 18:42:11,218 INFO sqlalchemy.engine.Engine [cached since 0.002373s ago] ('ZH_2', 'Unite 2: Un, deux, trois', "A l'oral: Compter de 1 a 9999\nSavoir enumerer des objets\nA l'ecrit: 19 caracteres", 'A1')
# 2025-07-05 18:42:11,218 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:11,219 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:11,219 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-05 18:42:11,219 INFO sqlalchemy.engine.Engine [cached since 0.003294s ago] ('ZH_3', "Unite 3: Aujourd'hui", "A l'oral: Savoir annoncer la date\nParler des moments de la journee et de l'heure\nA l'ecrit: 17 caracteres", 'A1')
# 2025-07-05 18:42:11,219 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:11,219 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:11,220 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-05 18:42:11,220 INFO sqlalchemy.engine.Engine [cached since 0.004137s ago] ('ZH_4', 'Unite 4: Ou allons-nous?', "A l'oral: Parler d'un evenement passe, d'une experience\nPouvoir se situer, parler ou l'on est, ou l'on va\nA l'ecrit: 17 caracteres", 'A1')
# 2025-07-05 18:42:11,220 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:11,220 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:11,220 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-05 18:42:11,221 INFO sqlalchemy.engine.Engine [cached since 0.004948s ago] ('ZH_5', 'Unite 5: Je ne suis pas vieux', "A l'oral: Decrire quelqu'un ou quelque chose\nUtilise les adjectifs\nA l'ecrit: 17 caracteres", 'A1')
# 2025-07-05 18:42:11,221 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:11,221 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:11,221 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-05 18:42:11,221 INFO sqlalchemy.engine.Engine [cached since 0.005877s ago] ('ZH_6', 'Unite 6: Ma famille', "A l'oral: Pouvoir presenter sa famille\nUtilise les demonstratifs\nA l'ecrit: 22 caracteres", 'A1')
# 2025-07-05 18:42:11,222 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:11,222 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:11,222 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-05 18:42:11,222 INFO sqlalchemy.engine.Engine [cached since 0.006846s ago] ('ZH_7', 'Unite 7: Mes amis', "A l'oral: Parler des ses amis\nParler des langues etrangeres\nComparer des gens ou des objets\nA l'ecrit: 18 caracteres", 'A1')
# 2025-07-05 18:42:11,223 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:11,223 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:11,223 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-05 18:42:11,223 INFO sqlalchemy.engine.Engine [cached since 0.007775s ago] ('ZH_8', "Unite 8: Qu'aimes-tu faire?", "A l'oral: Parler de ses activites favorites\nInterroger sur la maniere\nA l'ecrit: 16 caracteres", 'A2')
# 2025-07-05 18:42:11,224 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:11,224 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:11,224 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-05 18:42:11,224 INFO sqlalchemy.engine.Engine [cached since 0.00872s ago] ('ZH_9', 'Unite 9: Une journee classique', "A l'oral: Raconter sa journee\nParler des differents moyens de transport\nA l'ecrit: 16 caracteres", 'A2')
# 2025-07-05 18:42:11,225 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:11,225 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:11,225 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-05 18:42:11,225 INFO sqlalchemy.engine.Engine [cached since 0.009661s ago] ('ZH_10', 'Unite 10: Au travail', "A l'oral: Parler du monde du travail\nA l'ecrit: 18 caracteres", 'A2')
# 2025-07-05 18:42:11,226 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:11,226 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:11,226 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-05 18:42:11,226 INFO sqlalchemy.engine.Engine [cached since 0.0107s ago] ('ZH_11', 'Unite 11: Dans une grande ville', "A l'oral: Pouvoir demander son chemin\nSe reperer en ville\nA l'ecrit: 18 caracteres", 'A2')
# 2025-07-05 18:42:11,227 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:11,227 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:11,227 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-05 18:42:11,227 INFO sqlalchemy.engine.Engine [cached since 0.01171s ago] ('ZH_12', 'Unite 12: Faire des achats', "A l'oral: Negocier un prix\nFaire des achats\nA l'ecrit: 18 caracteres", 'A2')
# 2025-07-05 18:42:11,228 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:11,228 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:11,228 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-05 18:42:11,228 INFO sqlalchemy.engine.Engine [cached since 0.0127s ago] ('ZH_13', "Unite 13: En voyage a l'etranger", "A l'oral: Pouvoir raconter ou prevoir un voyage\nUtiliser 'Avant, apres, pendant'\nA l'ecrit: 17 caracteres", 'A2')
# 2025-07-05 18:42:11,229 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:11,229 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:11,229 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-05 18:42:11,229 INFO sqlalchemy.engine.Engine [cached since 0.01353s ago] ('ZH_14', 'Unite 14: La culture chinoise', "A l'oral: Decouvrir la culture chinoise\nParler des fetes et des vacances\nA l'ecrit: 19 caracteres", 'A2')
# 2025-07-05 18:42:11,229 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:11,230 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:11,230 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-05 18:42:11,230 INFO sqlalchemy.engine.Engine [cached since 0.01439s ago] ('ZH_15', 'Unite 15: A la maison', "A l'oral: Decrire une maison, un appartement\nUtiliser 吧 et les directionnels\nA l'ecrit: 17 caracteres", 'A2')
# 2025-07-05 18:42:11,230 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Add Vocabulary

# %%
# Initialize the database connection and create db file if it doesn't exist
engine, session = init_db(language_name)

directory_path = f'../data/{language_name}/vocabulary'

if not os.path.exists(directory_path):
    raise FileNotFoundError(f"No vocabulary found for {language_name}.")

vocs = []

# List all elements (files and directories) in the specified directory and get their full paths
elements_paths = [os.path.join(directory_path, element) for element in os.listdir(directory_path)]
for voc_file in elements_paths:
    if os.path.isfile(voc_file) and voc_file.endswith('.csv'):
        unit_id = re.sub("[^0-9]", "", os.path.basename(voc_file))
        df = pd.read_csv(voc_file)
        for idx, row in df.iterrows():
            vocs.append( 
                Vocabulary(
                    learn_id=f"{language_name.upper()}_{unit_id}_V{idx}",
                    word = row['word'],
                    translation = row["translation"],
                    phonetic = row["pinyin"],
                    example_sentence = row.get("example_sentence", ""),
                    type = row["type"],
                    parent=session.query(Unit).filter(Unit.unit_id == f"{language_name.upper()}_{unit_id}").first()
                )
            )
inserts(session, vocs)
session.close()
# Out:
# 2025-07-05 18:42:11,235 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:11,235 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-05 18:42:11,235 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-05 18:42:11,236 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-05 18:42:11,236 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-05 18:42:11,236 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-05 18:42:11,236 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-05 18:42:11,237 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-05 18:42:11,237 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-05 18:42:11,237 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-05 18:42:11,237 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-05 18:42:11,237 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:11,241 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:11,242 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,242 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('ZH_2', 1, 0)
# 2025-07-05 18:42:11,243 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,243 INFO sqlalchemy.engine.Engine [cached since 0.00131s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:11,244 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,244 INFO sqlalchemy.engine.Engine [cached since 0.002302s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:11,245 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,245 INFO sqlalchemy.engine.Engine [cached since 0.003002s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:11,246 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,246 INFO sqlalchemy.engine.Engine [cached since 0.003758s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:11,246 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,246 INFO sqlalchemy.engine.Engine [cached since 0.004449s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:11,247 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,247 INFO sqlalchemy.engine.Engine [cached since 0.005086s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:11,247 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,248 INFO sqlalchemy.engine.Engine [cached since 0.005674s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:11,248 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,248 INFO sqlalchemy.engine.Engine [cached since 0.006358s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:11,249 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,249 INFO sqlalchemy.engine.Engine [cached since 0.006963s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:11,249 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,249 INFO sqlalchemy.engine.Engine [cached since 0.007541s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:11,250 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,250 INFO sqlalchemy.engine.Engine [cached since 0.008111s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:11,250 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,251 INFO sqlalchemy.engine.Engine [cached since 0.008739s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:11,251 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,251 INFO sqlalchemy.engine.Engine [cached since 0.009322s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:11,252 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,252 INFO sqlalchemy.engine.Engine [cached since 0.009887s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:11,252 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,252 INFO sqlalchemy.engine.Engine [cached since 0.01056s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:11,253 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,253 INFO sqlalchemy.engine.Engine [cached since 0.0111s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:11,253 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,254 INFO sqlalchemy.engine.Engine [cached since 0.01166s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:11,254 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,254 INFO sqlalchemy.engine.Engine [cached since 0.0123s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:11,255 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,255 INFO sqlalchemy.engine.Engine [cached since 0.01287s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:11,255 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,255 INFO sqlalchemy.engine.Engine [cached since 0.01351s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:11,256 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,256 INFO sqlalchemy.engine.Engine [cached since 0.0142s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:11,257 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,257 INFO sqlalchemy.engine.Engine [cached since 0.01487s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:11,258 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,258 INFO sqlalchemy.engine.Engine [cached since 0.0165s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,259 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,259 INFO sqlalchemy.engine.Engine [cached since 0.01709s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,259 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,260 INFO sqlalchemy.engine.Engine [cached since 0.01767s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,260 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,260 INFO sqlalchemy.engine.Engine [cached since 0.01824s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,261 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,261 INFO sqlalchemy.engine.Engine [cached since 0.01881s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,261 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,261 INFO sqlalchemy.engine.Engine [cached since 0.01941s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,262 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,262 INFO sqlalchemy.engine.Engine [cached since 0.01998s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,262 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,262 INFO sqlalchemy.engine.Engine [cached since 0.02053s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,263 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,263 INFO sqlalchemy.engine.Engine [cached since 0.0211s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,264 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,264 INFO sqlalchemy.engine.Engine [cached since 0.02176s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,264 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,264 INFO sqlalchemy.engine.Engine [cached since 0.02229s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,265 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,265 INFO sqlalchemy.engine.Engine [cached since 0.02282s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,265 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,265 INFO sqlalchemy.engine.Engine [cached since 0.02337s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,266 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,266 INFO sqlalchemy.engine.Engine [cached since 0.0239s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,266 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,266 INFO sqlalchemy.engine.Engine [cached since 0.02447s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,267 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,267 INFO sqlalchemy.engine.Engine [cached since 0.02508s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,268 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,268 INFO sqlalchemy.engine.Engine [cached since 0.02571s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,268 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,268 INFO sqlalchemy.engine.Engine [cached since 0.0262s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,268 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,269 INFO sqlalchemy.engine.Engine [cached since 0.02669s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,269 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,269 INFO sqlalchemy.engine.Engine [cached since 0.02725s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,270 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,270 INFO sqlalchemy.engine.Engine [cached since 0.02787s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,270 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,270 INFO sqlalchemy.engine.Engine [cached since 0.02843s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,271 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,271 INFO sqlalchemy.engine.Engine [cached since 0.02905s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,271 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,272 INFO sqlalchemy.engine.Engine [cached since 0.02959s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,272 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,272 INFO sqlalchemy.engine.Engine [cached since 0.03019s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,273 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,273 INFO sqlalchemy.engine.Engine [cached since 0.03077s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,273 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,273 INFO sqlalchemy.engine.Engine [cached since 0.03137s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,274 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,274 INFO sqlalchemy.engine.Engine [cached since 0.03208s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,274 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,275 INFO sqlalchemy.engine.Engine [cached since 0.03266s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,275 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,275 INFO sqlalchemy.engine.Engine [cached since 0.03332s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,276 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,276 INFO sqlalchemy.engine.Engine [cached since 0.03399s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:11,277 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,277 INFO sqlalchemy.engine.Engine [cached since 0.03553s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:11,278 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,278 INFO sqlalchemy.engine.Engine [cached since 0.03614s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:11,279 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,279 INFO sqlalchemy.engine.Engine [cached since 0.03673s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:11,279 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,279 INFO sqlalchemy.engine.Engine [cached since 0.03746s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:11,280 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,280 INFO sqlalchemy.engine.Engine [cached since 0.03802s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:11,280 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,280 INFO sqlalchemy.engine.Engine [cached since 0.03857s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:11,281 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,281 INFO sqlalchemy.engine.Engine [cached since 0.03916s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:11,281 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,282 INFO sqlalchemy.engine.Engine [cached since 0.03971s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:11,282 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,282 INFO sqlalchemy.engine.Engine [cached since 0.04025s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:11,283 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,283 INFO sqlalchemy.engine.Engine [cached since 0.04089s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:11,283 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,283 INFO sqlalchemy.engine.Engine [cached since 0.04145s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:11,284 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,284 INFO sqlalchemy.engine.Engine [cached since 0.04199s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:11,284 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,284 INFO sqlalchemy.engine.Engine [cached since 0.04256s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:11,285 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,285 INFO sqlalchemy.engine.Engine [cached since 0.04308s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:11,285 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,286 INFO sqlalchemy.engine.Engine [cached since 0.0436s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:11,286 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,286 INFO sqlalchemy.engine.Engine [cached since 0.04416s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:11,286 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,287 INFO sqlalchemy.engine.Engine [cached since 0.04467s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:11,287 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,287 INFO sqlalchemy.engine.Engine [cached since 0.04524s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:11,288 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,288 INFO sqlalchemy.engine.Engine [cached since 0.04585s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:11,288 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,288 INFO sqlalchemy.engine.Engine [cached since 0.04638s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:11,289 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,289 INFO sqlalchemy.engine.Engine [cached since 0.047s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:11,289 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,290 INFO sqlalchemy.engine.Engine [cached since 0.04767s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:11,290 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,290 INFO sqlalchemy.engine.Engine [cached since 0.04827s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:11,291 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,291 INFO sqlalchemy.engine.Engine [cached since 0.04887s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:11,292 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,292 INFO sqlalchemy.engine.Engine [cached since 0.05049s ago] ('ZH_0', 1, 0)
# 2025-07-05 18:42:11,293 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,293 INFO sqlalchemy.engine.Engine [cached since 0.05112s ago] ('ZH_0', 1, 0)
# 2025-07-05 18:42:11,293 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,294 INFO sqlalchemy.engine.Engine [cached since 0.05172s ago] ('ZH_0', 1, 0)
# 2025-07-05 18:42:11,294 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,294 INFO sqlalchemy.engine.Engine [cached since 0.05228s ago] ('ZH_0', 1, 0)
# 2025-07-05 18:42:11,295 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,295 INFO sqlalchemy.engine.Engine [cached since 0.05285s ago] ('ZH_0', 1, 0)
# 2025-07-05 18:42:11,295 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,295 INFO sqlalchemy.engine.Engine [cached since 0.05336s ago] ('ZH_0', 1, 0)
# 2025-07-05 18:42:11,296 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,296 INFO sqlalchemy.engine.Engine [cached since 0.05398s ago] ('ZH_0', 1, 0)
# 2025-07-05 18:42:11,296 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,296 INFO sqlalchemy.engine.Engine [cached since 0.05455s ago] ('ZH_0', 1, 0)
# 2025-07-05 18:42:11,297 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,297 INFO sqlalchemy.engine.Engine [cached since 0.05508s ago] ('ZH_0', 1, 0)
# 2025-07-05 18:42:11,297 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,298 INFO sqlalchemy.engine.Engine [cached since 0.05565s ago] ('ZH_0', 1, 0)
# 2025-07-05 18:42:11,298 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,298 INFO sqlalchemy.engine.Engine [cached since 0.0562s ago] ('ZH_0', 1, 0)
# 2025-07-05 18:42:11,299 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,300 INFO sqlalchemy.engine.Engine [cached since 0.05765s ago] ('ZH_4', 1, 0)
# 2025-07-05 18:42:11,300 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,300 INFO sqlalchemy.engine.Engine [cached since 0.05817s ago] ('ZH_4', 1, 0)
# 2025-07-05 18:42:11,301 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,301 INFO sqlalchemy.engine.Engine [cached since 0.05871s ago] ('ZH_4', 1, 0)
# 2025-07-05 18:42:11,301 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,301 INFO sqlalchemy.engine.Engine [cached since 0.05924s ago] ('ZH_4', 1, 0)
# 2025-07-05 18:42:11,302 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,302 INFO sqlalchemy.engine.Engine [cached since 0.05976s ago] ('ZH_4', 1, 0)
# 2025-07-05 18:42:11,302 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,302 INFO sqlalchemy.engine.Engine [cached since 0.06034s ago] ('ZH_4', 1, 0)
# 2025-07-05 18:42:11,303 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,303 INFO sqlalchemy.engine.Engine [cached since 0.06105s ago] ('ZH_4', 1, 0)
# 2025-07-05 18:42:11,303 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,304 INFO sqlalchemy.engine.Engine [cached since 0.06159s ago] ('ZH_4', 1, 0)
# 2025-07-05 18:42:11,304 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,304 INFO sqlalchemy.engine.Engine [cached since 0.06214s ago] ('ZH_4', 1, 0)
# 2025-07-05 18:42:11,304 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,305 INFO sqlalchemy.engine.Engine [cached since 0.0627s ago] ('ZH_4', 1, 0)
# 2025-07-05 18:42:11,305 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,305 INFO sqlalchemy.engine.Engine [cached since 0.06326s ago] ('ZH_4', 1, 0)
# 2025-07-05 18:42:11,306 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,306 INFO sqlalchemy.engine.Engine [cached since 0.06393s ago] ('ZH_4', 1, 0)
# 2025-07-05 18:42:11,306 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,307 INFO sqlalchemy.engine.Engine [cached since 0.0646s ago] ('ZH_4', 1, 0)
# 2025-07-05 18:42:11,307 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,307 INFO sqlalchemy.engine.Engine [cached since 0.06523s ago] ('ZH_4', 1, 0)
# 2025-07-05 18:42:11,308 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,308 INFO sqlalchemy.engine.Engine [cached since 0.06579s ago] ('ZH_4', 1, 0)
# 2025-07-05 18:42:11,308 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,308 INFO sqlalchemy.engine.Engine [cached since 0.06631s ago] ('ZH_4', 1, 0)
# 2025-07-05 18:42:11,309 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,309 INFO sqlalchemy.engine.Engine [cached since 0.06689s ago] ('ZH_4', 1, 0)
# 2025-07-05 18:42:11,309 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,309 INFO sqlalchemy.engine.Engine [cached since 0.06745s ago] ('ZH_4', 1, 0)
# 2025-07-05 18:42:11,311 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,311 INFO sqlalchemy.engine.Engine [cached since 0.06895s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,311 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,311 INFO sqlalchemy.engine.Engine [cached since 0.06954s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,312 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,312 INFO sqlalchemy.engine.Engine [cached since 0.07013s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,312 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,313 INFO sqlalchemy.engine.Engine [cached since 0.07069s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,313 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,313 INFO sqlalchemy.engine.Engine [cached since 0.07129s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,314 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,314 INFO sqlalchemy.engine.Engine [cached since 0.07183s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,314 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,314 INFO sqlalchemy.engine.Engine [cached since 0.07236s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,315 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,315 INFO sqlalchemy.engine.Engine [cached since 0.07294s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,315 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,315 INFO sqlalchemy.engine.Engine [cached since 0.07341s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,316 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,316 INFO sqlalchemy.engine.Engine [cached since 0.07408s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,320 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,321 INFO sqlalchemy.engine.Engine [cached since 0.07922s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,323 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,324 INFO sqlalchemy.engine.Engine [cached since 0.08168s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,325 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,327 INFO sqlalchemy.engine.Engine [cached since 0.08452s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,335 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,339 INFO sqlalchemy.engine.Engine [cached since 0.09722s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,341 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,341 INFO sqlalchemy.engine.Engine [cached since 0.09875s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,341 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,341 INFO sqlalchemy.engine.Engine [cached since 0.09955s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,342 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,342 INFO sqlalchemy.engine.Engine [cached since 0.1003s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,343 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,344 INFO sqlalchemy.engine.Engine [cached since 0.1016s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,345 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,346 INFO sqlalchemy.engine.Engine [cached since 0.1039s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,348 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,348 INFO sqlalchemy.engine.Engine [cached since 0.1064s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,350 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,350 INFO sqlalchemy.engine.Engine [cached since 0.1079s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,350 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,351 INFO sqlalchemy.engine.Engine [cached since 0.1087s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,351 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,352 INFO sqlalchemy.engine.Engine [cached since 0.1096s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,352 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,352 INFO sqlalchemy.engine.Engine [cached since 0.1103s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,353 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,353 INFO sqlalchemy.engine.Engine [cached since 0.111s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,353 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,353 INFO sqlalchemy.engine.Engine [cached since 0.1115s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,354 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,354 INFO sqlalchemy.engine.Engine [cached since 0.1121s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:11,356 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,356 INFO sqlalchemy.engine.Engine [cached since 0.1139s ago] ('ZH_7', 1, 0)
# 2025-07-05 18:42:11,356 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,356 INFO sqlalchemy.engine.Engine [cached since 0.1146s ago] ('ZH_7', 1, 0)
# 2025-07-05 18:42:11,357 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,357 INFO sqlalchemy.engine.Engine [cached since 0.1151s ago] ('ZH_7', 1, 0)
# 2025-07-05 18:42:11,358 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,358 INFO sqlalchemy.engine.Engine [cached since 0.1157s ago] ('ZH_7', 1, 0)
# 2025-07-05 18:42:11,358 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,358 INFO sqlalchemy.engine.Engine [cached since 0.1163s ago] ('ZH_7', 1, 0)
# 2025-07-05 18:42:11,359 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,359 INFO sqlalchemy.engine.Engine [cached since 0.1169s ago] ('ZH_7', 1, 0)
# 2025-07-05 18:42:11,359 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,359 INFO sqlalchemy.engine.Engine [cached since 0.1174s ago] ('ZH_7', 1, 0)
# 2025-07-05 18:42:11,360 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:11,360 INFO sqlalchemy.engine.Engine [cached since 0.1179s ago] ('ZH_7', 1, 0)
# ...
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:12,890 INFO sqlalchemy.engine.Engine [cached since 1.254s ago] ('ZH_9',)
# 2025-07-05 18:42:12,890 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:12,890 INFO sqlalchemy.engine.Engine [cached since 1.257s ago] ('ZH_9_V4', '开', 'Conduire', 'Kāi', '', 'Verbes', 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:12,891 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:12,891 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:12,892 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:12,892 INFO sqlalchemy.engine.Engine [cached since 1.256s ago] ('ZH_9',)
# 2025-07-05 18:42:12,916 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:12,918 INFO sqlalchemy.engine.Engine [cached since 1.285s ago] ('ZH_9_V5', '开始', 'Commencer', 'Kāishǐ', '', 'Verbes', 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:12,920 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:12,927 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:12,929 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:12,929 INFO sqlalchemy.engine.Engine [cached since 1.294s ago] ('ZH_9',)
# 2025-07-05 18:42:12,931 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:12,932 INFO sqlalchemy.engine.Engine [cached since 1.298s ago] ('ZH_9_V6', '骑', 'Chevaucher', 'Qí', '', 'Verbes', 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:12,933 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:12,936 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:12,937 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:12,938 INFO sqlalchemy.engine.Engine [cached since 1.302s ago] ('ZH_9',)
# 2025-07-05 18:42:12,939 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:12,940 INFO sqlalchemy.engine.Engine [cached since 1.306s ago] ('ZH_9_V7', '上班', 'Commencer le travail', 'Shàngbān', '', 'Verbes', 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:12,941 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:12,943 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:12,944 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:12,945 INFO sqlalchemy.engine.Engine [cached since 1.309s ago] ('ZH_9',)
# 2025-07-05 18:42:12,946 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:12,947 INFO sqlalchemy.engine.Engine [cached since 1.314s ago] ('ZH_9_V8', '下班', 'Finir le travail', 'Xiàbān', '', 'Verbes', 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:12,949 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:12,951 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:12,952 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:12,953 INFO sqlalchemy.engine.Engine [cached since 1.317s ago] ('ZH_9',)
# 2025-07-05 18:42:12,954 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:12,955 INFO sqlalchemy.engine.Engine [cached since 1.321s ago] ('ZH_9_V9', '走路', 'Marcher', 'Zǒulù', '', 'Verbes', 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:12,956 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:12,959 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:12,960 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:12,961 INFO sqlalchemy.engine.Engine [cached since 1.325s ago] ('ZH_9',)
# 2025-07-05 18:42:12,963 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:12,964 INFO sqlalchemy.engine.Engine [cached since 1.331s ago] ('ZH_9_V10', '坐', "S'asseoir/prendre (véhicule)", 'Zuò', '', 'Verbes', 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:12,967 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:12,970 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:12,972 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:12,973 INFO sqlalchemy.engine.Engine [cached since 1.337s ago] ('ZH_9',)
# 2025-07-05 18:42:12,974 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:12,975 INFO sqlalchemy.engine.Engine [cached since 1.341s ago] ('ZH_9_V11', '游泳', 'Nager', 'Yóuyǒng', '', 'Verbes', 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:12,977 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:12,978 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:12,979 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:12,979 INFO sqlalchemy.engine.Engine [cached since 1.343s ago] ('ZH_9',)
# 2025-07-05 18:42:12,981 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:12,981 INFO sqlalchemy.engine.Engine [cached since 1.348s ago] ('ZH_9_V12', '无聊', 'Ennuyeux', 'Wúliáo', '', 'Adjectifs', 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:12,984 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:12,987 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:12,988 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:12,989 INFO sqlalchemy.engine.Engine [cached since 1.353s ago] ('ZH_9',)
# 2025-07-05 18:42:12,990 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:12,992 INFO sqlalchemy.engine.Engine [cached since 1.358s ago] ('ZH_9_V13', '有意思', 'Intéressant (polite)', 'Yǒu yìsi', '', 'Adjectifs', 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:12,994 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:12,998 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:12,999 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:12,999 INFO sqlalchemy.engine.Engine [cached since 1.363s ago] ('ZH_9',)
# 2025-07-05 18:42:13,000 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,000 INFO sqlalchemy.engine.Engine [cached since 1.367s ago] ('ZH_9_V14', '没意思', 'Inintéressant (polite)', 'Méi yìsi', '', 'Adjectifs', 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:13,001 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,002 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,002 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,003 INFO sqlalchemy.engine.Engine [cached since 1.367s ago] ('ZH_9',)
# 2025-07-05 18:42:13,003 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,004 INFO sqlalchemy.engine.Engine [cached since 1.37s ago] ('ZH_9_V15', '啊', "Particule modale d'exclamation", 'A', '', 'Divers', 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:13,004 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,006 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,006 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,006 INFO sqlalchemy.engine.Engine [cached since 1.37s ago] ('ZH_9',)
# 2025-07-05 18:42:13,007 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,007 INFO sqlalchemy.engine.Engine [cached since 1.374s ago] ('ZH_9_V16', '每', 'Chaque', 'Měi', '', 'Divers', 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:13,008 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,009 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,009 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,009 INFO sqlalchemy.engine.Engine [cached since 1.373s ago] ('ZH_9',)
# 2025-07-05 18:42:13,009 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,010 INFO sqlalchemy.engine.Engine [cached since 1.376s ago] ('ZH_9_V17', '然后', 'Ensuite', 'Ránhòu', '', 'Divers', 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:13,010 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,011 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,011 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,011 INFO sqlalchemy.engine.Engine [cached since 1.375s ago] ('ZH_9',)
# 2025-07-05 18:42:13,011 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,011 INFO sqlalchemy.engine.Engine [cached since 1.378s ago] ('ZH_9_V18', '同意', "Être d'accord", 'Tóngyì', '', 'Divers', 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:13,012 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,012 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,013 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,013 INFO sqlalchemy.engine.Engine [cached since 1.377s ago] ('ZH_9',)
# 2025-07-05 18:42:13,013 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,013 INFO sqlalchemy.engine.Engine [cached since 1.38s ago] ('ZH_9_V19', '先', "D'abord", 'Xiān', '', 'Divers', 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:13,014 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,017 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,022 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,024 INFO sqlalchemy.engine.Engine [cached since 1.388s ago] ('ZH_9',)
# 2025-07-05 18:42:13,025 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,026 INFO sqlalchemy.engine.Engine [cached since 1.392s ago] ('ZH_9_V20', '有点儿', 'Un petit peu', 'Yǒu diǎnr', '', 'Divers', 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:13,028 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,037 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,038 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,038 INFO sqlalchemy.engine.Engine [cached since 1.402s ago] ('ZH_9',)
# 2025-07-05 18:42:13,039 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,039 INFO sqlalchemy.engine.Engine [cached since 1.405s ago] ('ZH_9_V21', '公园', 'Parc public', 'Gōngyuán', '', 'Noms et expressions', 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:13,040 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,041 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,041 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,041 INFO sqlalchemy.engine.Engine [cached since 1.405s ago] ('ZH_9',)
# 2025-07-05 18:42:13,043 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,043 INFO sqlalchemy.engine.Engine [cached since 1.41s ago] ('ZH_9_V22', '看法', 'Point de vue', 'Kànfǎ', '', 'Noms et expressions', 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:13,044 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,046 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,046 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,047 INFO sqlalchemy.engine.Engine [cached since 1.411s ago] ('ZH_9',)
# 2025-07-05 18:42:13,047 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,047 INFO sqlalchemy.engine.Engine [cached since 1.414s ago] ('ZH_9_V23', '游泳池', 'Piscine', 'Yóuyǒngchí', '', 'Noms et expressions', 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:13,048 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Add Grammar Rules

# %%
# Initialize the database connection and create db file if it doesn't exist
engine, session = init_db(language_name)

directory_path = f'../data/{language_name}/grammar'

if not os.path.exists(directory_path):
    raise FileNotFoundError(f"No grammar files found for {language_name}.")

grammars = []

# List all elements (files and directories) in the specified directory and get their full paths
elements_paths = [os.path.join(directory_path, element) for element in os.listdir(directory_path)]
for grammar_file in elements_paths:
    if os.path.isfile(grammar_file) and grammar_file.endswith('.json'):
        unit_id = re.sub("[^0-9]", "", os.path.basename(grammar_file))
        with open(grammar_file, 'r') as f:
            grammar_data = json.load(f)
        for idx, row in enumerate(grammar_data):
            grammars.append( 
                GrammarRule(
                    learn_id=f"{language_name.upper()}_{unit_id}_G{idx + 1}",
                    title=row['title'],
                    explanation=row["content"],
                    parent=session.query(Unit).filter(Unit.unit_id == f"{language_name.upper()}_{unit_id}").first()
                )
            )
inserts(session, grammars)
session.close()
# Out:
# 2025-07-05 18:42:13,053 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,053 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-05 18:42:13,053 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-05 18:42:13,053 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-05 18:42:13,053 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-05 18:42:13,053 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-05 18:42:13,054 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-05 18:42:13,054 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-05 18:42:13,054 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-05 18:42:13,054 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-05 18:42:13,055 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-05 18:42:13,055 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,057 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,057 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,058 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('ZH_11', 1, 0)
# 2025-07-05 18:42:13,059 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,059 INFO sqlalchemy.engine.Engine [cached since 0.001318s ago] ('ZH_11', 1, 0)
# 2025-07-05 18:42:13,059 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,059 INFO sqlalchemy.engine.Engine [cached since 0.001925s ago] ('ZH_11', 1, 0)
# 2025-07-05 18:42:13,060 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,060 INFO sqlalchemy.engine.Engine [cached since 0.002504s ago] ('ZH_11', 1, 0)
# 2025-07-05 18:42:13,061 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,061 INFO sqlalchemy.engine.Engine [cached since 0.003716s ago] ('ZH_6', 1, 0)
# 2025-07-05 18:42:13,062 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,062 INFO sqlalchemy.engine.Engine [cached since 0.004283s ago] ('ZH_6', 1, 0)
# 2025-07-05 18:42:13,062 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,062 INFO sqlalchemy.engine.Engine [cached since 0.004839s ago] ('ZH_6', 1, 0)
# 2025-07-05 18:42:13,063 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,063 INFO sqlalchemy.engine.Engine [cached since 0.005524s ago] ('ZH_6', 1, 0)
# 2025-07-05 18:42:13,064 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,064 INFO sqlalchemy.engine.Engine [cached since 0.006723s ago] ('ZH_7', 1, 0)
# 2025-07-05 18:42:13,065 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,065 INFO sqlalchemy.engine.Engine [cached since 0.007298s ago] ('ZH_7', 1, 0)
# 2025-07-05 18:42:13,065 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,065 INFO sqlalchemy.engine.Engine [cached since 0.00787s ago] ('ZH_7', 1, 0)
# 2025-07-05 18:42:13,066 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,066 INFO sqlalchemy.engine.Engine [cached since 0.008498s ago] ('ZH_7', 1, 0)
# 2025-07-05 18:42:13,066 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,066 INFO sqlalchemy.engine.Engine [cached since 0.009052s ago] ('ZH_7', 1, 0)
# 2025-07-05 18:42:13,067 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,067 INFO sqlalchemy.engine.Engine [cached since 0.009556s ago] ('ZH_7', 1, 0)
# 2025-07-05 18:42:13,068 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,068 INFO sqlalchemy.engine.Engine [cached since 0.01051s ago] ('ZH_10', 1, 0)
# 2025-07-05 18:42:13,068 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,069 INFO sqlalchemy.engine.Engine [cached since 0.01109s ago] ('ZH_10', 1, 0)
# 2025-07-05 18:42:13,069 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,069 INFO sqlalchemy.engine.Engine [cached since 0.01166s ago] ('ZH_10', 1, 0)
# 2025-07-05 18:42:13,069 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,070 INFO sqlalchemy.engine.Engine [cached since 0.01219s ago] ('ZH_10', 1, 0)
# 2025-07-05 18:42:13,070 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,070 INFO sqlalchemy.engine.Engine [cached since 0.01284s ago] ('ZH_10', 1, 0)
# 2025-07-05 18:42:13,071 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,071 INFO sqlalchemy.engine.Engine [cached since 0.01333s ago] ('ZH_10', 1, 0)
# 2025-07-05 18:42:13,072 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,072 INFO sqlalchemy.engine.Engine [cached since 0.01429s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:13,072 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,072 INFO sqlalchemy.engine.Engine [cached since 0.01483s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:13,073 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,073 INFO sqlalchemy.engine.Engine [cached since 0.01551s ago] ('ZH_1', 1, 0)
# 2025-07-05 18:42:13,074 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,074 INFO sqlalchemy.engine.Engine [cached since 0.01643s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:13,074 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,074 INFO sqlalchemy.engine.Engine [cached since 0.01693s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:13,075 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,075 INFO sqlalchemy.engine.Engine [cached since 0.01744s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:13,075 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,075 INFO sqlalchemy.engine.Engine [cached since 0.01798s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:13,076 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,076 INFO sqlalchemy.engine.Engine [cached since 0.01861s ago] ('ZH_2', 1, 0)
# 2025-07-05 18:42:13,077 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,077 INFO sqlalchemy.engine.Engine [cached since 0.01967s ago] ('ZH_15', 1, 0)
# 2025-07-05 18:42:13,078 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,078 INFO sqlalchemy.engine.Engine [cached since 0.0202s ago] ('ZH_15', 1, 0)
# 2025-07-05 18:42:13,078 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,078 INFO sqlalchemy.engine.Engine [cached since 0.02069s ago] ('ZH_15', 1, 0)
# 2025-07-05 18:42:13,079 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,079 INFO sqlalchemy.engine.Engine [cached since 0.02127s ago] ('ZH_15', 1, 0)
# 2025-07-05 18:42:13,079 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,080 INFO sqlalchemy.engine.Engine [cached since 0.02216s ago] ('ZH_14', 1, 0)
# 2025-07-05 18:42:13,080 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,080 INFO sqlalchemy.engine.Engine [cached since 0.02268s ago] ('ZH_14', 1, 0)
# 2025-07-05 18:42:13,081 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,081 INFO sqlalchemy.engine.Engine [cached since 0.02335s ago] ('ZH_14', 1, 0)
# 2025-07-05 18:42:13,081 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,081 INFO sqlalchemy.engine.Engine [cached since 0.02402s ago] ('ZH_14', 1, 0)
# 2025-07-05 18:42:13,082 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,082 INFO sqlalchemy.engine.Engine [cached since 0.02467s ago] ('ZH_14', 1, 0)
# 2025-07-05 18:42:13,083 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,083 INFO sqlalchemy.engine.Engine [cached since 0.0259s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:13,084 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,084 INFO sqlalchemy.engine.Engine [cached since 0.02656s ago] ('ZH_3', 1, 0)
# 2025-07-05 18:42:13,085 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,085 INFO sqlalchemy.engine.Engine [cached since 0.02787s ago] ('ZH_8', 1, 0)
# 2025-07-05 18:42:13,086 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,086 INFO sqlalchemy.engine.Engine [cached since 0.02851s ago] ('ZH_8', 1, 0)
# 2025-07-05 18:42:13,086 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,087 INFO sqlalchemy.engine.Engine [cached since 0.02922s ago] ('ZH_8', 1, 0)
# 2025-07-05 18:42:13,087 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,088 INFO sqlalchemy.engine.Engine [cached since 0.03009s ago] ('ZH_8', 1, 0)
# 2025-07-05 18:42:13,088 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,088 INFO sqlalchemy.engine.Engine [cached since 0.0307s ago] ('ZH_8', 1, 0)
# 2025-07-05 18:42:13,090 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,090 INFO sqlalchemy.engine.Engine [cached since 0.03236s ago] ('ZH_4', 1, 0)
# 2025-07-05 18:42:13,090 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,091 INFO sqlalchemy.engine.Engine [cached since 0.03306s ago] ('ZH_4', 1, 0)
# 2025-07-05 18:42:13,091 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,091 INFO sqlalchemy.engine.Engine [cached since 0.03373s ago] ('ZH_4', 1, 0)
# 2025-07-05 18:42:13,092 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,092 INFO sqlalchemy.engine.Engine [cached since 0.03446s ago] ('ZH_4', 1, 0)
# 2025-07-05 18:42:13,093 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,093 INFO sqlalchemy.engine.Engine [cached since 0.03536s ago] ('ZH_4', 1, 0)
# 2025-07-05 18:42:13,094 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,094 INFO sqlalchemy.engine.Engine [cached since 0.03681s ago] ('ZH_13', 1, 0)
# 2025-07-05 18:42:13,095 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,095 INFO sqlalchemy.engine.Engine [cached since 0.03753s ago] ('ZH_13', 1, 0)
# 2025-07-05 18:42:13,095 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,096 INFO sqlalchemy.engine.Engine [cached since 0.03809s ago] ('ZH_13', 1, 0)
# 2025-07-05 18:42:13,096 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,096 INFO sqlalchemy.engine.Engine [cached since 0.03867s ago] ('ZH_13', 1, 0)
# 2025-07-05 18:42:13,097 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,097 INFO sqlalchemy.engine.Engine [cached since 0.03937s ago] ('ZH_13', 1, 0)
# 2025-07-05 18:42:13,098 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,098 INFO sqlalchemy.engine.Engine [cached since 0.04084s ago] ('ZH_12', 1, 0)
# 2025-07-05 18:42:13,099 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,099 INFO sqlalchemy.engine.Engine [cached since 0.04168s ago] ('ZH_12', 1, 0)
# 2025-07-05 18:42:13,100 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,100 INFO sqlalchemy.engine.Engine [cached since 0.0424s ago] ('ZH_12', 1, 0)
# 2025-07-05 18:42:13,101 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,101 INFO sqlalchemy.engine.Engine [cached since 0.04323s ago] ('ZH_12', 1, 0)
# 2025-07-05 18:42:13,101 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,101 INFO sqlalchemy.engine.Engine [cached since 0.04391s ago] ('ZH_12', 1, 0)
# 2025-07-05 18:42:13,103 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,103 INFO sqlalchemy.engine.Engine [cached since 0.04538s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:13,103 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,104 INFO sqlalchemy.engine.Engine [cached since 0.04607s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:13,104 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,104 INFO sqlalchemy.engine.Engine [cached since 0.04665s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:13,105 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,105 INFO sqlalchemy.engine.Engine [cached since 0.04736s ago] ('ZH_5', 1, 0)
# 2025-07-05 18:42:13,106 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,106 INFO sqlalchemy.engine.Engine [cached since 0.04888s ago] ('ZH_9', 1, 0)
# 2025-07-05 18:42:13,107 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,107 INFO sqlalchemy.engine.Engine [cached since 0.04941s ago] ('ZH_9', 1, 0)
# 2025-07-05 18:42:13,107 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,107 INFO sqlalchemy.engine.Engine [cached since 0.04991s ago] ('ZH_9', 1, 0)
# 2025-07-05 18:42:13,108 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,108 INFO sqlalchemy.engine.Engine [cached since 0.05041s ago] ('ZH_9', 1, 0)
# 2025-07-05 18:42:13,108 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,108 INFO sqlalchemy.engine.Engine [cached since 0.05089s ago] ('ZH_9', 1, 0)
# 2025-07-05 18:42:13,109 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-05 18:42:13,109 INFO sqlalchemy.engine.Engine [cached since 0.05141s ago] ('ZH_9', 1, 0)
# 2025-07-05 18:42:13,110 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,110 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('ZH_11_G1', 'Énumérer avec 第 dì', "第 dì permet de former des chiffres et nombres ordinaux.\nIl s'emploie de la façon suivante :\n\n第 + chiffre/nombre ( + Classificateur )\n\n* 第一 dì yī ... (918 characters truncated) ... s deux mots suivants signifient « étage » et peuvent s'employer sans 第 dì :\n\n* 三楼 sān lóu : « Troisième étage »\n* 四层 sì céng : « Quatrième étage »", 0, '2025-07-05', 'ZH_11')
# 2025-07-05 18:42:13,110 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,111 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,111 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,111 INFO sqlalchemy.engine.Engine [generated in 0.00014s] ('ZH_11',)
# 2025-07-05 18:42:13,111 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,112 INFO sqlalchemy.engine.Engine [cached since 0.002097s ago] ('ZH_11_G2', 'Exprimer une distance avec 离 lí', "离 lí est utilisé lorsqu'on souhaite exprimer une distance entre deux points. Il peut se traduire par « par rapport à ». La structure à employer, très ... (589 characters truncated) ... ē zhàn lí zhèr tài yuǎn le : « La gare est trop éloignée d’ici »\n* 酒吧离我的家比较远 jiǔbā lí wǒ de jiā bǐjiào yuǎn : « Le bar est plutôt loin de chez moi »", 0, '2025-07-05', 'ZH_11')
# 2025-07-05 18:42:13,112 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,112 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,112 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,113 INFO sqlalchemy.engine.Engine [cached since 0.001519s ago] ('ZH_11',)
# 2025-07-05 18:42:13,113 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,113 INFO sqlalchemy.engine.Engine [cached since 0.003535s ago] ('ZH_11_G3', 'Se diriger, suivre un itinéraire', 'Savoir utiliser les termes « droite », « gauche » et « tout droit » suffit pour se repérer, demander son chemin et comprendre un itinéraire. Lorsqu’o ... (238 characters truncated) ... tout droit »\n* 你先往前走一百米，然后往左拐 nǐ xiān wǎng qián zǒu yī bǎi mǐ, ránhòu wǎng zuǒ guǎi : « Va d’abord tout droit sur 100 mètres, puis tourne à gauche »', 0, '2025-07-05', 'ZH_11')
# 2025-07-05 18:42:13,113 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,114 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,114 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,114 INFO sqlalchemy.engine.Engine [cached since 0.002924s ago] ('ZH_11',)
# 2025-07-05 18:42:13,114 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,114 INFO sqlalchemy.engine.Engine [cached since 0.00482s ago] ('ZH_11_G4', "À l'intérieur de quelque chose", 'Pour indiquer que quelque chose se situe à l’intérieur de quelque chose d’autre, on utilise la structure suivante :\n\nNom 1 + 在 + Nom 2 + 里面\n\n* 你在 ... (240 characters truncated) ...  shàng ma ? : « Es-tu dans le bus ? »\n* 我在车上 wǒ zài chē shàng : « Je suis dans la voiture »\n* 我在火车上 wǒ zài huǒchē shàng : « Je suis dans le train »', 0, '2025-07-05', 'ZH_11')
# 2025-07-05 18:42:13,115 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,115 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,115 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,115 INFO sqlalchemy.engine.Engine [cached since 0.004267s ago] ('ZH_6',)
# 2025-07-05 18:42:13,116 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,116 INFO sqlalchemy.engine.Engine [cached since 0.00629s ago] ('ZH_6_G1', 'Les démonstratifs 这 zhè et 那 nà', "Le démonstratif le plus couramment utilisé en chinois est 这 zhè.\n这 zhè va rarement être utilisé tout seul, il est souvent couplé avec d'autres carac ... (1057 characters truncated) ... à-bas, c'est... »\n* 那个/那个人 nà ge rén : « Cette personne-là »\n* 那里是我的朋友的家 nà lǐ shì wǒ de péngyou de jiā : « Là-bas se trouve la maison de mon ami »", 0, '2025-07-05', 'ZH_6')
# 2025-07-05 18:42:13,116 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,116 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,117 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,117 INFO sqlalchemy.engine.Engine [cached since 0.005762s ago] ('ZH_6',)
# 2025-07-05 18:42:13,117 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,117 INFO sqlalchemy.engine.Engine [cached since 0.00768s ago] ('ZH_6_G2', 'Autres utilisations du caractère 的 de', "的 de, le caractère permettant de marquer la possession, peut s'utiliser à la suite d'un pronom personnel (ex. 我的 wǒ de « mon ») ou d'un nom (ex. 老师的书 ... (937 characters truncated) ... ncài : « C'est le plat que j'aime faire/préparer »\n* 这是我去年去的地方 zhè shì wǒ qùnián qù de dìfang : « C'est l'endroit où je suis allé l'année dernière »", 0, '2025-07-05', 'ZH_6')
# 2025-07-05 18:42:13,117 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,118 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,118 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,118 INFO sqlalchemy.engine.Engine [cached since 0.007046s ago] ('ZH_6',)
# 2025-07-05 18:42:13,118 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,118 INFO sqlalchemy.engine.Engine [cached since 0.008968s ago] ('ZH_6_G3', 'Exprimer "avec" à l\'aide de 跟 gēn et 一起 yīqǐ', "La préposition 跟 gēn, souvent utilisée avec 一起 yīqǐ (signifiant « ensemble »), permet de marquer l'accompagnement :\n\n* 我跟你去 wǒ gēn nǐ qù : « J'y va ... (142 characters truncated) ... gēn tā yīqǐ qù le gōngyuán : « Je suis allé au parc avec lui hier »\n* 我跟我的女朋友一起住 wǒ gēn wǒ de nǚ péngyou yīqǐ zhù : « J'habite avec ma petite amie »", 0, '2025-07-05', 'ZH_6')
# 2025-07-05 18:42:13,119 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,119 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,119 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,119 INFO sqlalchemy.engine.Engine [cached since 0.008371s ago] ('ZH_6',)
# 2025-07-05 18:42:13,120 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,120 INFO sqlalchemy.engine.Engine [cached since 0.01029s ago] ('ZH_6_G4', 'Les caractères ayant plusieurs prononciations', "Vous aurez certainement remarqué que certains caractères peuvent avoir plusieurs prononciations. Le changement de prononciation peut faire varier ou  ... (198 characters truncated) ...  : trouver que\n* 睡觉 shuìjiào : dormir\n\nCertains caractères comme le 都 de 首都 « la capitale » peuvent changer à la fois de prononciation et de sens.", 0, '2025-07-05', 'ZH_6')
# 2025-07-05 18:42:13,120 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,120 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,121 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,121 INFO sqlalchemy.engine.Engine [cached since 0.009625s ago] ('ZH_7',)
# 2025-07-05 18:42:13,121 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,121 INFO sqlalchemy.engine.Engine [cached since 0.01154s ago] ('ZH_7_G1', 'Comparer avec 比 bi ou 没有 méiyǒu', "**Utilisation de 比 bi**\nLe caractère 比 bǐ est utilisé en tant que comparatif de supériorité ou d'infériorité (et non d'égalité). Il peut être tradui ... (740 characters truncated) ...  : « Il est plus petit que moi » (littéralement « Il n'a pas ma taille »)\n* 妈妈没有爸爸高 māma méiyǒu bàba gāo : « Maman n'est pas aussi grande que papa »", 0, '2025-07-05', 'ZH_7')
# 2025-07-05 18:42:13,121 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,122 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,122 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,122 INFO sqlalchemy.engine.Engine [cached since 0.01103s ago] ('ZH_7',)
# 2025-07-05 18:42:13,122 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,122 INFO sqlalchemy.engine.Engine [cached since 0.01293s ago] ('ZH_7_G2', 'Interrogatif 谁 shéi/shuí', "谁 shéi est l'interrogatif signifiant « Qui ? ». Comme tous les mots interrogatifs, il se place à l'endroit où se trouvera la réponse :\n\n* 你是谁？ Nǐ s ... (401 characters truncated) ...  » et ne doit pas traduire le pronom relatif « qui » dans des phrases comme « La personne qui habite ici ». Pour cela, on utilise 的 de (cf. Leçon 6).", 0, '2025-07-05', 'ZH_7')
# 2025-07-05 18:42:13,123 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,123 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,123 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,123 INFO sqlalchemy.engine.Engine [cached since 0.01235s ago] ('ZH_7',)
# 2025-07-05 18:42:13,124 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,124 INFO sqlalchemy.engine.Engine [cached since 0.01427s ago] ('ZH_7_G3', 'Quelle(s) langue(s) sais-tu parler ?', "En général, on forme le nom d'une langue en ajoutant 语 yǔ (ou 文 wén) au nom du pays.\n\nPour les pays finissant par 国 guó, on remplace 国 guó par 语 yǔ ... (342 characters truncated) ... :\n\n* 中国 Zhōngguó (Chine) → 中文 Zhōngwén (chinois)\n* 汉语 Hànyǔ (chinois)\n\nNote : 汉语 Hànyǔ (chinois) et 韩语 Hányǔ (coréen) se prononcent très proche.", 0, '2025-07-05', 'ZH_7')
# 2025-07-05 18:42:13,124 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,124 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,125 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,125 INFO sqlalchemy.engine.Engine [cached since 0.01366s ago] ('ZH_7',)
# 2025-07-05 18:42:13,125 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,125 INFO sqlalchemy.engine.Engine [cached since 0.01563s ago] ('ZH_7_G4', 'Les adverbes 最 zuì et 太 ... 了 tài...le', "Les adverbes 最 zuì et 太 ... 了 tài...le s'emploient comme 很 hěn devant un adjectif, mais nuancent ou renforcent le propos :\n\n* 我很累 wǒ hěn lèi : « Je ... (11 characters truncated) ... ué »\n* 最累 zuì lèi : « Le plus fatigué »\n* 我太累了 wǒ tài lèi le : « Je suis trop fatigué »\n* 我不太累了 wǒ bù tài lèi le : « Je ne suis pas trop fatigué »", 0, '2025-07-05', 'ZH_7')
# 2025-07-05 18:42:13,125 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,126 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,126 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,126 INFO sqlalchemy.engine.Engine [cached since 0.015s ago] ('ZH_7',)
# 2025-07-05 18:42:13,126 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,126 INFO sqlalchemy.engine.Engine [cached since 0.01693s ago] ('ZH_7_G5', 'Tout, toutes et tous avec 都 dōu', 'Le caractère 都 peut se prononcer « dū » (dans 首都 shǒudū « capitale ») ou « dōu » quand il signifie « tout, tous ». Il se place directement après le n ... (122 characters truncated) ... ōu xiǎng qù Zhōngguó : « Nous voulons tous aller en Chine »\n* 我的朋友都 wǒ de péngyou dōu : « Tous mes amis »\n* 女生都 nǚshēng dōu : « Toutes les filles »', 0, '2025-07-05', 'ZH_7')
# 2025-07-05 18:42:13,127 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,127 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,127 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,127 INFO sqlalchemy.engine.Engine [cached since 0.01629s ago] ('ZH_7',)
# 2025-07-05 18:42:13,128 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,128 INFO sqlalchemy.engine.Engine [cached since 0.0182s ago] ('ZH_7_G6', 'Ensemble avec 一起 yīqǐ', '一起 yīqǐ a déjà été vu dans la structure 跟 gēn ... + 一起 yīqǐ (page 109) pour dire « avec ». 一起 yīqǐ peut aussi être utilisé seul et signifie « ensembl ... (50 characters truncated) ...  Elles vont regarder un film ensemble »\n* 我们一起去北京 wǒmen yīqǐ qù Běijīng : « Nous allons ensemble à Pékin »\n\nStructure : Sujet + 一起 + Verbe + Objet', 0, '2025-07-05', 'ZH_7')
# 2025-07-05 18:42:13,128 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,128 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,129 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,129 INFO sqlalchemy.engine.Engine [cached since 0.01769s ago] ('ZH_10',)
# 2025-07-05 18:42:13,129 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,129 INFO sqlalchemy.engine.Engine [cached since 0.01961s ago] ('ZH_10_G1', 'Indiquer le destinataire avec 给 gěi', "给 gěi, signifiant « donner », permet d'indiquer la cible d'une action.\n\nStructure : Sujet + 给 + cible + action\n\n* 你给我打电话 nǐ gěi wǒ dǎ diànhuà : « ... (45 characters truncated) ... i tā dǎ diànhuà : « Tu dois lui téléphoner »\n* 你给他写信 nǐ gěi tā xiěxìn : « Écris-lui une lettre »\n* 我给你做饭 wǒ gěi nǐ zuòfàn : « Je te fais à manger »", 0, '2025-07-05', 'ZH_10')
# 2025-07-05 18:42:13,129 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,130 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,130 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,130 INFO sqlalchemy.engine.Engine [cached since 0.01902s ago] ('ZH_10',)
# 2025-07-05 18:42:13,130 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,130 INFO sqlalchemy.engine.Engine [cached since 0.02093s ago] ('ZH_10_G2', '"Pouvoir" avec 能 néng ou 可以 kěyǐ', "Plusieurs verbes existent pour exprimer la possibilité, cependant ils ne peuvent pas s'employer de la même manière. Nous avons déjà étudié le verbe 会 ... (795 characters truncated) ... 停车吗？wǒ zài zhèr kěyǐ tíngchē ma ? : « Puis-je garer ma voiture ici ? »\n* 妈妈，我可以出去吗？māma, wǒ kěyǐ chūqù ma ? : « Maman, est-ce que je peux sortir ? »", 0, '2025-07-05', 'ZH_10')
# 2025-07-05 18:42:13,131 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,131 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,131 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,131 INFO sqlalchemy.engine.Engine [cached since 0.02042s ago] ('ZH_10',)
# 2025-07-05 18:42:13,132 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,132 INFO sqlalchemy.engine.Engine [cached since 0.02249s ago] ('ZH_10_G3', 'La condition avec 如果 ... 的话 rúguǒ ... de huà et 就 jiù', "如果 ... 的话 rúguǒ ... de huà et 就 jiù sont utilisés, ensemble ou séparément, afin d'introduire une condition et sa conséquence.\n\nStructure : 如果 + Suj ... (135 characters truncated) ... , appelle le médecin »\n* 如果他生病的话，他就不能去工作 rúguǒ tā shēngbìng de huà, tā jiù bù néng qù gōngzuò : « S'il est malade, il ne peut pas aller travailler »", 0, '2025-07-05', 'ZH_10')
# 2025-07-05 18:42:13,132 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,133 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,133 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,133 INFO sqlalchemy.engine.Engine [cached since 0.0221s ago] ('ZH_10',)
# 2025-07-05 18:42:13,133 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,134 INFO sqlalchemy.engine.Engine [cached since 0.02404s ago] ('ZH_10_G4', "Le comparatif d'égalité", "Nous avons étudié dans la leçon 7 les comparatifs de supériorité ou d'infériorité en utilisant le caractère 比 bǐ. Il ne faut pas employer 比 pour intr ... (338 characters truncated) ... la mienne »\n* 今天的会议和昨天的会议一样无聊 jīntiān de huìyì hé zuótiān de huìyì yīyàng wúliáo : « La réunion d'aujourd'hui est aussi ennuyeuse que celle d'hier »", 0, '2025-07-05', 'ZH_10')
# 2025-07-05 18:42:13,134 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,134 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,134 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,135 INFO sqlalchemy.engine.Engine [cached since 0.02363s ago] ('ZH_10',)
# 2025-07-05 18:42:13,135 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,135 INFO sqlalchemy.engine.Engine [cached since 0.02566s ago] ('ZH_10_G5', '"Encore, toujours" avec 还 hái', "还 hái peut être utilisé seul ou bien accompagné de 在 zài pour marquer qu'une action est « encore, toujours » en cours. On peut aussi l'utiliser avec  ... (391 characters truncated) ... »\n* 我还不会说中文 wǒ hái bù huì shuō zhōngwén : « Je ne sais toujours pas parler chinois »\n* 我还没有吃饭 wǒ hái méiyǒu chīfàn : « Je n'ai toujours pas mangé »", 0, '2025-07-05', 'ZH_10')
# 2025-07-05 18:42:13,135 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,136 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,136 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,136 INFO sqlalchemy.engine.Engine [cached since 0.02526s ago] ('ZH_10',)
# 2025-07-05 18:42:13,137 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,137 INFO sqlalchemy.engine.Engine [cached since 0.02732s ago] ('ZH_10_G6', '"Venir" avec 来 lái', "Le verbe 来 lái signifie « venir » et doit être utilisé lorsque l'on se rapproche de son interlocuteur.\n\n* 你来饭馆吃饭吗？nǐ lái fànguǎn chīfàn ma ? : « Vi ... (214 characters truncated) ... inverse, si l'interlocuteur s'éloigne, on utilisera le verbe 去 qù (« aller »), car il indique un déplacement vers un lieu éloigné de celui qui parle.", 0, '2025-07-05', 'ZH_10')
# 2025-07-05 18:42:13,137 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,138 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,138 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,138 INFO sqlalchemy.engine.Engine [cached since 0.02705s ago] ('ZH_1',)
# 2025-07-05 18:42:13,138 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,139 INFO sqlalchemy.engine.Engine [cached since 0.02911s ago] ('ZH_1_G1', 'Conjuguer', 'Une des facilités de la langue chinoise est qu’elle ne contient pas de conjugaison. Conjuguer le verbe être se résume à :\n\n- 我是 (wǒ shì) : Je suis\ ... (318 characters truncated) ... . Si les verbes chinois ne se conjuguent pas, il existe tout de même quelques particules et suffixes verbaux permettant de contextualiser une phrase.', 0, '2025-07-05', 'ZH_1')
# 2025-07-05 18:42:13,139 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,139 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,140 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,140 INFO sqlalchemy.engine.Engine [cached since 0.02866s ago] ('ZH_1',)
# 2025-07-05 18:42:13,140 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,140 INFO sqlalchemy.engine.Engine [cached since 0.0307s ago] ('ZH_1_G2', 'Affirmation et négation', 'La construction de base est `Sujet/Verbe/Objet`. Pour dire « Je suis français », nous dirons simplement :\n\n- 我是法国人 (wǒ shì fǎguórén) (je/être/franç ... (459 characters truncated) ... e ton, mais 不 bú shì car 是 shì est au quatrième ton. Cette modification se fait uniquement à l’oral et n’est généralement pas inscrite sur le pinyin.', 0, '2025-07-05', 'ZH_1')
# 2025-07-05 18:42:13,140 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,141 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,141 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,142 INFO sqlalchemy.engine.Engine [cached since 0.03048s ago] ('ZH_1',)
# ...
# 2025-07-05 18:42:13,203 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,203 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,204 INFO sqlalchemy.engine.Engine [cached since 0.0925s ago] ('ZH_12',)
# 2025-07-05 18:42:13,204 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,204 INFO sqlalchemy.engine.Engine [cached since 0.09485s ago] ('ZH_12_G2', 'Classificateurs ne pouvant pas être remplacés par 个 gè', "Certains classificateurs ne peuvent pas être remplacés par 个 gè (qui est, pour rappel, le classificateur universel), car ils apportent un sens partic ... (274 characters truncated) ...  gè niǎo : « Un oiseau »\n* 一群鸟 yī qún niǎo : « Un vol d’oiseaux »\n* 一些人 yī xiē rén : « Quelques personnes »\n* 一杯水 yī bēi shuǐ : « Un verre d’eau »", 0, '2025-07-05', 'ZH_12')
# 2025-07-05 18:42:13,205 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,205 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,206 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,206 INFO sqlalchemy.engine.Engine [cached since 0.09471s ago] ('ZH_12',)
# 2025-07-05 18:42:13,206 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,206 INFO sqlalchemy.engine.Engine [cached since 0.09667s ago] ('ZH_12_G3', 'Permettre quelque chose avec 让 ràng', "让 ràng est un verbe dit « causatif », qui peut être traduit par « laisser » ou « permettre » en français.\n\nStructure : Sujet + 让 + Personne/Objet + ... (128 characters truncated) ...  papa ne te laisse-t-il pas y aller ? »\n* 看 Titanic 电影让我很感动 kàn Titanic diànyǐng ràng wǒ hěn gǎndòng : « Regarder le film Titanic m'a beaucoup ému »", 0, '2025-07-05', 'ZH_12')
# 2025-07-05 18:42:13,206 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,207 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,207 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,207 INFO sqlalchemy.engine.Engine [cached since 0.09647s ago] ('ZH_12',)
# 2025-07-05 18:42:13,208 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,208 INFO sqlalchemy.engine.Engine [cached since 0.09841s ago] ('ZH_12_G4', 'Demander « combien » avec 多少 duōshǎo ou 几 jǐ', "Il existe deux façons principales de demander « combien » : 多少 duōshǎo et 几 jǐ. Voici leurs différences :\n\n* 几 jǐ est utilisé pour des quantités gé ... (695 characters truncated) ...  ici »\n* 我有十多元 wǒ yǒu shí duō yuán : « J’ai un peu plus de dix yuans »\n* 我有三十多块钱 wǒ yǒu sānshí duō kuài qián : « J’ai un peu plus de trente kuais »", 0, '2025-07-05', 'ZH_12')
# 2025-07-05 18:42:13,208 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,209 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,209 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,209 INFO sqlalchemy.engine.Engine [cached since 0.09815s ago] ('ZH_12',)
# 2025-07-05 18:42:13,209 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,210 INFO sqlalchemy.engine.Engine [cached since 0.1001s ago] ('ZH_12_G5', '« Quelques » avec 一些 yīxiē', "一些 yīxiē signifie « quelques » ou « certains » et désigne une quantité indéterminée. Il s'utilise selon le schéma suivant :\n\n一些 + Nom\n\n* 有一些人 yǒu yīxiē rén : « Il y a quelques personnes »\n* 爸爸买了一些书 bàba mǎi le yīxiē shū : « Papa a acheté quelques livres »", 0, '2025-07-05', 'ZH_12')
# 2025-07-05 18:42:13,210 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,211 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,211 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,211 INFO sqlalchemy.engine.Engine [cached since 0.1002s ago] ('ZH_5',)
# 2025-07-05 18:42:13,211 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,212 INFO sqlalchemy.engine.Engine [cached since 0.1022s ago] ('ZH_5_G1', 'Les adjectifs', "**Affirmation avec 很 hěn**\nLes noms doivent être liés aux autres noms à l'aide du verbe « être » 是 shì.\n\n* 妈妈 是 老师 māma shì lǎoshī : « Maman est p ... (1844 characters truncated) ... ǐhuan : « j'aime »\n* 我 讨厌 wǒ tǎoyàn : « je déteste »\n* 我 很 喜欢 wǒ hěn xǐhuan : « j'aime beaucoup »\n* 我 很 讨厌 wǒ hěn tǎoyàn : « je déteste vraiment »", 0, '2025-07-05', 'ZH_5')
# 2025-07-05 18:42:13,212 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,213 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,213 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,213 INFO sqlalchemy.engine.Engine [cached since 0.1019s ago] ('ZH_5',)
# 2025-07-05 18:42:13,213 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,214 INFO sqlalchemy.engine.Engine [cached since 0.1044s ago] ('ZH_5_G2', 'Énumérer avec 和 hé', "Le caractère 和 hé permet d'énumérer des noms communs. Nous pouvons traduire par « ainsi que », son emploi diffère donc du « et » français.\n\n* 我 的 妈 ... (132 characters truncated) ... n papa et moi »\n\n和 hé ne peut pas être utilisé pour lier deux phrases comme en français (ex. Ce matin je travaille et cet après-midi je me repose).", 0, '2025-07-05', 'ZH_5')
# 2025-07-05 18:42:13,214 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,215 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,215 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,215 INFO sqlalchemy.engine.Engine [cached since 0.1043s ago] ('ZH_5',)
# 2025-07-05 18:42:13,216 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,216 INFO sqlalchemy.engine.Engine [cached since 0.1066s ago] ('ZH_5_G3', 'Le caractère 的 de', "Le premier sens de 的 de est le possessif. L'ajout du caractère 的 de aux pronoms personnels permet de former les pronoms possessifs :\n\nPronom person ... (638 characters truncated) ...  de Chine »\n\nDéterminant + 的 + déterminé\n\nLe contexte est indispensable pour comprendre le sens qu'il a dans une phrase, un texte ou un dialogue.", 0, '2025-07-05', 'ZH_5')
# 2025-07-05 18:42:13,216 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,217 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,217 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,218 INFO sqlalchemy.engine.Engine [cached since 0.1065s ago] ('ZH_5',)
# 2025-07-05 18:42:13,218 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,218 INFO sqlalchemy.engine.Engine [cached since 0.1088s ago] ('ZH_5_G4', 'Les différentes utilisations de 要 yào', "Le premier sens de 要 yào est le verbe « vouloir ».\n\n* 我 要 工作 wǒ yào gōngzuò : « Je veux travailler »\n* 我 要 吃饭 wǒ yào chīfàn : « Je veux manger »\n ... (31 characters truncated) ... enir est la suivante :\n\nIl peut également avoir d'autres sens, tels que « devoir », « falloir » ou encore « aller faire/être sur le point de ... ».", 0, '2025-07-05', 'ZH_5')
# 2025-07-05 18:42:13,219 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,219 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,219 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,220 INFO sqlalchemy.engine.Engine [cached since 0.1085s ago] ('ZH_9',)
# 2025-07-05 18:42:13,220 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,220 INFO sqlalchemy.engine.Engine [cached since 0.1107s ago] ('ZH_9_G1', 'Moyens de transport', "Si en français nous employons généralement le verbe « prendre » lorsqu'il s'agit des moyens de transport, il convient d'utiliser le verbe 坐 zuò « s'a ... (471 characters truncated) ...  véhicule, il faut employer 开 kāi « conduire, ouvrir » :\n\n* 我开车 wǒ kāi chē : « Je conduis la voiture »\n* 我开飞机 wǒ kāi fēijī : « Je pilote l'avion »", 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:13,221 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,221 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,221 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,221 INFO sqlalchemy.engine.Engine [cached since 0.1105s ago] ('ZH_9',)
# 2025-07-05 18:42:13,222 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,222 INFO sqlalchemy.engine.Engine [cached since 0.1128s ago] ('ZH_9_G2', '"Chaque" avec 每 měi', '每 měi est employé dans la majorité des cas avec un classificateur derrière :\n\n* 每个人 měi gè rén : « Chaque personne »\n* 每个月 měi gè yuè : « Chaque m ... (100 characters truncated) ... it pas être employé dans les trois cas suivants :\n\n* 每年 měi nián : « Chaque année »\n* 每天 měi tiān : « Chaque jour »\n* 每日 měi rì : « Chaque jour »', 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:13,223 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,223 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,224 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,224 INFO sqlalchemy.engine.Engine [cached since 0.1128s ago] ('ZH_9',)
# 2025-07-05 18:42:13,224 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,224 INFO sqlalchemy.engine.Engine [cached since 0.1147s ago] ('ZH_9_G3', '"D\'abord... ensuite..." avec 先 xiān et 然后 ránhòu', "先 xiān « premièrement », et 然后 ránhòu « ensuite » peuvent être utilisés ensemble pour indiquer que deux événements se succèdent :\n\n* 我们先吃饭，然后看电视 wǒ ... (220 characters truncated) ... emièrement » peut également être utilisé seul :\n\n* 他先到了 tā xiān dào le : « Il est arrivé en premier »\n* 我先说 wǒ xiān shuō : « Je parle en premier »", 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:13,224 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,225 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,225 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,226 INFO sqlalchemy.engine.Engine [cached since 0.1145s ago] ('ZH_9',)
# 2025-07-05 18:42:13,226 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,226 INFO sqlalchemy.engine.Engine [cached since 0.1166s ago] ('ZH_9_G4', '"Un petit peu" avec 有点儿 yǒu diǎnr ou 一点儿 yī diǎnr', "**有点儿 yǒu diǎnr**\n有点儿 yǒu diǎnr ou simplement 有点 yǒu diǎn est utilisé avant un adjectif. Il est généralement employé dans des phrases négatives, pou ... (499 characters truncated) ... 宜一点儿 nǐ piányi yī diǎnr : « Baisse un peu le prix »\n* 你快一点儿 nǐ kuài yī diǎnr : « Dépêche-toi un peu »\n* 你慢一点儿 nǐ màn yī diǎnr : « Ralentis un peu »", 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:13,226 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,227 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,227 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,227 INFO sqlalchemy.engine.Engine [cached since 0.116s ago] ('ZH_9',)
# 2025-07-05 18:42:13,227 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,227 INFO sqlalchemy.engine.Engine [cached since 0.1179s ago] ('ZH_9_G5', 'Utiliser 比较 bǐjiào devant un verbe', "Nous avons vu dans la leçon précédente que l'adverbe 比较 bǐjiào signifie « relativement, plutôt » et qu'il était employé devant un adjectif afin de le ... (162 characters truncated) ... iào xǐhuan : « Je préfère »\n* 我不喜欢坐车，我比较喜欢走路 wǒ bù xǐhuan zuò chē, wǒ bǐjiào xǐhuan zǒulù : « Je n'aime pas prendre la voiture, je préfère marcher »", 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:13,228 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-05 18:42:13,228 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-05 18:42:13,228 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-05 18:42:13,229 INFO sqlalchemy.engine.Engine [cached since 0.1176s ago] ('ZH_9',)
# 2025-07-05 18:42:13,229 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-05 18:42:13,229 INFO sqlalchemy.engine.Engine [cached since 0.1196s ago] ('ZH_9_G6', 'Les particules modales placées en fin de phrase', 'Quelques particules modales sont habituellement rajoutées en fin de phrase pour donner un ton particulier à la phrase, en voici quelques exemples :\n ... (334 characters truncated) ... .\n\nIl existe également des interjections placées en début de phrase :\n\n* 嗯 en : équivalent du « hum... » français\n* 哎呀 āiyā : marque la surprise', 0, '2025-07-05', 'ZH_9')
# 2025-07-05 18:42:13,229 INFO sqlalchemy.engine.Engine COMMIT
# /var/folders/5p/bjh6crbn6fv0vtxy5sqmmxh00000gn/T/ipykernel_10069/1700351099.py:24: SAWarning: Object of type <GrammarRule> not in session, add operation along 'Unit.grammars' will not proceed (This warning originated from the Session 'autoflush' process, which was invoked automatically in response to a user-initiated operation. Consider using ``no_autoflush`` context manager if this warning happended while initializing objects.)
#   parent=session.query(Unit).filter(Unit.unit_id == f"{language_name.upper()}_{unit_id}").first()
# /Users/noe_jager/Documents/GitHub/vocabulary-dbms/src/lapp/dbms.py:79: SAWarning: Object of type <GrammarRule> not in session, add operation along 'Unit.grammars' will not proceed
#   session.commit()
