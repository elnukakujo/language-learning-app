# %%
import json
import pandas as pd
import os
import re
from lapp.dbms import init_db, inserts, modify, delete, find_by_attr, insert
from lapp.tables import Unit, Vocabulary, GrammarRule, Language

# %%
language_id = "zh"

# %% [markdown]
# ## Create a Language

# %%
engine, session = init_db()

if not os.path.exists("../db"):
    os.makedirs("../db")
    print(f"Created directory for database: ../db")

language = Language(
    language_id=language_id,
    name="Chinois",
    native_name="中文",
    level="A1",
    flag="🇨🇳"
)
insert(session, language)

session.close()
# Out:
# 2025-07-07 15:28:48,011 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:28:48,011 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("language")
# 2025-07-07 15:28:48,012 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 15:28:48,013 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-07 15:28:48,013 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 15:28:48,013 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-07 15:28:48,014 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 15:28:48,014 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-07 15:28:48,014 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 15:28:48,014 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-07 15:28:48,015 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 15:28:48,015 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-07 15:28:48,015 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 15:28:48,016 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:28:48,016 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:28:48,017 INFO sqlalchemy.engine.Engine INSERT INTO language (language_id, name, native_name, level, description, score, last_seen, flag, current_unit) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 15:28:48,017 INFO sqlalchemy.engine.Engine [generated in 0.00049s] ('zh', 'Chinois', '中文', 'A1', '', 0, '2025-07-07', '🇨🇳', None)
# 2025-07-07 15:28:48,020 INFO sqlalchemy.engine.Engine ROLLBACK
# Insert failed: (sqlite3.IntegrityError) UNIQUE constraint failed: language.language_id
# [SQL: INSERT INTO language (language_id, name, native_name, level, description, score, last_seen, flag, current_unit) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)]
# [parameters: ('zh', 'Chinois', '中文', 'A1', '', 0, '2025-07-07', '🇨🇳', None)]
# (Background on this error at: https://sqlalche.me/e/20/gkpj). Attempting to modify an existing record.
# 2025-07-07 15:28:48,023 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:28:48,025 INFO sqlalchemy.engine.Engine SELECT language.language_id AS language_language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.language_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:28:48,028 INFO sqlalchemy.engine.Engine [generated in 0.00319s] ('zh', 1, 0)
# 2025-07-07 15:28:48,038 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE ? = unit.language_id
# 2025-07-07 15:28:48,039 INFO sqlalchemy.engine.Engine [generated in 0.00115s] ('zh',)
# 2025-07-07 15:28:48,044 INFO sqlalchemy.engine.Engine SELECT calligraphy_character.learn_id AS calligraphy_character_learn_id, calligraphy_character.character AS calligraphy_character_character, calligraphy_character.translation AS calligraphy_character_translation, calligraphy_character.components AS calligraphy_character_components, calligraphy_character.score AS calligraphy_character_score, calligraphy_character.last_seen AS calligraphy_character_last_seen, calligraphy_character.unit_id AS calligraphy_character_unit_id
# FROM calligraphy_character
# WHERE ? = calligraphy_character.unit_id
# 2025-07-07 15:28:48,045 INFO sqlalchemy.engine.Engine [generated in 0.00082s] ('ZH_11',)
# 2025-07-07 15:28:48,046 INFO sqlalchemy.engine.Engine SELECT calligraphy_character.learn_id AS calligraphy_character_learn_id, calligraphy_character.character AS calligraphy_character_character, calligraphy_character.translation AS calligraphy_character_translation, calligraphy_character.components AS calligraphy_character_components, calligraphy_character.score AS calligraphy_character_score, calligraphy_character.last_seen AS calligraphy_character_last_seen, calligraphy_character.unit_id AS calligraphy_character_unit_id
# FROM calligraphy_character
# WHERE ? = calligraphy_character.unit_id
# 2025-07-07 15:28:48,046 INFO sqlalchemy.engine.Engine [cached since 0.001932s ago] ('ZH_9',)
# 2025-07-07 15:28:48,047 INFO sqlalchemy.engine.Engine SELECT calligraphy_character.learn_id AS calligraphy_character_learn_id, calligraphy_character.character AS calligraphy_character_character, calligraphy_character.translation AS calligraphy_character_translation, calligraphy_character.components AS calligraphy_character_components, calligraphy_character.score AS calligraphy_character_score, calligraphy_character.last_seen AS calligraphy_character_last_seen, calligraphy_character.unit_id AS calligraphy_character_unit_id
# FROM calligraphy_character
# WHERE ? = calligraphy_character.unit_id
# 2025-07-07 15:28:48,047 INFO sqlalchemy.engine.Engine [cached since 0.002966s ago] ('ZH_6',)
# 2025-07-07 15:28:48,048 INFO sqlalchemy.engine.Engine SELECT calligraphy_character.learn_id AS calligraphy_character_learn_id, calligraphy_character.character AS calligraphy_character_character, calligraphy_character.translation AS calligraphy_character_translation, calligraphy_character.components AS calligraphy_character_components, calligraphy_character.score AS calligraphy_character_score, calligraphy_character.last_seen AS calligraphy_character_last_seen, calligraphy_character.unit_id AS calligraphy_character_unit_id
# FROM calligraphy_character
# WHERE ? = calligraphy_character.unit_id
# 2025-07-07 15:28:48,048 INFO sqlalchemy.engine.Engine [cached since 0.003566s ago] ('ZH_7',)
# 2025-07-07 15:28:48,048 INFO sqlalchemy.engine.Engine SELECT calligraphy_character.learn_id AS calligraphy_character_learn_id, calligraphy_character.character AS calligraphy_character_character, calligraphy_character.translation AS calligraphy_character_translation, calligraphy_character.components AS calligraphy_character_components, calligraphy_character.score AS calligraphy_character_score, calligraphy_character.last_seen AS calligraphy_character_last_seen, calligraphy_character.unit_id AS calligraphy_character_unit_id
# FROM calligraphy_character
# WHERE ? = calligraphy_character.unit_id
# 2025-07-07 15:28:48,048 INFO sqlalchemy.engine.Engine [cached since 0.004074s ago] ('ZH_12',)
# 2025-07-07 15:28:48,048 INFO sqlalchemy.engine.Engine SELECT calligraphy_character.learn_id AS calligraphy_character_learn_id, calligraphy_character.character AS calligraphy_character_character, calligraphy_character.translation AS calligraphy_character_translation, calligraphy_character.components AS calligraphy_character_components, calligraphy_character.score AS calligraphy_character_score, calligraphy_character.last_seen AS calligraphy_character_last_seen, calligraphy_character.unit_id AS calligraphy_character_unit_id
# FROM calligraphy_character
# WHERE ? = calligraphy_character.unit_id
# 2025-07-07 15:28:48,049 INFO sqlalchemy.engine.Engine [cached since 0.004454s ago] ('ZH_2',)
# 2025-07-07 15:28:48,049 INFO sqlalchemy.engine.Engine SELECT calligraphy_character.learn_id AS calligraphy_character_learn_id, calligraphy_character.character AS calligraphy_character_character, calligraphy_character.translation AS calligraphy_character_translation, calligraphy_character.components AS calligraphy_character_components, calligraphy_character.score AS calligraphy_character_score, calligraphy_character.last_seen AS calligraphy_character_last_seen, calligraphy_character.unit_id AS calligraphy_character_unit_id
# FROM calligraphy_character
# WHERE ? = calligraphy_character.unit_id
# 2025-07-07 15:28:48,049 INFO sqlalchemy.engine.Engine [cached since 0.004957s ago] ('ZH_0',)
# 2025-07-07 15:28:48,049 INFO sqlalchemy.engine.Engine SELECT calligraphy_character.learn_id AS calligraphy_character_learn_id, calligraphy_character.character AS calligraphy_character_character, calligraphy_character.translation AS calligraphy_character_translation, calligraphy_character.components AS calligraphy_character_components, calligraphy_character.score AS calligraphy_character_score, calligraphy_character.last_seen AS calligraphy_character_last_seen, calligraphy_character.unit_id AS calligraphy_character_unit_id
# FROM calligraphy_character
# WHERE ? = calligraphy_character.unit_id
# 2025-07-07 15:28:48,050 INFO sqlalchemy.engine.Engine [cached since 0.005358s ago] ('ZH_13',)
# 2025-07-07 15:28:48,050 INFO sqlalchemy.engine.Engine SELECT calligraphy_character.learn_id AS calligraphy_character_learn_id, calligraphy_character.character AS calligraphy_character_character, calligraphy_character.translation AS calligraphy_character_translation, calligraphy_character.components AS calligraphy_character_components, calligraphy_character.score AS calligraphy_character_score, calligraphy_character.last_seen AS calligraphy_character_last_seen, calligraphy_character.unit_id AS calligraphy_character_unit_id
# FROM calligraphy_character
# WHERE ? = calligraphy_character.unit_id
# 2025-07-07 15:28:48,050 INFO sqlalchemy.engine.Engine [cached since 0.006033s ago] ('ZH_10',)
# 2025-07-07 15:28:48,051 INFO sqlalchemy.engine.Engine SELECT calligraphy_character.learn_id AS calligraphy_character_learn_id, calligraphy_character.character AS calligraphy_character_character, calligraphy_character.translation AS calligraphy_character_translation, calligraphy_character.components AS calligraphy_character_components, calligraphy_character.score AS calligraphy_character_score, calligraphy_character.last_seen AS calligraphy_character_last_seen, calligraphy_character.unit_id AS calligraphy_character_unit_id
# FROM calligraphy_character
# WHERE ? = calligraphy_character.unit_id
# 2025-07-07 15:28:48,051 INFO sqlalchemy.engine.Engine [cached since 0.006507s ago] ('ZH_4',)
# 2025-07-07 15:28:48,051 INFO sqlalchemy.engine.Engine SELECT calligraphy_character.learn_id AS calligraphy_character_learn_id, calligraphy_character.character AS calligraphy_character_character, calligraphy_character.translation AS calligraphy_character_translation, calligraphy_character.components AS calligraphy_character_components, calligraphy_character.score AS calligraphy_character_score, calligraphy_character.last_seen AS calligraphy_character_last_seen, calligraphy_character.unit_id AS calligraphy_character_unit_id
# FROM calligraphy_character
# WHERE ? = calligraphy_character.unit_id
# 2025-07-07 15:28:48,051 INFO sqlalchemy.engine.Engine [cached since 0.007206s ago] ('ZH_15',)
# 2025-07-07 15:28:48,052 INFO sqlalchemy.engine.Engine SELECT calligraphy_character.learn_id AS calligraphy_character_learn_id, calligraphy_character.character AS calligraphy_character_character, calligraphy_character.translation AS calligraphy_character_translation, calligraphy_character.components AS calligraphy_character_components, calligraphy_character.score AS calligraphy_character_score, calligraphy_character.last_seen AS calligraphy_character_last_seen, calligraphy_character.unit_id AS calligraphy_character_unit_id
# FROM calligraphy_character
# WHERE ? = calligraphy_character.unit_id
# 2025-07-07 15:28:48,052 INFO sqlalchemy.engine.Engine [cached since 0.007875s ago] ('ZH_8',)
# 2025-07-07 15:28:48,053 INFO sqlalchemy.engine.Engine SELECT calligraphy_character.learn_id AS calligraphy_character_learn_id, calligraphy_character.character AS calligraphy_character_character, calligraphy_character.translation AS calligraphy_character_translation, calligraphy_character.components AS calligraphy_character_components, calligraphy_character.score AS calligraphy_character_score, calligraphy_character.last_seen AS calligraphy_character_last_seen, calligraphy_character.unit_id AS calligraphy_character_unit_id
# FROM calligraphy_character
# WHERE ? = calligraphy_character.unit_id
# 2025-07-07 15:28:48,054 INFO sqlalchemy.engine.Engine [cached since 0.01012s ago] ('ZH_5',)
# 2025-07-07 15:28:48,057 INFO sqlalchemy.engine.Engine SELECT calligraphy_character.learn_id AS calligraphy_character_learn_id, calligraphy_character.character AS calligraphy_character_character, calligraphy_character.translation AS calligraphy_character_translation, calligraphy_character.components AS calligraphy_character_components, calligraphy_character.score AS calligraphy_character_score, calligraphy_character.last_seen AS calligraphy_character_last_seen, calligraphy_character.unit_id AS calligraphy_character_unit_id
# FROM calligraphy_character
# WHERE ? = calligraphy_character.unit_id
# 2025-07-07 15:28:48,057 INFO sqlalchemy.engine.Engine [cached since 0.01312s ago] ('ZH_3',)
# 2025-07-07 15:28:48,058 INFO sqlalchemy.engine.Engine SELECT calligraphy_character.learn_id AS calligraphy_character_learn_id, calligraphy_character.character AS calligraphy_character_character, calligraphy_character.translation AS calligraphy_character_translation, calligraphy_character.components AS calligraphy_character_components, calligraphy_character.score AS calligraphy_character_score, calligraphy_character.last_seen AS calligraphy_character_last_seen, calligraphy_character.unit_id AS calligraphy_character_unit_id
# FROM calligraphy_character
# WHERE ? = calligraphy_character.unit_id
# 2025-07-07 15:28:48,059 INFO sqlalchemy.engine.Engine [cached since 0.01469s ago] ('ZH_14',)
# 2025-07-07 15:28:48,059 INFO sqlalchemy.engine.Engine SELECT calligraphy_character.learn_id AS calligraphy_character_learn_id, calligraphy_character.character AS calligraphy_character_character, calligraphy_character.translation AS calligraphy_character_translation, calligraphy_character.components AS calligraphy_character_components, calligraphy_character.score AS calligraphy_character_score, calligraphy_character.last_seen AS calligraphy_character_last_seen, calligraphy_character.unit_id AS calligraphy_character_unit_id
# FROM calligraphy_character
# WHERE ? = calligraphy_character.unit_id
# 2025-07-07 15:28:48,059 INFO sqlalchemy.engine.Engine [cached since 0.01526s ago] ('ZH_1',)
# 2025-07-07 15:28:48,060 INFO sqlalchemy.engine.Engine SELECT grammar_rule.learn_id AS grammar_rule_learn_id, grammar_rule.title AS grammar_rule_title, grammar_rule.explanation AS grammar_rule_explanation, grammar_rule.score AS grammar_rule_score, grammar_rule.last_seen AS grammar_rule_last_seen, grammar_rule.unit_id AS grammar_rule_unit_id
# FROM grammar_rule
# WHERE ? = grammar_rule.unit_id
# 2025-07-07 15:28:48,060 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('ZH_11',)
# 2025-07-07 15:28:48,061 INFO sqlalchemy.engine.Engine SELECT grammar_rule.learn_id AS grammar_rule_learn_id, grammar_rule.title AS grammar_rule_title, grammar_rule.explanation AS grammar_rule_explanation, grammar_rule.score AS grammar_rule_score, grammar_rule.last_seen AS grammar_rule_last_seen, grammar_rule.unit_id AS grammar_rule_unit_id
# FROM grammar_rule
# WHERE ? = grammar_rule.unit_id
# 2025-07-07 15:28:48,061 INFO sqlalchemy.engine.Engine [cached since 0.001104s ago] ('ZH_9',)
# 2025-07-07 15:28:48,062 INFO sqlalchemy.engine.Engine SELECT grammar_rule.learn_id AS grammar_rule_learn_id, grammar_rule.title AS grammar_rule_title, grammar_rule.explanation AS grammar_rule_explanation, grammar_rule.score AS grammar_rule_score, grammar_rule.last_seen AS grammar_rule_last_seen, grammar_rule.unit_id AS grammar_rule_unit_id
# FROM grammar_rule
# WHERE ? = grammar_rule.unit_id
# 2025-07-07 15:28:48,062 INFO sqlalchemy.engine.Engine [cached since 0.001637s ago] ('ZH_6',)
# 2025-07-07 15:28:48,062 INFO sqlalchemy.engine.Engine SELECT grammar_rule.learn_id AS grammar_rule_learn_id, grammar_rule.title AS grammar_rule_title, grammar_rule.explanation AS grammar_rule_explanation, grammar_rule.score AS grammar_rule_score, grammar_rule.last_seen AS grammar_rule_last_seen, grammar_rule.unit_id AS grammar_rule_unit_id
# FROM grammar_rule
# WHERE ? = grammar_rule.unit_id
# 2025-07-07 15:28:48,062 INFO sqlalchemy.engine.Engine [cached since 0.00216s ago] ('ZH_7',)
# 2025-07-07 15:28:48,063 INFO sqlalchemy.engine.Engine SELECT grammar_rule.learn_id AS grammar_rule_learn_id, grammar_rule.title AS grammar_rule_title, grammar_rule.explanation AS grammar_rule_explanation, grammar_rule.score AS grammar_rule_score, grammar_rule.last_seen AS grammar_rule_last_seen, grammar_rule.unit_id AS grammar_rule_unit_id
# FROM grammar_rule
# WHERE ? = grammar_rule.unit_id
# 2025-07-07 15:28:48,063 INFO sqlalchemy.engine.Engine [cached since 0.002704s ago] ('ZH_12',)
# 2025-07-07 15:28:48,063 INFO sqlalchemy.engine.Engine SELECT grammar_rule.learn_id AS grammar_rule_learn_id, grammar_rule.title AS grammar_rule_title, grammar_rule.explanation AS grammar_rule_explanation, grammar_rule.score AS grammar_rule_score, grammar_rule.last_seen AS grammar_rule_last_seen, grammar_rule.unit_id AS grammar_rule_unit_id
# FROM grammar_rule
# WHERE ? = grammar_rule.unit_id
# 2025-07-07 15:28:48,063 INFO sqlalchemy.engine.Engine [cached since 0.003262s ago] ('ZH_2',)
# 2025-07-07 15:28:48,064 INFO sqlalchemy.engine.Engine SELECT grammar_rule.learn_id AS grammar_rule_learn_id, grammar_rule.title AS grammar_rule_title, grammar_rule.explanation AS grammar_rule_explanation, grammar_rule.score AS grammar_rule_score, grammar_rule.last_seen AS grammar_rule_last_seen, grammar_rule.unit_id AS grammar_rule_unit_id
# FROM grammar_rule
# WHERE ? = grammar_rule.unit_id
# 2025-07-07 15:28:48,064 INFO sqlalchemy.engine.Engine [cached since 0.003751s ago] ('ZH_0',)
# 2025-07-07 15:28:48,064 INFO sqlalchemy.engine.Engine SELECT grammar_rule.learn_id AS grammar_rule_learn_id, grammar_rule.title AS grammar_rule_title, grammar_rule.explanation AS grammar_rule_explanation, grammar_rule.score AS grammar_rule_score, grammar_rule.last_seen AS grammar_rule_last_seen, grammar_rule.unit_id AS grammar_rule_unit_id
# FROM grammar_rule
# WHERE ? = grammar_rule.unit_id
# 2025-07-07 15:28:48,064 INFO sqlalchemy.engine.Engine [cached since 0.004121s ago] ('ZH_13',)
# 2025-07-07 15:28:48,065 INFO sqlalchemy.engine.Engine SELECT grammar_rule.learn_id AS grammar_rule_learn_id, grammar_rule.title AS grammar_rule_title, grammar_rule.explanation AS grammar_rule_explanation, grammar_rule.score AS grammar_rule_score, grammar_rule.last_seen AS grammar_rule_last_seen, grammar_rule.unit_id AS grammar_rule_unit_id
# FROM grammar_rule
# WHERE ? = grammar_rule.unit_id
# 2025-07-07 15:28:48,065 INFO sqlalchemy.engine.Engine [cached since 0.004572s ago] ('ZH_10',)
# 2025-07-07 15:28:48,065 INFO sqlalchemy.engine.Engine SELECT grammar_rule.learn_id AS grammar_rule_learn_id, grammar_rule.title AS grammar_rule_title, grammar_rule.explanation AS grammar_rule_explanation, grammar_rule.score AS grammar_rule_score, grammar_rule.last_seen AS grammar_rule_last_seen, grammar_rule.unit_id AS grammar_rule_unit_id
# FROM grammar_rule
# WHERE ? = grammar_rule.unit_id
# 2025-07-07 15:28:48,065 INFO sqlalchemy.engine.Engine [cached since 0.005072s ago] ('ZH_4',)
# 2025-07-07 15:28:48,065 INFO sqlalchemy.engine.Engine SELECT grammar_rule.learn_id AS grammar_rule_learn_id, grammar_rule.title AS grammar_rule_title, grammar_rule.explanation AS grammar_rule_explanation, grammar_rule.score AS grammar_rule_score, grammar_rule.last_seen AS grammar_rule_last_seen, grammar_rule.unit_id AS grammar_rule_unit_id
# FROM grammar_rule
# WHERE ? = grammar_rule.unit_id
# 2025-07-07 15:28:48,066 INFO sqlalchemy.engine.Engine [cached since 0.005453s ago] ('ZH_15',)
# 2025-07-07 15:28:48,066 INFO sqlalchemy.engine.Engine SELECT grammar_rule.learn_id AS grammar_rule_learn_id, grammar_rule.title AS grammar_rule_title, grammar_rule.explanation AS grammar_rule_explanation, grammar_rule.score AS grammar_rule_score, grammar_rule.last_seen AS grammar_rule_last_seen, grammar_rule.unit_id AS grammar_rule_unit_id
# FROM grammar_rule
# WHERE ? = grammar_rule.unit_id
# 2025-07-07 15:28:48,066 INFO sqlalchemy.engine.Engine [cached since 0.005824s ago] ('ZH_8',)
# 2025-07-07 15:28:48,066 INFO sqlalchemy.engine.Engine SELECT grammar_rule.learn_id AS grammar_rule_learn_id, grammar_rule.title AS grammar_rule_title, grammar_rule.explanation AS grammar_rule_explanation, grammar_rule.score AS grammar_rule_score, grammar_rule.last_seen AS grammar_rule_last_seen, grammar_rule.unit_id AS grammar_rule_unit_id
# FROM grammar_rule
# WHERE ? = grammar_rule.unit_id
# 2025-07-07 15:28:48,066 INFO sqlalchemy.engine.Engine [cached since 0.006248s ago] ('ZH_5',)
# 2025-07-07 15:28:48,067 INFO sqlalchemy.engine.Engine SELECT grammar_rule.learn_id AS grammar_rule_learn_id, grammar_rule.title AS grammar_rule_title, grammar_rule.explanation AS grammar_rule_explanation, grammar_rule.score AS grammar_rule_score, grammar_rule.last_seen AS grammar_rule_last_seen, grammar_rule.unit_id AS grammar_rule_unit_id
# FROM grammar_rule
# WHERE ? = grammar_rule.unit_id
# 2025-07-07 15:28:48,067 INFO sqlalchemy.engine.Engine [cached since 0.006679s ago] ('ZH_3',)
# 2025-07-07 15:28:48,067 INFO sqlalchemy.engine.Engine SELECT grammar_rule.learn_id AS grammar_rule_learn_id, grammar_rule.title AS grammar_rule_title, grammar_rule.explanation AS grammar_rule_explanation, grammar_rule.score AS grammar_rule_score, grammar_rule.last_seen AS grammar_rule_last_seen, grammar_rule.unit_id AS grammar_rule_unit_id
# FROM grammar_rule
# WHERE ? = grammar_rule.unit_id
# 2025-07-07 15:28:48,067 INFO sqlalchemy.engine.Engine [cached since 0.007072s ago] ('ZH_14',)
# 2025-07-07 15:28:48,068 INFO sqlalchemy.engine.Engine SELECT grammar_rule.learn_id AS grammar_rule_learn_id, grammar_rule.title AS grammar_rule_title, grammar_rule.explanation AS grammar_rule_explanation, grammar_rule.score AS grammar_rule_score, grammar_rule.last_seen AS grammar_rule_last_seen, grammar_rule.unit_id AS grammar_rule_unit_id
# FROM grammar_rule
# WHERE ? = grammar_rule.unit_id
# 2025-07-07 15:28:48,068 INFO sqlalchemy.engine.Engine [cached since 0.007915s ago] ('ZH_1',)
# 2025-07-07 15:28:48,069 INFO sqlalchemy.engine.Engine SELECT vocabulary.learn_id AS vocabulary_learn_id, vocabulary.word AS vocabulary_word, vocabulary.translation AS vocabulary_translation, vocabulary.phonetic AS vocabulary_phonetic, vocabulary.example_sentence AS vocabulary_example_sentence, vocabulary.type AS vocabulary_type, vocabulary.score AS vocabulary_score, vocabulary.last_seen AS vocabulary_last_seen, vocabulary.unit_id AS vocabulary_unit_id
# FROM vocabulary
# WHERE ? = vocabulary.unit_id
# 2025-07-07 15:28:48,069 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('ZH_11',)
# 2025-07-07 15:28:48,070 INFO sqlalchemy.engine.Engine SELECT vocabulary.learn_id AS vocabulary_learn_id, vocabulary.word AS vocabulary_word, vocabulary.translation AS vocabulary_translation, vocabulary.phonetic AS vocabulary_phonetic, vocabulary.example_sentence AS vocabulary_example_sentence, vocabulary.type AS vocabulary_type, vocabulary.score AS vocabulary_score, vocabulary.last_seen AS vocabulary_last_seen, vocabulary.unit_id AS vocabulary_unit_id
# FROM vocabulary
# WHERE ? = vocabulary.unit_id
# 2025-07-07 15:28:48,070 INFO sqlalchemy.engine.Engine [cached since 0.001032s ago] ('ZH_9',)
# 2025-07-07 15:28:48,070 INFO sqlalchemy.engine.Engine SELECT vocabulary.learn_id AS vocabulary_learn_id, vocabulary.word AS vocabulary_word, vocabulary.translation AS vocabulary_translation, vocabulary.phonetic AS vocabulary_phonetic, vocabulary.example_sentence AS vocabulary_example_sentence, vocabulary.type AS vocabulary_type, vocabulary.score AS vocabulary_score, vocabulary.last_seen AS vocabulary_last_seen, vocabulary.unit_id AS vocabulary_unit_id
# FROM vocabulary
# WHERE ? = vocabulary.unit_id
# 2025-07-07 15:28:48,070 INFO sqlalchemy.engine.Engine [cached since 0.00154s ago] ('ZH_6',)
# 2025-07-07 15:28:48,071 INFO sqlalchemy.engine.Engine SELECT vocabulary.learn_id AS vocabulary_learn_id, vocabulary.word AS vocabulary_word, vocabulary.translation AS vocabulary_translation, vocabulary.phonetic AS vocabulary_phonetic, vocabulary.example_sentence AS vocabulary_example_sentence, vocabulary.type AS vocabulary_type, vocabulary.score AS vocabulary_score, vocabulary.last_seen AS vocabulary_last_seen, vocabulary.unit_id AS vocabulary_unit_id
# FROM vocabulary
# WHERE ? = vocabulary.unit_id
# 2025-07-07 15:28:48,071 INFO sqlalchemy.engine.Engine [cached since 0.002144s ago] ('ZH_7',)
# 2025-07-07 15:28:48,072 INFO sqlalchemy.engine.Engine SELECT vocabulary.learn_id AS vocabulary_learn_id, vocabulary.word AS vocabulary_word, vocabulary.translation AS vocabulary_translation, vocabulary.phonetic AS vocabulary_phonetic, vocabulary.example_sentence AS vocabulary_example_sentence, vocabulary.type AS vocabulary_type, vocabulary.score AS vocabulary_score, vocabulary.last_seen AS vocabulary_last_seen, vocabulary.unit_id AS vocabulary_unit_id
# FROM vocabulary
# WHERE ? = vocabulary.unit_id
# 2025-07-07 15:28:48,072 INFO sqlalchemy.engine.Engine [cached since 0.003072s ago] ('ZH_12',)
# 2025-07-07 15:28:48,073 INFO sqlalchemy.engine.Engine SELECT vocabulary.learn_id AS vocabulary_learn_id, vocabulary.word AS vocabulary_word, vocabulary.translation AS vocabulary_translation, vocabulary.phonetic AS vocabulary_phonetic, vocabulary.example_sentence AS vocabulary_example_sentence, vocabulary.type AS vocabulary_type, vocabulary.score AS vocabulary_score, vocabulary.last_seen AS vocabulary_last_seen, vocabulary.unit_id AS vocabulary_unit_id
# FROM vocabulary
# WHERE ? = vocabulary.unit_id
# 2025-07-07 15:28:48,073 INFO sqlalchemy.engine.Engine [cached since 0.004268s ago] ('ZH_2',)
# 2025-07-07 15:28:48,074 INFO sqlalchemy.engine.Engine SELECT vocabulary.learn_id AS vocabulary_learn_id, vocabulary.word AS vocabulary_word, vocabulary.translation AS vocabulary_translation, vocabulary.phonetic AS vocabulary_phonetic, vocabulary.example_sentence AS vocabulary_example_sentence, vocabulary.type AS vocabulary_type, vocabulary.score AS vocabulary_score, vocabulary.last_seen AS vocabulary_last_seen, vocabulary.unit_id AS vocabulary_unit_id
# FROM vocabulary
# WHERE ? = vocabulary.unit_id
# 2025-07-07 15:28:48,074 INFO sqlalchemy.engine.Engine [cached since 0.005217s ago] ('ZH_0',)
# 2025-07-07 15:28:48,075 INFO sqlalchemy.engine.Engine SELECT vocabulary.learn_id AS vocabulary_learn_id, vocabulary.word AS vocabulary_word, vocabulary.translation AS vocabulary_translation, vocabulary.phonetic AS vocabulary_phonetic, vocabulary.example_sentence AS vocabulary_example_sentence, vocabulary.type AS vocabulary_type, vocabulary.score AS vocabulary_score, vocabulary.last_seen AS vocabulary_last_seen, vocabulary.unit_id AS vocabulary_unit_id
# FROM vocabulary
# WHERE ? = vocabulary.unit_id
# 2025-07-07 15:28:48,075 INFO sqlalchemy.engine.Engine [cached since 0.006141s ago] ('ZH_13',)
# 2025-07-07 15:28:48,075 INFO sqlalchemy.engine.Engine SELECT vocabulary.learn_id AS vocabulary_learn_id, vocabulary.word AS vocabulary_word, vocabulary.translation AS vocabulary_translation, vocabulary.phonetic AS vocabulary_phonetic, vocabulary.example_sentence AS vocabulary_example_sentence, vocabulary.type AS vocabulary_type, vocabulary.score AS vocabulary_score, vocabulary.last_seen AS vocabulary_last_seen, vocabulary.unit_id AS vocabulary_unit_id
# FROM vocabulary
# WHERE ? = vocabulary.unit_id
# 2025-07-07 15:28:48,076 INFO sqlalchemy.engine.Engine [cached since 0.006816s ago] ('ZH_10',)
# 2025-07-07 15:28:48,076 INFO sqlalchemy.engine.Engine SELECT vocabulary.learn_id AS vocabulary_learn_id, vocabulary.word AS vocabulary_word, vocabulary.translation AS vocabulary_translation, vocabulary.phonetic AS vocabulary_phonetic, vocabulary.example_sentence AS vocabulary_example_sentence, vocabulary.type AS vocabulary_type, vocabulary.score AS vocabulary_score, vocabulary.last_seen AS vocabulary_last_seen, vocabulary.unit_id AS vocabulary_unit_id
# FROM vocabulary
# WHERE ? = vocabulary.unit_id
# 2025-07-07 15:28:48,076 INFO sqlalchemy.engine.Engine [cached since 0.007429s ago] ('ZH_4',)
# 2025-07-07 15:28:48,077 INFO sqlalchemy.engine.Engine SELECT vocabulary.learn_id AS vocabulary_learn_id, vocabulary.word AS vocabulary_word, vocabulary.translation AS vocabulary_translation, vocabulary.phonetic AS vocabulary_phonetic, vocabulary.example_sentence AS vocabulary_example_sentence, vocabulary.type AS vocabulary_type, vocabulary.score AS vocabulary_score, vocabulary.last_seen AS vocabulary_last_seen, vocabulary.unit_id AS vocabulary_unit_id
# FROM vocabulary
# WHERE ? = vocabulary.unit_id
# 2025-07-07 15:28:48,077 INFO sqlalchemy.engine.Engine [cached since 0.007992s ago] ('ZH_15',)
# 2025-07-07 15:28:48,077 INFO sqlalchemy.engine.Engine SELECT vocabulary.learn_id AS vocabulary_learn_id, vocabulary.word AS vocabulary_word, vocabulary.translation AS vocabulary_translation, vocabulary.phonetic AS vocabulary_phonetic, vocabulary.example_sentence AS vocabulary_example_sentence, vocabulary.type AS vocabulary_type, vocabulary.score AS vocabulary_score, vocabulary.last_seen AS vocabulary_last_seen, vocabulary.unit_id AS vocabulary_unit_id
# FROM vocabulary
# WHERE ? = vocabulary.unit_id
# 2025-07-07 15:28:48,077 INFO sqlalchemy.engine.Engine [cached since 0.008548s ago] ('ZH_8',)
# 2025-07-07 15:28:48,078 INFO sqlalchemy.engine.Engine SELECT vocabulary.learn_id AS vocabulary_learn_id, vocabulary.word AS vocabulary_word, vocabulary.translation AS vocabulary_translation, vocabulary.phonetic AS vocabulary_phonetic, vocabulary.example_sentence AS vocabulary_example_sentence, vocabulary.type AS vocabulary_type, vocabulary.score AS vocabulary_score, vocabulary.last_seen AS vocabulary_last_seen, vocabulary.unit_id AS vocabulary_unit_id
# FROM vocabulary
# WHERE ? = vocabulary.unit_id
# 2025-07-07 15:28:48,078 INFO sqlalchemy.engine.Engine [cached since 0.009279s ago] ('ZH_5',)
# 2025-07-07 15:28:48,078 INFO sqlalchemy.engine.Engine SELECT vocabulary.learn_id AS vocabulary_learn_id, vocabulary.word AS vocabulary_word, vocabulary.translation AS vocabulary_translation, vocabulary.phonetic AS vocabulary_phonetic, vocabulary.example_sentence AS vocabulary_example_sentence, vocabulary.type AS vocabulary_type, vocabulary.score AS vocabulary_score, vocabulary.last_seen AS vocabulary_last_seen, vocabulary.unit_id AS vocabulary_unit_id
# FROM vocabulary
# WHERE ? = vocabulary.unit_id
# 2025-07-07 15:28:48,078 INFO sqlalchemy.engine.Engine [cached since 0.009788s ago] ('ZH_3',)
# 2025-07-07 15:28:48,079 INFO sqlalchemy.engine.Engine SELECT vocabulary.learn_id AS vocabulary_learn_id, vocabulary.word AS vocabulary_word, vocabulary.translation AS vocabulary_translation, vocabulary.phonetic AS vocabulary_phonetic, vocabulary.example_sentence AS vocabulary_example_sentence, vocabulary.type AS vocabulary_type, vocabulary.score AS vocabulary_score, vocabulary.last_seen AS vocabulary_last_seen, vocabulary.unit_id AS vocabulary_unit_id
# FROM vocabulary
# WHERE ? = vocabulary.unit_id
# 2025-07-07 15:28:48,079 INFO sqlalchemy.engine.Engine [cached since 0.01035s ago] ('ZH_14',)
# 2025-07-07 15:28:48,080 INFO sqlalchemy.engine.Engine SELECT vocabulary.learn_id AS vocabulary_learn_id, vocabulary.word AS vocabulary_word, vocabulary.translation AS vocabulary_translation, vocabulary.phonetic AS vocabulary_phonetic, vocabulary.example_sentence AS vocabulary_example_sentence, vocabulary.type AS vocabulary_type, vocabulary.score AS vocabulary_score, vocabulary.last_seen AS vocabulary_last_seen, vocabulary.unit_id AS vocabulary_unit_id
# FROM vocabulary
# WHERE ? = vocabulary.unit_id
# 2025-07-07 15:28:48,080 INFO sqlalchemy.engine.Engine [cached since 0.01093s ago] ('ZH_1',)
# 2025-07-07 15:28:48,081 INFO sqlalchemy.engine.Engine SELECT exercises.learn_id AS exercises_learn_id, exercises.exercise_type AS exercises_exercise_type, exercises.question AS exercises_question, exercises.support AS exercises_support, exercises.answer AS exercises_answer, exercises.score AS exercises_score, exercises.last_seen AS exercises_last_seen, exercises.unit_id AS exercises_unit_id
# FROM exercises
# WHERE ? = exercises.unit_id
# 2025-07-07 15:28:48,081 INFO sqlalchemy.engine.Engine [generated in 0.00014s] ('ZH_11',)
# 2025-07-07 15:28:48,081 INFO sqlalchemy.engine.Engine SELECT exercises.learn_id AS exercises_learn_id, exercises.exercise_type AS exercises_exercise_type, exercises.question AS exercises_question, exercises.support AS exercises_support, exercises.answer AS exercises_answer, exercises.score AS exercises_score, exercises.last_seen AS exercises_last_seen, exercises.unit_id AS exercises_unit_id
# FROM exercises
# WHERE ? = exercises.unit_id
# 2025-07-07 15:28:48,081 INFO sqlalchemy.engine.Engine [cached since 0.0006715s ago] ('ZH_9',)
# 2025-07-07 15:28:48,081 INFO sqlalchemy.engine.Engine SELECT exercises.learn_id AS exercises_learn_id, exercises.exercise_type AS exercises_exercise_type, exercises.question AS exercises_question, exercises.support AS exercises_support, exercises.answer AS exercises_answer, exercises.score AS exercises_score, exercises.last_seen AS exercises_last_seen, exercises.unit_id AS exercises_unit_id
# FROM exercises
# WHERE ? = exercises.unit_id
# 2025-07-07 15:28:48,082 INFO sqlalchemy.engine.Engine [cached since 0.001027s ago] ('ZH_6',)
# 2025-07-07 15:28:48,082 INFO sqlalchemy.engine.Engine SELECT exercises.learn_id AS exercises_learn_id, exercises.exercise_type AS exercises_exercise_type, exercises.question AS exercises_question, exercises.support AS exercises_support, exercises.answer AS exercises_answer, exercises.score AS exercises_score, exercises.last_seen AS exercises_last_seen, exercises.unit_id AS exercises_unit_id
# FROM exercises
# WHERE ? = exercises.unit_id
# 2025-07-07 15:28:48,082 INFO sqlalchemy.engine.Engine [cached since 0.001357s ago] ('ZH_7',)
# 2025-07-07 15:28:48,082 INFO sqlalchemy.engine.Engine SELECT exercises.learn_id AS exercises_learn_id, exercises.exercise_type AS exercises_exercise_type, exercises.question AS exercises_question, exercises.support AS exercises_support, exercises.answer AS exercises_answer, exercises.score AS exercises_score, exercises.last_seen AS exercises_last_seen, exercises.unit_id AS exercises_unit_id
# FROM exercises
# WHERE ? = exercises.unit_id
# 2025-07-07 15:28:48,082 INFO sqlalchemy.engine.Engine [cached since 0.001701s ago] ('ZH_12',)
# 2025-07-07 15:28:48,082 INFO sqlalchemy.engine.Engine SELECT exercises.learn_id AS exercises_learn_id, exercises.exercise_type AS exercises_exercise_type, exercises.question AS exercises_question, exercises.support AS exercises_support, exercises.answer AS exercises_answer, exercises.score AS exercises_score, exercises.last_seen AS exercises_last_seen, exercises.unit_id AS exercises_unit_id
# FROM exercises
# WHERE ? = exercises.unit_id
# 2025-07-07 15:28:48,083 INFO sqlalchemy.engine.Engine [cached since 0.002053s ago] ('ZH_2',)
# 2025-07-07 15:28:48,083 INFO sqlalchemy.engine.Engine SELECT exercises.learn_id AS exercises_learn_id, exercises.exercise_type AS exercises_exercise_type, exercises.question AS exercises_question, exercises.support AS exercises_support, exercises.answer AS exercises_answer, exercises.score AS exercises_score, exercises.last_seen AS exercises_last_seen, exercises.unit_id AS exercises_unit_id
# FROM exercises
# WHERE ? = exercises.unit_id
# 2025-07-07 15:28:48,083 INFO sqlalchemy.engine.Engine [cached since 0.0024s ago] ('ZH_0',)
# 2025-07-07 15:28:48,083 INFO sqlalchemy.engine.Engine SELECT exercises.learn_id AS exercises_learn_id, exercises.exercise_type AS exercises_exercise_type, exercises.question AS exercises_question, exercises.support AS exercises_support, exercises.answer AS exercises_answer, exercises.score AS exercises_score, exercises.last_seen AS exercises_last_seen, exercises.unit_id AS exercises_unit_id
# FROM exercises
# WHERE ? = exercises.unit_id
# 2025-07-07 15:28:48,083 INFO sqlalchemy.engine.Engine [cached since 0.002755s ago] ('ZH_13',)
# 2025-07-07 15:28:48,084 INFO sqlalchemy.engine.Engine SELECT exercises.learn_id AS exercises_learn_id, exercises.exercise_type AS exercises_exercise_type, exercises.question AS exercises_question, exercises.support AS exercises_support, exercises.answer AS exercises_answer, exercises.score AS exercises_score, exercises.last_seen AS exercises_last_seen, exercises.unit_id AS exercises_unit_id
# FROM exercises
# WHERE ? = exercises.unit_id
# 2025-07-07 15:28:48,084 INFO sqlalchemy.engine.Engine [cached since 0.003251s ago] ('ZH_10',)
# 2025-07-07 15:28:48,084 INFO sqlalchemy.engine.Engine SELECT exercises.learn_id AS exercises_learn_id, exercises.exercise_type AS exercises_exercise_type, exercises.question AS exercises_question, exercises.support AS exercises_support, exercises.answer AS exercises_answer, exercises.score AS exercises_score, exercises.last_seen AS exercises_last_seen, exercises.unit_id AS exercises_unit_id
# FROM exercises
# WHERE ? = exercises.unit_id
# 2025-07-07 15:28:48,084 INFO sqlalchemy.engine.Engine [cached since 0.003657s ago] ('ZH_4',)
# 2025-07-07 15:28:48,084 INFO sqlalchemy.engine.Engine SELECT exercises.learn_id AS exercises_learn_id, exercises.exercise_type AS exercises_exercise_type, exercises.question AS exercises_question, exercises.support AS exercises_support, exercises.answer AS exercises_answer, exercises.score AS exercises_score, exercises.last_seen AS exercises_last_seen, exercises.unit_id AS exercises_unit_id
# FROM exercises
# WHERE ? = exercises.unit_id
# 2025-07-07 15:28:48,085 INFO sqlalchemy.engine.Engine [cached since 0.004041s ago] ('ZH_15',)
# 2025-07-07 15:28:48,085 INFO sqlalchemy.engine.Engine SELECT exercises.learn_id AS exercises_learn_id, exercises.exercise_type AS exercises_exercise_type, exercises.question AS exercises_question, exercises.support AS exercises_support, exercises.answer AS exercises_answer, exercises.score AS exercises_score, exercises.last_seen AS exercises_last_seen, exercises.unit_id AS exercises_unit_id
# FROM exercises
# WHERE ? = exercises.unit_id
# 2025-07-07 15:28:48,085 INFO sqlalchemy.engine.Engine [cached since 0.004392s ago] ('ZH_8',)
# 2025-07-07 15:28:48,085 INFO sqlalchemy.engine.Engine SELECT exercises.learn_id AS exercises_learn_id, exercises.exercise_type AS exercises_exercise_type, exercises.question AS exercises_question, exercises.support AS exercises_support, exercises.answer AS exercises_answer, exercises.score AS exercises_score, exercises.last_seen AS exercises_last_seen, exercises.unit_id AS exercises_unit_id
# FROM exercises
# WHERE ? = exercises.unit_id
# 2025-07-07 15:28:48,085 INFO sqlalchemy.engine.Engine [cached since 0.00476s ago] ('ZH_5',)
# 2025-07-07 15:28:48,086 INFO sqlalchemy.engine.Engine SELECT exercises.learn_id AS exercises_learn_id, exercises.exercise_type AS exercises_exercise_type, exercises.question AS exercises_question, exercises.support AS exercises_support, exercises.answer AS exercises_answer, exercises.score AS exercises_score, exercises.last_seen AS exercises_last_seen, exercises.unit_id AS exercises_unit_id
# FROM exercises
# WHERE ? = exercises.unit_id
# 2025-07-07 15:28:48,086 INFO sqlalchemy.engine.Engine [cached since 0.005109s ago] ('ZH_3',)
# 2025-07-07 15:28:48,086 INFO sqlalchemy.engine.Engine SELECT exercises.learn_id AS exercises_learn_id, exercises.exercise_type AS exercises_exercise_type, exercises.question AS exercises_question, exercises.support AS exercises_support, exercises.answer AS exercises_answer, exercises.score AS exercises_score, exercises.last_seen AS exercises_last_seen, exercises.unit_id AS exercises_unit_id
# FROM exercises
# WHERE ? = exercises.unit_id
# 2025-07-07 15:28:48,086 INFO sqlalchemy.engine.Engine [cached since 0.005437s ago] ('ZH_14',)
# 2025-07-07 15:28:48,086 INFO sqlalchemy.engine.Engine SELECT exercises.learn_id AS exercises_learn_id, exercises.exercise_type AS exercises_exercise_type, exercises.question AS exercises_question, exercises.support AS exercises_support, exercises.answer AS exercises_answer, exercises.score AS exercises_score, exercises.last_seen AS exercises_last_seen, exercises.unit_id AS exercises_unit_id
# FROM exercises
# WHERE ? = exercises.unit_id
# 2025-07-07 15:28:48,086 INFO sqlalchemy.engine.Engine [cached since 0.005793s ago] ('ZH_1',)
# 2025-07-07 15:28:48,088 INFO sqlalchemy.engine.Engine DELETE FROM grammar_rule WHERE grammar_rule.learn_id = ?
# 2025-07-07 15:28:48,089 INFO sqlalchemy.engine.Engine [generated in 0.00037s] [('ZH_10_G1',), ('ZH_10_G2',), ('ZH_10_G3',), ('ZH_10_G4',), ('ZH_10_G5',), ('ZH_10_G6',), ('ZH_11_G1',), ('ZH_11_G2',)  ... displaying 10 of 69 total bound parameter sets ...  ('ZH_9_G5',), ('ZH_9_G6',)]
# 2025-07-07 15:28:48,092 INFO sqlalchemy.engine.Engine DELETE FROM vocabulary WHERE vocabulary.learn_id = ?
# 2025-07-07 15:28:48,092 INFO sqlalchemy.engine.Engine [generated in 0.00052s] [('ZH_0_V0',), ('ZH_0_V1',), ('ZH_0_V10',), ('ZH_0_V2',), ('ZH_0_V3',), ('ZH_0_V4',), ('ZH_0_V5',), ('ZH_0_V6',)  ... displaying 10 of 417 total bound parameter sets ...  ('ZH_9_V8',), ('ZH_9_V9',)]
# 2025-07-07 15:28:48,095 INFO sqlalchemy.engine.Engine DELETE FROM unit WHERE unit.unit_id = ?
# 2025-07-07 15:28:48,096 INFO sqlalchemy.engine.Engine [generated in 0.00023s] [('ZH_0',), ('ZH_1',), ('ZH_10',), ('ZH_11',), ('ZH_12',), ('ZH_13',), ('ZH_14',), ('ZH_15',)  ... displaying 10 of 16 total bound parameter sets ...  ('ZH_8',), ('ZH_9',)]
# 2025-07-07 15:28:48,096 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Add Units

# %%
# Initialize the database connection and create db file if it doesn't exist
engine, session = init_db()

# Initialize the database
with open(f'../data/{language_id}/units.json', 'r', encoding="utf8") as f:
    units_array = json.load(f)
    
units = []
for idx, unit_data in enumerate(units_array):
    units.append(
        Unit(
            unit_id = f"{language_id.upper()}_{idx}",
            title = unit_data['title'],
            description = unit_data['description'],
            level = unit_data['level'],
            language_id = language_id,
        )
    )
inserts(session, units)
session.close()
# Out:
# 2025-07-07 15:26:07,031 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:07,032 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("language")
# 2025-07-07 15:26:07,032 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 15:26:07,032 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-07 15:26:07,033 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 15:26:07,034 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-07 15:26:07,034 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 15:26:07,035 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-07 15:26:07,035 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 15:26:07,036 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-07 15:26:07,036 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 15:26:07,036 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-07 15:26:07,036 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 15:26:07,037 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:07,038 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:07,039 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:07,039 INFO sqlalchemy.engine.Engine [generated in 0.00025s] ('ZH_0', 'Lecon introductive: Bonjour!', "A l'oral: Connaitre les salutations de base\nA l'ecrit: 5 caracteres", 'A1', 0, 'zh')
# 2025-07-07 15:26:07,040 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:07,041 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:07,041 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:07,041 INFO sqlalchemy.engine.Engine [cached since 0.002078s ago] ('ZH_1', "Unite 1: Comment t'appelles-tu?", "A l'oral: Savoir se presenter et presenter quelqu'un\nParler de sa nationalite\nA l'ecrit: 19 caracteres", 'A1', 0, 'zh')
# 2025-07-07 15:26:07,042 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:07,043 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:07,043 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:07,043 INFO sqlalchemy.engine.Engine [cached since 0.004294s ago] ('ZH_2', 'Unite 2: Un, deux, trois', "A l'oral: Compter de 1 a 9999\nSavoir enumerer des objets\nA l'ecrit: 19 caracteres", 'A1', 0, 'zh')
# 2025-07-07 15:26:07,044 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:07,045 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:07,045 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:07,046 INFO sqlalchemy.engine.Engine [cached since 0.00673s ago] ('ZH_3', "Unite 3: Aujourd'hui", "A l'oral: Savoir annoncer la date\nParler des moments de la journee et de l'heure\nA l'ecrit: 17 caracteres", 'A1', 0, 'zh')
# 2025-07-07 15:26:07,046 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:07,047 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:07,048 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:07,048 INFO sqlalchemy.engine.Engine [cached since 0.008868s ago] ('ZH_4', 'Unite 4: Ou allons-nous?', "A l'oral: Parler d'un evenement passe, d'une experience\nPouvoir se situer, parler ou l'on est, ou l'on va\nA l'ecrit: 17 caracteres", 'A1', 0, 'zh')
# 2025-07-07 15:26:07,048 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:07,049 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:07,049 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:07,049 INFO sqlalchemy.engine.Engine [cached since 0.01058s ago] ('ZH_5', 'Unite 5: Je ne suis pas vieux', "A l'oral: Decrire quelqu'un ou quelque chose\nUtilise les adjectifs\nA l'ecrit: 17 caracteres", 'A1', 0, 'zh')
# 2025-07-07 15:26:07,050 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:07,050 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:07,051 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:07,051 INFO sqlalchemy.engine.Engine [cached since 0.01189s ago] ('ZH_6', 'Unite 6: Ma famille', "A l'oral: Pouvoir presenter sa famille\nUtilise les demonstratifs\nA l'ecrit: 22 caracteres", 'A1', 0, 'zh')
# 2025-07-07 15:26:07,051 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:07,052 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:07,052 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:07,052 INFO sqlalchemy.engine.Engine [cached since 0.01347s ago] ('ZH_7', 'Unite 7: Mes amis', "A l'oral: Parler des ses amis\nParler des langues etrangeres\nComparer des gens ou des objets\nA l'ecrit: 18 caracteres", 'A1', 0, 'zh')
# 2025-07-07 15:26:07,053 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:07,054 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:07,054 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:07,054 INFO sqlalchemy.engine.Engine [cached since 0.01516s ago] ('ZH_8', "Unite 8: Qu'aimes-tu faire?", "A l'oral: Parler de ses activites favorites\nInterroger sur la maniere\nA l'ecrit: 16 caracteres", 'A2', 0, 'zh')
# 2025-07-07 15:26:07,054 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:07,055 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:07,055 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:07,055 INFO sqlalchemy.engine.Engine [cached since 0.01645s ago] ('ZH_9', 'Unite 9: Une journee classique', "A l'oral: Raconter sa journee\nParler des differents moyens de transport\nA l'ecrit: 16 caracteres", 'A2', 0, 'zh')
# 2025-07-07 15:26:07,056 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:07,056 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:07,056 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:07,057 INFO sqlalchemy.engine.Engine [cached since 0.01765s ago] ('ZH_10', 'Unite 10: Au travail', "A l'oral: Parler du monde du travail\nA l'ecrit: 18 caracteres", 'A2', 0, 'zh')
# 2025-07-07 15:26:07,057 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:07,058 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:07,058 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:07,058 INFO sqlalchemy.engine.Engine [cached since 0.01911s ago] ('ZH_11', 'Unite 11: Dans une grande ville', "A l'oral: Pouvoir demander son chemin\nSe reperer en ville\nA l'ecrit: 18 caracteres", 'A2', 0, 'zh')
# 2025-07-07 15:26:07,059 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:07,059 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:07,060 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:07,060 INFO sqlalchemy.engine.Engine [cached since 0.02096s ago] ('ZH_12', 'Unite 12: Faire des achats', "A l'oral: Negocier un prix\nFaire des achats\nA l'ecrit: 18 caracteres", 'A2', 0, 'zh')
# 2025-07-07 15:26:07,060 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:07,061 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:07,061 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:07,061 INFO sqlalchemy.engine.Engine [cached since 0.02215s ago] ('ZH_13', "Unite 13: En voyage a l'etranger", "A l'oral: Pouvoir raconter ou prevoir un voyage\nUtiliser 'Avant, apres, pendant'\nA l'ecrit: 17 caracteres", 'A2', 0, 'zh')
# 2025-07-07 15:26:07,061 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:07,062 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:07,062 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:07,062 INFO sqlalchemy.engine.Engine [cached since 0.02336s ago] ('ZH_14', 'Unite 14: La culture chinoise', "A l'oral: Decouvrir la culture chinoise\nParler des fetes et des vacances\nA l'ecrit: 19 caracteres", 'A2', 0, 'zh')
# 2025-07-07 15:26:07,063 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:07,063 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:07,063 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:07,064 INFO sqlalchemy.engine.Engine [cached since 0.02468s ago] ('ZH_15', 'Unite 15: A la maison', "A l'oral: Decrire une maison, un appartement\nUtiliser 吧 et les directionnels\nA l'ecrit: 17 caracteres", 'A2', 0, 'zh')
# 2025-07-07 15:26:07,064 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Add Vocabulary

# %%
# Initialize the database connection and create db file if it doesn't exist
engine, session = init_db()

directory_path = f'../data/{language_id}/vocabulary'

if not os.path.exists(directory_path):
    raise FileNotFoundError(f"No vocabulary found for {language_id}.")

vocs = []

# List all elements (files and directories) in the specified directory and get their full paths
elements_paths = [os.path.join(directory_path, element) for element in os.listdir(directory_path)]
for voc_file in elements_paths:
    if os.path.isfile(voc_file) and voc_file.endswith('.csv'):
        unit_id = re.sub("[^0-9]", "", os.path.basename(voc_file))
        df = pd.read_csv(voc_file)
        for idx, row in df.iterrows():
            vocs.append( 
                Vocabulary(
                    learn_id=f"{language_id.upper()}_{unit_id}_V{idx}",
                    word = row['word'],
                    translation = row["translation"],
                    phonetic = row["pinyin"],
                    example_sentence = row.get("example_sentence", ""),
                    type = row["type"],
                    parent=session.query(Unit).filter(Unit.unit_id == f"{language_id.upper()}_{unit_id}").first()
                )
            )
inserts(session, vocs)
session.close()
# Out:
# 2025-07-07 15:26:57,639 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:57,640 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("language")
# 2025-07-07 15:26:57,640 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 15:26:57,641 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-07 15:26:57,641 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 15:26:57,642 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-07 15:26:57,642 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 15:26:57,643 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-07 15:26:57,643 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 15:26:57,644 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-07 15:26:57,644 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 15:26:57,644 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-07 15:26:57,645 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 15:26:57,645 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:57,654 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:57,655 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,656 INFO sqlalchemy.engine.Engine [generated in 0.00073s] ('ZH_2', 1, 0)
# 2025-07-07 15:26:57,658 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,658 INFO sqlalchemy.engine.Engine [cached since 0.002681s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:26:57,659 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,659 INFO sqlalchemy.engine.Engine [cached since 0.003753s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:26:57,660 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,660 INFO sqlalchemy.engine.Engine [cached since 0.004641s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:26:57,661 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,661 INFO sqlalchemy.engine.Engine [cached since 0.00552s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:26:57,661 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,662 INFO sqlalchemy.engine.Engine [cached since 0.006521s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:26:57,663 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,663 INFO sqlalchemy.engine.Engine [cached since 0.007807s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:26:57,664 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,664 INFO sqlalchemy.engine.Engine [cached since 0.009145s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:26:57,665 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,666 INFO sqlalchemy.engine.Engine [cached since 0.01041s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:26:57,667 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,668 INFO sqlalchemy.engine.Engine [cached since 0.01282s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:26:57,670 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,670 INFO sqlalchemy.engine.Engine [cached since 0.01498s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:26:57,671 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,671 INFO sqlalchemy.engine.Engine [cached since 0.01622s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:26:57,673 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,673 INFO sqlalchemy.engine.Engine [cached since 0.01783s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:26:57,675 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,675 INFO sqlalchemy.engine.Engine [cached since 0.01972s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:26:57,676 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,676 INFO sqlalchemy.engine.Engine [cached since 0.02061s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:26:57,676 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,677 INFO sqlalchemy.engine.Engine [cached since 0.02139s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:26:57,677 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,678 INFO sqlalchemy.engine.Engine [cached since 0.02241s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:26:57,678 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,679 INFO sqlalchemy.engine.Engine [cached since 0.02336s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:26:57,679 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,679 INFO sqlalchemy.engine.Engine [cached since 0.02407s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:26:57,680 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,680 INFO sqlalchemy.engine.Engine [cached since 0.02475s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:26:57,681 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,681 INFO sqlalchemy.engine.Engine [cached since 0.02547s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:26:57,681 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,681 INFO sqlalchemy.engine.Engine [cached since 0.02606s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:26:57,682 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,682 INFO sqlalchemy.engine.Engine [cached since 0.02675s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:26:57,684 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,684 INFO sqlalchemy.engine.Engine [cached since 0.02848s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,684 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,684 INFO sqlalchemy.engine.Engine [cached since 0.02912s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,685 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,685 INFO sqlalchemy.engine.Engine [cached since 0.02971s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,685 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,686 INFO sqlalchemy.engine.Engine [cached since 0.03043s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,686 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,686 INFO sqlalchemy.engine.Engine [cached since 0.03102s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,687 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,687 INFO sqlalchemy.engine.Engine [cached since 0.0316s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,687 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,687 INFO sqlalchemy.engine.Engine [cached since 0.03223s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,689 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,690 INFO sqlalchemy.engine.Engine [cached since 0.0347s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,691 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,691 INFO sqlalchemy.engine.Engine [cached since 0.03565s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,691 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,692 INFO sqlalchemy.engine.Engine [cached since 0.03632s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,692 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,692 INFO sqlalchemy.engine.Engine [cached since 0.03694s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,693 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,693 INFO sqlalchemy.engine.Engine [cached since 0.03769s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,693 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,694 INFO sqlalchemy.engine.Engine [cached since 0.03836s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,694 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,694 INFO sqlalchemy.engine.Engine [cached since 0.03895s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,695 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,695 INFO sqlalchemy.engine.Engine [cached since 0.03962s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,695 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,695 INFO sqlalchemy.engine.Engine [cached since 0.04018s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,696 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,696 INFO sqlalchemy.engine.Engine [cached since 0.04085s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,697 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,697 INFO sqlalchemy.engine.Engine [cached since 0.04145s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,697 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,697 INFO sqlalchemy.engine.Engine [cached since 0.04207s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,698 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,698 INFO sqlalchemy.engine.Engine [cached since 0.04293s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,699 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,699 INFO sqlalchemy.engine.Engine [cached since 0.04425s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,700 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,700 INFO sqlalchemy.engine.Engine [cached since 0.04509s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,701 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,701 INFO sqlalchemy.engine.Engine [cached since 0.04578s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,701 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,702 INFO sqlalchemy.engine.Engine [cached since 0.04638s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,702 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,702 INFO sqlalchemy.engine.Engine [cached since 0.04699s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,703 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,703 INFO sqlalchemy.engine.Engine [cached since 0.04759s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,703 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,703 INFO sqlalchemy.engine.Engine [cached since 0.04817s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,704 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,704 INFO sqlalchemy.engine.Engine [cached since 0.04873s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,704 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,704 INFO sqlalchemy.engine.Engine [cached since 0.04929s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,705 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,705 INFO sqlalchemy.engine.Engine [cached since 0.04988s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,706 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,707 INFO sqlalchemy.engine.Engine [cached since 0.05149s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:26:57,709 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,709 INFO sqlalchemy.engine.Engine [cached since 0.05371s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:26:57,710 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,710 INFO sqlalchemy.engine.Engine [cached since 0.05458s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:26:57,710 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,710 INFO sqlalchemy.engine.Engine [cached since 0.05527s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:26:57,711 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,711 INFO sqlalchemy.engine.Engine [cached since 0.05593s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:26:57,712 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,712 INFO sqlalchemy.engine.Engine [cached since 0.05649s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:26:57,712 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,712 INFO sqlalchemy.engine.Engine [cached since 0.05708s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:26:57,713 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,713 INFO sqlalchemy.engine.Engine [cached since 0.0577s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:26:57,713 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,714 INFO sqlalchemy.engine.Engine [cached since 0.05834s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:26:57,714 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,714 INFO sqlalchemy.engine.Engine [cached since 0.05889s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:26:57,714 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,715 INFO sqlalchemy.engine.Engine [cached since 0.05943s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:26:57,715 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,715 INFO sqlalchemy.engine.Engine [cached since 0.05997s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:26:57,716 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,716 INFO sqlalchemy.engine.Engine [cached since 0.06051s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:26:57,716 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,716 INFO sqlalchemy.engine.Engine [cached since 0.06109s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:26:57,717 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,717 INFO sqlalchemy.engine.Engine [cached since 0.06173s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:26:57,717 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,717 INFO sqlalchemy.engine.Engine [cached since 0.06231s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:26:57,718 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,718 INFO sqlalchemy.engine.Engine [cached since 0.06289s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:26:57,719 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,719 INFO sqlalchemy.engine.Engine [cached since 0.06346s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:26:57,719 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,719 INFO sqlalchemy.engine.Engine [cached since 0.06408s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:26:57,720 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,720 INFO sqlalchemy.engine.Engine [cached since 0.06476s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:26:57,721 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,721 INFO sqlalchemy.engine.Engine [cached since 0.0656s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:26:57,722 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,722 INFO sqlalchemy.engine.Engine [cached since 0.06661s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:26:57,723 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,723 INFO sqlalchemy.engine.Engine [cached since 0.06775s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:26:57,723 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,724 INFO sqlalchemy.engine.Engine [cached since 0.06837s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:26:57,724 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,724 INFO sqlalchemy.engine.Engine [cached since 0.06898s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:26:57,725 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,726 INFO sqlalchemy.engine.Engine [cached since 0.07042s ago] ('ZH_0', 1, 0)
# 2025-07-07 15:26:57,726 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,726 INFO sqlalchemy.engine.Engine [cached since 0.07107s ago] ('ZH_0', 1, 0)
# 2025-07-07 15:26:57,727 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,727 INFO sqlalchemy.engine.Engine [cached since 0.0717s ago] ('ZH_0', 1, 0)
# 2025-07-07 15:26:57,727 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,727 INFO sqlalchemy.engine.Engine [cached since 0.07228s ago] ('ZH_0', 1, 0)
# 2025-07-07 15:26:57,728 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,728 INFO sqlalchemy.engine.Engine [cached since 0.07287s ago] ('ZH_0', 1, 0)
# 2025-07-07 15:26:57,728 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,729 INFO sqlalchemy.engine.Engine [cached since 0.07339s ago] ('ZH_0', 1, 0)
# 2025-07-07 15:26:57,729 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,729 INFO sqlalchemy.engine.Engine [cached since 0.07395s ago] ('ZH_0', 1, 0)
# 2025-07-07 15:26:57,730 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,730 INFO sqlalchemy.engine.Engine [cached since 0.07466s ago] ('ZH_0', 1, 0)
# 2025-07-07 15:26:57,730 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,731 INFO sqlalchemy.engine.Engine [cached since 0.07539s ago] ('ZH_0', 1, 0)
# 2025-07-07 15:26:57,731 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,731 INFO sqlalchemy.engine.Engine [cached since 0.07611s ago] ('ZH_0', 1, 0)
# 2025-07-07 15:26:57,732 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,732 INFO sqlalchemy.engine.Engine [cached since 0.07667s ago] ('ZH_0', 1, 0)
# 2025-07-07 15:26:57,733 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,733 INFO sqlalchemy.engine.Engine [cached since 0.07828s ago] ('ZH_4', 1, 0)
# 2025-07-07 15:26:57,734 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,734 INFO sqlalchemy.engine.Engine [cached since 0.07903s ago] ('ZH_4', 1, 0)
# 2025-07-07 15:26:57,735 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,735 INFO sqlalchemy.engine.Engine [cached since 0.07963s ago] ('ZH_4', 1, 0)
# 2025-07-07 15:26:57,735 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,735 INFO sqlalchemy.engine.Engine [cached since 0.08019s ago] ('ZH_4', 1, 0)
# 2025-07-07 15:26:57,736 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,736 INFO sqlalchemy.engine.Engine [cached since 0.08073s ago] ('ZH_4', 1, 0)
# 2025-07-07 15:26:57,736 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,737 INFO sqlalchemy.engine.Engine [cached since 0.08136s ago] ('ZH_4', 1, 0)
# 2025-07-07 15:26:57,737 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,737 INFO sqlalchemy.engine.Engine [cached since 0.08194s ago] ('ZH_4', 1, 0)
# 2025-07-07 15:26:57,738 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,738 INFO sqlalchemy.engine.Engine [cached since 0.08255s ago] ('ZH_4', 1, 0)
# 2025-07-07 15:26:57,739 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,739 INFO sqlalchemy.engine.Engine [cached since 0.08401s ago] ('ZH_4', 1, 0)
# 2025-07-07 15:26:57,740 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,740 INFO sqlalchemy.engine.Engine [cached since 0.08485s ago] ('ZH_4', 1, 0)
# 2025-07-07 15:26:57,741 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,741 INFO sqlalchemy.engine.Engine [cached since 0.08593s ago] ('ZH_4', 1, 0)
# 2025-07-07 15:26:57,742 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,742 INFO sqlalchemy.engine.Engine [cached since 0.08704s ago] ('ZH_4', 1, 0)
# 2025-07-07 15:26:57,743 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,743 INFO sqlalchemy.engine.Engine [cached since 0.08779s ago] ('ZH_4', 1, 0)
# 2025-07-07 15:26:57,743 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,744 INFO sqlalchemy.engine.Engine [cached since 0.08838s ago] ('ZH_4', 1, 0)
# 2025-07-07 15:26:57,744 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,744 INFO sqlalchemy.engine.Engine [cached since 0.08899s ago] ('ZH_4', 1, 0)
# 2025-07-07 15:26:57,745 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,745 INFO sqlalchemy.engine.Engine [cached since 0.0896s ago] ('ZH_4', 1, 0)
# 2025-07-07 15:26:57,745 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,745 INFO sqlalchemy.engine.Engine [cached since 0.09022s ago] ('ZH_4', 1, 0)
# 2025-07-07 15:26:57,746 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,746 INFO sqlalchemy.engine.Engine [cached since 0.09091s ago] ('ZH_4', 1, 0)
# 2025-07-07 15:26:57,748 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,748 INFO sqlalchemy.engine.Engine [cached since 0.09244s ago] ('ZH_5', 1, 0)
# 2025-07-07 15:26:57,748 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,748 INFO sqlalchemy.engine.Engine [cached since 0.09301s ago] ('ZH_5', 1, 0)
# 2025-07-07 15:26:57,749 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,749 INFO sqlalchemy.engine.Engine [cached since 0.09353s ago] ('ZH_5', 1, 0)
# 2025-07-07 15:26:57,749 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,749 INFO sqlalchemy.engine.Engine [cached since 0.0941s ago] ('ZH_5', 1, 0)
# 2025-07-07 15:26:57,750 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,750 INFO sqlalchemy.engine.Engine [cached since 0.09463s ago] ('ZH_5', 1, 0)
# 2025-07-07 15:26:57,750 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,750 INFO sqlalchemy.engine.Engine [cached since 0.09519s ago] ('ZH_5', 1, 0)
# 2025-07-07 15:26:57,751 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,751 INFO sqlalchemy.engine.Engine [cached since 0.09579s ago] ('ZH_5', 1, 0)
# 2025-07-07 15:26:57,752 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,752 INFO sqlalchemy.engine.Engine [cached since 0.09652s ago] ('ZH_5', 1, 0)
# 2025-07-07 15:26:57,752 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,753 INFO sqlalchemy.engine.Engine [cached since 0.09733s ago] ('ZH_5', 1, 0)
# 2025-07-07 15:26:57,753 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,753 INFO sqlalchemy.engine.Engine [cached since 0.09799s ago] ('ZH_5', 1, 0)
# 2025-07-07 15:26:57,754 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:26:57,754 INFO sqlalchemy.engine.Engine [cached since 0.09854s ago] ('ZH_5', 1, 0)
# 2025-07-07 15:26:57,754 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# ...
# 2025-07-07 15:26:59,718 INFO sqlalchemy.engine.Engine [cached since 1.536s ago] ('ZH_9_V5', '开始', 'Commencer', 'Kāishǐ', '', 'Verbes', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:26:59,719 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:59,719 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:59,720 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:26:59,720 INFO sqlalchemy.engine.Engine [cached since 1.533s ago] ('ZH_9',)
# 2025-07-07 15:26:59,720 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:59,720 INFO sqlalchemy.engine.Engine [cached since 1.538s ago] ('ZH_9_V6', '骑', 'Chevaucher', 'Qí', '', 'Verbes', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:26:59,721 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:59,722 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:59,722 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:26:59,722 INFO sqlalchemy.engine.Engine [cached since 1.536s ago] ('ZH_9',)
# 2025-07-07 15:26:59,723 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:59,723 INFO sqlalchemy.engine.Engine [cached since 1.54s ago] ('ZH_9_V7', '上班', 'Commencer le travail', 'Shàngbān', '', 'Verbes', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:26:59,723 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:59,724 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:59,724 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:26:59,724 INFO sqlalchemy.engine.Engine [cached since 1.538s ago] ('ZH_9',)
# 2025-07-07 15:26:59,725 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:59,725 INFO sqlalchemy.engine.Engine [cached since 1.542s ago] ('ZH_9_V8', '下班', 'Finir le travail', 'Xiàbān', '', 'Verbes', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:26:59,725 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:59,726 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:59,726 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:26:59,726 INFO sqlalchemy.engine.Engine [cached since 1.54s ago] ('ZH_9',)
# 2025-07-07 15:26:59,727 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:59,727 INFO sqlalchemy.engine.Engine [cached since 1.544s ago] ('ZH_9_V9', '走路', 'Marcher', 'Zǒulù', '', 'Verbes', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:26:59,727 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:59,728 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:59,728 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:26:59,729 INFO sqlalchemy.engine.Engine [cached since 1.542s ago] ('ZH_9',)
# 2025-07-07 15:26:59,730 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:59,730 INFO sqlalchemy.engine.Engine [cached since 1.547s ago] ('ZH_9_V10', '坐', "S'asseoir/prendre (véhicule)", 'Zuò', '', 'Verbes', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:26:59,730 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:59,731 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:59,732 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:26:59,732 INFO sqlalchemy.engine.Engine [cached since 1.545s ago] ('ZH_9',)
# 2025-07-07 15:26:59,732 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:59,732 INFO sqlalchemy.engine.Engine [cached since 1.55s ago] ('ZH_9_V11', '游泳', 'Nager', 'Yóuyǒng', '', 'Verbes', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:26:59,733 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:59,733 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:59,734 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:26:59,734 INFO sqlalchemy.engine.Engine [cached since 1.547s ago] ('ZH_9',)
# 2025-07-07 15:26:59,734 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:59,735 INFO sqlalchemy.engine.Engine [cached since 1.552s ago] ('ZH_9_V12', '无聊', 'Ennuyeux', 'Wúliáo', '', 'Adjectifs', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:26:59,735 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:59,736 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:59,736 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:26:59,736 INFO sqlalchemy.engine.Engine [cached since 1.549s ago] ('ZH_9',)
# 2025-07-07 15:26:59,736 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:59,736 INFO sqlalchemy.engine.Engine [cached since 1.554s ago] ('ZH_9_V13', '有意思', 'Intéressant (polite)', 'Yǒu yìsi', '', 'Adjectifs', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:26:59,737 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:59,738 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:59,738 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:26:59,738 INFO sqlalchemy.engine.Engine [cached since 1.551s ago] ('ZH_9',)
# 2025-07-07 15:26:59,739 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:59,739 INFO sqlalchemy.engine.Engine [cached since 1.556s ago] ('ZH_9_V14', '没意思', 'Inintéressant (polite)', 'Méi yìsi', '', 'Adjectifs', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:26:59,739 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:59,741 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:59,743 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:26:59,743 INFO sqlalchemy.engine.Engine [cached since 1.556s ago] ('ZH_9',)
# 2025-07-07 15:26:59,744 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:59,744 INFO sqlalchemy.engine.Engine [cached since 1.561s ago] ('ZH_9_V15', '啊', "Particule modale d'exclamation", 'A', '', 'Divers', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:26:59,745 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:59,746 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:59,746 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:26:59,746 INFO sqlalchemy.engine.Engine [cached since 1.559s ago] ('ZH_9',)
# 2025-07-07 15:26:59,746 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:59,747 INFO sqlalchemy.engine.Engine [cached since 1.564s ago] ('ZH_9_V16', '每', 'Chaque', 'Měi', '', 'Divers', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:26:59,747 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:59,748 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:59,748 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:26:59,748 INFO sqlalchemy.engine.Engine [cached since 1.562s ago] ('ZH_9',)
# 2025-07-07 15:26:59,749 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:59,749 INFO sqlalchemy.engine.Engine [cached since 1.566s ago] ('ZH_9_V17', '然后', 'Ensuite', 'Ránhòu', '', 'Divers', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:26:59,749 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:59,750 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:59,750 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:26:59,750 INFO sqlalchemy.engine.Engine [cached since 1.564s ago] ('ZH_9',)
# 2025-07-07 15:26:59,751 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:59,751 INFO sqlalchemy.engine.Engine [cached since 1.568s ago] ('ZH_9_V18', '同意', "Être d'accord", 'Tóngyì', '', 'Divers', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:26:59,751 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:59,752 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:59,752 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:26:59,753 INFO sqlalchemy.engine.Engine [cached since 1.566s ago] ('ZH_9',)
# 2025-07-07 15:26:59,753 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:59,753 INFO sqlalchemy.engine.Engine [cached since 1.57s ago] ('ZH_9_V19', '先', "D'abord", 'Xiān', '', 'Divers', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:26:59,754 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:59,754 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:59,755 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:26:59,755 INFO sqlalchemy.engine.Engine [cached since 1.568s ago] ('ZH_9',)
# 2025-07-07 15:26:59,755 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:59,755 INFO sqlalchemy.engine.Engine [cached since 1.573s ago] ('ZH_9_V20', '有点儿', 'Un petit peu', 'Yǒu diǎnr', '', 'Divers', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:26:59,756 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:59,757 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:59,757 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:26:59,757 INFO sqlalchemy.engine.Engine [cached since 1.57s ago] ('ZH_9',)
# 2025-07-07 15:26:59,757 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:59,758 INFO sqlalchemy.engine.Engine [cached since 1.575s ago] ('ZH_9_V21', '公园', 'Parc public', 'Gōngyuán', '', 'Noms et expressions', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:26:59,758 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:59,759 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:59,759 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:26:59,759 INFO sqlalchemy.engine.Engine [cached since 1.573s ago] ('ZH_9',)
# 2025-07-07 15:26:59,760 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:59,760 INFO sqlalchemy.engine.Engine [cached since 1.577s ago] ('ZH_9_V22', '看法', 'Point de vue', 'Kànfǎ', '', 'Noms et expressions', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:26:59,760 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:26:59,761 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:26:59,762 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:26:59,762 INFO sqlalchemy.engine.Engine [cached since 1.575s ago] ('ZH_9',)
# 2025-07-07 15:26:59,762 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (learn_id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-07 15:26:59,763 INFO sqlalchemy.engine.Engine [cached since 1.58s ago] ('ZH_9_V23', '游泳池', 'Piscine', 'Yóuyǒngchí', '', 'Noms et expressions', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:26:59,763 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Add Grammar Rules

# %%
# Initialize the database connection and create db file if it doesn't exist
engine, session = init_db()

directory_path = f'../data/{language_id}/grammar'

if not os.path.exists(directory_path):
    raise FileNotFoundError(f"No grammar files found for {language_id}.")

grammars = []

# List all elements (files and directories) in the specified directory and get their full paths
elements_paths = [os.path.join(directory_path, element) for element in os.listdir(directory_path)]
for grammar_file in elements_paths:
    if os.path.isfile(grammar_file) and grammar_file.endswith('.json'):
        unit_id = re.sub("[^0-9]", "", os.path.basename(grammar_file))
        with open(grammar_file, 'r', encoding="utf8") as f:
            grammar_data = json.load(f)
        for idx, row in enumerate(grammar_data):
            grammars.append( 
                GrammarRule(
                    learn_id=f"{language_id.upper()}_{unit_id}_G{idx + 1}",
                    title=row['title'],
                    explanation=row["content"],
                    parent=session.query(Unit).filter(Unit.unit_id == f"{language_id.upper()}_{unit_id}").first()
                )
            )
inserts(session, grammars)
session.close()
# Out:
# 2025-07-07 15:27:27,410 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,411 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("language")
# 2025-07-07 15:27:27,411 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 15:27:27,412 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-07 15:27:27,412 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 15:27:27,412 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-07 15:27:27,412 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 15:27:27,413 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-07 15:27:27,413 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 15:27:27,413 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-07 15:27:27,414 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 15:27:27,414 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-07 15:27:27,414 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-07 15:27:27,415 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,416 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,417 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,417 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('ZH_11', 1, 0)
# 2025-07-07 15:27:27,418 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,418 INFO sqlalchemy.engine.Engine [cached since 0.001189s ago] ('ZH_11', 1, 0)
# 2025-07-07 15:27:27,419 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,419 INFO sqlalchemy.engine.Engine [cached since 0.001851s ago] ('ZH_11', 1, 0)
# 2025-07-07 15:27:27,419 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,419 INFO sqlalchemy.engine.Engine [cached since 0.00245s ago] ('ZH_11', 1, 0)
# 2025-07-07 15:27:27,420 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,421 INFO sqlalchemy.engine.Engine [cached since 0.003704s ago] ('ZH_6', 1, 0)
# 2025-07-07 15:27:27,422 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,422 INFO sqlalchemy.engine.Engine [cached since 0.005371s ago] ('ZH_6', 1, 0)
# 2025-07-07 15:27:27,424 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,424 INFO sqlalchemy.engine.Engine [cached since 0.007248s ago] ('ZH_6', 1, 0)
# 2025-07-07 15:27:27,425 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,425 INFO sqlalchemy.engine.Engine [cached since 0.008567s ago] ('ZH_6', 1, 0)
# 2025-07-07 15:27:27,427 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,427 INFO sqlalchemy.engine.Engine [cached since 0.009887s ago] ('ZH_7', 1, 0)
# 2025-07-07 15:27:27,427 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,427 INFO sqlalchemy.engine.Engine [cached since 0.01054s ago] ('ZH_7', 1, 0)
# 2025-07-07 15:27:27,428 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,428 INFO sqlalchemy.engine.Engine [cached since 0.01117s ago] ('ZH_7', 1, 0)
# 2025-07-07 15:27:27,429 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,429 INFO sqlalchemy.engine.Engine [cached since 0.01192s ago] ('ZH_7', 1, 0)
# 2025-07-07 15:27:27,429 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,429 INFO sqlalchemy.engine.Engine [cached since 0.01248s ago] ('ZH_7', 1, 0)
# 2025-07-07 15:27:27,430 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,430 INFO sqlalchemy.engine.Engine [cached since 0.01305s ago] ('ZH_7', 1, 0)
# 2025-07-07 15:27:27,431 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,432 INFO sqlalchemy.engine.Engine [cached since 0.01468s ago] ('ZH_10', 1, 0)
# 2025-07-07 15:27:27,432 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,432 INFO sqlalchemy.engine.Engine [cached since 0.01536s ago] ('ZH_10', 1, 0)
# 2025-07-07 15:27:27,433 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,433 INFO sqlalchemy.engine.Engine [cached since 0.01595s ago] ('ZH_10', 1, 0)
# 2025-07-07 15:27:27,433 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,433 INFO sqlalchemy.engine.Engine [cached since 0.01651s ago] ('ZH_10', 1, 0)
# 2025-07-07 15:27:27,434 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,434 INFO sqlalchemy.engine.Engine [cached since 0.01708s ago] ('ZH_10', 1, 0)
# 2025-07-07 15:27:27,434 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,435 INFO sqlalchemy.engine.Engine [cached since 0.01772s ago] ('ZH_10', 1, 0)
# 2025-07-07 15:27:27,435 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,435 INFO sqlalchemy.engine.Engine [cached since 0.01861s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:27:27,436 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,436 INFO sqlalchemy.engine.Engine [cached since 0.01909s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:27:27,436 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,436 INFO sqlalchemy.engine.Engine [cached since 0.01962s ago] ('ZH_1', 1, 0)
# 2025-07-07 15:27:27,437 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,437 INFO sqlalchemy.engine.Engine [cached since 0.02046s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:27:27,438 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,438 INFO sqlalchemy.engine.Engine [cached since 0.0211s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:27:27,438 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,438 INFO sqlalchemy.engine.Engine [cached since 0.02165s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:27:27,440 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,440 INFO sqlalchemy.engine.Engine [cached since 0.02323s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:27:27,441 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,441 INFO sqlalchemy.engine.Engine [cached since 0.02406s ago] ('ZH_2', 1, 0)
# 2025-07-07 15:27:27,442 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,443 INFO sqlalchemy.engine.Engine [cached since 0.0258s ago] ('ZH_15', 1, 0)
# 2025-07-07 15:27:27,444 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,444 INFO sqlalchemy.engine.Engine [cached since 0.02746s ago] ('ZH_15', 1, 0)
# 2025-07-07 15:27:27,445 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,445 INFO sqlalchemy.engine.Engine [cached since 0.02827s ago] ('ZH_15', 1, 0)
# 2025-07-07 15:27:27,446 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,446 INFO sqlalchemy.engine.Engine [cached since 0.02892s ago] ('ZH_15', 1, 0)
# 2025-07-07 15:27:27,447 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,447 INFO sqlalchemy.engine.Engine [cached since 0.0298s ago] ('ZH_14', 1, 0)
# 2025-07-07 15:27:27,447 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,447 INFO sqlalchemy.engine.Engine [cached since 0.03032s ago] ('ZH_14', 1, 0)
# 2025-07-07 15:27:27,448 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,448 INFO sqlalchemy.engine.Engine [cached since 0.03082s ago] ('ZH_14', 1, 0)
# 2025-07-07 15:27:27,448 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,448 INFO sqlalchemy.engine.Engine [cached since 0.03141s ago] ('ZH_14', 1, 0)
# 2025-07-07 15:27:27,449 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,449 INFO sqlalchemy.engine.Engine [cached since 0.03197s ago] ('ZH_14', 1, 0)
# 2025-07-07 15:27:27,450 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,450 INFO sqlalchemy.engine.Engine [cached since 0.03291s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:27:27,450 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,450 INFO sqlalchemy.engine.Engine [cached since 0.03343s ago] ('ZH_3', 1, 0)
# 2025-07-07 15:27:27,451 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,451 INFO sqlalchemy.engine.Engine [cached since 0.03433s ago] ('ZH_8', 1, 0)
# 2025-07-07 15:27:27,452 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,452 INFO sqlalchemy.engine.Engine [cached since 0.03513s ago] ('ZH_8', 1, 0)
# 2025-07-07 15:27:27,452 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,453 INFO sqlalchemy.engine.Engine [cached since 0.03572s ago] ('ZH_8', 1, 0)
# 2025-07-07 15:27:27,453 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,453 INFO sqlalchemy.engine.Engine [cached since 0.03626s ago] ('ZH_8', 1, 0)
# 2025-07-07 15:27:27,454 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,454 INFO sqlalchemy.engine.Engine [cached since 0.03679s ago] ('ZH_8', 1, 0)
# 2025-07-07 15:27:27,454 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,455 INFO sqlalchemy.engine.Engine [cached since 0.03774s ago] ('ZH_4', 1, 0)
# 2025-07-07 15:27:27,455 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,455 INFO sqlalchemy.engine.Engine [cached since 0.03829s ago] ('ZH_4', 1, 0)
# 2025-07-07 15:27:27,456 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,457 INFO sqlalchemy.engine.Engine [cached since 0.03977s ago] ('ZH_4', 1, 0)
# 2025-07-07 15:27:27,457 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,457 INFO sqlalchemy.engine.Engine [cached since 0.04054s ago] ('ZH_4', 1, 0)
# 2025-07-07 15:27:27,458 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,458 INFO sqlalchemy.engine.Engine [cached since 0.04108s ago] ('ZH_4', 1, 0)
# 2025-07-07 15:27:27,459 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,459 INFO sqlalchemy.engine.Engine [cached since 0.04211s ago] ('ZH_13', 1, 0)
# 2025-07-07 15:27:27,459 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,459 INFO sqlalchemy.engine.Engine [cached since 0.04264s ago] ('ZH_13', 1, 0)
# 2025-07-07 15:27:27,460 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,460 INFO sqlalchemy.engine.Engine [cached since 0.0432s ago] ('ZH_13', 1, 0)
# 2025-07-07 15:27:27,460 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,461 INFO sqlalchemy.engine.Engine [cached since 0.04377s ago] ('ZH_13', 1, 0)
# 2025-07-07 15:27:27,461 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,461 INFO sqlalchemy.engine.Engine [cached since 0.04438s ago] ('ZH_13', 1, 0)
# 2025-07-07 15:27:27,462 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,462 INFO sqlalchemy.engine.Engine [cached since 0.04553s ago] ('ZH_12', 1, 0)
# 2025-07-07 15:27:27,463 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,463 INFO sqlalchemy.engine.Engine [cached since 0.04606s ago] ('ZH_12', 1, 0)
# 2025-07-07 15:27:27,463 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,463 INFO sqlalchemy.engine.Engine [cached since 0.04658s ago] ('ZH_12', 1, 0)
# 2025-07-07 15:27:27,464 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,464 INFO sqlalchemy.engine.Engine [cached since 0.04708s ago] ('ZH_12', 1, 0)
# 2025-07-07 15:27:27,464 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,464 INFO sqlalchemy.engine.Engine [cached since 0.04758s ago] ('ZH_12', 1, 0)
# 2025-07-07 15:27:27,465 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,465 INFO sqlalchemy.engine.Engine [cached since 0.04853s ago] ('ZH_5', 1, 0)
# 2025-07-07 15:27:27,466 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,466 INFO sqlalchemy.engine.Engine [cached since 0.04907s ago] ('ZH_5', 1, 0)
# 2025-07-07 15:27:27,466 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,466 INFO sqlalchemy.engine.Engine [cached since 0.04955s ago] ('ZH_5', 1, 0)
# 2025-07-07 15:27:27,467 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,467 INFO sqlalchemy.engine.Engine [cached since 0.05009s ago] ('ZH_5', 1, 0)
# 2025-07-07 15:27:27,468 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,468 INFO sqlalchemy.engine.Engine [cached since 0.05084s ago] ('ZH_9', 1, 0)
# 2025-07-07 15:27:27,468 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,468 INFO sqlalchemy.engine.Engine [cached since 0.05141s ago] ('ZH_9', 1, 0)
# 2025-07-07 15:27:27,469 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,469 INFO sqlalchemy.engine.Engine [cached since 0.05196s ago] ('ZH_9', 1, 0)
# 2025-07-07 15:27:27,469 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,469 INFO sqlalchemy.engine.Engine [cached since 0.05243s ago] ('ZH_9', 1, 0)
# 2025-07-07 15:27:27,470 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,470 INFO sqlalchemy.engine.Engine [cached since 0.05291s ago] ('ZH_9', 1, 0)
# 2025-07-07 15:27:27,470 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-07 15:27:27,470 INFO sqlalchemy.engine.Engine [cached since 0.0534s ago] ('ZH_9', 1, 0)
# 2025-07-07 15:27:27,471 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,471 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('ZH_11_G1', 'Énumérer avec 第 dì', "第 dì permet de former des chiffres et nombres ordinaux.\nIl s'emploie de la façon suivante :\n\n第 + chiffre/nombre ( + Classificateur )\n\n* 第一 dì yī ... (918 characters truncated) ... s deux mots suivants signifient « étage » et peuvent s'employer sans 第 dì :\n\n* 三楼 sān lóu : « Troisième étage »\n* 四层 sì céng : « Quatrième étage »", 0, '2025-07-07', 'ZH_11')
# 2025-07-07 15:27:27,472 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,473 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,474 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,474 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('ZH_11',)
# 2025-07-07 15:27:27,475 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,475 INFO sqlalchemy.engine.Engine [cached since 0.003732s ago] ('ZH_11_G2', 'Exprimer une distance avec 离 lí', "离 lí est utilisé lorsqu'on souhaite exprimer une distance entre deux points. Il peut se traduire par « par rapport à ». La structure à employer, très ... (589 characters truncated) ... ē zhàn lí zhèr tài yuǎn le : « La gare est trop éloignée d’ici »\n* 酒吧离我的家比较远 jiǔbā lí wǒ de jiā bǐjiào yuǎn : « Le bar est plutôt loin de chez moi »", 0, '2025-07-07', 'ZH_11')
# 2025-07-07 15:27:27,475 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,476 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,476 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,476 INFO sqlalchemy.engine.Engine [cached since 0.002216s ago] ('ZH_11',)
# 2025-07-07 15:27:27,476 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,476 INFO sqlalchemy.engine.Engine [cached since 0.005447s ago] ('ZH_11_G3', 'Se diriger, suivre un itinéraire', 'Savoir utiliser les termes « droite », « gauche » et « tout droit » suffit pour se repérer, demander son chemin et comprendre un itinéraire. Lorsqu’o ... (238 characters truncated) ... tout droit »\n* 你先往前走一百米，然后往左拐 nǐ xiān wǎng qián zǒu yī bǎi mǐ, ránhòu wǎng zuǒ guǎi : « Va d’abord tout droit sur 100 mètres, puis tourne à gauche »', 0, '2025-07-07', 'ZH_11')
# 2025-07-07 15:27:27,477 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,477 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,477 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,477 INFO sqlalchemy.engine.Engine [cached since 0.003499s ago] ('ZH_11',)
# 2025-07-07 15:27:27,478 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,478 INFO sqlalchemy.engine.Engine [cached since 0.006741s ago] ('ZH_11_G4', "À l'intérieur de quelque chose", 'Pour indiquer que quelque chose se situe à l’intérieur de quelque chose d’autre, on utilise la structure suivante :\n\nNom 1 + 在 + Nom 2 + 里面\n\n* 你在 ... (240 characters truncated) ...  shàng ma ? : « Es-tu dans le bus ? »\n* 我在车上 wǒ zài chē shàng : « Je suis dans la voiture »\n* 我在火车上 wǒ zài huǒchē shàng : « Je suis dans le train »', 0, '2025-07-07', 'ZH_11')
# 2025-07-07 15:27:27,478 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,478 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,479 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,479 INFO sqlalchemy.engine.Engine [cached since 0.004847s ago] ('ZH_6',)
# 2025-07-07 15:27:27,479 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,479 INFO sqlalchemy.engine.Engine [cached since 0.008106s ago] ('ZH_6_G1', 'Les démonstratifs 这 zhè et 那 nà', "Le démonstratif le plus couramment utilisé en chinois est 这 zhè.\n这 zhè va rarement être utilisé tout seul, il est souvent couplé avec d'autres carac ... (1057 characters truncated) ... à-bas, c'est... »\n* 那个/那个人 nà ge rén : « Cette personne-là »\n* 那里是我的朋友的家 nà lǐ shì wǒ de péngyou de jiā : « Là-bas se trouve la maison de mon ami »", 0, '2025-07-07', 'ZH_6')
# 2025-07-07 15:27:27,479 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,480 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,480 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,480 INFO sqlalchemy.engine.Engine [cached since 0.006208s ago] ('ZH_6',)
# 2025-07-07 15:27:27,480 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,480 INFO sqlalchemy.engine.Engine [cached since 0.009498s ago] ('ZH_6_G2', 'Autres utilisations du caractère 的 de', "的 de, le caractère permettant de marquer la possession, peut s'utiliser à la suite d'un pronom personnel (ex. 我的 wǒ de « mon ») ou d'un nom (ex. 老师的书 ... (937 characters truncated) ... ncài : « C'est le plat que j'aime faire/préparer »\n* 这是我去年去的地方 zhè shì wǒ qùnián qù de dìfang : « C'est l'endroit où je suis allé l'année dernière »", 0, '2025-07-07', 'ZH_6')
# 2025-07-07 15:27:27,481 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,481 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,481 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,482 INFO sqlalchemy.engine.Engine [cached since 0.007698s ago] ('ZH_6',)
# 2025-07-07 15:27:27,482 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,482 INFO sqlalchemy.engine.Engine [cached since 0.01105s ago] ('ZH_6_G3', 'Exprimer "avec" à l\'aide de 跟 gēn et 一起 yīqǐ', "La préposition 跟 gēn, souvent utilisée avec 一起 yīqǐ (signifiant « ensemble »), permet de marquer l'accompagnement :\n\n* 我跟你去 wǒ gēn nǐ qù : « J'y va ... (142 characters truncated) ... gēn tā yīqǐ qù le gōngyuán : « Je suis allé au parc avec lui hier »\n* 我跟我的女朋友一起住 wǒ gēn wǒ de nǚ péngyou yīqǐ zhù : « J'habite avec ma petite amie »", 0, '2025-07-07', 'ZH_6')
# 2025-07-07 15:27:27,482 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,483 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,483 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,483 INFO sqlalchemy.engine.Engine [cached since 0.009396s ago] ('ZH_6',)
# 2025-07-07 15:27:27,483 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,484 INFO sqlalchemy.engine.Engine [cached since 0.01264s ago] ('ZH_6_G4', 'Les caractères ayant plusieurs prononciations', "Vous aurez certainement remarqué que certains caractères peuvent avoir plusieurs prononciations. Le changement de prononciation peut faire varier ou  ... (198 characters truncated) ...  : trouver que\n* 睡觉 shuìjiào : dormir\n\nCertains caractères comme le 都 de 首都 « la capitale » peuvent changer à la fois de prononciation et de sens.", 0, '2025-07-07', 'ZH_6')
# 2025-07-07 15:27:27,484 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,484 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,485 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,485 INFO sqlalchemy.engine.Engine [cached since 0.01086s ago] ('ZH_7',)
# 2025-07-07 15:27:27,485 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,485 INFO sqlalchemy.engine.Engine [cached since 0.0141s ago] ('ZH_7_G1', 'Comparer avec 比 bi ou 没有 méiyǒu', "**Utilisation de 比 bi**\nLe caractère 比 bǐ est utilisé en tant que comparatif de supériorité ou d'infériorité (et non d'égalité). Il peut être tradui ... (740 characters truncated) ...  : « Il est plus petit que moi » (littéralement « Il n'a pas ma taille »)\n* 妈妈没有爸爸高 māma méiyǒu bàba gāo : « Maman n'est pas aussi grande que papa »", 0, '2025-07-07', 'ZH_7')
# 2025-07-07 15:27:27,485 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,486 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,486 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,486 INFO sqlalchemy.engine.Engine [cached since 0.01213s ago] ('ZH_7',)
# 2025-07-07 15:27:27,486 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,486 INFO sqlalchemy.engine.Engine [cached since 0.01535s ago] ('ZH_7_G2', 'Interrogatif 谁 shéi/shuí', "谁 shéi est l'interrogatif signifiant « Qui ? ». Comme tous les mots interrogatifs, il se place à l'endroit où se trouvera la réponse :\n\n* 你是谁？ Nǐ s ... (401 characters truncated) ...  » et ne doit pas traduire le pronom relatif « qui » dans des phrases comme « La personne qui habite ici ». Pour cela, on utilise 的 de (cf. Leçon 6).", 0, '2025-07-07', 'ZH_7')
# 2025-07-07 15:27:27,487 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,487 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,487 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,487 INFO sqlalchemy.engine.Engine [cached since 0.01344s ago] ('ZH_7',)
# 2025-07-07 15:27:27,488 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,488 INFO sqlalchemy.engine.Engine [cached since 0.01674s ago] ('ZH_7_G3', 'Quelle(s) langue(s) sais-tu parler ?', "En général, on forme le nom d'une langue en ajoutant 语 yǔ (ou 文 wén) au nom du pays.\n\nPour les pays finissant par 国 guó, on remplace 国 guó par 语 yǔ ... (342 characters truncated) ... :\n\n* 中国 Zhōngguó (Chine) → 中文 Zhōngwén (chinois)\n* 汉语 Hànyǔ (chinois)\n\nNote : 汉语 Hànyǔ (chinois) et 韩语 Hányǔ (coréen) se prononcent très proche.", 0, '2025-07-07', 'ZH_7')
# 2025-07-07 15:27:27,489 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,489 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,489 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,490 INFO sqlalchemy.engine.Engine [cached since 0.01565s ago] ('ZH_7',)
# 2025-07-07 15:27:27,490 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,490 INFO sqlalchemy.engine.Engine [cached since 0.01895s ago] ('ZH_7_G4', 'Les adverbes 最 zuì et 太 ... 了 tài...le', "Les adverbes 最 zuì et 太 ... 了 tài...le s'emploient comme 很 hěn devant un adjectif, mais nuancent ou renforcent le propos :\n\n* 我很累 wǒ hěn lèi : « Je ... (11 characters truncated) ... ué »\n* 最累 zuì lèi : « Le plus fatigué »\n* 我太累了 wǒ tài lèi le : « Je suis trop fatigué »\n* 我不太累了 wǒ bù tài lèi le : « Je ne suis pas trop fatigué »", 0, '2025-07-07', 'ZH_7')
# 2025-07-07 15:27:27,490 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,491 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,491 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,491 INFO sqlalchemy.engine.Engine [cached since 0.01717s ago] ('ZH_7',)
# 2025-07-07 15:27:27,491 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,492 INFO sqlalchemy.engine.Engine [cached since 0.02058s ago] ('ZH_7_G5', 'Tout, toutes et tous avec 都 dōu', 'Le caractère 都 peut se prononcer « dū » (dans 首都 shǒudū « capitale ») ou « dōu » quand il signifie « tout, tous ». Il se place directement après le n ... (122 characters truncated) ... ōu xiǎng qù Zhōngguó : « Nous voulons tous aller en Chine »\n* 我的朋友都 wǒ de péngyou dōu : « Tous mes amis »\n* 女生都 nǚshēng dōu : « Toutes les filles »', 0, '2025-07-07', 'ZH_7')
# 2025-07-07 15:27:27,492 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,492 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,493 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,493 INFO sqlalchemy.engine.Engine [cached since 0.01897s ago] ('ZH_7',)
# 2025-07-07 15:27:27,493 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,493 INFO sqlalchemy.engine.Engine [cached since 0.02232s ago] ('ZH_7_G6', 'Ensemble avec 一起 yīqǐ', '一起 yīqǐ a déjà été vu dans la structure 跟 gēn ... + 一起 yīqǐ (page 109) pour dire « avec ». 一起 yīqǐ peut aussi être utilisé seul et signifie « ensembl ... (50 characters truncated) ...  Elles vont regarder un film ensemble »\n* 我们一起去北京 wǒmen yīqǐ qù Běijīng : « Nous allons ensemble à Pékin »\n\nStructure : Sujet + 一起 + Verbe + Objet', 0, '2025-07-07', 'ZH_7')
# 2025-07-07 15:27:27,494 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,494 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,494 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,494 INFO sqlalchemy.engine.Engine [cached since 0.02044s ago] ('ZH_10',)
# 2025-07-07 15:27:27,495 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,495 INFO sqlalchemy.engine.Engine [cached since 0.02369s ago] ('ZH_10_G1', 'Indiquer le destinataire avec 给 gěi', "给 gěi, signifiant « donner », permet d'indiquer la cible d'une action.\n\nStructure : Sujet + 给 + cible + action\n\n* 你给我打电话 nǐ gěi wǒ dǎ diànhuà : « ... (45 characters truncated) ... i tā dǎ diànhuà : « Tu dois lui téléphoner »\n* 你给他写信 nǐ gěi tā xiěxìn : « Écris-lui une lettre »\n* 我给你做饭 wǒ gěi nǐ zuòfàn : « Je te fais à manger »", 0, '2025-07-07', 'ZH_10')
# 2025-07-07 15:27:27,495 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,495 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,496 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,496 INFO sqlalchemy.engine.Engine [cached since 0.02177s ago] ('ZH_10',)
# 2025-07-07 15:27:27,496 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,496 INFO sqlalchemy.engine.Engine [cached since 0.02499s ago] ('ZH_10_G2', '"Pouvoir" avec 能 néng ou 可以 kěyǐ', "Plusieurs verbes existent pour exprimer la possibilité, cependant ils ne peuvent pas s'employer de la même manière. Nous avons déjà étudié le verbe 会 ... (795 characters truncated) ... 停车吗？wǒ zài zhèr kěyǐ tíngchē ma ? : « Puis-je garer ma voiture ici ? »\n* 妈妈，我可以出去吗？māma, wǒ kěyǐ chūqù ma ? : « Maman, est-ce que je peux sortir ? »", 0, '2025-07-07', 'ZH_10')
# 2025-07-07 15:27:27,496 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,497 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,497 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,497 INFO sqlalchemy.engine.Engine [cached since 0.02303s ago] ('ZH_10',)
# 2025-07-07 15:27:27,497 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,497 INFO sqlalchemy.engine.Engine [cached since 0.02627s ago] ('ZH_10_G3', 'La condition avec 如果 ... 的话 rúguǒ ... de huà et 就 jiù', "如果 ... 的话 rúguǒ ... de huà et 就 jiù sont utilisés, ensemble ou séparément, afin d'introduire une condition et sa conséquence.\n\nStructure : 如果 + Suj ... (135 characters truncated) ... , appelle le médecin »\n* 如果他生病的话，他就不能去工作 rúguǒ tā shēngbìng de huà, tā jiù bù néng qù gōngzuò : « S'il est malade, il ne peut pas aller travailler »", 0, '2025-07-07', 'ZH_10')
# 2025-07-07 15:27:27,497 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,498 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,498 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# ...
# 2025-07-07 15:27:27,589 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,590 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,590 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,590 INFO sqlalchemy.engine.Engine [cached since 0.1166s ago] ('ZH_12',)
# 2025-07-07 15:27:27,591 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,591 INFO sqlalchemy.engine.Engine [cached since 0.1202s ago] ('ZH_12_G3', 'Permettre quelque chose avec 让 ràng', "让 ràng est un verbe dit « causatif », qui peut être traduit par « laisser » ou « permettre » en français.\n\nStructure : Sujet + 让 + Personne/Objet + ... (128 characters truncated) ...  papa ne te laisse-t-il pas y aller ? »\n* 看 Titanic 电影让我很感动 kàn Titanic diànyǐng ràng wǒ hěn gǎndòng : « Regarder le film Titanic m'a beaucoup ému »", 0, '2025-07-07', 'ZH_12')
# 2025-07-07 15:27:27,592 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,592 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,592 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,592 INFO sqlalchemy.engine.Engine [cached since 0.1185s ago] ('ZH_12',)
# 2025-07-07 15:27:27,593 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,593 INFO sqlalchemy.engine.Engine [cached since 0.1217s ago] ('ZH_12_G4', 'Demander « combien » avec 多少 duōshǎo ou 几 jǐ', "Il existe deux façons principales de demander « combien » : 多少 duōshǎo et 几 jǐ. Voici leurs différences :\n\n* 几 jǐ est utilisé pour des quantités gé ... (695 characters truncated) ...  ici »\n* 我有十多元 wǒ yǒu shí duō yuán : « J’ai un peu plus de dix yuans »\n* 我有三十多块钱 wǒ yǒu sānshí duō kuài qián : « J’ai un peu plus de trente kuais »", 0, '2025-07-07', 'ZH_12')
# 2025-07-07 15:27:27,593 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,593 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,594 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,594 INFO sqlalchemy.engine.Engine [cached since 0.12s ago] ('ZH_12',)
# 2025-07-07 15:27:27,594 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,594 INFO sqlalchemy.engine.Engine [cached since 0.1235s ago] ('ZH_12_G5', '« Quelques » avec 一些 yīxiē', "一些 yīxiē signifie « quelques » ou « certains » et désigne une quantité indéterminée. Il s'utilise selon le schéma suivant :\n\n一些 + Nom\n\n* 有一些人 yǒu yīxiē rén : « Il y a quelques personnes »\n* 爸爸买了一些书 bàba mǎi le yīxiē shū : « Papa a acheté quelques livres »", 0, '2025-07-07', 'ZH_12')
# 2025-07-07 15:27:27,595 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,595 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,596 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,596 INFO sqlalchemy.engine.Engine [cached since 0.1219s ago] ('ZH_5',)
# 2025-07-07 15:27:27,596 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,596 INFO sqlalchemy.engine.Engine [cached since 0.1252s ago] ('ZH_5_G1', 'Les adjectifs', "**Affirmation avec 很 hěn**\nLes noms doivent être liés aux autres noms à l'aide du verbe « être » 是 shì.\n\n* 妈妈 是 老师 māma shì lǎoshī : « Maman est p ... (1844 characters truncated) ... ǐhuan : « j'aime »\n* 我 讨厌 wǒ tǎoyàn : « je déteste »\n* 我 很 喜欢 wǒ hěn xǐhuan : « j'aime beaucoup »\n* 我 很 讨厌 wǒ hěn tǎoyàn : « je déteste vraiment »", 0, '2025-07-07', 'ZH_5')
# 2025-07-07 15:27:27,596 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,597 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,597 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,597 INFO sqlalchemy.engine.Engine [cached since 0.1234s ago] ('ZH_5',)
# 2025-07-07 15:27:27,597 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,598 INFO sqlalchemy.engine.Engine [cached since 0.1266s ago] ('ZH_5_G2', 'Énumérer avec 和 hé', "Le caractère 和 hé permet d'énumérer des noms communs. Nous pouvons traduire par « ainsi que », son emploi diffère donc du « et » français.\n\n* 我 的 妈 ... (132 characters truncated) ... n papa et moi »\n\n和 hé ne peut pas être utilisé pour lier deux phrases comme en français (ex. Ce matin je travaille et cet après-midi je me repose).", 0, '2025-07-07', 'ZH_5')
# 2025-07-07 15:27:27,598 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,598 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,598 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,599 INFO sqlalchemy.engine.Engine [cached since 0.1247s ago] ('ZH_5',)
# 2025-07-07 15:27:27,599 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,599 INFO sqlalchemy.engine.Engine [cached since 0.128s ago] ('ZH_5_G3', 'Le caractère 的 de', "Le premier sens de 的 de est le possessif. L'ajout du caractère 的 de aux pronoms personnels permet de former les pronoms possessifs :\n\nPronom person ... (638 characters truncated) ...  de Chine »\n\nDéterminant + 的 + déterminé\n\nLe contexte est indispensable pour comprendre le sens qu'il a dans une phrase, un texte ou un dialogue.", 0, '2025-07-07', 'ZH_5')
# 2025-07-07 15:27:27,599 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,600 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,600 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,600 INFO sqlalchemy.engine.Engine [cached since 0.1262s ago] ('ZH_5',)
# 2025-07-07 15:27:27,600 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,601 INFO sqlalchemy.engine.Engine [cached since 0.1296s ago] ('ZH_5_G4', 'Les différentes utilisations de 要 yào', "Le premier sens de 要 yào est le verbe « vouloir ».\n\n* 我 要 工作 wǒ yào gōngzuò : « Je veux travailler »\n* 我 要 吃饭 wǒ yào chīfàn : « Je veux manger »\n ... (31 characters truncated) ... enir est la suivante :\n\nIl peut également avoir d'autres sens, tels que « devoir », « falloir » ou encore « aller faire/être sur le point de ... ».", 0, '2025-07-07', 'ZH_5')
# 2025-07-07 15:27:27,601 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,601 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,601 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,602 INFO sqlalchemy.engine.Engine [cached since 0.1277s ago] ('ZH_9',)
# 2025-07-07 15:27:27,602 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,602 INFO sqlalchemy.engine.Engine [cached since 0.1309s ago] ('ZH_9_G1', 'Moyens de transport', "Si en français nous employons généralement le verbe « prendre » lorsqu'il s'agit des moyens de transport, il convient d'utiliser le verbe 坐 zuò « s'a ... (471 characters truncated) ...  véhicule, il faut employer 开 kāi « conduire, ouvrir » :\n\n* 我开车 wǒ kāi chē : « Je conduis la voiture »\n* 我开飞机 wǒ kāi fēijī : « Je pilote l'avion »", 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:27:27,602 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,603 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,603 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,605 INFO sqlalchemy.engine.Engine [cached since 0.1314s ago] ('ZH_9',)
# 2025-07-07 15:27:27,606 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,609 INFO sqlalchemy.engine.Engine [cached since 0.1381s ago] ('ZH_9_G2', '"Chaque" avec 每 měi', '每 měi est employé dans la majorité des cas avec un classificateur derrière :\n\n* 每个人 měi gè rén : « Chaque personne »\n* 每个月 měi gè yuè : « Chaque m ... (100 characters truncated) ... it pas être employé dans les trois cas suivants :\n\n* 每年 měi nián : « Chaque année »\n* 每天 měi tiān : « Chaque jour »\n* 每日 měi rì : « Chaque jour »', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:27:27,610 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,614 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,617 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# /var/folders/5p/bjh6crbn6fv0vtxy5sqmmxh00000gn/T/ipykernel_19139/3000667266.py:24: SAWarning: Object of type <GrammarRule> not in session, add operation along 'Unit.grammars' will not proceed (This warning originated from the Session 'autoflush' process, which was invoked automatically in response to a user-initiated operation. Consider using ``no_autoflush`` context manager if this warning happended while initializing objects.)
#   parent=session.query(Unit).filter(Unit.unit_id == f"{language_id.upper()}_{unit_id}").first()
# /Users/noe_jager/Documents/GitHub/vocabulary-dbms/src/lapp/dbms.py:80: SAWarning: Object of type <GrammarRule> not in session, add operation along 'Unit.grammars' will not proceed
#   session.commit()
# 2025-07-07 15:27:27,621 INFO sqlalchemy.engine.Engine [cached since 0.1467s ago] ('ZH_9',)
# 2025-07-07 15:27:27,626 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,629 INFO sqlalchemy.engine.Engine [cached since 0.1575s ago] ('ZH_9_G3', '"D\'abord... ensuite..." avec 先 xiān et 然后 ránhòu', "先 xiān « premièrement », et 然后 ránhòu « ensuite » peuvent être utilisés ensemble pour indiquer que deux événements se succèdent :\n\n* 我们先吃饭，然后看电视 wǒ ... (220 characters truncated) ... emièrement » peut également être utilisé seul :\n\n* 他先到了 tā xiān dào le : « Il est arrivé en premier »\n* 我先说 wǒ xiān shuō : « Je parle en premier »", 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:27:27,629 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,631 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,631 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,631 INFO sqlalchemy.engine.Engine [cached since 0.1573s ago] ('ZH_9',)
# 2025-07-07 15:27:27,631 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,632 INFO sqlalchemy.engine.Engine [cached since 0.1607s ago] ('ZH_9_G4', '"Un petit peu" avec 有点儿 yǒu diǎnr ou 一点儿 yī diǎnr', "**有点儿 yǒu diǎnr**\n有点儿 yǒu diǎnr ou simplement 有点 yǒu diǎn est utilisé avant un adjectif. Il est généralement employé dans des phrases négatives, pou ... (499 characters truncated) ... 宜一点儿 nǐ piányi yī diǎnr : « Baisse un peu le prix »\n* 你快一点儿 nǐ kuài yī diǎnr : « Dépêche-toi un peu »\n* 你慢一点儿 nǐ màn yī diǎnr : « Ralentis un peu »", 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:27:27,632 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,633 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,634 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,636 INFO sqlalchemy.engine.Engine [cached since 0.1617s ago] ('ZH_9',)
# 2025-07-07 15:27:27,637 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,639 INFO sqlalchemy.engine.Engine [cached since 0.1678s ago] ('ZH_9_G5', 'Utiliser 比较 bǐjiào devant un verbe', "Nous avons vu dans la leçon précédente que l'adverbe 比较 bǐjiào signifie « relativement, plutôt » et qu'il était employé devant un adjectif afin de le ... (162 characters truncated) ... iào xǐhuan : « Je préfère »\n* 我不喜欢坐车，我比较喜欢走路 wǒ bù xǐhuan zuò chē, wǒ bǐjiào xǐhuan zǒulù : « Je n'aime pas prendre la voiture, je préfère marcher »", 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:27:27,640 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-07 15:27:27,641 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-07 15:27:27,642 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-07 15:27:27,642 INFO sqlalchemy.engine.Engine [cached since 0.1679s ago] ('ZH_9',)
# 2025-07-07 15:27:27,642 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (learn_id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-07 15:27:27,642 INFO sqlalchemy.engine.Engine [cached since 0.1715s ago] ('ZH_9_G6', 'Les particules modales placées en fin de phrase', 'Quelques particules modales sont habituellement rajoutées en fin de phrase pour donner un ton particulier à la phrase, en voici quelques exemples :\n ... (334 characters truncated) ... .\n\nIl existe également des interjections placées en début de phrase :\n\n* 嗯 en : équivalent du « hum... » français\n* 哎呀 āiyā : marque la surprise', 0, '2025-07-07', 'ZH_9')
# 2025-07-07 15:27:27,643 INFO sqlalchemy.engine.Engine COMMIT
