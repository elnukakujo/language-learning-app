# %%
import json
import pandas as pd
import os
import re
from lapp.dbms import init_db, inserts, modify, delete, find_by_attr
from lapp.tables import Unit, Vocabulary, GrammarRule

# %%
language_name = "zh"

# %% [markdown]
# ## Add Units

# %%
# Initialize the database connection and create db file if it doesn't exist
engine, session = init_db(language_name)

if not os.path.exists(f'../data/{language_name}'):
    raise FileNotFoundError(f"Dataset for {language_name} not found.")

# Initialize the database
with open(f'../data/{language_name}/units.json', 'r') as f:
    units_array = json.load(f)
    
units = []
for idx, unit_data in enumerate(units_array):
    units.append(
        Unit(
            unit_id = f"{language_name.upper()}_{idx}",
            title = unit_data['title'],
            description = unit_data['description'],
            level = unit_data['level']
        )
    )
inserts(session, units)
session.close()
# Out:
# 2025-07-04 23:27:11,328 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:11,328 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-04 23:27:11,328 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-04 23:27:11,328 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("unit")
# 2025-07-04 23:27:11,328 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-04 23:27:11,329 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-04 23:27:11,329 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-04 23:27:11,329 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("calligraphy_character")
# 2025-07-04 23:27:11,329 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-04 23:27:11,329 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-04 23:27:11,329 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-04 23:27:11,330 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("grammar_rule")
# 2025-07-04 23:27:11,330 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-04 23:27:11,330 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-04 23:27:11,330 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-04 23:27:11,330 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("vocabulary")
# 2025-07-04 23:27:11,330 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-04 23:27:11,330 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-04 23:27:11,331 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-04 23:27:11,331 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("exercises")
# 2025-07-04 23:27:11,331 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-04 23:27:11,331 INFO sqlalchemy.engine.Engine
# CREATE TABLE unit (
# 	unit_id VARCHAR NOT NULL,
# 	title VARCHAR,
# 	description VARCHAR,
# 	level VARCHAR,
# 	PRIMARY KEY (unit_id)
# )
#
#
# 2025-07-04 23:27:11,331 INFO sqlalchemy.engine.Engine [no key 0.00014s] ()
# 2025-07-04 23:27:11,332 INFO sqlalchemy.engine.Engine CREATE INDEX ix_unit_unit_id ON unit (unit_id)
# 2025-07-04 23:27:11,332 INFO sqlalchemy.engine.Engine [no key 0.00011s] ()
# 2025-07-04 23:27:11,332 INFO sqlalchemy.engine.Engine CREATE INDEX ix_unit_title ON unit (title)
# 2025-07-04 23:27:11,332 INFO sqlalchemy.engine.Engine [no key 0.00012s] ()
# 2025-07-04 23:27:11,333 INFO sqlalchemy.engine.Engine
# CREATE TABLE calligraphy_character (
# 	char_id VARCHAR NOT NULL,
# 	character VARCHAR,
# 	char_translation VARCHAR,
# 	components VARCHAR,
# 	score INTEGER,
# 	last_seen DATE,
# 	unit_id VARCHAR NOT NULL,
# 	PRIMARY KEY (char_id),
# 	FOREIGN KEY(unit_id) REFERENCES unit (unit_id)
# )
#
#
# 2025-07-04 23:27:11,333 INFO sqlalchemy.engine.Engine [no key 0.00011s] ()
# 2025-07-04 23:27:11,334 INFO sqlalchemy.engine.Engine CREATE INDEX ix_calligraphy_character_char_id ON calligraphy_character (char_id)
# 2025-07-04 23:27:11,334 INFO sqlalchemy.engine.Engine [no key 0.00010s] ()
# 2025-07-04 23:27:11,334 INFO sqlalchemy.engine.Engine CREATE INDEX ix_calligraphy_character_character ON calligraphy_character (character)
# 2025-07-04 23:27:11,334 INFO sqlalchemy.engine.Engine [no key 0.00014s] ()
# 2025-07-04 23:27:11,335 INFO sqlalchemy.engine.Engine
# CREATE TABLE grammar_rule (
# 	grammar_id VARCHAR NOT NULL,
# 	grammar_title VARCHAR,
# 	explanation VARCHAR,
# 	score INTEGER,
# 	last_seen DATE,
# 	unit_id VARCHAR NOT NULL,
# 	PRIMARY KEY (grammar_id),
# 	FOREIGN KEY(unit_id) REFERENCES unit (unit_id)
# )
#
#
# 2025-07-04 23:27:11,335 INFO sqlalchemy.engine.Engine [no key 0.00011s] ()
# 2025-07-04 23:27:11,335 INFO sqlalchemy.engine.Engine CREATE INDEX ix_grammar_rule_grammar_title ON grammar_rule (grammar_title)
# 2025-07-04 23:27:11,335 INFO sqlalchemy.engine.Engine [no key 0.00012s] ()
# 2025-07-04 23:27:11,336 INFO sqlalchemy.engine.Engine CREATE INDEX ix_grammar_rule_grammar_id ON grammar_rule (grammar_id)
# 2025-07-04 23:27:11,336 INFO sqlalchemy.engine.Engine [no key 0.00010s] ()
# 2025-07-04 23:27:11,336 INFO sqlalchemy.engine.Engine
# CREATE TABLE vocabulary (
# 	voc_id VARCHAR NOT NULL,
# 	word VARCHAR,
# 	voc_translation VARCHAR,
# 	voc_phonetic VARCHAR,
# 	example_sentence VARCHAR,
# 	voc_type VARCHAR,
# 	score INTEGER,
# 	last_seen DATE,
# 	unit_id VARCHAR NOT NULL,
# 	PRIMARY KEY (voc_id),
# 	FOREIGN KEY(unit_id) REFERENCES unit (unit_id)
# )
#
#
# 2025-07-04 23:27:11,336 INFO sqlalchemy.engine.Engine [no key 0.00011s] ()
# 2025-07-04 23:27:11,337 INFO sqlalchemy.engine.Engine CREATE INDEX ix_vocabulary_word ON vocabulary (word)
# 2025-07-04 23:27:11,337 INFO sqlalchemy.engine.Engine [no key 0.00011s] ()
# 2025-07-04 23:27:11,337 INFO sqlalchemy.engine.Engine CREATE INDEX ix_vocabulary_voc_id ON vocabulary (voc_id)
# 2025-07-04 23:27:11,337 INFO sqlalchemy.engine.Engine [no key 0.00014s] ()
# 2025-07-04 23:27:11,338 INFO sqlalchemy.engine.Engine
# CREATE TABLE exercises (
# 	exercise_id VARCHAR NOT NULL,
# 	exercise_type VARCHAR,
# 	question VARCHAR,
# 	support VARCHAR,
# 	answer VARCHAR,
# 	score INTEGER,
# 	last_seen DATE,
# 	unit_id VARCHAR NOT NULL,
# 	PRIMARY KEY (exercise_id),
# 	FOREIGN KEY(unit_id) REFERENCES unit (unit_id)
# )
#
#
# 2025-07-04 23:27:11,338 INFO sqlalchemy.engine.Engine [no key 0.00012s] ()
# 2025-07-04 23:27:11,338 INFO sqlalchemy.engine.Engine CREATE INDEX ix_exercises_exercise_id ON exercises (exercise_id)
# 2025-07-04 23:27:11,339 INFO sqlalchemy.engine.Engine [no key 0.00011s] ()
# 2025-07-04 23:27:11,339 INFO sqlalchemy.engine.Engine CREATE INDEX ix_exercises_exercise_type ON exercises (exercise_type)
# 2025-07-04 23:27:11,339 INFO sqlalchemy.engine.Engine [no key 0.00010s] ()
# 2025-07-04 23:27:11,339 INFO sqlalchemy.engine.Engine CREATE INDEX ix_exercises_question ON exercises (question)
# 2025-07-04 23:27:11,340 INFO sqlalchemy.engine.Engine [no key 0.00011s] ()
# 2025-07-04 23:27:11,340 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:11,344 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:11,345 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-04 23:27:11,345 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('ZH_0', 'Lecon introductive: Bonjour!', "A l'oral: Connaitre les salutations de base\nA l'ecrit: 5 caracteres", 'A1')
# 2025-07-04 23:27:11,345 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:11,346 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:11,346 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-04 23:27:11,346 INFO sqlalchemy.engine.Engine [cached since 0.001413s ago] ('ZH_1', "Unite 1: Comment t'appelles-tu?", "A l'oral: Savoir se presenter et presenter quelqu'un\nParler de sa nationalite\nA l'ecrit: 19 caracteres", 'A1')
# 2025-07-04 23:27:11,346 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:11,347 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:11,347 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-04 23:27:11,347 INFO sqlalchemy.engine.Engine [cached since 0.002289s ago] ('ZH_2', 'Unite 2: Un, deux, trois', "A l'oral: Compter de 1 a 9999\nSavoir enumerer des objets\nA l'ecrit: 19 caracteres", 'A1')
# 2025-07-04 23:27:11,347 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:11,348 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:11,348 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-04 23:27:11,348 INFO sqlalchemy.engine.Engine [cached since 0.003226s ago] ('ZH_3', "Unite 3: Aujourd'hui", "A l'oral: Savoir annoncer la date\nParler des moments de la journee et de l'heure\nA l'ecrit: 17 caracteres", 'A1')
# 2025-07-04 23:27:11,348 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:11,349 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:11,349 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-04 23:27:11,349 INFO sqlalchemy.engine.Engine [cached since 0.004121s ago] ('ZH_4', 'Unite 4: Ou allons-nous?', "A l'oral: Parler d'un evenement passe, d'une experience\nPouvoir se situer, parler ou l'on est, ou l'on va\nA l'ecrit: 17 caracteres", 'A1')
# 2025-07-04 23:27:11,349 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:11,349 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:11,349 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-04 23:27:11,350 INFO sqlalchemy.engine.Engine [cached since 0.004901s ago] ('ZH_5', 'Unite 5: Je ne suis pas vieux', "A l'oral: Decrire quelqu'un ou quelque chose\nUtilise les adjectifs\nA l'ecrit: 17 caracteres", 'A1')
# 2025-07-04 23:27:11,350 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:11,350 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:11,350 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-04 23:27:11,350 INFO sqlalchemy.engine.Engine [cached since 0.005795s ago] ('ZH_6', 'Unite 6: Ma famille', "A l'oral: Pouvoir presenter sa famille\nUtilise les demonstratifs\nA l'ecrit: 22 caracteres", 'A1')
# 2025-07-04 23:27:11,351 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:11,351 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:11,351 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-04 23:27:11,351 INFO sqlalchemy.engine.Engine [cached since 0.006631s ago] ('ZH_7', 'Unite 7: Mes amis', "A l'oral: Parler des ses amis\nParler des langues etrangeres\nComparer des gens ou des objets\nA l'ecrit: 18 caracteres", 'A1')
# 2025-07-04 23:27:11,352 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:11,352 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:11,352 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-04 23:27:11,352 INFO sqlalchemy.engine.Engine [cached since 0.007471s ago] ('ZH_8', "Unite 8: Qu'aimes-tu faire?", "A l'oral: Parler de ses activites favorites\nInterroger sur la maniere\nA l'ecrit: 16 caracteres", 'A2')
# 2025-07-04 23:27:11,352 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:11,353 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:11,353 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-04 23:27:11,353 INFO sqlalchemy.engine.Engine [cached since 0.008277s ago] ('ZH_9', 'Unite 9: Une journee classique', "A l'oral: Raconter sa journee\nParler des differents moyens de transport\nA l'ecrit: 16 caracteres", 'A2')
# 2025-07-04 23:27:11,353 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:11,354 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:11,354 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-04 23:27:11,354 INFO sqlalchemy.engine.Engine [cached since 0.009141s ago] ('ZH_10', 'Unite 10: Au travail', "A l'oral: Parler du monde du travail\nA l'ecrit: 18 caracteres", 'A2')
# 2025-07-04 23:27:11,354 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:11,354 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:11,355 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-04 23:27:11,355 INFO sqlalchemy.engine.Engine [cached since 0.009995s ago] ('ZH_11', 'Unite 11: Dans une grande ville', "A l'oral: Pouvoir demander son chemin\nSe reperer en ville\nA l'ecrit: 18 caracteres", 'A2')
# 2025-07-04 23:27:11,355 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:11,355 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:11,355 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-04 23:27:11,355 INFO sqlalchemy.engine.Engine [cached since 0.01077s ago] ('ZH_12', 'Unite 12: Faire des achats', "A l'oral: Negocier un prix\nFaire des achats\nA l'ecrit: 18 caracteres", 'A2')
# 2025-07-04 23:27:11,356 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:11,356 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:11,356 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-04 23:27:11,356 INFO sqlalchemy.engine.Engine [cached since 0.01163s ago] ('ZH_13', "Unite 13: En voyage a l'etranger", "A l'oral: Pouvoir raconter ou prevoir un voyage\nUtiliser 'Avant, apres, pendant'\nA l'ecrit: 17 caracteres", 'A2')
# 2025-07-04 23:27:11,357 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:11,357 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:11,357 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-04 23:27:11,357 INFO sqlalchemy.engine.Engine [cached since 0.01251s ago] ('ZH_14', 'Unite 14: La culture chinoise', "A l'oral: Decouvrir la culture chinoise\nParler des fetes et des vacances\nA l'ecrit: 19 caracteres", 'A2')
# 2025-07-04 23:27:11,357 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:11,358 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:11,358 INFO sqlalchemy.engine.Engine INSERT INTO unit (unit_id, title, description, level) VALUES (?, ?, ?, ?)
# 2025-07-04 23:27:11,358 INFO sqlalchemy.engine.Engine [cached since 0.01338s ago] ('ZH_15', 'Unite 15: A la maison', "A l'oral: Decrire une maison, un appartement\nUtiliser 吧 et les directionnels\nA l'ecrit: 17 caracteres", 'A2')
# 2025-07-04 23:27:11,358 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Add Vocabulary

# %%
# Initialize the database connection and create db file if it doesn't exist
engine, session = init_db(language_name)

directory_path = f'../data/{language_name}/vocabulary'

if not os.path.exists(directory_path):
    raise FileNotFoundError(f"No vocabulary found for {language_name}.")

vocs = []

# List all elements (files and directories) in the specified directory and get their full paths
elements_paths = [os.path.join(directory_path, element) for element in os.listdir(directory_path)]
for voc_file in elements_paths:
    if os.path.isfile(voc_file) and voc_file.endswith('.csv'):
        unit_id = re.sub("[^0-9]", "", os.path.basename(voc_file))
        df = pd.read_csv(voc_file)
        for idx, row in df.iterrows():
            vocs.append( 
                Vocabulary(
                    voc_id=f"{language_name.upper()}_{unit_id}_V{idx}",
                    word = row['word'],
                    voc_translation = row["translation"],
                    voc_phonetic = row["pinyin"],
                    example_sentence = row.get("example_sentence", ""),
                    voc_type = row["type"],
                    parent=session.query(Unit).filter(Unit.unit_id == f"{language_name.upper()}_{unit_id}").first()
                )
            )
inserts(session, vocs)
session.close()
# Out:
# 2025-07-04 23:27:11,363 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:11,363 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-04 23:27:11,363 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-04 23:27:11,363 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-04 23:27:11,363 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-04 23:27:11,364 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-04 23:27:11,364 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-04 23:27:11,364 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-04 23:27:11,364 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-04 23:27:11,364 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-04 23:27:11,365 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-04 23:27:11,365 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:11,368 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:11,369 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,369 INFO sqlalchemy.engine.Engine [generated in 0.00017s] ('ZH_2', 1, 0)
# 2025-07-04 23:27:11,370 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,370 INFO sqlalchemy.engine.Engine [cached since 0.001126s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:11,370 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,370 INFO sqlalchemy.engine.Engine [cached since 0.00175s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:11,371 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,371 INFO sqlalchemy.engine.Engine [cached since 0.002464s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:11,372 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,372 INFO sqlalchemy.engine.Engine [cached since 0.003161s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:11,372 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,372 INFO sqlalchemy.engine.Engine [cached since 0.00378s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:11,373 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,373 INFO sqlalchemy.engine.Engine [cached since 0.00444s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:11,373 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,374 INFO sqlalchemy.engine.Engine [cached since 0.005021s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:11,374 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,374 INFO sqlalchemy.engine.Engine [cached since 0.005673s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:11,375 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,375 INFO sqlalchemy.engine.Engine [cached since 0.006244s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:11,375 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,375 INFO sqlalchemy.engine.Engine [cached since 0.006801s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:11,376 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,376 INFO sqlalchemy.engine.Engine [cached since 0.007457s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:11,377 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,377 INFO sqlalchemy.engine.Engine [cached since 0.008177s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:11,377 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,377 INFO sqlalchemy.engine.Engine [cached since 0.008798s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:11,378 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,378 INFO sqlalchemy.engine.Engine [cached since 0.009347s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:11,378 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,379 INFO sqlalchemy.engine.Engine [cached since 0.009937s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:11,379 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,379 INFO sqlalchemy.engine.Engine [cached since 0.01052s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:11,380 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,380 INFO sqlalchemy.engine.Engine [cached since 0.01113s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:11,380 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,380 INFO sqlalchemy.engine.Engine [cached since 0.0118s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:11,381 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,381 INFO sqlalchemy.engine.Engine [cached since 0.01235s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:11,381 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,381 INFO sqlalchemy.engine.Engine [cached since 0.0129s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:11,382 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,382 INFO sqlalchemy.engine.Engine [cached since 0.01345s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:11,383 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,383 INFO sqlalchemy.engine.Engine [cached since 0.01407s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:11,384 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,384 INFO sqlalchemy.engine.Engine [cached since 0.01544s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,384 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,385 INFO sqlalchemy.engine.Engine [cached since 0.01603s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,385 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,385 INFO sqlalchemy.engine.Engine [cached since 0.01661s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,386 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,386 INFO sqlalchemy.engine.Engine [cached since 0.01722s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,386 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,386 INFO sqlalchemy.engine.Engine [cached since 0.01786s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,387 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,387 INFO sqlalchemy.engine.Engine [cached since 0.01842s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,387 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,388 INFO sqlalchemy.engine.Engine [cached since 0.01896s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,388 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,388 INFO sqlalchemy.engine.Engine [cached since 0.0195s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,388 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,389 INFO sqlalchemy.engine.Engine [cached since 0.02002s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,389 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,389 INFO sqlalchemy.engine.Engine [cached since 0.02063s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,390 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,390 INFO sqlalchemy.engine.Engine [cached since 0.0211s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,390 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,390 INFO sqlalchemy.engine.Engine [cached since 0.02173s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,391 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,391 INFO sqlalchemy.engine.Engine [cached since 0.02259s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,392 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,392 INFO sqlalchemy.engine.Engine [cached since 0.0235s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,393 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,393 INFO sqlalchemy.engine.Engine [cached since 0.02418s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,393 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,393 INFO sqlalchemy.engine.Engine [cached since 0.02482s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,394 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,394 INFO sqlalchemy.engine.Engine [cached since 0.02538s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,394 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,394 INFO sqlalchemy.engine.Engine [cached since 0.02586s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,395 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,395 INFO sqlalchemy.engine.Engine [cached since 0.02642s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,395 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,395 INFO sqlalchemy.engine.Engine [cached since 0.02688s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,396 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,396 INFO sqlalchemy.engine.Engine [cached since 0.0274s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,396 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,397 INFO sqlalchemy.engine.Engine [cached since 0.02795s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,397 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,397 INFO sqlalchemy.engine.Engine [cached since 0.02844s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,397 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,398 INFO sqlalchemy.engine.Engine [cached since 0.02903s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,398 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,398 INFO sqlalchemy.engine.Engine [cached since 0.02957s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,399 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,399 INFO sqlalchemy.engine.Engine [cached since 0.03012s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,399 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,399 INFO sqlalchemy.engine.Engine [cached since 0.03072s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,400 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,400 INFO sqlalchemy.engine.Engine [cached since 0.03127s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,400 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,400 INFO sqlalchemy.engine.Engine [cached since 0.03182s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,401 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,401 INFO sqlalchemy.engine.Engine [cached since 0.03229s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,401 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,401 INFO sqlalchemy.engine.Engine [cached since 0.03286s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:11,403 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,403 INFO sqlalchemy.engine.Engine [cached since 0.03415s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:11,403 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,403 INFO sqlalchemy.engine.Engine [cached since 0.03486s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:11,404 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,404 INFO sqlalchemy.engine.Engine [cached since 0.03544s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:11,404 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,405 INFO sqlalchemy.engine.Engine [cached since 0.03603s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:11,405 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,405 INFO sqlalchemy.engine.Engine [cached since 0.03662s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:11,406 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,406 INFO sqlalchemy.engine.Engine [cached since 0.03711s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:11,406 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,406 INFO sqlalchemy.engine.Engine [cached since 0.03771s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:11,407 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,407 INFO sqlalchemy.engine.Engine [cached since 0.03827s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:11,407 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,407 INFO sqlalchemy.engine.Engine [cached since 0.03875s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:11,408 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,408 INFO sqlalchemy.engine.Engine [cached since 0.03937s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:11,408 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,409 INFO sqlalchemy.engine.Engine [cached since 0.04002s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:11,409 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,409 INFO sqlalchemy.engine.Engine [cached since 0.04057s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:11,410 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,410 INFO sqlalchemy.engine.Engine [cached since 0.04122s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:11,410 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,410 INFO sqlalchemy.engine.Engine [cached since 0.04171s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:11,411 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,411 INFO sqlalchemy.engine.Engine [cached since 0.04219s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:11,411 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,411 INFO sqlalchemy.engine.Engine [cached since 0.04274s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:11,412 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,412 INFO sqlalchemy.engine.Engine [cached since 0.04331s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:11,412 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,413 INFO sqlalchemy.engine.Engine [cached since 0.04395s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:11,413 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,413 INFO sqlalchemy.engine.Engine [cached since 0.04444s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:11,413 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,414 INFO sqlalchemy.engine.Engine [cached since 0.04498s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:11,414 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,414 INFO sqlalchemy.engine.Engine [cached since 0.04547s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:11,414 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,415 INFO sqlalchemy.engine.Engine [cached since 0.04599s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:11,415 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,415 INFO sqlalchemy.engine.Engine [cached since 0.04656s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:11,416 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,416 INFO sqlalchemy.engine.Engine [cached since 0.04715s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:11,417 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,417 INFO sqlalchemy.engine.Engine [cached since 0.04839s ago] ('ZH_0', 1, 0)
# 2025-07-04 23:27:11,417 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,418 INFO sqlalchemy.engine.Engine [cached since 0.04897s ago] ('ZH_0', 1, 0)
# 2025-07-04 23:27:11,418 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,418 INFO sqlalchemy.engine.Engine [cached since 0.0496s ago] ('ZH_0', 1, 0)
# 2025-07-04 23:27:11,419 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,419 INFO sqlalchemy.engine.Engine [cached since 0.05007s ago] ('ZH_0', 1, 0)
# 2025-07-04 23:27:11,419 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,419 INFO sqlalchemy.engine.Engine [cached since 0.05062s ago] ('ZH_0', 1, 0)
# 2025-07-04 23:27:11,420 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,420 INFO sqlalchemy.engine.Engine [cached since 0.0512s ago] ('ZH_0', 1, 0)
# 2025-07-04 23:27:11,420 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,420 INFO sqlalchemy.engine.Engine [cached since 0.05179s ago] ('ZH_0', 1, 0)
# 2025-07-04 23:27:11,421 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,421 INFO sqlalchemy.engine.Engine [cached since 0.05234s ago] ('ZH_0', 1, 0)
# 2025-07-04 23:27:11,421 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,421 INFO sqlalchemy.engine.Engine [cached since 0.05282s ago] ('ZH_0', 1, 0)
# 2025-07-04 23:27:11,422 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,422 INFO sqlalchemy.engine.Engine [cached since 0.05336s ago] ('ZH_0', 1, 0)
# 2025-07-04 23:27:11,422 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,423 INFO sqlalchemy.engine.Engine [cached since 0.05394s ago] ('ZH_0', 1, 0)
# 2025-07-04 23:27:11,424 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,424 INFO sqlalchemy.engine.Engine [cached since 0.05509s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:11,424 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,424 INFO sqlalchemy.engine.Engine [cached since 0.0556s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:11,425 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,425 INFO sqlalchemy.engine.Engine [cached since 0.05618s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:11,425 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,425 INFO sqlalchemy.engine.Engine [cached since 0.05674s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:11,426 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,426 INFO sqlalchemy.engine.Engine [cached since 0.05733s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:11,426 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,426 INFO sqlalchemy.engine.Engine [cached since 0.05784s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:11,427 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,427 INFO sqlalchemy.engine.Engine [cached since 0.05835s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:11,427 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,427 INFO sqlalchemy.engine.Engine [cached since 0.05889s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:11,428 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,428 INFO sqlalchemy.engine.Engine [cached since 0.05943s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:11,428 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,429 INFO sqlalchemy.engine.Engine [cached since 0.06001s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:11,429 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,429 INFO sqlalchemy.engine.Engine [cached since 0.06056s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:11,430 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,430 INFO sqlalchemy.engine.Engine [cached since 0.0611s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:11,430 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,430 INFO sqlalchemy.engine.Engine [cached since 0.06164s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:11,431 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,431 INFO sqlalchemy.engine.Engine [cached since 0.06218s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:11,431 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,431 INFO sqlalchemy.engine.Engine [cached since 0.06272s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:11,432 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,432 INFO sqlalchemy.engine.Engine [cached since 0.06331s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:11,432 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,432 INFO sqlalchemy.engine.Engine [cached since 0.06383s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:11,433 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,433 INFO sqlalchemy.engine.Engine [cached since 0.06431s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:11,434 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,434 INFO sqlalchemy.engine.Engine [cached since 0.06545s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,434 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,435 INFO sqlalchemy.engine.Engine [cached since 0.06601s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,435 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,435 INFO sqlalchemy.engine.Engine [cached since 0.06664s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,436 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,436 INFO sqlalchemy.engine.Engine [cached since 0.06717s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,436 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,436 INFO sqlalchemy.engine.Engine [cached since 0.06771s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,437 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,437 INFO sqlalchemy.engine.Engine [cached since 0.06825s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,437 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,437 INFO sqlalchemy.engine.Engine [cached since 0.06879s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,438 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,438 INFO sqlalchemy.engine.Engine [cached since 0.06934s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,438 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,439 INFO sqlalchemy.engine.Engine [cached since 0.06993s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,439 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,439 INFO sqlalchemy.engine.Engine [cached since 0.07039s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,439 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,440 INFO sqlalchemy.engine.Engine [cached since 0.07096s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,440 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,440 INFO sqlalchemy.engine.Engine [cached since 0.0715s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,441 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,441 INFO sqlalchemy.engine.Engine [cached since 0.0721s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,441 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,441 INFO sqlalchemy.engine.Engine [cached since 0.07267s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,442 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,442 INFO sqlalchemy.engine.Engine [cached since 0.0733s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,442 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,442 INFO sqlalchemy.engine.Engine [cached since 0.07383s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,443 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,443 INFO sqlalchemy.engine.Engine [cached since 0.07436s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,443 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,443 INFO sqlalchemy.engine.Engine [cached since 0.07486s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,444 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,444 INFO sqlalchemy.engine.Engine [cached since 0.07542s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,444 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,445 INFO sqlalchemy.engine.Engine [cached since 0.076s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,445 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,445 INFO sqlalchemy.engine.Engine [cached since 0.07653s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,445 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,446 INFO sqlalchemy.engine.Engine [cached since 0.07703s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,446 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,446 INFO sqlalchemy.engine.Engine [cached since 0.07755s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,447 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,447 INFO sqlalchemy.engine.Engine [cached since 0.07813s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,447 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,447 INFO sqlalchemy.engine.Engine [cached since 0.07866s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,448 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,448 INFO sqlalchemy.engine.Engine [cached since 0.07922s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,448 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,448 INFO sqlalchemy.engine.Engine [cached since 0.07976s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:11,449 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,449 INFO sqlalchemy.engine.Engine [cached since 0.08085s ago] ('ZH_7', 1, 0)
# 2025-07-04 23:27:11,450 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,450 INFO sqlalchemy.engine.Engine [cached since 0.08131s ago] ('ZH_7', 1, 0)
# 2025-07-04 23:27:11,450 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,450 INFO sqlalchemy.engine.Engine [cached since 0.08185s ago] ('ZH_7', 1, 0)
# 2025-07-04 23:27:11,451 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,451 INFO sqlalchemy.engine.Engine [cached since 0.08231s ago] ('ZH_7', 1, 0)
# 2025-07-04 23:27:11,451 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,451 INFO sqlalchemy.engine.Engine [cached since 0.08288s ago] ('ZH_7', 1, 0)
# 2025-07-04 23:27:11,452 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,452 INFO sqlalchemy.engine.Engine [cached since 0.08337s ago] ('ZH_7', 1, 0)
# 2025-07-04 23:27:11,452 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,452 INFO sqlalchemy.engine.Engine [cached since 0.0839s ago] ('ZH_7', 1, 0)
# 2025-07-04 23:27:11,453 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:11,453 INFO sqlalchemy.engine.Engine [cached since 0.08443s ago] ('ZH_7', 1, 0)
# ...
# 2025-07-04 23:27:12,939 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (voc_id, word, voc_translation, voc_phonetic, example_sentence, voc_type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:12,939 INFO sqlalchemy.engine.Engine [cached since 1.177s ago] ('ZH_9_V4', '开', 'Conduire', 'Kāi', '', 'Verbes', 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:12,939 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:12,940 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:12,940 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:12,940 INFO sqlalchemy.engine.Engine [cached since 1.176s ago] ('ZH_9',)
# 2025-07-04 23:27:12,941 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (voc_id, word, voc_translation, voc_phonetic, example_sentence, voc_type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:12,941 INFO sqlalchemy.engine.Engine [cached since 1.179s ago] ('ZH_9_V5', '开始', 'Commencer', 'Kāishǐ', '', 'Verbes', 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:12,941 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:12,942 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:12,942 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:12,942 INFO sqlalchemy.engine.Engine [cached since 1.178s ago] ('ZH_9',)
# 2025-07-04 23:27:12,942 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (voc_id, word, voc_translation, voc_phonetic, example_sentence, voc_type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:12,942 INFO sqlalchemy.engine.Engine [cached since 1.18s ago] ('ZH_9_V6', '骑', 'Chevaucher', 'Qí', '', 'Verbes', 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:12,943 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:12,943 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:12,944 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:12,944 INFO sqlalchemy.engine.Engine [cached since 1.18s ago] ('ZH_9',)
# 2025-07-04 23:27:12,944 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (voc_id, word, voc_translation, voc_phonetic, example_sentence, voc_type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:12,944 INFO sqlalchemy.engine.Engine [cached since 1.182s ago] ('ZH_9_V7', '上班', 'Commencer le travail', 'Shàngbān', '', 'Verbes', 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:12,945 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:12,945 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:12,945 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:12,946 INFO sqlalchemy.engine.Engine [cached since 1.182s ago] ('ZH_9',)
# 2025-07-04 23:27:12,946 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (voc_id, word, voc_translation, voc_phonetic, example_sentence, voc_type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:12,946 INFO sqlalchemy.engine.Engine [cached since 1.184s ago] ('ZH_9_V8', '下班', 'Finir le travail', 'Xiàbān', '', 'Verbes', 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:12,946 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:12,947 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:12,947 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:12,947 INFO sqlalchemy.engine.Engine [cached since 1.183s ago] ('ZH_9',)
# 2025-07-04 23:27:12,948 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (voc_id, word, voc_translation, voc_phonetic, example_sentence, voc_type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:12,948 INFO sqlalchemy.engine.Engine [cached since 1.186s ago] ('ZH_9_V9', '走路', 'Marcher', 'Zǒulù', '', 'Verbes', 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:12,948 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:12,949 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:12,949 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:12,949 INFO sqlalchemy.engine.Engine [cached since 1.185s ago] ('ZH_9',)
# 2025-07-04 23:27:12,949 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (voc_id, word, voc_translation, voc_phonetic, example_sentence, voc_type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:12,949 INFO sqlalchemy.engine.Engine [cached since 1.187s ago] ('ZH_9_V10', '坐', "S'asseoir/prendre (véhicule)", 'Zuò', '', 'Verbes', 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:12,950 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:12,950 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:12,951 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:12,951 INFO sqlalchemy.engine.Engine [cached since 1.187s ago] ('ZH_9',)
# 2025-07-04 23:27:12,951 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (voc_id, word, voc_translation, voc_phonetic, example_sentence, voc_type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:12,951 INFO sqlalchemy.engine.Engine [cached since 1.189s ago] ('ZH_9_V11', '游泳', 'Nager', 'Yóuyǒng', '', 'Verbes', 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:12,951 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:12,952 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:12,952 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:12,952 INFO sqlalchemy.engine.Engine [cached since 1.188s ago] ('ZH_9',)
# 2025-07-04 23:27:12,953 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (voc_id, word, voc_translation, voc_phonetic, example_sentence, voc_type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:12,953 INFO sqlalchemy.engine.Engine [cached since 1.191s ago] ('ZH_9_V12', '无聊', 'Ennuyeux', 'Wúliáo', '', 'Adjectifs', 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:12,953 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:12,954 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:12,954 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:12,954 INFO sqlalchemy.engine.Engine [cached since 1.19s ago] ('ZH_9',)
# 2025-07-04 23:27:12,954 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (voc_id, word, voc_translation, voc_phonetic, example_sentence, voc_type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:12,954 INFO sqlalchemy.engine.Engine [cached since 1.192s ago] ('ZH_9_V13', '有意思', 'Intéressant (polite)', 'Yǒu yìsi', '', 'Adjectifs', 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:12,955 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:12,955 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:12,956 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:12,956 INFO sqlalchemy.engine.Engine [cached since 1.192s ago] ('ZH_9',)
# 2025-07-04 23:27:12,956 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (voc_id, word, voc_translation, voc_phonetic, example_sentence, voc_type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:12,956 INFO sqlalchemy.engine.Engine [cached since 1.194s ago] ('ZH_9_V14', '没意思', 'Inintéressant (polite)', 'Méi yìsi', '', 'Adjectifs', 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:12,956 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:12,957 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:12,957 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:12,957 INFO sqlalchemy.engine.Engine [cached since 1.193s ago] ('ZH_9',)
# 2025-07-04 23:27:12,958 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (voc_id, word, voc_translation, voc_phonetic, example_sentence, voc_type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:12,958 INFO sqlalchemy.engine.Engine [cached since 1.196s ago] ('ZH_9_V15', '啊', "Particule modale d'exclamation", 'A', '', 'Divers', 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:12,958 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:12,959 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:12,959 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:12,959 INFO sqlalchemy.engine.Engine [cached since 1.195s ago] ('ZH_9',)
# 2025-07-04 23:27:12,959 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (voc_id, word, voc_translation, voc_phonetic, example_sentence, voc_type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:12,959 INFO sqlalchemy.engine.Engine [cached since 1.197s ago] ('ZH_9_V16', '每', 'Chaque', 'Měi', '', 'Divers', 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:12,960 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:12,960 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:12,961 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:12,961 INFO sqlalchemy.engine.Engine [cached since 1.197s ago] ('ZH_9',)
# 2025-07-04 23:27:12,961 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (voc_id, word, voc_translation, voc_phonetic, example_sentence, voc_type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:12,961 INFO sqlalchemy.engine.Engine [cached since 1.199s ago] ('ZH_9_V17', '然后', 'Ensuite', 'Ránhòu', '', 'Divers', 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:12,961 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:12,962 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:12,962 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:12,962 INFO sqlalchemy.engine.Engine [cached since 1.198s ago] ('ZH_9',)
# 2025-07-04 23:27:12,963 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (voc_id, word, voc_translation, voc_phonetic, example_sentence, voc_type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:12,963 INFO sqlalchemy.engine.Engine [cached since 1.201s ago] ('ZH_9_V18', '同意', "Être d'accord", 'Tóngyì', '', 'Divers', 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:12,965 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:12,986 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:12,993 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:12,994 INFO sqlalchemy.engine.Engine [cached since 1.23s ago] ('ZH_9',)
# 2025-07-04 23:27:12,994 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (voc_id, word, voc_translation, voc_phonetic, example_sentence, voc_type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:12,995 INFO sqlalchemy.engine.Engine [cached since 1.233s ago] ('ZH_9_V19', '先', "D'abord", 'Xiān', '', 'Divers', 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:12,996 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,002 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,004 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,005 INFO sqlalchemy.engine.Engine [cached since 1.241s ago] ('ZH_9',)
# 2025-07-04 23:27:13,006 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (voc_id, word, voc_translation, voc_phonetic, example_sentence, voc_type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,007 INFO sqlalchemy.engine.Engine [cached since 1.245s ago] ('ZH_9_V20', '有点儿', 'Un petit peu', 'Yǒu diǎnr', '', 'Divers', 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:13,008 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,010 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,011 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,012 INFO sqlalchemy.engine.Engine [cached since 1.248s ago] ('ZH_9',)
# 2025-07-04 23:27:13,013 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (voc_id, word, voc_translation, voc_phonetic, example_sentence, voc_type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,014 INFO sqlalchemy.engine.Engine [cached since 1.252s ago] ('ZH_9_V21', '公园', 'Parc public', 'Gōngyuán', '', 'Noms et expressions', 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:13,015 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,017 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,017 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,018 INFO sqlalchemy.engine.Engine [cached since 1.254s ago] ('ZH_9',)
# 2025-07-04 23:27:13,018 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (voc_id, word, voc_translation, voc_phonetic, example_sentence, voc_type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,019 INFO sqlalchemy.engine.Engine [cached since 1.257s ago] ('ZH_9_V22', '看法', 'Point de vue', 'Kànfǎ', '', 'Noms et expressions', 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:13,019 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,022 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,023 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,024 INFO sqlalchemy.engine.Engine [cached since 1.26s ago] ('ZH_9',)
# 2025-07-04 23:27:13,024 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (voc_id, word, voc_translation, voc_phonetic, example_sentence, voc_type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,025 INFO sqlalchemy.engine.Engine [cached since 1.263s ago] ('ZH_9_V23', '游泳池', 'Piscine', 'Yóuyǒngchí', '', 'Noms et expressions', 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:13,027 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Add Grammar Rules

# %%
# Initialize the database connection and create db file if it doesn't exist
engine, session = init_db(language_name)

directory_path = f'../data/{language_name}/grammar'

if not os.path.exists(directory_path):
    raise FileNotFoundError(f"No grammar files found for {language_name}.")

grammars = []

# List all elements (files and directories) in the specified directory and get their full paths
elements_paths = [os.path.join(directory_path, element) for element in os.listdir(directory_path)]
for grammar_file in elements_paths:
    if os.path.isfile(grammar_file) and grammar_file.endswith('.json'):
        unit_id = os.path.basename(grammar_file).replace('.json', '')[-1]
        with open(grammar_file, 'r') as f:
            grammar_data = json.load(f)
        for idx, row in enumerate(grammar_data):
            grammars.append( 
                GrammarRule(
                    grammar_id=f"{language_name.upper()}_{unit_id}_G{idx + 1}",
                    grammar_title=row['title'],
                    explanation=row["content"],
                    parent=session.query(Unit).filter(Unit.unit_id == f"{language_name.upper()}_{unit_id}").first()
                )
            )
inserts(session, grammars)
session.close()
# Out:
# 2025-07-04 23:27:13,039 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,040 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-04 23:27:13,040 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-04 23:27:13,041 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-04 23:27:13,042 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-04 23:27:13,042 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-04 23:27:13,043 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-04 23:27:13,044 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-04 23:27:13,045 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-04 23:27:13,046 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-04 23:27:13,047 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-04 23:27:13,048 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,051 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,054 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,054 INFO sqlalchemy.engine.Engine [generated in 0.00058s] ('ZH_1', 1, 0)
# 2025-07-04 23:27:13,056 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,056 INFO sqlalchemy.engine.Engine [cached since 0.002165s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:13,057 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,057 INFO sqlalchemy.engine.Engine [cached since 0.002966s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:13,057 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,057 INFO sqlalchemy.engine.Engine [cached since 0.003616s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:13,058 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,058 INFO sqlalchemy.engine.Engine [cached since 0.004571s ago] ('ZH_6', 1, 0)
# 2025-07-04 23:27:13,059 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,059 INFO sqlalchemy.engine.Engine [cached since 0.00547s ago] ('ZH_6', 1, 0)
# 2025-07-04 23:27:13,060 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,060 INFO sqlalchemy.engine.Engine [cached since 0.006339s ago] ('ZH_6', 1, 0)
# 2025-07-04 23:27:13,061 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,061 INFO sqlalchemy.engine.Engine [cached since 0.007218s ago] ('ZH_6', 1, 0)
# 2025-07-04 23:27:13,063 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,063 INFO sqlalchemy.engine.Engine [cached since 0.009278s ago] ('ZH_7', 1, 0)
# 2025-07-04 23:27:13,065 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,065 INFO sqlalchemy.engine.Engine [cached since 0.01152s ago] ('ZH_7', 1, 0)
# 2025-07-04 23:27:13,067 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,068 INFO sqlalchemy.engine.Engine [cached since 0.01368s ago] ('ZH_7', 1, 0)
# 2025-07-04 23:27:13,070 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,070 INFO sqlalchemy.engine.Engine [cached since 0.01642s ago] ('ZH_7', 1, 0)
# 2025-07-04 23:27:13,072 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,072 INFO sqlalchemy.engine.Engine [cached since 0.01806s ago] ('ZH_7', 1, 0)
# 2025-07-04 23:27:13,073 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,074 INFO sqlalchemy.engine.Engine [cached since 0.02012s ago] ('ZH_7', 1, 0)
# 2025-07-04 23:27:13,076 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,076 INFO sqlalchemy.engine.Engine [cached since 0.02223s ago] ('ZH_0', 1, 0)
# 2025-07-04 23:27:13,078 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,078 INFO sqlalchemy.engine.Engine [cached since 0.02412s ago] ('ZH_0', 1, 0)
# 2025-07-04 23:27:13,079 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,080 INFO sqlalchemy.engine.Engine [cached since 0.02575s ago] ('ZH_0', 1, 0)
# 2025-07-04 23:27:13,080 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,080 INFO sqlalchemy.engine.Engine [cached since 0.02658s ago] ('ZH_0', 1, 0)
# 2025-07-04 23:27:13,081 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,081 INFO sqlalchemy.engine.Engine [cached since 0.0272s ago] ('ZH_0', 1, 0)
# 2025-07-04 23:27:13,081 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,082 INFO sqlalchemy.engine.Engine [cached since 0.02779s ago] ('ZH_0', 1, 0)
# 2025-07-04 23:27:13,082 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,082 INFO sqlalchemy.engine.Engine [cached since 0.02857s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:13,083 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,083 INFO sqlalchemy.engine.Engine [cached since 0.02921s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:13,084 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,084 INFO sqlalchemy.engine.Engine [cached since 0.02977s ago] ('ZH_1', 1, 0)
# 2025-07-04 23:27:13,084 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,084 INFO sqlalchemy.engine.Engine [cached since 0.03056s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:13,085 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,085 INFO sqlalchemy.engine.Engine [cached since 0.03125s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:13,086 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,086 INFO sqlalchemy.engine.Engine [cached since 0.03188s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:13,086 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,086 INFO sqlalchemy.engine.Engine [cached since 0.03247s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:13,087 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,087 INFO sqlalchemy.engine.Engine [cached since 0.03306s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:13,087 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,088 INFO sqlalchemy.engine.Engine [cached since 0.03384s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:13,088 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,088 INFO sqlalchemy.engine.Engine [cached since 0.03446s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:13,089 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,089 INFO sqlalchemy.engine.Engine [cached since 0.03499s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:13,089 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,089 INFO sqlalchemy.engine.Engine [cached since 0.03556s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:13,090 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,090 INFO sqlalchemy.engine.Engine [cached since 0.03619s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:13,090 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,091 INFO sqlalchemy.engine.Engine [cached since 0.03672s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:13,091 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,091 INFO sqlalchemy.engine.Engine [cached since 0.0374s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:13,092 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,092 INFO sqlalchemy.engine.Engine [cached since 0.038s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:13,092 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,092 INFO sqlalchemy.engine.Engine [cached since 0.03856s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:13,093 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,093 INFO sqlalchemy.engine.Engine [cached since 0.03922s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:13,094 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,096 INFO sqlalchemy.engine.Engine [cached since 0.04179s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:13,098 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,098 INFO sqlalchemy.engine.Engine [cached since 0.04449s ago] ('ZH_8', 1, 0)
# 2025-07-04 23:27:13,100 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,100 INFO sqlalchemy.engine.Engine [cached since 0.04641s ago] ('ZH_8', 1, 0)
# 2025-07-04 23:27:13,102 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,103 INFO sqlalchemy.engine.Engine [cached since 0.04921s ago] ('ZH_8', 1, 0)
# 2025-07-04 23:27:13,105 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,105 INFO sqlalchemy.engine.Engine [cached since 0.05112s ago] ('ZH_8', 1, 0)
# 2025-07-04 23:27:13,106 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,107 INFO sqlalchemy.engine.Engine [cached since 0.05285s ago] ('ZH_8', 1, 0)
# 2025-07-04 23:27:13,108 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,108 INFO sqlalchemy.engine.Engine [cached since 0.0545s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:13,110 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,110 INFO sqlalchemy.engine.Engine [cached since 0.05633s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:13,111 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,112 INFO sqlalchemy.engine.Engine [cached since 0.0581s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:13,113 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,114 INFO sqlalchemy.engine.Engine [cached since 0.05998s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:13,116 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,116 INFO sqlalchemy.engine.Engine [cached since 0.06235s ago] ('ZH_4', 1, 0)
# 2025-07-04 23:27:13,118 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,118 INFO sqlalchemy.engine.Engine [cached since 0.06436s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:13,119 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,119 INFO sqlalchemy.engine.Engine [cached since 0.0651s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:13,119 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,120 INFO sqlalchemy.engine.Engine [cached since 0.0658s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:13,120 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,120 INFO sqlalchemy.engine.Engine [cached since 0.06649s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:13,121 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,121 INFO sqlalchemy.engine.Engine [cached since 0.06716s ago] ('ZH_3', 1, 0)
# 2025-07-04 23:27:13,122 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,122 INFO sqlalchemy.engine.Engine [cached since 0.06811s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:13,122 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,123 INFO sqlalchemy.engine.Engine [cached since 0.06907s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:13,124 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,124 INFO sqlalchemy.engine.Engine [cached since 0.07055s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:13,126 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,126 INFO sqlalchemy.engine.Engine [cached since 0.0723s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:13,128 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,129 INFO sqlalchemy.engine.Engine [cached since 0.07472s ago] ('ZH_2', 1, 0)
# 2025-07-04 23:27:13,129 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,130 INFO sqlalchemy.engine.Engine [cached since 0.07582s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:13,130 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,130 INFO sqlalchemy.engine.Engine [cached since 0.07642s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:13,131 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,131 INFO sqlalchemy.engine.Engine [cached since 0.07708s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:13,131 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,131 INFO sqlalchemy.engine.Engine [cached since 0.07765s ago] ('ZH_5', 1, 0)
# 2025-07-04 23:27:13,132 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,132 INFO sqlalchemy.engine.Engine [cached since 0.07843s ago] ('ZH_9', 1, 0)
# 2025-07-04 23:27:13,133 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,133 INFO sqlalchemy.engine.Engine [cached since 0.07913s ago] ('ZH_9', 1, 0)
# 2025-07-04 23:27:13,133 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,133 INFO sqlalchemy.engine.Engine [cached since 0.07962s ago] ('ZH_9', 1, 0)
# 2025-07-04 23:27:13,134 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,134 INFO sqlalchemy.engine.Engine [cached since 0.0802s ago] ('ZH_9', 1, 0)
# 2025-07-04 23:27:13,134 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,135 INFO sqlalchemy.engine.Engine [cached since 0.08073s ago] ('ZH_9', 1, 0)
# 2025-07-04 23:27:13,135 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,135 INFO sqlalchemy.engine.Engine [cached since 0.08133s ago] ('ZH_9', 1, 0)
# 2025-07-04 23:27:13,136 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,136 INFO sqlalchemy.engine.Engine [generated in 0.00029s] ('ZH_1_G1', 'Énumérer avec 第 dì', "第 dì permet de former des chiffres et nombres ordinaux.\nIl s'emploie de la façon suivante :\n\n第 + chiffre/nombre ( + Classificateur )\n\n* 第一 dì yī ... (918 characters truncated) ... s deux mots suivants signifient « étage » et peuvent s'employer sans 第 dì :\n\n* 三楼 sān lóu : « Troisième étage »\n* 四层 sì céng : « Quatrième étage »", 0, '2025-07-04', 'ZH_1')
# 2025-07-04 23:27:13,137 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,137 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,138 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,138 INFO sqlalchemy.engine.Engine [generated in 0.00014s] ('ZH_1',)
# 2025-07-04 23:27:13,138 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,138 INFO sqlalchemy.engine.Engine [cached since 0.002319s ago] ('ZH_1_G2', 'Exprimer une distance avec 离 lí', "离 lí est utilisé lorsqu'on souhaite exprimer une distance entre deux points. Il peut se traduire par « par rapport à ». La structure à employer, très ... (589 characters truncated) ... ē zhàn lí zhèr tài yuǎn le : « La gare est trop éloignée d’ici »\n* 酒吧离我的家比较远 jiǔbā lí wǒ de jiā bǐjiào yuǎn : « Le bar est plutôt loin de chez moi »", 0, '2025-07-04', 'ZH_1')
# 2025-07-04 23:27:13,138 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,139 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,139 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,139 INFO sqlalchemy.engine.Engine [cached since 0.00181s ago] ('ZH_1',)
# 2025-07-04 23:27:13,140 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,140 INFO sqlalchemy.engine.Engine [cached since 0.003926s ago] ('ZH_1_G3', 'Se diriger, suivre un itinéraire', 'Savoir utiliser les termes « droite », « gauche » et « tout droit » suffit pour se repérer, demander son chemin et comprendre un itinéraire. Lorsqu’o ... (238 characters truncated) ... tout droit »\n* 你先往前走一百米，然后往左拐 nǐ xiān wǎng qián zǒu yī bǎi mǐ, ránhòu wǎng zuǒ guǎi : « Va d’abord tout droit sur 100 mètres, puis tourne à gauche »', 0, '2025-07-04', 'ZH_1')
# 2025-07-04 23:27:13,140 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,140 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,141 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,141 INFO sqlalchemy.engine.Engine [cached since 0.003134s ago] ('ZH_1',)
# 2025-07-04 23:27:13,141 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,141 INFO sqlalchemy.engine.Engine [cached since 0.005231s ago] ('ZH_1_G4', "À l'intérieur de quelque chose", 'Pour indiquer que quelque chose se situe à l’intérieur de quelque chose d’autre, on utilise la structure suivante :\n\nNom 1 + 在 + Nom 2 + 里面\n\n* 你在 ... (240 characters truncated) ...  shàng ma ? : « Es-tu dans le bus ? »\n* 我在车上 wǒ zài chē shàng : « Je suis dans la voiture »\n* 我在火车上 wǒ zài huǒchē shàng : « Je suis dans le train »', 0, '2025-07-04', 'ZH_1')
# 2025-07-04 23:27:13,141 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,142 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,142 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,142 INFO sqlalchemy.engine.Engine [cached since 0.004604s ago] ('ZH_6',)
# 2025-07-04 23:27:13,142 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,143 INFO sqlalchemy.engine.Engine [cached since 0.006707s ago] ('ZH_6_G1', 'Les démonstratifs 这 zhè et 那 nà', "Le démonstratif le plus couramment utilisé en chinois est 这 zhè.\n这 zhè va rarement être utilisé tout seul, il est souvent couplé avec d'autres carac ... (1057 characters truncated) ... à-bas, c'est... »\n* 那个/那个人 nà ge rén : « Cette personne-là »\n* 那里是我的朋友的家 nà lǐ shì wǒ de péngyou de jiā : « Là-bas se trouve la maison de mon ami »", 0, '2025-07-04', 'ZH_6')
# 2025-07-04 23:27:13,143 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,143 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,144 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,144 INFO sqlalchemy.engine.Engine [cached since 0.006113s ago] ('ZH_6',)
# 2025-07-04 23:27:13,144 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,144 INFO sqlalchemy.engine.Engine [cached since 0.008243s ago] ('ZH_6_G2', 'Autres utilisations du caractère 的 de', "的 de, le caractère permettant de marquer la possession, peut s'utiliser à la suite d'un pronom personnel (ex. 我的 wǒ de « mon ») ou d'un nom (ex. 老师的书 ... (937 characters truncated) ... ncài : « C'est le plat que j'aime faire/préparer »\n* 这是我去年去的地方 zhè shì wǒ qùnián qù de dìfang : « C'est l'endroit où je suis allé l'année dernière »", 0, '2025-07-04', 'ZH_6')
# 2025-07-04 23:27:13,144 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,145 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,145 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,145 INFO sqlalchemy.engine.Engine [cached since 0.007604s ago] ('ZH_6',)
# 2025-07-04 23:27:13,145 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,146 INFO sqlalchemy.engine.Engine [cached since 0.00973s ago] ('ZH_6_G3', 'Exprimer "avec" à l\'aide de 跟 gēn et 一起 yīqǐ', "La préposition 跟 gēn, souvent utilisée avec 一起 yīqǐ (signifiant « ensemble »), permet de marquer l'accompagnement :\n\n* 我跟你去 wǒ gēn nǐ qù : « J'y va ... (142 characters truncated) ... gēn tā yīqǐ qù le gōngyuán : « Je suis allé au parc avec lui hier »\n* 我跟我的女朋友一起住 wǒ gēn wǒ de nǚ péngyou yīqǐ zhù : « J'habite avec ma petite amie »", 0, '2025-07-04', 'ZH_6')
# 2025-07-04 23:27:13,146 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,146 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,146 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,146 INFO sqlalchemy.engine.Engine [cached since 0.008941s ago] ('ZH_6',)
# 2025-07-04 23:27:13,147 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,147 INFO sqlalchemy.engine.Engine [cached since 0.01101s ago] ('ZH_6_G4', 'Les caractères ayant plusieurs prononciations', "Vous aurez certainement remarqué que certains caractères peuvent avoir plusieurs prononciations. Le changement de prononciation peut faire varier ou  ... (198 characters truncated) ...  : trouver que\n* 睡觉 shuìjiào : dormir\n\nCertains caractères comme le 都 de 首都 « la capitale » peuvent changer à la fois de prononciation et de sens.", 0, '2025-07-04', 'ZH_6')
# 2025-07-04 23:27:13,147 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,147 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,148 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,148 INFO sqlalchemy.engine.Engine [cached since 0.01024s ago] ('ZH_7',)
# 2025-07-04 23:27:13,148 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,148 INFO sqlalchemy.engine.Engine [cached since 0.01232s ago] ('ZH_7_G1', 'Comparer avec 比 bi ou 没有 méiyǒu', "**Utilisation de 比 bi**\nLe caractère 比 bǐ est utilisé en tant que comparatif de supériorité ou d'infériorité (et non d'égalité). Il peut être tradui ... (740 characters truncated) ...  : « Il est plus petit que moi » (littéralement « Il n'a pas ma taille »)\n* 妈妈没有爸爸高 māma méiyǒu bàba gāo : « Maman n'est pas aussi grande que papa »", 0, '2025-07-04', 'ZH_7')
# 2025-07-04 23:27:13,148 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,149 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,149 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,149 INFO sqlalchemy.engine.Engine [cached since 0.01157s ago] ('ZH_7',)
# 2025-07-04 23:27:13,149 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,149 INFO sqlalchemy.engine.Engine [cached since 0.01367s ago] ('ZH_7_G2', 'Interrogatif 谁 shéi/shuí', "谁 shéi est l'interrogatif signifiant « Qui ? ». Comme tous les mots interrogatifs, il se place à l'endroit où se trouvera la réponse :\n\n* 你是谁？ Nǐ s ... (401 characters truncated) ...  » et ne doit pas traduire le pronom relatif « qui » dans des phrases comme « La personne qui habite ici ». Pour cela, on utilise 的 de (cf. Leçon 6).", 0, '2025-07-04', 'ZH_7')
# 2025-07-04 23:27:13,150 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,150 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,150 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,150 INFO sqlalchemy.engine.Engine [cached since 0.01283s ago] ('ZH_7',)
# 2025-07-04 23:27:13,151 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,151 INFO sqlalchemy.engine.Engine [cached since 0.01493s ago] ('ZH_7_G3', 'Quelle(s) langue(s) sais-tu parler ?', "En général, on forme le nom d'une langue en ajoutant 语 yǔ (ou 文 wén) au nom du pays.\n\nPour les pays finissant par 国 guó, on remplace 国 guó par 语 yǔ ... (342 characters truncated) ... :\n\n* 中国 Zhōngguó (Chine) → 中文 Zhōngwén (chinois)\n* 汉语 Hànyǔ (chinois)\n\nNote : 汉语 Hànyǔ (chinois) et 韩语 Hányǔ (coréen) se prononcent très proche.", 0, '2025-07-04', 'ZH_7')
# 2025-07-04 23:27:13,151 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,151 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,152 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,152 INFO sqlalchemy.engine.Engine [cached since 0.01412s ago] ('ZH_7',)
# 2025-07-04 23:27:13,152 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,152 INFO sqlalchemy.engine.Engine [cached since 0.01618s ago] ('ZH_7_G4', 'Les adverbes 最 zuì et 太 ... 了 tài...le', "Les adverbes 最 zuì et 太 ... 了 tài...le s'emploient comme 很 hěn devant un adjectif, mais nuancent ou renforcent le propos :\n\n* 我很累 wǒ hěn lèi : « Je ... (11 characters truncated) ... ué »\n* 最累 zuì lèi : « Le plus fatigué »\n* 我太累了 wǒ tài lèi le : « Je suis trop fatigué »\n* 我不太累了 wǒ bù tài lèi le : « Je ne suis pas trop fatigué »", 0, '2025-07-04', 'ZH_7')
# 2025-07-04 23:27:13,152 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,153 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,153 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,153 INFO sqlalchemy.engine.Engine [cached since 0.01545s ago] ('ZH_7',)
# 2025-07-04 23:27:13,153 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,153 INFO sqlalchemy.engine.Engine [cached since 0.01754s ago] ('ZH_7_G5', 'Tout, toutes et tous avec 都 dōu', 'Le caractère 都 peut se prononcer « dū » (dans 首都 shǒudū « capitale ») ou « dōu » quand il signifie « tout, tous ». Il se place directement après le n ... (122 characters truncated) ... ōu xiǎng qù Zhōngguó : « Nous voulons tous aller en Chine »\n* 我的朋友都 wǒ de péngyou dōu : « Tous mes amis »\n* 女生都 nǚshēng dōu : « Toutes les filles »', 0, '2025-07-04', 'ZH_7')
# 2025-07-04 23:27:13,154 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,154 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,154 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,154 INFO sqlalchemy.engine.Engine [cached since 0.01676s ago] ('ZH_7',)
# 2025-07-04 23:27:13,155 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,155 INFO sqlalchemy.engine.Engine [cached since 0.01885s ago] ('ZH_7_G6', 'Ensemble avec 一起 yīqǐ', '一起 yīqǐ a déjà été vu dans la structure 跟 gēn ... + 一起 yīqǐ (page 109) pour dire « avec ». 一起 yīqǐ peut aussi être utilisé seul et signifie « ensembl ... (50 characters truncated) ...  Elles vont regarder un film ensemble »\n* 我们一起去北京 wǒmen yīqǐ qù Běijīng : « Nous allons ensemble à Pékin »\n\nStructure : Sujet + 一起 + Verbe + Objet', 0, '2025-07-04', 'ZH_7')
# 2025-07-04 23:27:13,155 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,155 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,155 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,156 INFO sqlalchemy.engine.Engine [cached since 0.01803s ago] ('ZH_0',)
# 2025-07-04 23:27:13,156 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,156 INFO sqlalchemy.engine.Engine [cached since 0.0201s ago] ('ZH_0_G1', 'Indiquer le destinataire avec 给 gěi', "给 gěi, signifiant « donner », permet d'indiquer la cible d'une action.\n\nStructure : Sujet + 给 + cible + action\n\n* 你给我打电话 nǐ gěi wǒ dǎ diànhuà : « ... (45 characters truncated) ... i tā dǎ diànhuà : « Tu dois lui téléphoner »\n* 你给他写信 nǐ gěi tā xiěxìn : « Écris-lui une lettre »\n* 我给你做饭 wǒ gěi nǐ zuòfàn : « Je te fais à manger »", 0, '2025-07-04', 'ZH_0')
# 2025-07-04 23:27:13,156 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,156 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,157 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,157 INFO sqlalchemy.engine.Engine [cached since 0.01924s ago] ('ZH_0',)
# 2025-07-04 23:27:13,157 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,157 INFO sqlalchemy.engine.Engine [cached since 0.02135s ago] ('ZH_0_G2', '"Pouvoir" avec 能 néng ou 可以 kěyǐ', "Plusieurs verbes existent pour exprimer la possibilité, cependant ils ne peuvent pas s'employer de la même manière. Nous avons déjà étudié le verbe 会 ... (795 characters truncated) ... 停车吗？wǒ zài zhèr kěyǐ tíngchē ma ? : « Puis-je garer ma voiture ici ? »\n* 妈妈，我可以出去吗？māma, wǒ kěyǐ chūqù ma ? : « Maman, est-ce que je peux sortir ? »", 0, '2025-07-04', 'ZH_0')
# 2025-07-04 23:27:13,157 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,158 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,158 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,158 INFO sqlalchemy.engine.Engine [cached since 0.02061s ago] ('ZH_0',)
# 2025-07-04 23:27:13,158 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,158 INFO sqlalchemy.engine.Engine [cached since 0.02268s ago] ('ZH_0_G3', 'La condition avec 如果 ... 的话 rúguǒ ... de huà et 就 jiù', "如果 ... 的话 rúguǒ ... de huà et 就 jiù sont utilisés, ensemble ou séparément, afin d'introduire une condition et sa conséquence.\n\nStructure : 如果 + Suj ... (135 characters truncated) ... , appelle le médecin »\n* 如果他生病的话，他就不能去工作 rúguǒ tā shēngbìng de huà, tā jiù bù néng qù gōngzuò : « S'il est malade, il ne peut pas aller travailler »", 0, '2025-07-04', 'ZH_0')
# 2025-07-04 23:27:13,159 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,159 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,159 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,159 INFO sqlalchemy.engine.Engine [cached since 0.02191s ago] ('ZH_0',)
# 2025-07-04 23:27:13,160 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,160 INFO sqlalchemy.engine.Engine [cached since 0.02406s ago] ('ZH_0_G4', "Le comparatif d'égalité", "Nous avons étudié dans la leçon 7 les comparatifs de supériorité ou d'infériorité en utilisant le caractère 比 bǐ. Il ne faut pas employer 比 pour intr ... (338 characters truncated) ... la mienne »\n* 今天的会议和昨天的会议一样无聊 jīntiān de huìyì hé zuótiān de huìyì yīyàng wúliáo : « La réunion d'aujourd'hui est aussi ennuyeuse que celle d'hier »", 0, '2025-07-04', 'ZH_0')
# 2025-07-04 23:27:13,160 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,161 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,161 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,161 INFO sqlalchemy.engine.Engine [cached since 0.02331s ago] ('ZH_0',)
# 2025-07-04 23:27:13,161 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,161 INFO sqlalchemy.engine.Engine [cached since 0.02544s ago] ('ZH_0_G5', '"Encore, toujours" avec 还 hái', "还 hái peut être utilisé seul ou bien accompagné de 在 zài pour marquer qu'une action est « encore, toujours » en cours. On peut aussi l'utiliser avec  ... (391 characters truncated) ... »\n* 我还不会说中文 wǒ hái bù huì shuō zhōngwén : « Je ne sais toujours pas parler chinois »\n* 我还没有吃饭 wǒ hái méiyǒu chīfàn : « Je n'ai toujours pas mangé »", 0, '2025-07-04', 'ZH_0')
# 2025-07-04 23:27:13,162 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,162 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,162 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,162 INFO sqlalchemy.engine.Engine [cached since 0.02472s ago] ('ZH_0',)
# 2025-07-04 23:27:13,162 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,163 INFO sqlalchemy.engine.Engine [cached since 0.02683s ago] ('ZH_0_G6', '"Venir" avec 来 lái', "Le verbe 来 lái signifie « venir » et doit être utilisé lorsque l'on se rapproche de son interlocuteur.\n\n* 你来饭馆吃饭吗？nǐ lái fànguǎn chīfàn ma ? : « Vi ... (214 characters truncated) ... inverse, si l'interlocuteur s'éloigne, on utilisera le verbe 去 qù (« aller »), car il indique un déplacement vers un lieu éloigné de celui qui parle.", 0, '2025-07-04', 'ZH_0')
# 2025-07-04 23:27:13,163 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,163 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,163 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,164 INFO sqlalchemy.engine.Engine [cached since 0.02602s ago] ('ZH_1',)
# 2025-07-04 23:27:13,164 INFO sqlalchemy.engine.Engine SELECT grammar_rule.grammar_id AS grammar_rule_grammar_id, grammar_rule.grammar_title AS grammar_rule_grammar_title, grammar_rule.explanation AS grammar_rule_explanation, grammar_rule.score AS grammar_rule_score, grammar_rule.last_seen AS grammar_rule_last_seen, grammar_rule.unit_id AS grammar_rule_unit_id
# FROM grammar_rule
# WHERE grammar_rule.grammar_id = ?
# 2025-07-04 23:27:13,164 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('ZH_1_G1',)
# 2025-07-04 23:27:13,165 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,165 INFO sqlalchemy.engine.Engine [cached since 0.02903s ago] ('ZH_1_G1', 'Conjuguer', 'Une des facilités de la langue chinoise est qu’elle ne contient pas de conjugaison. Conjuguer le verbe être se résume à :\n\n- 我是 (wǒ shì) : Je suis\ ... (318 characters truncated) ... . Si les verbes chinois ne se conjuguent pas, il existe tout de même quelques particules et suffixes verbaux permettant de contextualiser une phrase.', 0, '2025-07-04', 'ZH_1')
# 2025-07-04 23:27:13,165 INFO sqlalchemy.engine.Engine ROLLBACK
# /var/folders/5p/bjh6crbn6fv0vtxy5sqmmxh00000gn/T/ipykernel_6471/2044141348.py:24: SAWarning: Object of type <GrammarRule> not in session, add operation along 'Unit.grammars' will not proceed (This warning originated from the Session 'autoflush' process, which was invoked automatically in response to a user-initiated operation. Consider using ``no_autoflush`` context manager if this warning happended while initializing objects.)
#   parent=session.query(Unit).filter(Unit.unit_id == f"{language_name.upper()}_{unit_id}").first()
# /Users/noe_jager/Documents/GitHub/vocabulary-dbms/src/lapp/dbms.py:74: SAWarning: Object of type <GrammarRule> not in session, add operation along 'Unit.grammars' will not proceed
#   session.commit()
# ...
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,284 INFO sqlalchemy.engine.Engine [cached since 0.1463s ago] ('ZH_5',)
# 2025-07-04 23:27:13,284 INFO sqlalchemy.engine.Engine UPDATE grammar_rule SET grammar_title=?, explanation=? WHERE grammar_rule.grammar_id = ?
# 2025-07-04 23:27:13,284 INFO sqlalchemy.engine.Engine [cached since 0.1171s ago] ('Énumérer avec 和 hé', "Le caractère 和 hé permet d'énumérer des noms communs. Nous pouvons traduire par « ainsi que », son emploi diffère donc du « et » français.\n\n* 我 的 妈 ... (132 characters truncated) ... n papa et moi »\n\n和 hé ne peut pas être utilisé pour lier deux phrases comme en français (ex. Ce matin je travaille et cet après-midi je me repose).", 'ZH_5_G2')
# 2025-07-04 23:27:13,285 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,285 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,285 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,285 INFO sqlalchemy.engine.Engine [cached since 0.1477s ago] ('ZH_5',)
# 2025-07-04 23:27:13,286 INFO sqlalchemy.engine.Engine SELECT grammar_rule.grammar_id AS grammar_rule_grammar_id, grammar_rule.grammar_title AS grammar_rule_grammar_title, grammar_rule.explanation AS grammar_rule_explanation, grammar_rule.score AS grammar_rule_score, grammar_rule.last_seen AS grammar_rule_last_seen, grammar_rule.unit_id AS grammar_rule_unit_id
# FROM grammar_rule
# WHERE grammar_rule.grammar_id = ?
# 2025-07-04 23:27:13,286 INFO sqlalchemy.engine.Engine [cached since 0.1215s ago] ('ZH_5_G3',)
# 2025-07-04 23:27:13,286 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,286 INFO sqlalchemy.engine.Engine [cached since 0.1503s ago] ('ZH_5_G3', 'Le caractère 的 de', "Le premier sens de 的 de est le possessif. L'ajout du caractère 的 de aux pronoms personnels permet de former les pronoms possessifs :\n\nPronom person ... (638 characters truncated) ...  de Chine »\n\nDéterminant + 的 + déterminé\n\nLe contexte est indispensable pour comprendre le sens qu'il a dans une phrase, un texte ou un dialogue.", 0, '2025-07-04', 'ZH_5')
# 2025-07-04 23:27:13,286 INFO sqlalchemy.engine.Engine ROLLBACK
# /Users/noe_jager/Documents/GitHub/vocabulary-dbms/src/lapp/dbms.py:74: SAWarning: New instance <GrammarRule at 0x10c602600> with identity key (<class 'lapp.tables.GrammarRule'>, ('ZH_5_G3',), None) conflicts with persistent instance <GrammarRule at 0x10c6016a0>
#   session.commit()
# Insert failed: (sqlite3.IntegrityError) UNIQUE constraint failed: grammar_rule.grammar_id
# [SQL: INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)]
# [parameters: ('ZH_5_G3', 'Le caractère 的 de', "Le premier sens de 的 de est le possessif. L'ajout du caractère 的 de aux pronoms personnels permet de former les pronoms possessifs :\n\nPronom person ... (638 characters truncated) ...  de Chine »\n\nDéterminant + 的 + déterminé\n\nLe contexte est indispensable pour comprendre le sens qu'il a dans une phrase, un texte ou un dialogue.", 0, '2025-07-04', 'ZH_5')]
# (Background on this error at: https://sqlalche.me/e/20/gkpj). Attempting to modify an existing record.
# 2025-07-04 23:27:13,287 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,287 INFO sqlalchemy.engine.Engine SELECT grammar_rule.grammar_id AS grammar_rule_grammar_id, grammar_rule.grammar_title AS grammar_rule_grammar_title, grammar_rule.explanation AS grammar_rule_explanation, grammar_rule.score AS grammar_rule_score, grammar_rule.last_seen AS grammar_rule_last_seen, grammar_rule.unit_id AS grammar_rule_unit_id
# FROM grammar_rule
# WHERE grammar_rule.grammar_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,287 INFO sqlalchemy.engine.Engine [cached since 0.1213s ago] ('ZH_5_G3', 1, 0)
# 2025-07-04 23:27:13,287 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,288 INFO sqlalchemy.engine.Engine [cached since 0.15s ago] ('ZH_5',)
# 2025-07-04 23:27:13,288 INFO sqlalchemy.engine.Engine UPDATE grammar_rule SET grammar_title=?, explanation=? WHERE grammar_rule.grammar_id = ?
# 2025-07-04 23:27:13,288 INFO sqlalchemy.engine.Engine [cached since 0.1208s ago] ('Le caractère 的 de', "Le premier sens de 的 de est le possessif. L'ajout du caractère 的 de aux pronoms personnels permet de former les pronoms possessifs :\n\nPronom person ... (638 characters truncated) ...  de Chine »\n\nDéterminant + 的 + déterminé\n\nLe contexte est indispensable pour comprendre le sens qu'il a dans une phrase, un texte ou un dialogue.", 'ZH_5_G3')
# 2025-07-04 23:27:13,288 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,289 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,289 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,289 INFO sqlalchemy.engine.Engine [cached since 0.1518s ago] ('ZH_5',)
# 2025-07-04 23:27:13,290 INFO sqlalchemy.engine.Engine SELECT grammar_rule.grammar_id AS grammar_rule_grammar_id, grammar_rule.grammar_title AS grammar_rule_grammar_title, grammar_rule.explanation AS grammar_rule_explanation, grammar_rule.score AS grammar_rule_score, grammar_rule.last_seen AS grammar_rule_last_seen, grammar_rule.unit_id AS grammar_rule_unit_id
# FROM grammar_rule
# WHERE grammar_rule.grammar_id = ?
# 2025-07-04 23:27:13,290 INFO sqlalchemy.engine.Engine [cached since 0.1257s ago] ('ZH_5_G4',)
# 2025-07-04 23:27:13,290 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,290 INFO sqlalchemy.engine.Engine [cached since 0.1544s ago] ('ZH_5_G4', 'Les différentes utilisations de 要 yào', "Le premier sens de 要 yào est le verbe « vouloir ».\n\n* 我 要 工作 wǒ yào gōngzuò : « Je veux travailler »\n* 我 要 吃饭 wǒ yào chīfàn : « Je veux manger »\n ... (31 characters truncated) ... enir est la suivante :\n\nIl peut également avoir d'autres sens, tels que « devoir », « falloir » ou encore « aller faire/être sur le point de ... ».", 0, '2025-07-04', 'ZH_5')
# 2025-07-04 23:27:13,290 INFO sqlalchemy.engine.Engine ROLLBACK
# /Users/noe_jager/Documents/GitHub/vocabulary-dbms/src/lapp/dbms.py:74: SAWarning: New instance <GrammarRule at 0x10c6021e0> with identity key (<class 'lapp.tables.GrammarRule'>, ('ZH_5_G4',), None) conflicts with persistent instance <GrammarRule at 0x10c601a30>
#   session.commit()
# Insert failed: (sqlite3.IntegrityError) UNIQUE constraint failed: grammar_rule.grammar_id
# [SQL: INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)]
# [parameters: ('ZH_5_G4', 'Les différentes utilisations de 要 yào', "Le premier sens de 要 yào est le verbe « vouloir ».\n\n* 我 要 工作 wǒ yào gōngzuò : « Je veux travailler »\n* 我 要 吃饭 wǒ yào chīfàn : « Je veux manger »\n ... (31 characters truncated) ... enir est la suivante :\n\nIl peut également avoir d'autres sens, tels que « devoir », « falloir » ou encore « aller faire/être sur le point de ... ».", 0, '2025-07-04', 'ZH_5')]
# (Background on this error at: https://sqlalche.me/e/20/gkpj). Attempting to modify an existing record.
# 2025-07-04 23:27:13,291 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,291 INFO sqlalchemy.engine.Engine SELECT grammar_rule.grammar_id AS grammar_rule_grammar_id, grammar_rule.grammar_title AS grammar_rule_grammar_title, grammar_rule.explanation AS grammar_rule_explanation, grammar_rule.score AS grammar_rule_score, grammar_rule.last_seen AS grammar_rule_last_seen, grammar_rule.unit_id AS grammar_rule_unit_id
# FROM grammar_rule
# WHERE grammar_rule.grammar_id = ?
#  LIMIT ? OFFSET ?
# 2025-07-04 23:27:13,291 INFO sqlalchemy.engine.Engine [cached since 0.1253s ago] ('ZH_5_G4', 1, 0)
# 2025-07-04 23:27:13,291 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,291 INFO sqlalchemy.engine.Engine [cached since 0.154s ago] ('ZH_5',)
# 2025-07-04 23:27:13,292 INFO sqlalchemy.engine.Engine UPDATE grammar_rule SET grammar_title=?, explanation=? WHERE grammar_rule.grammar_id = ?
# 2025-07-04 23:27:13,292 INFO sqlalchemy.engine.Engine [cached since 0.1248s ago] ('Les différentes utilisations de 要 yào', "Le premier sens de 要 yào est le verbe « vouloir ».\n\n* 我 要 工作 wǒ yào gōngzuò : « Je veux travailler »\n* 我 要 吃饭 wǒ yào chīfàn : « Je veux manger »\n ... (31 characters truncated) ... enir est la suivante :\n\nIl peut également avoir d'autres sens, tels que « devoir », « falloir » ou encore « aller faire/être sur le point de ... ».", 'ZH_5_G4')
# 2025-07-04 23:27:13,292 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,293 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,293 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,293 INFO sqlalchemy.engine.Engine [cached since 0.1555s ago] ('ZH_9',)
# 2025-07-04 23:27:13,293 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,294 INFO sqlalchemy.engine.Engine [cached since 0.1578s ago] ('ZH_9_G1', 'Moyens de transport', "Si en français nous employons généralement le verbe « prendre » lorsqu'il s'agit des moyens de transport, il convient d'utiliser le verbe 坐 zuò « s'a ... (471 characters truncated) ...  véhicule, il faut employer 开 kāi « conduire, ouvrir » :\n\n* 我开车 wǒ kāi chē : « Je conduis la voiture »\n* 我开飞机 wǒ kāi fēijī : « Je pilote l'avion »", 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:13,294 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,294 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,294 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,294 INFO sqlalchemy.engine.Engine [cached since 0.157s ago] ('ZH_9',)
# 2025-07-04 23:27:13,295 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,295 INFO sqlalchemy.engine.Engine [cached since 0.159s ago] ('ZH_9_G2', '"Chaque" avec 每 měi', '每 měi est employé dans la majorité des cas avec un classificateur derrière :\n\n* 每个人 měi gè rén : « Chaque personne »\n* 每个月 měi gè yuè : « Chaque m ... (100 characters truncated) ... it pas être employé dans les trois cas suivants :\n\n* 每年 měi nián : « Chaque année »\n* 每天 měi tiān : « Chaque jour »\n* 每日 měi rì : « Chaque jour »', 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:13,295 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,295 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,296 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,296 INFO sqlalchemy.engine.Engine [cached since 0.1583s ago] ('ZH_9',)
# 2025-07-04 23:27:13,296 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,296 INFO sqlalchemy.engine.Engine [cached since 0.1603s ago] ('ZH_9_G3', '"D\'abord... ensuite..." avec 先 xiān et 然后 ránhòu', "先 xiān « premièrement », et 然后 ránhòu « ensuite » peuvent être utilisés ensemble pour indiquer que deux événements se succèdent :\n\n* 我们先吃饭，然后看电视 wǒ ... (220 characters truncated) ... emièrement » peut également être utilisé seul :\n\n* 他先到了 tā xiān dào le : « Il est arrivé en premier »\n* 我先说 wǒ xiān shuō : « Je parle en premier »", 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:13,296 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,297 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,297 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,297 INFO sqlalchemy.engine.Engine [cached since 0.1595s ago] ('ZH_9',)
# 2025-07-04 23:27:13,297 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,297 INFO sqlalchemy.engine.Engine [cached since 0.1616s ago] ('ZH_9_G4', '"Un petit peu" avec 有点儿 yǒu diǎnr ou 一点儿 yī diǎnr', "**有点儿 yǒu diǎnr**\n有点儿 yǒu diǎnr ou simplement 有点 yǒu diǎn est utilisé avant un adjectif. Il est généralement employé dans des phrases négatives, pou ... (499 characters truncated) ... 宜一点儿 nǐ piányi yī diǎnr : « Baisse un peu le prix »\n* 你快一点儿 nǐ kuài yī diǎnr : « Dépêche-toi un peu »\n* 你慢一点儿 nǐ màn yī diǎnr : « Ralentis un peu »", 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:13,298 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,298 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,299 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,299 INFO sqlalchemy.engine.Engine [cached since 0.1612s ago] ('ZH_9',)
# 2025-07-04 23:27:13,299 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,299 INFO sqlalchemy.engine.Engine [cached since 0.1633s ago] ('ZH_9_G5', 'Utiliser 比较 bǐjiào devant un verbe', "Nous avons vu dans la leçon précédente que l'adverbe 比较 bǐjiào signifie « relativement, plutôt » et qu'il était employé devant un adjectif afin de le ... (162 characters truncated) ... iào xǐhuan : « Je préfère »\n* 我不喜欢坐车，我比较喜欢走路 wǒ bù xǐhuan zuò chē, wǒ bǐjiào xǐhuan zǒulù : « Je n'aime pas prendre la voiture, je préfère marcher »", 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:13,299 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-04 23:27:13,300 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-04 23:27:13,300 INFO sqlalchemy.engine.Engine SELECT unit.unit_id AS unit_unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level
# FROM unit
# WHERE unit.unit_id = ?
# 2025-07-04 23:27:13,300 INFO sqlalchemy.engine.Engine [cached since 0.1626s ago] ('ZH_9',)
# 2025-07-04 23:27:13,300 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (grammar_id, grammar_title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-04 23:27:13,301 INFO sqlalchemy.engine.Engine [cached since 0.1647s ago] ('ZH_9_G6', 'Les particules modales placées en fin de phrase', 'Quelques particules modales sont habituellement rajoutées en fin de phrase pour donner un ton particulier à la phrase, en voici quelques exemples :\n ... (334 characters truncated) ... .\n\nIl existe également des interjections placées en début de phrase :\n\n* 嗯 en : équivalent du « hum... » français\n* 哎呀 āiyā : marque la surprise', 0, '2025-07-04', 'ZH_9')
# 2025-07-04 23:27:13,301 INFO sqlalchemy.engine.Engine COMMIT
