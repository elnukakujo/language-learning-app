# %%
import json
import pandas as pd
import os
import re
from lapp.dbms import init_db, inserts, modify, delete, find_by_attr, insert
from lapp.tables import Unit, Vocabulary, GrammarRule, Language, CalligraphyCharacter

# %%
language_id = "zh"

# %% [markdown]
# ## Create a Language

# %%
engine, session = init_db()

if not os.path.exists("../db"):
    os.makedirs("../db")
    print(f"Created directory for database: ../db")

language = Language(
    id=language_id.upper(),
    name="Chinois",
    native_name="中文",
    level="A1",
    flag="🇨🇳"
)
insert(session, language)

session.close()
# Out:
# 2025-07-09 18:44:07,737 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:07,737 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("language")
# 2025-07-09 18:44:07,737 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:07,738 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("language")
# 2025-07-09 18:44:07,738 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:07,738 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-09 18:44:07,738 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:07,738 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("unit")
# 2025-07-09 18:44:07,739 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:07,739 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-09 18:44:07,739 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:07,739 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("calligraphy_character")
# 2025-07-09 18:44:07,739 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:07,739 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-09 18:44:07,739 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:07,740 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("grammar_rule")
# 2025-07-09 18:44:07,740 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:07,740 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-09 18:44:07,740 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:07,740 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("vocabulary")
# 2025-07-09 18:44:07,740 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:07,740 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-09 18:44:07,741 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:07,741 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("exercises")
# 2025-07-09 18:44:07,741 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:07,741 INFO sqlalchemy.engine.Engine
# CREATE TABLE language (
# 	id VARCHAR NOT NULL,
# 	name VARCHAR,
# 	native_name VARCHAR,
# 	level VARCHAR,
# 	description VARCHAR,
# 	score INTEGER,
# 	last_seen DATE,
# 	flag VARCHAR,
# 	current_unit VARCHAR,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(current_unit) REFERENCES unit (id)
# )
#
#
# 2025-07-09 18:44:07,742 INFO sqlalchemy.engine.Engine [no key 0.00013s] ()
# 2025-07-09 18:44:07,742 INFO sqlalchemy.engine.Engine CREATE INDEX ix_language_id ON language (id)
# 2025-07-09 18:44:07,742 INFO sqlalchemy.engine.Engine [no key 0.00009s] ()
# 2025-07-09 18:44:07,743 INFO sqlalchemy.engine.Engine CREATE INDEX ix_language_name ON language (name)
# 2025-07-09 18:44:07,743 INFO sqlalchemy.engine.Engine [no key 0.00010s] ()
# 2025-07-09 18:44:07,743 INFO sqlalchemy.engine.Engine
# CREATE TABLE unit (
# 	id VARCHAR NOT NULL,
# 	title VARCHAR,
# 	description VARCHAR,
# 	level VARCHAR,
# 	score INTEGER,
# 	language_id VARCHAR NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(language_id) REFERENCES language (id)
# )
#
#
# 2025-07-09 18:44:07,743 INFO sqlalchemy.engine.Engine [no key 0.00018s] ()
# 2025-07-09 18:44:07,744 INFO sqlalchemy.engine.Engine CREATE INDEX ix_unit_id ON unit (id)
# 2025-07-09 18:44:07,744 INFO sqlalchemy.engine.Engine [no key 0.00013s] ()
# 2025-07-09 18:44:07,744 INFO sqlalchemy.engine.Engine CREATE INDEX ix_unit_title ON unit (title)
# 2025-07-09 18:44:07,744 INFO sqlalchemy.engine.Engine [no key 0.00012s] ()
# 2025-07-09 18:44:07,745 INFO sqlalchemy.engine.Engine
# CREATE TABLE calligraphy_character (
# 	id VARCHAR NOT NULL,
# 	character VARCHAR,
# 	components VARCHAR,
# 	phonetic VARCHAR,
# 	meaning VARCHAR,
# 	example_word VARCHAR,
# 	score INTEGER,
# 	last_seen DATE,
# 	unit_id VARCHAR NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(unit_id) REFERENCES unit (id)
# )
#
#
# 2025-07-09 18:44:07,745 INFO sqlalchemy.engine.Engine [no key 0.00011s] ()
# 2025-07-09 18:44:07,745 INFO sqlalchemy.engine.Engine CREATE INDEX ix_calligraphy_character_character ON calligraphy_character (character)
# 2025-07-09 18:44:07,746 INFO sqlalchemy.engine.Engine [no key 0.00011s] ()
# 2025-07-09 18:44:07,746 INFO sqlalchemy.engine.Engine CREATE INDEX ix_calligraphy_character_id ON calligraphy_character (id)
# 2025-07-09 18:44:07,746 INFO sqlalchemy.engine.Engine [no key 0.00011s] ()
# 2025-07-09 18:44:07,747 INFO sqlalchemy.engine.Engine
# CREATE TABLE grammar_rule (
# 	id VARCHAR NOT NULL,
# 	title VARCHAR,
# 	explanation VARCHAR,
# 	score INTEGER,
# 	last_seen DATE,
# 	unit_id VARCHAR NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(unit_id) REFERENCES unit (id)
# )
#
#
# 2025-07-09 18:44:07,747 INFO sqlalchemy.engine.Engine [no key 0.00021s] ()
# 2025-07-09 18:44:07,747 INFO sqlalchemy.engine.Engine CREATE INDEX ix_grammar_rule_id ON grammar_rule (id)
# 2025-07-09 18:44:07,747 INFO sqlalchemy.engine.Engine [no key 0.00009s] ()
# 2025-07-09 18:44:07,748 INFO sqlalchemy.engine.Engine CREATE INDEX ix_grammar_rule_title ON grammar_rule (title)
# 2025-07-09 18:44:07,748 INFO sqlalchemy.engine.Engine [no key 0.00010s] ()
# 2025-07-09 18:44:07,748 INFO sqlalchemy.engine.Engine
# CREATE TABLE vocabulary (
# 	id VARCHAR NOT NULL,
# 	word VARCHAR,
# 	translation VARCHAR,
# 	phonetic VARCHAR,
# 	example_sentence VARCHAR,
# 	type VARCHAR,
# 	score INTEGER,
# 	last_seen DATE,
# 	unit_id VARCHAR NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(unit_id) REFERENCES unit (id)
# )
#
#
# 2025-07-09 18:44:07,748 INFO sqlalchemy.engine.Engine [no key 0.00010s] ()
# 2025-07-09 18:44:07,749 INFO sqlalchemy.engine.Engine CREATE INDEX ix_vocabulary_id ON vocabulary (id)
# 2025-07-09 18:44:07,749 INFO sqlalchemy.engine.Engine [no key 0.00010s] ()
# 2025-07-09 18:44:07,749 INFO sqlalchemy.engine.Engine CREATE INDEX ix_vocabulary_word ON vocabulary (word)
# 2025-07-09 18:44:07,749 INFO sqlalchemy.engine.Engine [no key 0.00011s] ()
# 2025-07-09 18:44:07,750 INFO sqlalchemy.engine.Engine
# CREATE TABLE exercises (
# 	id VARCHAR NOT NULL,
# 	exercise_type VARCHAR,
# 	question VARCHAR,
# 	support VARCHAR,
# 	answer VARCHAR,
# 	score INTEGER,
# 	last_seen DATE,
# 	unit_id VARCHAR NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(unit_id) REFERENCES unit (id)
# )
#
#
# 2025-07-09 18:44:07,750 INFO sqlalchemy.engine.Engine [no key 0.00016s] ()
# 2025-07-09 18:44:07,751 INFO sqlalchemy.engine.Engine CREATE INDEX ix_exercises_exercise_type ON exercises (exercise_type)
# 2025-07-09 18:44:07,751 INFO sqlalchemy.engine.Engine [no key 0.00009s] ()
# 2025-07-09 18:44:07,751 INFO sqlalchemy.engine.Engine CREATE INDEX ix_exercises_id ON exercises (id)
# 2025-07-09 18:44:07,751 INFO sqlalchemy.engine.Engine [no key 0.00010s] ()
# 2025-07-09 18:44:07,752 INFO sqlalchemy.engine.Engine CREATE INDEX ix_exercises_question ON exercises (question)
# 2025-07-09 18:44:07,752 INFO sqlalchemy.engine.Engine [no key 0.00011s] ()
# 2025-07-09 18:44:07,752 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:07,757 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:07,757 INFO sqlalchemy.engine.Engine INSERT INTO language (id, name, native_name, level, description, score, last_seen, flag, current_unit) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:07,757 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('ZH', 'Chinois', '中文', 'A1', '', 0, '2025-07-09', '🇨🇳', None)
# 2025-07-09 18:44:07,758 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Add Units

# %%
# Initialize the database connection and create db file if it doesn't exist
engine, session = init_db()

# Initialize the database
with open(f'../data/{language_id}/units.json', 'r', encoding="utf8") as f:
    units_array = json.load(f)
    
units = []
for idx, unit_data in enumerate(units_array):
    units.append(
        Unit(
            id = f"{language_id.upper()}_{idx}",
            title = unit_data['title'],
            description = unit_data['description'],
            level = unit_data['level'],
            parent = language,
        )
    )
inserts(session, units)
session.close()
# Out:
# 2025-07-09 18:44:07,763 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:07,763 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("language")
# 2025-07-09 18:44:07,763 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:07,763 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-09 18:44:07,764 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:07,764 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-09 18:44:07,764 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:07,764 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-09 18:44:07,764 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:07,764 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-09 18:44:07,765 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:07,765 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-09 18:44:07,765 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:07,765 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:07,767 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:07,768 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-09 18:44:07,768 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('ZH',)
# 2025-07-09 18:44:07,769 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:07,769 INFO sqlalchemy.engine.Engine [generated in 0.00014s] ('ZH_0', 'Lecon introductive: Bonjour!', "A l'oral: Connaitre les salutations de base. \n\nA l'ecrit: 5 caracteres", 'A1', 0, 'ZH')
# 2025-07-09 18:44:07,769 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:07,770 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:07,770 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-09 18:44:07,771 INFO sqlalchemy.engine.Engine [generated in 0.00024s] ('ZH',)
# 2025-07-09 18:44:07,771 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:07,771 INFO sqlalchemy.engine.Engine [cached since 0.002034s ago] ('ZH_1', "Unite 1: Comment t'appelles-tu?", "A l'oral: Savoir se presenter et presenter quelqu'un. \n\nParler de sa nationalite. \n\nA l'ecrit: 19 caracteres", 'A1', 0, 'ZH')
# 2025-07-09 18:44:07,771 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:07,772 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:07,772 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-09 18:44:07,772 INFO sqlalchemy.engine.Engine [cached since 0.001879s ago] ('ZH',)
# 2025-07-09 18:44:07,772 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:07,773 INFO sqlalchemy.engine.Engine [cached since 0.003615s ago] ('ZH_2', 'Unite 2: Un, deux, trois', "A l'oral: Compter de 1 a 9999. \n\nSavoir enumerer des objets. \n\nA l'ecrit: 19 caracteres", 'A1', 0, 'ZH')
# 2025-07-09 18:44:07,773 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:07,773 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:07,773 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-09 18:44:07,774 INFO sqlalchemy.engine.Engine [cached since 0.003323s ago] ('ZH',)
# 2025-07-09 18:44:07,774 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:07,774 INFO sqlalchemy.engine.Engine [cached since 0.005075s ago] ('ZH_3', "Unite 3: Aujourd'hui", "A l'oral: Savoir annoncer la date. \n\nParler des moments de la journee et de l'heure. \n\nA l'ecrit: 17 caracteres", 'A1', 0, 'ZH')
# 2025-07-09 18:44:07,774 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:07,775 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:07,775 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-09 18:44:07,775 INFO sqlalchemy.engine.Engine [cached since 0.0047s ago] ('ZH',)
# 2025-07-09 18:44:07,775 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:07,775 INFO sqlalchemy.engine.Engine [cached since 0.006393s ago] ('ZH_4', 'Unite 4: Ou allons-nous?', "A l'oral: Parler d'un evenement passe, d'une experience. \n\nPouvoir se situer, parler ou l'on est, ou l'on va. \n\nA l'ecrit: 17 caracteres", 'A1', 0, 'ZH')
# 2025-07-09 18:44:07,776 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:07,776 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:07,776 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-09 18:44:07,776 INFO sqlalchemy.engine.Engine [cached since 0.005974s ago] ('ZH',)
# 2025-07-09 18:44:07,777 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:07,777 INFO sqlalchemy.engine.Engine [cached since 0.007699s ago] ('ZH_5', 'Unite 5: Je ne suis pas vieux', "A l'oral: Decrire quelqu'un ou quelque chose. \n\nUtilise les adjectifs. \n\nA l'ecrit: 17 caracteres", 'A1', 0, 'ZH')
# 2025-07-09 18:44:07,777 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:07,777 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:07,777 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-09 18:44:07,778 INFO sqlalchemy.engine.Engine [cached since 0.007273s ago] ('ZH',)
# 2025-07-09 18:44:07,778 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:07,778 INFO sqlalchemy.engine.Engine [cached since 0.008996s ago] ('ZH_6', 'Unite 6: Ma famille', "A l'oral: Pouvoir presenter sa famille. \n\nUtilise les demonstratifs. \n\nA l'ecrit: 22 caracteres", 'A1', 0, 'ZH')
# 2025-07-09 18:44:07,778 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:07,779 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:07,779 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-09 18:44:07,779 INFO sqlalchemy.engine.Engine [cached since 0.008633s ago] ('ZH',)
# 2025-07-09 18:44:07,779 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:07,779 INFO sqlalchemy.engine.Engine [cached since 0.01034s ago] ('ZH_7', 'Unite 7: Mes amis', "A l'oral: Parler des ses amis. \n\nParler des langues etrangeres. \n\nComparer des gens ou des objets. \n\nA l'ecrit: 18 caracteres", 'A1', 0, 'ZH')
# 2025-07-09 18:44:07,780 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:07,780 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:07,780 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-09 18:44:07,780 INFO sqlalchemy.engine.Engine [cached since 0.009941s ago] ('ZH',)
# 2025-07-09 18:44:07,780 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:07,781 INFO sqlalchemy.engine.Engine [cached since 0.01162s ago] ('ZH_8', "Unite 8: Qu'aimes-tu faire?", "A l'oral: Parler de ses activites favorites. \n\nInterroger sur la maniere. \n\nA l'ecrit: 16 caracteres", 'A2', 0, 'ZH')
# 2025-07-09 18:44:07,781 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:07,781 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:07,781 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-09 18:44:07,782 INFO sqlalchemy.engine.Engine [cached since 0.01129s ago] ('ZH',)
# 2025-07-09 18:44:07,782 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:07,782 INFO sqlalchemy.engine.Engine [cached since 0.01302s ago] ('ZH_9', 'Unite 9: Une journee classique', "A l'oral: Raconter sa journee. \n\nParler des differents moyens de transport. \n\nA l'ecrit: 16 caracteres", 'A2', 0, 'ZH')
# 2025-07-09 18:44:07,782 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:07,783 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:07,783 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-09 18:44:07,783 INFO sqlalchemy.engine.Engine [cached since 0.01261s ago] ('ZH',)
# 2025-07-09 18:44:07,783 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:07,783 INFO sqlalchemy.engine.Engine [cached since 0.0143s ago] ('ZH_10', 'Unite 10: Au travail', "A l'oral: Parler du monde du travail. \n\nA l'ecrit: 18 caracteres", 'A2', 0, 'ZH')
# 2025-07-09 18:44:07,784 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:07,784 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:07,784 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-09 18:44:07,784 INFO sqlalchemy.engine.Engine [cached since 0.01385s ago] ('ZH',)
# 2025-07-09 18:44:07,784 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:07,785 INFO sqlalchemy.engine.Engine [cached since 0.01555s ago] ('ZH_11', 'Unite 11: Dans une grande ville', "A l'oral: Pouvoir demander son chemin. \n\nSe reperer en ville. \n\nA l'ecrit: 18 caracteres", 'A2', 0, 'ZH')
# 2025-07-09 18:44:07,785 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:07,785 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:07,785 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-09 18:44:07,786 INFO sqlalchemy.engine.Engine [cached since 0.01522s ago] ('ZH',)
# 2025-07-09 18:44:07,786 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:07,786 INFO sqlalchemy.engine.Engine [cached since 0.01697s ago] ('ZH_12', 'Unite 12: Faire des achats', "A l'oral: Negocier un prix. \n\nFaire des achats. \n\nA l'ecrit: 18 caracteres", 'A2', 0, 'ZH')
# 2025-07-09 18:44:07,786 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:07,787 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:07,787 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-09 18:44:07,787 INFO sqlalchemy.engine.Engine [cached since 0.01653s ago] ('ZH',)
# 2025-07-09 18:44:07,787 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:07,787 INFO sqlalchemy.engine.Engine [cached since 0.01823s ago] ('ZH_13', "Unite 13: En voyage a l'etranger", "A l'oral: Pouvoir raconter ou prevoir un voyage. \n\nUtiliser 'Avant, apres, pendant'. \n\nA l'ecrit: 17 caracteres", 'A2', 0, 'ZH')
# 2025-07-09 18:44:07,787 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:07,788 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:07,788 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-09 18:44:07,788 INFO sqlalchemy.engine.Engine [cached since 0.01792s ago] ('ZH',)
# 2025-07-09 18:44:07,789 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:07,789 INFO sqlalchemy.engine.Engine [cached since 0.01964s ago] ('ZH_14', 'Unite 14: La culture chinoise', "A l'oral: Decouvrir la culture chinoise. \n\nParler des fetes et des vacances. \n\nA l'ecrit: 19 caracteres", 'A2', 0, 'ZH')
# 2025-07-09 18:44:07,789 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:07,789 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:07,790 INFO sqlalchemy.engine.Engine SELECT language.id AS language_id, language.name AS language_name, language.native_name AS language_native_name, language.level AS language_level, language.description AS language_description, language.score AS language_score, language.last_seen AS language_last_seen, language.flag AS language_flag, language.current_unit AS language_current_unit
# FROM language
# WHERE language.id = ?
# 2025-07-09 18:44:07,790 INFO sqlalchemy.engine.Engine [cached since 0.01933s ago] ('ZH',)
# 2025-07-09 18:44:07,790 INFO sqlalchemy.engine.Engine INSERT INTO unit (id, title, description, level, score, language_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:07,790 INFO sqlalchemy.engine.Engine [cached since 0.02102s ago] ('ZH_15', 'Unite 15: A la maison', "A l'oral: Decrire une maison, un appartement. \n\nUtiliser 吧 et les directionnels. \n\nA l'ecrit: 17 caracteres", 'A2', 0, 'ZH')
# 2025-07-09 18:44:07,793 INFO sqlalchemy.engine.Engine COMMIT
# /Users/noe_jager/Documents/GitHub/vocabulary-dbms/src/lapp/dbms.py:80: SAWarning: Object of type <Unit> not in session, add operation along 'Language.units' will not proceed
#   session.commit()

# %% [markdown]
# ## Add Vocabulary

# %%
# Initialize the database connection and create db file if it doesn't exist
engine, session = init_db()

directory_path = f'../data/{language_id}/vocabulary'

if not os.path.exists(directory_path):
    raise FileNotFoundError(f"No vocabulary found for {language_id}.")

vocs = []

# List all elements (files and directories) in the specified directory and get their full paths
elements_paths = [os.path.join(directory_path, element) for element in os.listdir(directory_path)]
for voc_file in elements_paths:
    if os.path.isfile(voc_file) and voc_file.endswith('.csv'):
        unit_id = re.sub("[^0-9]", "", os.path.basename(voc_file))
        df = pd.read_csv(voc_file)
        for idx, row in df.iterrows():
            vocs.append( 
                Vocabulary(
                    id=f"{language_id.upper()}_{unit_id}_V{idx}",
                    word = row['word'],
                    translation = row["translation"],
                    phonetic = row["pinyin"],
                    example_sentence = row.get("example_sentence", ""),
                    type = row["type"],
                    parent=session.query(Unit).filter(Unit.id == f"{language_id.upper()}_{unit_id}").first()
                )
            )
inserts(session, vocs)
session.close()
# Out:
# 2025-07-09 18:44:07,798 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:07,798 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("language")
# 2025-07-09 18:44:07,798 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:07,798 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-09 18:44:07,798 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:07,799 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-09 18:44:07,799 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:07,799 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-09 18:44:07,799 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:07,799 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-09 18:44:07,799 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:07,800 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-09 18:44:07,800 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:07,800 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:07,802 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:07,803 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,803 INFO sqlalchemy.engine.Engine [generated in 0.00015s] ('ZH_2', 1, 0)
# 2025-07-09 18:44:07,804 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,804 INFO sqlalchemy.engine.Engine [cached since 0.001115s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:07,805 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,805 INFO sqlalchemy.engine.Engine [cached since 0.001795s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:07,805 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,805 INFO sqlalchemy.engine.Engine [cached since 0.002465s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:07,806 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,806 INFO sqlalchemy.engine.Engine [cached since 0.003059s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:07,807 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,807 INFO sqlalchemy.engine.Engine [cached since 0.00371s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:07,807 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,807 INFO sqlalchemy.engine.Engine [cached since 0.004367s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:07,808 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,808 INFO sqlalchemy.engine.Engine [cached since 0.005s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:07,808 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,809 INFO sqlalchemy.engine.Engine [cached since 0.00557s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:07,809 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,809 INFO sqlalchemy.engine.Engine [cached since 0.006166s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:07,810 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,810 INFO sqlalchemy.engine.Engine [cached since 0.006821s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:07,810 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,810 INFO sqlalchemy.engine.Engine [cached since 0.007407s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:07,811 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,811 INFO sqlalchemy.engine.Engine [cached since 0.008046s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:07,811 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,812 INFO sqlalchemy.engine.Engine [cached since 0.008632s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:07,812 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,812 INFO sqlalchemy.engine.Engine [cached since 0.009202s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:07,813 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,813 INFO sqlalchemy.engine.Engine [cached since 0.009833s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:07,813 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,813 INFO sqlalchemy.engine.Engine [cached since 0.01043s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:07,814 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,814 INFO sqlalchemy.engine.Engine [cached since 0.01103s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:07,814 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,815 INFO sqlalchemy.engine.Engine [cached since 0.01164s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:07,815 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,815 INFO sqlalchemy.engine.Engine [cached since 0.01222s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:07,816 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,816 INFO sqlalchemy.engine.Engine [cached since 0.0128s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:07,816 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,816 INFO sqlalchemy.engine.Engine [cached since 0.01341s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:07,817 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,817 INFO sqlalchemy.engine.Engine [cached since 0.01397s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:07,818 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,818 INFO sqlalchemy.engine.Engine [cached since 0.01547s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,819 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,819 INFO sqlalchemy.engine.Engine [cached since 0.01625s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,820 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,820 INFO sqlalchemy.engine.Engine [cached since 0.01688s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,820 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,820 INFO sqlalchemy.engine.Engine [cached since 0.01751s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,821 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,821 INFO sqlalchemy.engine.Engine [cached since 0.0181s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,822 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,822 INFO sqlalchemy.engine.Engine [cached since 0.01873s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,822 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,822 INFO sqlalchemy.engine.Engine [cached since 0.01938s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,823 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,823 INFO sqlalchemy.engine.Engine [cached since 0.01993s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,823 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,823 INFO sqlalchemy.engine.Engine [cached since 0.02049s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,824 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,824 INFO sqlalchemy.engine.Engine [cached since 0.02105s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,825 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,825 INFO sqlalchemy.engine.Engine [cached since 0.02167s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,825 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,825 INFO sqlalchemy.engine.Engine [cached since 0.02228s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,826 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,826 INFO sqlalchemy.engine.Engine [cached since 0.02284s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,826 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,826 INFO sqlalchemy.engine.Engine [cached since 0.02339s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,827 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,827 INFO sqlalchemy.engine.Engine [cached since 0.02393s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,827 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,827 INFO sqlalchemy.engine.Engine [cached since 0.02447s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,828 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,828 INFO sqlalchemy.engine.Engine [cached since 0.02506s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,829 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,829 INFO sqlalchemy.engine.Engine [cached since 0.02562s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,829 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,829 INFO sqlalchemy.engine.Engine [cached since 0.02616s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,830 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,830 INFO sqlalchemy.engine.Engine [cached since 0.02676s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,830 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,830 INFO sqlalchemy.engine.Engine [cached since 0.02731s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,831 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,831 INFO sqlalchemy.engine.Engine [cached since 0.02787s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,831 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,831 INFO sqlalchemy.engine.Engine [cached since 0.02845s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,832 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,832 INFO sqlalchemy.engine.Engine [cached since 0.02901s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,832 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,833 INFO sqlalchemy.engine.Engine [cached since 0.02959s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,833 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,833 INFO sqlalchemy.engine.Engine [cached since 0.03015s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,834 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,834 INFO sqlalchemy.engine.Engine [cached since 0.03072s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,834 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,834 INFO sqlalchemy.engine.Engine [cached since 0.03147s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,835 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,835 INFO sqlalchemy.engine.Engine [cached since 0.03205s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,835 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,836 INFO sqlalchemy.engine.Engine [cached since 0.03257s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,836 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,836 INFO sqlalchemy.engine.Engine [cached since 0.03315s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:07,837 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,838 INFO sqlalchemy.engine.Engine [cached since 0.03459s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:07,838 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,838 INFO sqlalchemy.engine.Engine [cached since 0.03517s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:07,839 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,839 INFO sqlalchemy.engine.Engine [cached since 0.03573s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:07,839 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,839 INFO sqlalchemy.engine.Engine [cached since 0.0363s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:07,840 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,840 INFO sqlalchemy.engine.Engine [cached since 0.03689s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:07,840 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,840 INFO sqlalchemy.engine.Engine [cached since 0.03745s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:07,841 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,841 INFO sqlalchemy.engine.Engine [cached since 0.03808s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:07,842 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,842 INFO sqlalchemy.engine.Engine [cached since 0.03865s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:07,842 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,842 INFO sqlalchemy.engine.Engine [cached since 0.03918s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:07,843 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,843 INFO sqlalchemy.engine.Engine [cached since 0.03976s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:07,843 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,843 INFO sqlalchemy.engine.Engine [cached since 0.04033s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:07,844 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,844 INFO sqlalchemy.engine.Engine [cached since 0.04088s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:07,844 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,844 INFO sqlalchemy.engine.Engine [cached since 0.04144s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:07,845 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,845 INFO sqlalchemy.engine.Engine [cached since 0.04202s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:07,845 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,846 INFO sqlalchemy.engine.Engine [cached since 0.04258s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:07,846 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,846 INFO sqlalchemy.engine.Engine [cached since 0.04311s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:07,846 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,847 INFO sqlalchemy.engine.Engine [cached since 0.04363s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:07,847 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,847 INFO sqlalchemy.engine.Engine [cached since 0.04415s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:07,848 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,848 INFO sqlalchemy.engine.Engine [cached since 0.04467s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:07,848 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,848 INFO sqlalchemy.engine.Engine [cached since 0.04521s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:07,849 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,849 INFO sqlalchemy.engine.Engine [cached since 0.04578s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:07,849 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,849 INFO sqlalchemy.engine.Engine [cached since 0.04633s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:07,850 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,850 INFO sqlalchemy.engine.Engine [cached since 0.04691s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:07,850 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,851 INFO sqlalchemy.engine.Engine [cached since 0.04754s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:07,852 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,852 INFO sqlalchemy.engine.Engine [cached since 0.04875s ago] ('ZH_0', 1, 0)
# 2025-07-09 18:44:07,852 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,852 INFO sqlalchemy.engine.Engine [cached since 0.04939s ago] ('ZH_0', 1, 0)
# 2025-07-09 18:44:07,853 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,853 INFO sqlalchemy.engine.Engine [cached since 0.04991s ago] ('ZH_0', 1, 0)
# 2025-07-09 18:44:07,853 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,853 INFO sqlalchemy.engine.Engine [cached since 0.05045s ago] ('ZH_0', 1, 0)
# 2025-07-09 18:44:07,854 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,854 INFO sqlalchemy.engine.Engine [cached since 0.05109s ago] ('ZH_0', 1, 0)
# 2025-07-09 18:44:07,854 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,855 INFO sqlalchemy.engine.Engine [cached since 0.05163s ago] ('ZH_0', 1, 0)
# 2025-07-09 18:44:07,855 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,855 INFO sqlalchemy.engine.Engine [cached since 0.05215s ago] ('ZH_0', 1, 0)
# 2025-07-09 18:44:07,856 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,856 INFO sqlalchemy.engine.Engine [cached since 0.05268s ago] ('ZH_0', 1, 0)
# 2025-07-09 18:44:07,856 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,856 INFO sqlalchemy.engine.Engine [cached since 0.05322s ago] ('ZH_0', 1, 0)
# 2025-07-09 18:44:07,857 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,857 INFO sqlalchemy.engine.Engine [cached since 0.0538s ago] ('ZH_0', 1, 0)
# 2025-07-09 18:44:07,857 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,857 INFO sqlalchemy.engine.Engine [cached since 0.05436s ago] ('ZH_0', 1, 0)
# 2025-07-09 18:44:07,858 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,859 INFO sqlalchemy.engine.Engine [cached since 0.05559s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:07,859 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,859 INFO sqlalchemy.engine.Engine [cached since 0.05609s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:07,859 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,860 INFO sqlalchemy.engine.Engine [cached since 0.05661s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:07,860 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,860 INFO sqlalchemy.engine.Engine [cached since 0.05726s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:07,861 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,861 INFO sqlalchemy.engine.Engine [cached since 0.0578s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:07,861 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,861 INFO sqlalchemy.engine.Engine [cached since 0.05836s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:07,862 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,862 INFO sqlalchemy.engine.Engine [cached since 0.05892s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:07,862 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,862 INFO sqlalchemy.engine.Engine [cached since 0.05948s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:07,863 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,863 INFO sqlalchemy.engine.Engine [cached since 0.06002s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:07,863 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,864 INFO sqlalchemy.engine.Engine [cached since 0.06056s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:07,864 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,864 INFO sqlalchemy.engine.Engine [cached since 0.06112s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:07,865 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,865 INFO sqlalchemy.engine.Engine [cached since 0.06164s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:07,865 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,865 INFO sqlalchemy.engine.Engine [cached since 0.06217s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:07,866 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,866 INFO sqlalchemy.engine.Engine [cached since 0.0627s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:07,866 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,866 INFO sqlalchemy.engine.Engine [cached since 0.06324s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:07,867 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,867 INFO sqlalchemy.engine.Engine [cached since 0.06386s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:07,867 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,867 INFO sqlalchemy.engine.Engine [cached since 0.0644s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:07,868 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,868 INFO sqlalchemy.engine.Engine [cached since 0.06494s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:07,869 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,869 INFO sqlalchemy.engine.Engine [cached since 0.06609s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:07,870 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,870 INFO sqlalchemy.engine.Engine [cached since 0.06674s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:07,870 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,870 INFO sqlalchemy.engine.Engine [cached since 0.0674s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:07,871 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,871 INFO sqlalchemy.engine.Engine [cached since 0.06809s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:07,872 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,872 INFO sqlalchemy.engine.Engine [cached since 0.06875s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:07,872 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,872 INFO sqlalchemy.engine.Engine [cached since 0.06931s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:07,873 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,873 INFO sqlalchemy.engine.Engine [cached since 0.06987s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:07,873 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,873 INFO sqlalchemy.engine.Engine [cached since 0.0705s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:07,874 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,874 INFO sqlalchemy.engine.Engine [cached since 0.07103s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:07,874 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,875 INFO sqlalchemy.engine.Engine [cached since 0.07156s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:07,875 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,875 INFO sqlalchemy.engine.Engine [cached since 0.07209s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:07,875 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,876 INFO sqlalchemy.engine.Engine [cached since 0.07263s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:07,876 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,876 INFO sqlalchemy.engine.Engine [cached since 0.07318s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:07,877 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,877 INFO sqlalchemy.engine.Engine [cached since 0.07375s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:07,877 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,877 INFO sqlalchemy.engine.Engine [cached since 0.07428s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:07,878 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:07,878 INFO sqlalchemy.engine.Engine [cached since 0.07486s ago] ('ZH_5', 1, 0)
# ...
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,531 INFO sqlalchemy.engine.Engine [cached since 1.387s ago] ('ZH_9',)
# 2025-07-09 18:44:09,531 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,532 INFO sqlalchemy.engine.Engine [cached since 1.39s ago] ('ZH_9_V5', '开始', 'Commencer', 'Kāishǐ', '', 'Verbes', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,532 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,533 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,533 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,533 INFO sqlalchemy.engine.Engine [cached since 1.389s ago] ('ZH_9',)
# 2025-07-09 18:44:09,533 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,534 INFO sqlalchemy.engine.Engine [cached since 1.391s ago] ('ZH_9_V6', '骑', 'Chevaucher', 'Qí', '', 'Verbes', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,534 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,535 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,535 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,535 INFO sqlalchemy.engine.Engine [cached since 1.392s ago] ('ZH_9',)
# 2025-07-09 18:44:09,536 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,536 INFO sqlalchemy.engine.Engine [cached since 1.394s ago] ('ZH_9_V7', '上班', 'Commencer le travail', 'Shàngbān', '', 'Verbes', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,536 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,537 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,537 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,538 INFO sqlalchemy.engine.Engine [cached since 1.394s ago] ('ZH_9',)
# 2025-07-09 18:44:09,539 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,539 INFO sqlalchemy.engine.Engine [cached since 1.397s ago] ('ZH_9_V8', '下班', 'Finir le travail', 'Xiàbān', '', 'Verbes', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,539 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,540 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,541 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,541 INFO sqlalchemy.engine.Engine [cached since 1.397s ago] ('ZH_9',)
# 2025-07-09 18:44:09,541 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,542 INFO sqlalchemy.engine.Engine [cached since 1.4s ago] ('ZH_9_V9', '走路', 'Marcher', 'Zǒulù', '', 'Verbes', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,542 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,543 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,543 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,543 INFO sqlalchemy.engine.Engine [cached since 1.4s ago] ('ZH_9',)
# 2025-07-09 18:44:09,544 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,544 INFO sqlalchemy.engine.Engine [cached since 1.402s ago] ('ZH_9_V10', '坐', "S'asseoir/prendre (véhicule)", 'Zuò', '', 'Verbes', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,544 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,545 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,545 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,546 INFO sqlalchemy.engine.Engine [cached since 1.402s ago] ('ZH_9',)
# 2025-07-09 18:44:09,546 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,546 INFO sqlalchemy.engine.Engine [cached since 1.404s ago] ('ZH_9_V11', '游泳', 'Nager', 'Yóuyǒng', '', 'Verbes', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,546 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,550 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,551 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,553 INFO sqlalchemy.engine.Engine [cached since 1.409s ago] ('ZH_9',)
# 2025-07-09 18:44:09,554 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,555 INFO sqlalchemy.engine.Engine [cached since 1.413s ago] ('ZH_9_V12', '无聊', 'Ennuyeux', 'Wúliáo', '', 'Adjectifs', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,557 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,558 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,560 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,563 INFO sqlalchemy.engine.Engine [cached since 1.419s ago] ('ZH_9',)
# 2025-07-09 18:44:09,573 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,574 INFO sqlalchemy.engine.Engine [cached since 1.432s ago] ('ZH_9_V13', '有意思', 'Intéressant (polite)', 'Yǒu yìsi', '', 'Adjectifs', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,575 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,579 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,583 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,583 INFO sqlalchemy.engine.Engine [cached since 1.44s ago] ('ZH_9',)
# 2025-07-09 18:44:09,584 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,585 INFO sqlalchemy.engine.Engine [cached since 1.443s ago] ('ZH_9_V14', '没意思', 'Inintéressant (polite)', 'Méi yìsi', '', 'Adjectifs', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,586 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,588 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,589 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,589 INFO sqlalchemy.engine.Engine [cached since 1.445s ago] ('ZH_9',)
# 2025-07-09 18:44:09,590 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,591 INFO sqlalchemy.engine.Engine [cached since 1.448s ago] ('ZH_9_V15', '啊', "Particule modale d'exclamation", 'A', '', 'Divers', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,592 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,593 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,594 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,594 INFO sqlalchemy.engine.Engine [cached since 1.45s ago] ('ZH_9',)
# 2025-07-09 18:44:09,595 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,596 INFO sqlalchemy.engine.Engine [cached since 1.454s ago] ('ZH_9_V16', '每', 'Chaque', 'Měi', '', 'Divers', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,597 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,599 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,600 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,601 INFO sqlalchemy.engine.Engine [cached since 1.457s ago] ('ZH_9',)
# 2025-07-09 18:44:09,602 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,602 INFO sqlalchemy.engine.Engine [cached since 1.46s ago] ('ZH_9_V17', '然后', 'Ensuite', 'Ránhòu', '', 'Divers', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,603 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,605 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,606 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,607 INFO sqlalchemy.engine.Engine [cached since 1.463s ago] ('ZH_9',)
# 2025-07-09 18:44:09,608 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,608 INFO sqlalchemy.engine.Engine [cached since 1.466s ago] ('ZH_9_V18', '同意', "Être d'accord", 'Tóngyì', '', 'Divers', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,609 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,610 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,612 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,612 INFO sqlalchemy.engine.Engine [cached since 1.468s ago] ('ZH_9',)
# 2025-07-09 18:44:09,614 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,615 INFO sqlalchemy.engine.Engine [cached since 1.472s ago] ('ZH_9_V19', '先', "D'abord", 'Xiān', '', 'Divers', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,616 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,617 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,618 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,618 INFO sqlalchemy.engine.Engine [cached since 1.475s ago] ('ZH_9',)
# 2025-07-09 18:44:09,619 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,619 INFO sqlalchemy.engine.Engine [cached since 1.477s ago] ('ZH_9_V20', '有点儿', 'Un petit peu', 'Yǒu diǎnr', '', 'Divers', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,620 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,622 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,623 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,623 INFO sqlalchemy.engine.Engine [cached since 1.48s ago] ('ZH_9',)
# 2025-07-09 18:44:09,624 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,625 INFO sqlalchemy.engine.Engine [cached since 1.482s ago] ('ZH_9_V21', '公园', 'Parc public', 'Gōngyuán', '', 'Noms et expressions', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,626 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,627 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,628 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,628 INFO sqlalchemy.engine.Engine [cached since 1.485s ago] ('ZH_9',)
# 2025-07-09 18:44:09,629 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,630 INFO sqlalchemy.engine.Engine [cached since 1.488s ago] ('ZH_9_V22', '看法', 'Point de vue', 'Kànfǎ', '', 'Noms et expressions', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,631 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,633 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,633 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,634 INFO sqlalchemy.engine.Engine [cached since 1.49s ago] ('ZH_9',)
# 2025-07-09 18:44:09,634 INFO sqlalchemy.engine.Engine INSERT INTO vocabulary (id, word, translation, phonetic, example_sentence, type, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,635 INFO sqlalchemy.engine.Engine [cached since 1.492s ago] ('ZH_9_V23', '游泳池', 'Piscine', 'Yóuyǒngchí', '', 'Noms et expressions', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,635 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Add Grammar Rules

# %%
# Initialize the database connection and create db file if it doesn't exist
engine, session = init_db()

directory_path = f'../data/{language_id}/grammar'

if not os.path.exists(directory_path):
    raise FileNotFoundError(f"No grammar files found for {language_id}.")

grammars = []

# List all elements (files and directories) in the specified directory and get their full paths
elements_paths = [os.path.join(directory_path, element) for element in os.listdir(directory_path)]
for grammar_file in elements_paths:
    if os.path.isfile(grammar_file) and grammar_file.endswith('.json'):
        unit_id = re.sub("[^0-9]", "", os.path.basename(grammar_file))
        with open(grammar_file, 'r', encoding="utf8") as f:
            grammar_data = json.load(f)
        for idx, row in enumerate(grammar_data):
            grammars.append( 
                GrammarRule(
                    id=f"{language_id.upper()}_{unit_id}_G{idx + 1}",
                    title=row['title'],
                    explanation=row["content"],
                    parent=session.query(Unit).filter(Unit.id == f"{language_id.upper()}_{unit_id}").first()
                )
            )
inserts(session, grammars)
session.close()
# Out:
# 2025-07-09 18:44:09,666 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,667 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("language")
# 2025-07-09 18:44:09,671 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:09,673 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-09 18:44:09,673 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:09,674 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-09 18:44:09,674 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:09,674 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-09 18:44:09,674 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:09,675 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-09 18:44:09,675 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:09,675 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-09 18:44:09,675 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:09,675 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,677 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,677 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,677 INFO sqlalchemy.engine.Engine [generated in 0.00024s] ('ZH_11', 1, 0)
# 2025-07-09 18:44:09,678 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,678 INFO sqlalchemy.engine.Engine [cached since 0.001077s ago] ('ZH_11', 1, 0)
# 2025-07-09 18:44:09,679 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,679 INFO sqlalchemy.engine.Engine [cached since 0.001736s ago] ('ZH_11', 1, 0)
# 2025-07-09 18:44:09,679 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,679 INFO sqlalchemy.engine.Engine [cached since 0.002299s ago] ('ZH_11', 1, 0)
# 2025-07-09 18:44:09,680 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,681 INFO sqlalchemy.engine.Engine [cached since 0.003328s ago] ('ZH_6', 1, 0)
# 2025-07-09 18:44:09,681 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,681 INFO sqlalchemy.engine.Engine [cached since 0.00391s ago] ('ZH_6', 1, 0)
# 2025-07-09 18:44:09,682 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,682 INFO sqlalchemy.engine.Engine [cached since 0.004444s ago] ('ZH_6', 1, 0)
# 2025-07-09 18:44:09,682 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,682 INFO sqlalchemy.engine.Engine [cached since 0.004986s ago] ('ZH_6', 1, 0)
# 2025-07-09 18:44:09,683 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,683 INFO sqlalchemy.engine.Engine [cached since 0.005884s ago] ('ZH_7', 1, 0)
# 2025-07-09 18:44:09,684 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,684 INFO sqlalchemy.engine.Engine [cached since 0.006467s ago] ('ZH_7', 1, 0)
# 2025-07-09 18:44:09,684 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,684 INFO sqlalchemy.engine.Engine [cached since 0.007018s ago] ('ZH_7', 1, 0)
# 2025-07-09 18:44:09,685 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,685 INFO sqlalchemy.engine.Engine [cached since 0.007581s ago] ('ZH_7', 1, 0)
# 2025-07-09 18:44:09,685 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,685 INFO sqlalchemy.engine.Engine [cached since 0.00812s ago] ('ZH_7', 1, 0)
# 2025-07-09 18:44:09,686 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,686 INFO sqlalchemy.engine.Engine [cached since 0.008765s ago] ('ZH_7', 1, 0)
# 2025-07-09 18:44:09,687 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,687 INFO sqlalchemy.engine.Engine [cached since 0.009693s ago] ('ZH_10', 1, 0)
# 2025-07-09 18:44:09,687 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,687 INFO sqlalchemy.engine.Engine [cached since 0.01021s ago] ('ZH_10', 1, 0)
# 2025-07-09 18:44:09,688 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,688 INFO sqlalchemy.engine.Engine [cached since 0.01081s ago] ('ZH_10', 1, 0)
# 2025-07-09 18:44:09,688 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,689 INFO sqlalchemy.engine.Engine [cached since 0.01139s ago] ('ZH_10', 1, 0)
# 2025-07-09 18:44:09,689 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,689 INFO sqlalchemy.engine.Engine [cached since 0.01196s ago] ('ZH_10', 1, 0)
# 2025-07-09 18:44:09,690 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,690 INFO sqlalchemy.engine.Engine [cached since 0.01249s ago] ('ZH_10', 1, 0)
# 2025-07-09 18:44:09,690 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,691 INFO sqlalchemy.engine.Engine [cached since 0.01337s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:09,691 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,691 INFO sqlalchemy.engine.Engine [cached since 0.01393s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:09,692 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,692 INFO sqlalchemy.engine.Engine [cached since 0.01445s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:09,692 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,693 INFO sqlalchemy.engine.Engine [cached since 0.01534s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:09,693 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,693 INFO sqlalchemy.engine.Engine [cached since 0.01589s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:09,693 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,694 INFO sqlalchemy.engine.Engine [cached since 0.01643s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:09,694 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,694 INFO sqlalchemy.engine.Engine [cached since 0.01701s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:09,695 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,695 INFO sqlalchemy.engine.Engine [cached since 0.01756s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:09,695 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,696 INFO sqlalchemy.engine.Engine [cached since 0.01833s ago] ('ZH_15', 1, 0)
# 2025-07-09 18:44:09,696 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,696 INFO sqlalchemy.engine.Engine [cached since 0.01885s ago] ('ZH_15', 1, 0)
# 2025-07-09 18:44:09,696 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,697 INFO sqlalchemy.engine.Engine [cached since 0.01946s ago] ('ZH_15', 1, 0)
# 2025-07-09 18:44:09,697 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,697 INFO sqlalchemy.engine.Engine [cached since 0.01996s ago] ('ZH_15', 1, 0)
# 2025-07-09 18:44:09,698 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,698 INFO sqlalchemy.engine.Engine [cached since 0.02076s ago] ('ZH_14', 1, 0)
# 2025-07-09 18:44:09,698 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,698 INFO sqlalchemy.engine.Engine [cached since 0.0213s ago] ('ZH_14', 1, 0)
# 2025-07-09 18:44:09,699 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,699 INFO sqlalchemy.engine.Engine [cached since 0.0218s ago] ('ZH_14', 1, 0)
# 2025-07-09 18:44:09,699 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,699 INFO sqlalchemy.engine.Engine [cached since 0.02231s ago] ('ZH_14', 1, 0)
# 2025-07-09 18:44:09,700 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,700 INFO sqlalchemy.engine.Engine [cached since 0.02294s ago] ('ZH_14', 1, 0)
# 2025-07-09 18:44:09,701 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,701 INFO sqlalchemy.engine.Engine [cached since 0.02377s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:09,701 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,701 INFO sqlalchemy.engine.Engine [cached since 0.02429s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:09,702 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,702 INFO sqlalchemy.engine.Engine [cached since 0.0251s ago] ('ZH_8', 1, 0)
# 2025-07-09 18:44:09,703 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,703 INFO sqlalchemy.engine.Engine [cached since 0.02565s ago] ('ZH_8', 1, 0)
# 2025-07-09 18:44:09,703 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,703 INFO sqlalchemy.engine.Engine [cached since 0.02616s ago] ('ZH_8', 1, 0)
# 2025-07-09 18:44:09,704 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,704 INFO sqlalchemy.engine.Engine [cached since 0.02668s ago] ('ZH_8', 1, 0)
# 2025-07-09 18:44:09,704 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,704 INFO sqlalchemy.engine.Engine [cached since 0.02719s ago] ('ZH_8', 1, 0)
# 2025-07-09 18:44:09,705 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,705 INFO sqlalchemy.engine.Engine [cached since 0.02795s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:09,706 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,706 INFO sqlalchemy.engine.Engine [cached since 0.02848s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:09,706 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,706 INFO sqlalchemy.engine.Engine [cached since 0.02906s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:09,707 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,707 INFO sqlalchemy.engine.Engine [cached since 0.02957s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:09,707 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,707 INFO sqlalchemy.engine.Engine [cached since 0.03013s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:09,708 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,708 INFO sqlalchemy.engine.Engine [cached since 0.03101s ago] ('ZH_13', 1, 0)
# 2025-07-09 18:44:09,709 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,709 INFO sqlalchemy.engine.Engine [cached since 0.03152s ago] ('ZH_13', 1, 0)
# 2025-07-09 18:44:09,709 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,709 INFO sqlalchemy.engine.Engine [cached since 0.03203s ago] ('ZH_13', 1, 0)
# 2025-07-09 18:44:09,710 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,710 INFO sqlalchemy.engine.Engine [cached since 0.03263s ago] ('ZH_13', 1, 0)
# 2025-07-09 18:44:09,710 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,710 INFO sqlalchemy.engine.Engine [cached since 0.03317s ago] ('ZH_13', 1, 0)
# 2025-07-09 18:44:09,711 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,711 INFO sqlalchemy.engine.Engine [cached since 0.03391s ago] ('ZH_12', 1, 0)
# 2025-07-09 18:44:09,711 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,712 INFO sqlalchemy.engine.Engine [cached since 0.03443s ago] ('ZH_12', 1, 0)
# 2025-07-09 18:44:09,712 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,712 INFO sqlalchemy.engine.Engine [cached since 0.03496s ago] ('ZH_12', 1, 0)
# 2025-07-09 18:44:09,713 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,713 INFO sqlalchemy.engine.Engine [cached since 0.03551s ago] ('ZH_12', 1, 0)
# 2025-07-09 18:44:09,713 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,713 INFO sqlalchemy.engine.Engine [cached since 0.03601s ago] ('ZH_12', 1, 0)
# 2025-07-09 18:44:09,714 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,714 INFO sqlalchemy.engine.Engine [cached since 0.03683s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:09,714 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,715 INFO sqlalchemy.engine.Engine [cached since 0.03735s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:09,715 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,715 INFO sqlalchemy.engine.Engine [cached since 0.03785s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:09,715 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,716 INFO sqlalchemy.engine.Engine [cached since 0.03837s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:09,716 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,716 INFO sqlalchemy.engine.Engine [cached since 0.03918s ago] ('ZH_9', 1, 0)
# 2025-07-09 18:44:09,717 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,717 INFO sqlalchemy.engine.Engine [cached since 0.03968s ago] ('ZH_9', 1, 0)
# 2025-07-09 18:44:09,717 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,717 INFO sqlalchemy.engine.Engine [cached since 0.04021s ago] ('ZH_9', 1, 0)
# 2025-07-09 18:44:09,718 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,718 INFO sqlalchemy.engine.Engine [cached since 0.04071s ago] ('ZH_9', 1, 0)
# 2025-07-09 18:44:09,718 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,718 INFO sqlalchemy.engine.Engine [cached since 0.04124s ago] ('ZH_9', 1, 0)
# 2025-07-09 18:44:09,719 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,719 INFO sqlalchemy.engine.Engine [cached since 0.04185s ago] ('ZH_9', 1, 0)
# 2025-07-09 18:44:09,720 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,720 INFO sqlalchemy.engine.Engine [generated in 0.00015s] ('ZH_11_G1', 'Énumérer avec 第 dì', "第 dì permet de former des chiffres et nombres ordinaux.\nIl s'emploie de la façon suivante :\n\n第 + chiffre/nombre ( + Classificateur )\n\n* 第一 dì yī ... (918 characters truncated) ... s deux mots suivants signifient « étage » et peuvent s'employer sans 第 dì :\n\n* 三楼 sān lóu : « Troisième étage »\n* 四层 sì céng : « Quatrième étage »", 0, '2025-07-09', 'ZH_11')
# 2025-07-09 18:44:09,720 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,721 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,721 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,721 INFO sqlalchemy.engine.Engine [generated in 0.00011s] ('ZH_11',)
# 2025-07-09 18:44:09,721 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,722 INFO sqlalchemy.engine.Engine [cached since 0.001933s ago] ('ZH_11_G2', 'Exprimer une distance avec 离 lí', "离 lí est utilisé lorsqu'on souhaite exprimer une distance entre deux points. Il peut se traduire par « par rapport à ». La structure à employer, très ... (589 characters truncated) ... ē zhàn lí zhèr tài yuǎn le : « La gare est trop éloignée d’ici »\n* 酒吧离我的家比较远 jiǔbā lí wǒ de jiā bǐjiào yuǎn : « Le bar est plutôt loin de chez moi »", 0, '2025-07-09', 'ZH_11')
# 2025-07-09 18:44:09,722 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,722 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,722 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,723 INFO sqlalchemy.engine.Engine [cached since 0.001551s ago] ('ZH_11',)
# 2025-07-09 18:44:09,723 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,723 INFO sqlalchemy.engine.Engine [cached since 0.003253s ago] ('ZH_11_G3', 'Se diriger, suivre un itinéraire', 'Savoir utiliser les termes « droite », « gauche » et « tout droit » suffit pour se repérer, demander son chemin et comprendre un itinéraire. Lorsqu’o ... (238 characters truncated) ... tout droit »\n* 你先往前走一百米，然后往左拐 nǐ xiān wǎng qián zǒu yī bǎi mǐ, ránhòu wǎng zuǒ guǎi : « Va d’abord tout droit sur 100 mètres, puis tourne à gauche »', 0, '2025-07-09', 'ZH_11')
# 2025-07-09 18:44:09,723 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,724 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,724 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,724 INFO sqlalchemy.engine.Engine [cached since 0.002849s ago] ('ZH_11',)
# 2025-07-09 18:44:09,724 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,724 INFO sqlalchemy.engine.Engine [cached since 0.004559s ago] ('ZH_11_G4', "À l'intérieur de quelque chose", 'Pour indiquer que quelque chose se situe à l’intérieur de quelque chose d’autre, on utilise la structure suivante :\n\nNom 1 + 在 + Nom 2 + 里面\n\n* 你在 ... (240 characters truncated) ...  shàng ma ? : « Es-tu dans le bus ? »\n* 我在车上 wǒ zài chē shàng : « Je suis dans la voiture »\n* 我在火车上 wǒ zài huǒchē shàng : « Je suis dans le train »', 0, '2025-07-09', 'ZH_11')
# 2025-07-09 18:44:09,725 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,725 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,725 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,725 INFO sqlalchemy.engine.Engine [cached since 0.004174s ago] ('ZH_6',)
# 2025-07-09 18:44:09,725 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,726 INFO sqlalchemy.engine.Engine [cached since 0.005901s ago] ('ZH_6_G1', 'Les démonstratifs 这 zhè et 那 nà', "Le démonstratif le plus couramment utilisé en chinois est 这 zhè.\n这 zhè va rarement être utilisé tout seul, il est souvent couplé avec d'autres carac ... (1057 characters truncated) ... à-bas, c'est... »\n* 那个/那个人 nà ge rén : « Cette personne-là »\n* 那里是我的朋友的家 nà lǐ shì wǒ de péngyou de jiā : « Là-bas se trouve la maison de mon ami »", 0, '2025-07-09', 'ZH_6')
# 2025-07-09 18:44:09,726 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,726 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,726 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,727 INFO sqlalchemy.engine.Engine [cached since 0.005516s ago] ('ZH_6',)
# 2025-07-09 18:44:09,727 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,727 INFO sqlalchemy.engine.Engine [cached since 0.007246s ago] ('ZH_6_G2', 'Autres utilisations du caractère 的 de', "的 de, le caractère permettant de marquer la possession, peut s'utiliser à la suite d'un pronom personnel (ex. 我的 wǒ de « mon ») ou d'un nom (ex. 老师的书 ... (937 characters truncated) ... ncài : « C'est le plat que j'aime faire/préparer »\n* 这是我去年去的地方 zhè shì wǒ qùnián qù de dìfang : « C'est l'endroit où je suis allé l'année dernière »", 0, '2025-07-09', 'ZH_6')
# 2025-07-09 18:44:09,727 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,728 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,728 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,728 INFO sqlalchemy.engine.Engine [cached since 0.006855s ago] ('ZH_6',)
# 2025-07-09 18:44:09,728 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,728 INFO sqlalchemy.engine.Engine [cached since 0.008618s ago] ('ZH_6_G3', 'Exprimer "avec" à l\'aide de 跟 gēn et 一起 yīqǐ', "La préposition 跟 gēn, souvent utilisée avec 一起 yīqǐ (signifiant « ensemble »), permet de marquer l'accompagnement :\n\n* 我跟你去 wǒ gēn nǐ qù : « J'y va ... (142 characters truncated) ... gēn tā yīqǐ qù le gōngyuán : « Je suis allé au parc avec lui hier »\n* 我跟我的女朋友一起住 wǒ gēn wǒ de nǚ péngyou yīqǐ zhù : « J'habite avec ma petite amie »", 0, '2025-07-09', 'ZH_6')
# 2025-07-09 18:44:09,729 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,729 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,729 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,729 INFO sqlalchemy.engine.Engine [cached since 0.008293s ago] ('ZH_6',)
# 2025-07-09 18:44:09,730 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,730 INFO sqlalchemy.engine.Engine [cached since 0.009984s ago] ('ZH_6_G4', 'Les caractères ayant plusieurs prononciations', "Vous aurez certainement remarqué que certains caractères peuvent avoir plusieurs prononciations. Le changement de prononciation peut faire varier ou  ... (198 characters truncated) ...  : trouver que\n* 睡觉 shuìjiào : dormir\n\nCertains caractères comme le 都 de 首都 « la capitale » peuvent changer à la fois de prononciation et de sens.", 0, '2025-07-09', 'ZH_6')
# 2025-07-09 18:44:09,730 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,730 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,731 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,731 INFO sqlalchemy.engine.Engine [cached since 0.009613s ago] ('ZH_7',)
# 2025-07-09 18:44:09,731 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,731 INFO sqlalchemy.engine.Engine [cached since 0.01153s ago] ('ZH_7_G1', 'Comparer avec 比 bi ou 没有 méiyǒu', "**Utilisation de 比 bi**\nLe caractère 比 bǐ est utilisé en tant que comparatif de supériorité ou d'infériorité (et non d'égalité). Il peut être tradui ... (740 characters truncated) ...  : « Il est plus petit que moi » (littéralement « Il n'a pas ma taille »)\n* 妈妈没有爸爸高 māma méiyǒu bàba gāo : « Maman n'est pas aussi grande que papa »", 0, '2025-07-09', 'ZH_7')
# 2025-07-09 18:44:09,731 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,732 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,732 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,732 INFO sqlalchemy.engine.Engine [cached since 0.01115s ago] ('ZH_7',)
# 2025-07-09 18:44:09,732 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,733 INFO sqlalchemy.engine.Engine [cached since 0.01285s ago] ('ZH_7_G2', 'Interrogatif 谁 shéi/shuí', "谁 shéi est l'interrogatif signifiant « Qui ? ». Comme tous les mots interrogatifs, il se place à l'endroit où se trouvera la réponse :\n\n* 你是谁？ Nǐ s ... (401 characters truncated) ...  » et ne doit pas traduire le pronom relatif « qui » dans des phrases comme « La personne qui habite ici ». Pour cela, on utilise 的 de (cf. Leçon 6).", 0, '2025-07-09', 'ZH_7')
# 2025-07-09 18:44:09,733 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,733 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,733 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,733 INFO sqlalchemy.engine.Engine [cached since 0.01243s ago] ('ZH_7',)
# 2025-07-09 18:44:09,734 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,734 INFO sqlalchemy.engine.Engine [cached since 0.01417s ago] ('ZH_7_G3', 'Quelle(s) langue(s) sais-tu parler ?', "En général, on forme le nom d'une langue en ajoutant 语 yǔ (ou 文 wén) au nom du pays.\n\nPour les pays finissant par 国 guó, on remplace 国 guó par 语 yǔ ... (342 characters truncated) ... :\n\n* 中国 Zhōngguó (Chine) → 中文 Zhōngwén (chinois)\n* 汉语 Hànyǔ (chinois)\n\nNote : 汉语 Hànyǔ (chinois) et 韩语 Hányǔ (coréen) se prononcent très proche.", 0, '2025-07-09', 'ZH_7')
# 2025-07-09 18:44:09,734 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,734 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,735 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,735 INFO sqlalchemy.engine.Engine [cached since 0.01373s ago] ('ZH_7',)
# 2025-07-09 18:44:09,735 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,735 INFO sqlalchemy.engine.Engine [cached since 0.01547s ago] ('ZH_7_G4', 'Les adverbes 最 zuì et 太 ... 了 tài...le', "Les adverbes 最 zuì et 太 ... 了 tài...le s'emploient comme 很 hěn devant un adjectif, mais nuancent ou renforcent le propos :\n\n* 我很累 wǒ hěn lèi : « Je ... (11 characters truncated) ... ué »\n* 最累 zuì lèi : « Le plus fatigué »\n* 我太累了 wǒ tài lèi le : « Je suis trop fatigué »\n* 我不太累了 wǒ bù tài lèi le : « Je ne suis pas trop fatigué »", 0, '2025-07-09', 'ZH_7')
# 2025-07-09 18:44:09,735 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,736 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,736 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,736 INFO sqlalchemy.engine.Engine [cached since 0.01501s ago] ('ZH_7',)
# 2025-07-09 18:44:09,736 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,736 INFO sqlalchemy.engine.Engine [cached since 0.01675s ago] ('ZH_7_G5', 'Tout, toutes et tous avec 都 dōu', 'Le caractère 都 peut se prononcer « dū » (dans 首都 shǒudū « capitale ») ou « dōu » quand il signifie « tout, tous ». Il se place directement après le n ... (122 characters truncated) ... ōu xiǎng qù Zhōngguó : « Nous voulons tous aller en Chine »\n* 我的朋友都 wǒ de péngyou dōu : « Tous mes amis »\n* 女生都 nǚshēng dōu : « Toutes les filles »', 0, '2025-07-09', 'ZH_7')
# 2025-07-09 18:44:09,737 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,737 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,737 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,737 INFO sqlalchemy.engine.Engine [cached since 0.01639s ago] ('ZH_7',)
# 2025-07-09 18:44:09,738 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,738 INFO sqlalchemy.engine.Engine [cached since 0.01813s ago] ('ZH_7_G6', 'Ensemble avec 一起 yīqǐ', '一起 yīqǐ a déjà été vu dans la structure 跟 gēn ... + 一起 yīqǐ (page 109) pour dire « avec ». 一起 yīqǐ peut aussi être utilisé seul et signifie « ensembl ... (50 characters truncated) ...  Elles vont regarder un film ensemble »\n* 我们一起去北京 wǒmen yīqǐ qù Běijīng : « Nous allons ensemble à Pékin »\n\nStructure : Sujet + 一起 + Verbe + Objet', 0, '2025-07-09', 'ZH_7')
# 2025-07-09 18:44:09,738 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,738 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,739 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,739 INFO sqlalchemy.engine.Engine [cached since 0.01773s ago] ('ZH_10',)
# 2025-07-09 18:44:09,739 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,739 INFO sqlalchemy.engine.Engine [cached since 0.01945s ago] ('ZH_10_G1', 'Indiquer le destinataire avec 给 gěi', "给 gěi, signifiant « donner », permet d'indiquer la cible d'une action.\n\nStructure : Sujet + 给 + cible + action\n\n* 你给我打电话 nǐ gěi wǒ dǎ diànhuà : « ... (45 characters truncated) ... i tā dǎ diànhuà : « Tu dois lui téléphoner »\n* 你给他写信 nǐ gěi tā xiěxìn : « Écris-lui une lettre »\n* 我给你做饭 wǒ gěi nǐ zuòfàn : « Je te fais à manger »", 0, '2025-07-09', 'ZH_10')
# 2025-07-09 18:44:09,739 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,740 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,740 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,740 INFO sqlalchemy.engine.Engine [cached since 0.01905s ago] ('ZH_10',)
# 2025-07-09 18:44:09,740 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,741 INFO sqlalchemy.engine.Engine [cached since 0.02086s ago] ('ZH_10_G2', '"Pouvoir" avec 能 néng ou 可以 kěyǐ', "Plusieurs verbes existent pour exprimer la possibilité, cependant ils ne peuvent pas s'employer de la même manière. Nous avons déjà étudié le verbe 会 ... (795 characters truncated) ... 停车吗？wǒ zài zhèr kěyǐ tíngchē ma ? : « Puis-je garer ma voiture ici ? »\n* 妈妈，我可以出去吗？māma, wǒ kěyǐ chūqù ma ? : « Maman, est-ce que je peux sortir ? »", 0, '2025-07-09', 'ZH_10')
# 2025-07-09 18:44:09,741 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,741 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,741 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,741 INFO sqlalchemy.engine.Engine [cached since 0.02038s ago] ('ZH_10',)
# 2025-07-09 18:44:09,742 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,742 INFO sqlalchemy.engine.Engine [cached since 0.0221s ago] ('ZH_10_G3', 'La condition avec 如果 ... 的话 rúguǒ ... de huà et 就 jiù', "如果 ... 的话 rúguǒ ... de huà et 就 jiù sont utilisés, ensemble ou séparément, afin d'introduire une condition et sa conséquence.\n\nStructure : 如果 + Suj ... (135 characters truncated) ... , appelle le médecin »\n* 如果他生病的话，他就不能去工作 rúguǒ tā shēngbìng de huà, tā jiù bù néng qù gōngzuò : « S'il est malade, il ne peut pas aller travailler »", 0, '2025-07-09', 'ZH_10')
# 2025-07-09 18:44:09,742 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,742 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,743 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,743 INFO sqlalchemy.engine.Engine [cached since 0.02165s ago] ('ZH_10',)
# 2025-07-09 18:44:09,743 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,743 INFO sqlalchemy.engine.Engine [cached since 0.02342s ago] ('ZH_10_G4', "Le comparatif d'égalité", "Nous avons étudié dans la leçon 7 les comparatifs de supériorité ou d'infériorité en utilisant le caractère 比 bǐ. Il ne faut pas employer 比 pour intr ... (338 characters truncated) ... la mienne »\n* 今天的会议和昨天的会议一样无聊 jīntiān de huìyì hé zuótiān de huìyì yīyàng wúliáo : « La réunion d'aujourd'hui est aussi ennuyeuse que celle d'hier »", 0, '2025-07-09', 'ZH_10')
# 2025-07-09 18:44:09,743 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,744 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,744 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,744 INFO sqlalchemy.engine.Engine [cached since 0.02298s ago] ('ZH_10',)
# ...
# 2025-07-09 18:44:09,818 INFO sqlalchemy.engine.Engine [cached since 0.09796s ago] ('ZH_12_G2', 'Classificateurs ne pouvant pas être remplacés par 个 gè', "Certains classificateurs ne peuvent pas être remplacés par 个 gè (qui est, pour rappel, le classificateur universel), car ils apportent un sens partic ... (274 characters truncated) ...  gè niǎo : « Un oiseau »\n* 一群鸟 yī qún niǎo : « Un vol d’oiseaux »\n* 一些人 yī xiē rén : « Quelques personnes »\n* 一杯水 yī bēi shuǐ : « Un verre d’eau »", 0, '2025-07-09', 'ZH_12')
# 2025-07-09 18:44:09,818 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,818 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,819 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,819 INFO sqlalchemy.engine.Engine [cached since 0.0977s ago] ('ZH_12',)
# 2025-07-09 18:44:09,819 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,819 INFO sqlalchemy.engine.Engine [cached since 0.09944s ago] ('ZH_12_G3', 'Permettre quelque chose avec 让 ràng', "让 ràng est un verbe dit « causatif », qui peut être traduit par « laisser » ou « permettre » en français.\n\nStructure : Sujet + 让 + Personne/Objet + ... (128 characters truncated) ...  papa ne te laisse-t-il pas y aller ? »\n* 看 Titanic 电影让我很感动 kàn Titanic diànyǐng ràng wǒ hěn gǎndòng : « Regarder le film Titanic m'a beaucoup ému »", 0, '2025-07-09', 'ZH_12')
# 2025-07-09 18:44:09,819 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,820 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,820 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,820 INFO sqlalchemy.engine.Engine [cached since 0.09913s ago] ('ZH_12',)
# 2025-07-09 18:44:09,820 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,821 INFO sqlalchemy.engine.Engine [cached since 0.1009s ago] ('ZH_12_G4', 'Demander « combien » avec 多少 duōshǎo ou 几 jǐ', "Il existe deux façons principales de demander « combien » : 多少 duōshǎo et 几 jǐ. Voici leurs différences :\n\n* 几 jǐ est utilisé pour des quantités gé ... (695 characters truncated) ...  ici »\n* 我有十多元 wǒ yǒu shí duō yuán : « J’ai un peu plus de dix yuans »\n* 我有三十多块钱 wǒ yǒu sānshí duō kuài qián : « J’ai un peu plus de trente kuais »", 0, '2025-07-09', 'ZH_12')
# 2025-07-09 18:44:09,821 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,821 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,821 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,822 INFO sqlalchemy.engine.Engine [cached since 0.1006s ago] ('ZH_12',)
# 2025-07-09 18:44:09,822 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,822 INFO sqlalchemy.engine.Engine [cached since 0.1023s ago] ('ZH_12_G5', '« Quelques » avec 一些 yīxiē', "一些 yīxiē signifie « quelques » ou « certains » et désigne une quantité indéterminée. Il s'utilise selon le schéma suivant :\n\n一些 + Nom\n\n* 有一些人 yǒu yīxiē rén : « Il y a quelques personnes »\n* 爸爸买了一些书 bàba mǎi le yīxiē shū : « Papa a acheté quelques livres »", 0, '2025-07-09', 'ZH_12')
# 2025-07-09 18:44:09,822 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,823 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,823 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,823 INFO sqlalchemy.engine.Engine [cached since 0.1019s ago] ('ZH_5',)
# 2025-07-09 18:44:09,823 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,823 INFO sqlalchemy.engine.Engine [cached since 0.1037s ago] ('ZH_5_G1', 'Les adjectifs', "**Affirmation avec 很 hěn**\nLes noms doivent être liés aux autres noms à l'aide du verbe « être » 是 shì.\n\n* 妈妈 是 老师 māma shì lǎoshī : « Maman est p ... (1844 characters truncated) ... ǐhuan : « j'aime »\n* 我 讨厌 wǒ tǎoyàn : « je déteste »\n* 我 很 喜欢 wǒ hěn xǐhuan : « j'aime beaucoup »\n* 我 很 讨厌 wǒ hěn tǎoyàn : « je déteste vraiment »", 0, '2025-07-09', 'ZH_5')
# 2025-07-09 18:44:09,824 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,824 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,824 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,824 INFO sqlalchemy.engine.Engine [cached since 0.1033s ago] ('ZH_5',)
# 2025-07-09 18:44:09,825 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,825 INFO sqlalchemy.engine.Engine [cached since 0.105s ago] ('ZH_5_G2', 'Énumérer avec 和 hé', "Le caractère 和 hé permet d'énumérer des noms communs. Nous pouvons traduire par « ainsi que », son emploi diffère donc du « et » français.\n\n* 我 的 妈 ... (132 characters truncated) ... n papa et moi »\n\n和 hé ne peut pas être utilisé pour lier deux phrases comme en français (ex. Ce matin je travaille et cet après-midi je me repose).", 0, '2025-07-09', 'ZH_5')
# 2025-07-09 18:44:09,825 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,825 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,825 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,826 INFO sqlalchemy.engine.Engine [cached since 0.1046s ago] ('ZH_5',)
# 2025-07-09 18:44:09,826 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,826 INFO sqlalchemy.engine.Engine [cached since 0.1063s ago] ('ZH_5_G3', 'Le caractère 的 de', "Le premier sens de 的 de est le possessif. L'ajout du caractère 的 de aux pronoms personnels permet de former les pronoms possessifs :\n\nPronom person ... (638 characters truncated) ...  de Chine »\n\nDéterminant + 的 + déterminé\n\nLe contexte est indispensable pour comprendre le sens qu'il a dans une phrase, un texte ou un dialogue.", 0, '2025-07-09', 'ZH_5')
# 2025-07-09 18:44:09,826 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,827 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,827 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,827 INFO sqlalchemy.engine.Engine [cached since 0.1059s ago] ('ZH_5',)
# 2025-07-09 18:44:09,827 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,827 INFO sqlalchemy.engine.Engine [cached since 0.1077s ago] ('ZH_5_G4', 'Les différentes utilisations de 要 yào', "Le premier sens de 要 yào est le verbe « vouloir ».\n\n* 我 要 工作 wǒ yào gōngzuò : « Je veux travailler »\n* 我 要 吃饭 wǒ yào chīfàn : « Je veux manger »\n ... (31 characters truncated) ... enir est la suivante :\n\nIl peut également avoir d'autres sens, tels que « devoir », « falloir » ou encore « aller faire/être sur le point de ... ».", 0, '2025-07-09', 'ZH_5')
# 2025-07-09 18:44:09,828 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,828 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,828 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,828 INFO sqlalchemy.engine.Engine [cached since 0.1073s ago] ('ZH_9',)
# 2025-07-09 18:44:09,829 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,829 INFO sqlalchemy.engine.Engine [cached since 0.109s ago] ('ZH_9_G1', 'Moyens de transport', "Si en français nous employons généralement le verbe « prendre » lorsqu'il s'agit des moyens de transport, il convient d'utiliser le verbe 坐 zuò « s'a ... (471 characters truncated) ...  véhicule, il faut employer 开 kāi « conduire, ouvrir » :\n\n* 我开车 wǒ kāi chē : « Je conduis la voiture »\n* 我开飞机 wǒ kāi fēijī : « Je pilote l'avion »", 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,829 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,829 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,829 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,830 INFO sqlalchemy.engine.Engine [cached since 0.1085s ago] ('ZH_9',)
# 2025-07-09 18:44:09,830 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,830 INFO sqlalchemy.engine.Engine [cached since 0.1102s ago] ('ZH_9_G2', '"Chaque" avec 每 měi', '每 měi est employé dans la majorité des cas avec un classificateur derrière :\n\n* 每个人 měi gè rén : « Chaque personne »\n* 每个月 měi gè yuè : « Chaque m ... (100 characters truncated) ... it pas être employé dans les trois cas suivants :\n\n* 每年 měi nián : « Chaque année »\n* 每天 měi tiān : « Chaque jour »\n* 每日 měi rì : « Chaque jour »', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,830 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,831 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,831 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,831 INFO sqlalchemy.engine.Engine [cached since 0.1099s ago] ('ZH_9',)
# 2025-07-09 18:44:09,831 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,831 INFO sqlalchemy.engine.Engine [cached since 0.1115s ago] ('ZH_9_G3', '"D\'abord... ensuite..." avec 先 xiān et 然后 ránhòu', "先 xiān « premièrement », et 然后 ránhòu « ensuite » peuvent être utilisés ensemble pour indiquer que deux événements se succèdent :\n\n* 我们先吃饭，然后看电视 wǒ ... (220 characters truncated) ... emièrement » peut également être utilisé seul :\n\n* 他先到了 tā xiān dào le : « Il est arrivé en premier »\n* 我先说 wǒ xiān shuō : « Je parle en premier »", 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,831 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,832 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,832 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,832 INFO sqlalchemy.engine.Engine [cached since 0.1112s ago] ('ZH_9',)
# 2025-07-09 18:44:09,832 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,833 INFO sqlalchemy.engine.Engine [cached since 0.1129s ago] ('ZH_9_G4', '"Un petit peu" avec 有点儿 yǒu diǎnr ou 一点儿 yī diǎnr', "**有点儿 yǒu diǎnr**\n有点儿 yǒu diǎnr ou simplement 有点 yǒu diǎn est utilisé avant un adjectif. Il est généralement employé dans des phrases négatives, pou ... (499 characters truncated) ... 宜一点儿 nǐ piányi yī diǎnr : « Baisse un peu le prix »\n* 你快一点儿 nǐ kuài yī diǎnr : « Dépêche-toi un peu »\n* 你慢一点儿 nǐ màn yī diǎnr : « Ralentis un peu »", 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,833 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,833 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,833 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,834 INFO sqlalchemy.engine.Engine [cached since 0.1125s ago] ('ZH_9',)
# 2025-07-09 18:44:09,834 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,834 INFO sqlalchemy.engine.Engine [cached since 0.1142s ago] ('ZH_9_G5', 'Utiliser 比较 bǐjiào devant un verbe', "Nous avons vu dans la leçon précédente que l'adverbe 比较 bǐjiào signifie « relativement, plutôt » et qu'il était employé devant un adjectif afin de le ... (162 characters truncated) ... iào xǐhuan : « Je préfère »\n* 我不喜欢坐车，我比较喜欢走路 wǒ bù xǐhuan zuò chē, wǒ bǐjiào xǐhuan zǒulù : « Je n'aime pas prendre la voiture, je préfère marcher »", 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,834 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:09,835 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,835 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:09,835 INFO sqlalchemy.engine.Engine [cached since 0.1138s ago] ('ZH_9',)
# 2025-07-09 18:44:09,835 INFO sqlalchemy.engine.Engine INSERT INTO grammar_rule (id, title, explanation, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:09,835 INFO sqlalchemy.engine.Engine [cached since 0.1156s ago] ('ZH_9_G6', 'Les particules modales placées en fin de phrase', 'Quelques particules modales sont habituellement rajoutées en fin de phrase pour donner un ton particulier à la phrase, en voici quelques exemples :\n ... (334 characters truncated) ... .\n\nIl existe également des interjections placées en début de phrase :\n\n* 嗯 en : équivalent du « hum... » français\n* 哎呀 āiyā : marque la surprise', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:09,836 INFO sqlalchemy.engine.Engine COMMIT
# /var/folders/5p/bjh6crbn6fv0vtxy5sqmmxh00000gn/T/ipykernel_20824/1242808380.py:24: SAWarning: Object of type <GrammarRule> not in session, add operation along 'Unit.grammars' will not proceed (This warning originated from the Session 'autoflush' process, which was invoked automatically in response to a user-initiated operation. Consider using ``no_autoflush`` context manager if this warning happended while initializing objects.)
#   parent=session.query(Unit).filter(Unit.id == f"{language_id.upper()}_{unit_id}").first()
# /Users/noe_jager/Documents/GitHub/vocabulary-dbms/src/lapp/dbms.py:80: SAWarning: Object of type <GrammarRule> not in session, add operation along 'Unit.grammars' will not proceed
#   session.commit()

# %% [markdown]
# ## Add Characters

# %%
# Initialize the database connection and create db file if it doesn't exist
from lapp.api.main import unit


engine, session = init_db()

directory_path = f'../data/{language_id}/character'

if not os.path.exists(directory_path):
    raise FileNotFoundError(f"No character files found for {language_id}.")

characters = []

# List all elements (files and directories) in the specified directory and get their full paths
elements_paths = [os.path.join(directory_path, element) for element in os.listdir(directory_path)]
for character_file in elements_paths:
    if os.path.isfile(character_file) and character_file.endswith('.csv'):
        unit_id = re.sub("[^0-9]", "", os.path.basename(character_file))
        print(f"Processing: {unit_id}")
        df = pd.read_csv(character_file)
        for idx, row in enumerate(df.itertuples(index=False)):
            characters.append(
                CalligraphyCharacter(
                    id=f"{language_id.upper()}_{unit_id}_C{idx + 1}",
                    character=row.character,
                    components=row.components,
                    phonetic=row.phonetic,
                    meaning=row.meaning,
                    example_word=row.example_word,
                    parent=session.query(Unit).filter(Unit.id == f"{language_id.upper()}_{unit_id}").first()
                )
            )
inserts(session, characters)
session.close()
# Out:
# 2025-07-09 18:44:09,977 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,977 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("language")
# 2025-07-09 18:44:09,978 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:09,978 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("unit")
# 2025-07-09 18:44:09,978 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:09,979 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("calligraphy_character")
# 2025-07-09 18:44:09,979 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:09,979 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("grammar_rule")
# 2025-07-09 18:44:09,980 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:09,980 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("vocabulary")
# 2025-07-09 18:44:09,980 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:09,981 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("exercises")
# 2025-07-09 18:44:09,981 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-09 18:44:09,982 INFO sqlalchemy.engine.Engine COMMIT
# Processing: 2
# 2025-07-09 18:44:09,984 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:09,984 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,984 INFO sqlalchemy.engine.Engine [generated in 0.00025s] ('ZH_2', 1, 0)
# 2025-07-09 18:44:09,985 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,986 INFO sqlalchemy.engine.Engine [cached since 0.001355s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:09,986 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,986 INFO sqlalchemy.engine.Engine [cached since 0.002146s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:09,987 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,987 INFO sqlalchemy.engine.Engine [cached since 0.00315s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:09,988 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,988 INFO sqlalchemy.engine.Engine [cached since 0.003987s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:09,989 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,989 INFO sqlalchemy.engine.Engine [cached since 0.004581s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:09,989 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,990 INFO sqlalchemy.engine.Engine [cached since 0.00527s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:09,990 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,991 INFO sqlalchemy.engine.Engine [cached since 0.006323s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:09,992 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,992 INFO sqlalchemy.engine.Engine [cached since 0.007616s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:09,993 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,993 INFO sqlalchemy.engine.Engine [cached since 0.008759s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:09,994 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,994 INFO sqlalchemy.engine.Engine [cached since 0.009864s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:09,995 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,995 INFO sqlalchemy.engine.Engine [cached since 0.0108s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:09,996 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,996 INFO sqlalchemy.engine.Engine [cached since 0.01155s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:09,997 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,997 INFO sqlalchemy.engine.Engine [cached since 0.01264s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:09,998 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,998 INFO sqlalchemy.engine.Engine [cached since 0.01405s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:09,999 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:09,999 INFO sqlalchemy.engine.Engine [cached since 0.01474s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:10,000 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,000 INFO sqlalchemy.engine.Engine [cached since 0.01565s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:10,001 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,001 INFO sqlalchemy.engine.Engine [cached since 0.01674s ago] ('ZH_2', 1, 0)
# 2025-07-09 18:44:10,002 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,003 INFO sqlalchemy.engine.Engine [cached since 0.0185s ago] ('ZH_2', 1, 0)
# Processing: 3
# 2025-07-09 18:44:10,006 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,006 INFO sqlalchemy.engine.Engine [cached since 0.02176s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:10,007 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,007 INFO sqlalchemy.engine.Engine [cached since 0.02297s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:10,008 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,008 INFO sqlalchemy.engine.Engine [cached since 0.02409s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:10,009 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,010 INFO sqlalchemy.engine.Engine [cached since 0.02526s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:10,010 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,011 INFO sqlalchemy.engine.Engine [cached since 0.02654s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:10,012 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,012 INFO sqlalchemy.engine.Engine [cached since 0.02765s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:10,013 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,013 INFO sqlalchemy.engine.Engine [cached since 0.02888s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:10,014 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,014 INFO sqlalchemy.engine.Engine [cached since 0.03022s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:10,015 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,015 INFO sqlalchemy.engine.Engine [cached since 0.03101s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:10,016 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,016 INFO sqlalchemy.engine.Engine [cached since 0.03201s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:10,018 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,018 INFO sqlalchemy.engine.Engine [cached since 0.03374s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:10,020 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,021 INFO sqlalchemy.engine.Engine [cached since 0.03638s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:10,022 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,022 INFO sqlalchemy.engine.Engine [cached since 0.03773s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:10,023 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,023 INFO sqlalchemy.engine.Engine [cached since 0.03888s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:10,024 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,025 INFO sqlalchemy.engine.Engine [cached since 0.04037s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:10,025 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,025 INFO sqlalchemy.engine.Engine [cached since 0.04119s ago] ('ZH_3', 1, 0)
# 2025-07-09 18:44:10,026 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,026 INFO sqlalchemy.engine.Engine [cached since 0.04191s ago] ('ZH_3', 1, 0)
# Processing: 1
# 2025-07-09 18:44:10,031 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,032 INFO sqlalchemy.engine.Engine [cached since 0.04783s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:10,033 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,033 INFO sqlalchemy.engine.Engine [cached since 0.0488s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:10,034 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,034 INFO sqlalchemy.engine.Engine [cached since 0.0497s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:10,036 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,037 INFO sqlalchemy.engine.Engine [cached since 0.05233s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:10,038 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,038 INFO sqlalchemy.engine.Engine [cached since 0.05404s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:10,039 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,040 INFO sqlalchemy.engine.Engine [cached since 0.05556s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:10,041 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,041 INFO sqlalchemy.engine.Engine [cached since 0.05656s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:10,042 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,042 INFO sqlalchemy.engine.Engine [cached since 0.0575s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:10,042 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,043 INFO sqlalchemy.engine.Engine [cached since 0.05844s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:10,043 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,044 INFO sqlalchemy.engine.Engine [cached since 0.05939s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:10,044 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,045 INFO sqlalchemy.engine.Engine [cached since 0.06076s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:10,046 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,047 INFO sqlalchemy.engine.Engine [cached since 0.06253s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:10,048 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,048 INFO sqlalchemy.engine.Engine [cached since 0.06355s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:10,048 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,048 INFO sqlalchemy.engine.Engine [cached since 0.06414s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:10,049 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,049 INFO sqlalchemy.engine.Engine [cached since 0.06503s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:10,050 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,050 INFO sqlalchemy.engine.Engine [cached since 0.066s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:10,052 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,052 INFO sqlalchemy.engine.Engine [cached since 0.06822s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:10,055 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,055 INFO sqlalchemy.engine.Engine [cached since 0.07053s ago] ('ZH_1', 1, 0)
# 2025-07-09 18:44:10,056 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,056 INFO sqlalchemy.engine.Engine [cached since 0.07222s ago] ('ZH_1', 1, 0)
# Processing: 4
# 2025-07-09 18:44:10,058 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,058 INFO sqlalchemy.engine.Engine [cached since 0.07368s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:10,059 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,059 INFO sqlalchemy.engine.Engine [cached since 0.07437s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:10,059 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,059 INFO sqlalchemy.engine.Engine [cached since 0.07494s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:10,060 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,060 INFO sqlalchemy.engine.Engine [cached since 0.07556s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:10,060 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,060 INFO sqlalchemy.engine.Engine [cached since 0.07615s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:10,061 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,061 INFO sqlalchemy.engine.Engine [cached since 0.07679s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:10,061 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,062 INFO sqlalchemy.engine.Engine [cached since 0.07738s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:10,062 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,062 INFO sqlalchemy.engine.Engine [cached since 0.07804s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:10,063 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,063 INFO sqlalchemy.engine.Engine [cached since 0.07862s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:10,063 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,063 INFO sqlalchemy.engine.Engine [cached since 0.07921s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:10,064 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,064 INFO sqlalchemy.engine.Engine [cached since 0.07976s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:10,065 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,065 INFO sqlalchemy.engine.Engine [cached since 0.0804s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:10,065 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,065 INFO sqlalchemy.engine.Engine [cached since 0.08097s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:10,066 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,066 INFO sqlalchemy.engine.Engine [cached since 0.08163s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:10,066 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,066 INFO sqlalchemy.engine.Engine [cached since 0.08219s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:10,067 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,067 INFO sqlalchemy.engine.Engine [cached since 0.08284s ago] ('ZH_4', 1, 0)
# 2025-07-09 18:44:10,068 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,068 INFO sqlalchemy.engine.Engine [cached since 0.08339s ago] ('ZH_4', 1, 0)
# Processing: 5
# 2025-07-09 18:44:10,070 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,070 INFO sqlalchemy.engine.Engine [cached since 0.08619s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:10,071 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,071 INFO sqlalchemy.engine.Engine [cached since 0.08684s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:10,072 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,072 INFO sqlalchemy.engine.Engine [cached since 0.08749s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:10,072 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,072 INFO sqlalchemy.engine.Engine [cached since 0.08818s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:10,073 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,073 INFO sqlalchemy.engine.Engine [cached since 0.0888s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:10,074 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,074 INFO sqlalchemy.engine.Engine [cached since 0.08948s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:10,074 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,074 INFO sqlalchemy.engine.Engine [cached since 0.0901s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:10,075 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,075 INFO sqlalchemy.engine.Engine [cached since 0.09069s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:10,075 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,075 INFO sqlalchemy.engine.Engine [cached since 0.09124s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:10,076 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,076 INFO sqlalchemy.engine.Engine [cached since 0.0918s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:10,076 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,077 INFO sqlalchemy.engine.Engine [cached since 0.09235s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:10,077 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,077 INFO sqlalchemy.engine.Engine [cached since 0.09295s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:10,078 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,078 INFO sqlalchemy.engine.Engine [cached since 0.09349s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:10,078 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,078 INFO sqlalchemy.engine.Engine [cached since 0.09403s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:10,079 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,079 INFO sqlalchemy.engine.Engine [cached since 0.09455s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:10,079 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,079 INFO sqlalchemy.engine.Engine [cached since 0.09507s ago] ('ZH_5', 1, 0)
# 2025-07-09 18:44:10,080 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,080 INFO sqlalchemy.engine.Engine [cached since 0.09568s ago] ('ZH_5', 1, 0)
# Processing: 7
# 2025-07-09 18:44:10,081 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,081 INFO sqlalchemy.engine.Engine [cached since 0.0972s ago] ('ZH_7', 1, 0)
# 2025-07-09 18:44:10,082 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,082 INFO sqlalchemy.engine.Engine [cached since 0.0978s ago] ('ZH_7', 1, 0)
# 2025-07-09 18:44:10,082 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,083 INFO sqlalchemy.engine.Engine [cached since 0.09835s ago] ('ZH_7', 1, 0)
# 2025-07-09 18:44:10,083 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,083 INFO sqlalchemy.engine.Engine [cached since 0.09897s ago] ('ZH_7', 1, 0)
# 2025-07-09 18:44:10,084 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,084 INFO sqlalchemy.engine.Engine [cached since 0.09986s ago] ('ZH_7', 1, 0)
# 2025-07-09 18:44:10,085 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,085 INFO sqlalchemy.engine.Engine [cached since 0.1005s ago] ('ZH_7', 1, 0)
# 2025-07-09 18:44:10,086 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,086 INFO sqlalchemy.engine.Engine [cached since 0.1022s ago] ('ZH_7', 1, 0)
# 2025-07-09 18:44:10,087 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,087 INFO sqlalchemy.engine.Engine [cached since 0.1031s ago] ('ZH_7', 1, 0)
# 2025-07-09 18:44:10,088 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,088 INFO sqlalchemy.engine.Engine [cached since 0.1037s ago] ('ZH_7', 1, 0)
# 2025-07-09 18:44:10,088 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,089 INFO sqlalchemy.engine.Engine [cached since 0.1043s ago] ('ZH_7', 1, 0)
# 2025-07-09 18:44:10,089 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,089 INFO sqlalchemy.engine.Engine [cached since 0.1049s ago] ('ZH_7', 1, 0)
# 2025-07-09 18:44:10,090 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,090 INFO sqlalchemy.engine.Engine [cached since 0.1056s ago] ('ZH_7', 1, 0)
# 2025-07-09 18:44:10,090 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,090 INFO sqlalchemy.engine.Engine [cached since 0.1061s ago] ('ZH_7', 1, 0)
# 2025-07-09 18:44:10,091 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,091 INFO sqlalchemy.engine.Engine [cached since 0.1066s ago] ('ZH_7', 1, 0)
# 2025-07-09 18:44:10,091 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,091 INFO sqlalchemy.engine.Engine [cached since 0.1072s ago] ('ZH_7', 1, 0)
# 2025-07-09 18:44:10,092 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,092 INFO sqlalchemy.engine.Engine [cached since 0.1077s ago] ('ZH_7', 1, 0)
# 2025-07-09 18:44:10,093 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,093 INFO sqlalchemy.engine.Engine [cached since 0.1085s ago] ('ZH_7', 1, 0)
# 2025-07-09 18:44:10,093 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,094 INFO sqlalchemy.engine.Engine [cached since 0.1094s ago] ('ZH_7', 1, 0)
# Processing: 6
# 2025-07-09 18:44:10,095 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,095 INFO sqlalchemy.engine.Engine [cached since 0.111s ago] ('ZH_6', 1, 0)
# 2025-07-09 18:44:10,096 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,096 INFO sqlalchemy.engine.Engine [cached since 0.1116s ago] ('ZH_6', 1, 0)
# 2025-07-09 18:44:10,096 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,097 INFO sqlalchemy.engine.Engine [cached since 0.1123s ago] ('ZH_6', 1, 0)
# 2025-07-09 18:44:10,097 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,097 INFO sqlalchemy.engine.Engine [cached since 0.1129s ago] ('ZH_6', 1, 0)
# 2025-07-09 18:44:10,098 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,098 INFO sqlalchemy.engine.Engine [cached since 0.1136s ago] ('ZH_6', 1, 0)
# 2025-07-09 18:44:10,098 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,098 INFO sqlalchemy.engine.Engine [cached since 0.1142s ago] ('ZH_6', 1, 0)
# 2025-07-09 18:44:10,099 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,099 INFO sqlalchemy.engine.Engine [cached since 0.1147s ago] ('ZH_6', 1, 0)
# 2025-07-09 18:44:10,099 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,100 INFO sqlalchemy.engine.Engine [cached since 0.1153s ago] ('ZH_6', 1, 0)
# 2025-07-09 18:44:10,100 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,100 INFO sqlalchemy.engine.Engine [cached since 0.1159s ago] ('ZH_6', 1, 0)
# 2025-07-09 18:44:10,101 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,101 INFO sqlalchemy.engine.Engine [cached since 0.1164s ago] ('ZH_6', 1, 0)
# 2025-07-09 18:44:10,101 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,101 INFO sqlalchemy.engine.Engine [cached since 0.117s ago] ('ZH_6', 1, 0)
# 2025-07-09 18:44:10,102 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,103 INFO sqlalchemy.engine.Engine [cached since 0.1185s ago] ('ZH_6', 1, 0)
# 2025-07-09 18:44:10,104 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,104 INFO sqlalchemy.engine.Engine [cached since 0.1195s ago] ('ZH_6', 1, 0)
# 2025-07-09 18:44:10,104 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,104 INFO sqlalchemy.engine.Engine [cached since 0.1201s ago] ('ZH_6', 1, 0)
# 2025-07-09 18:44:10,105 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,105 INFO sqlalchemy.engine.Engine [cached since 0.1206s ago] ('ZH_6', 1, 0)
# 2025-07-09 18:44:10,105 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
#  LIMIT ? OFFSET ?
# 2025-07-09 18:44:10,106 INFO sqlalchemy.engine.Engine [cached since 0.1214s ago] ('ZH_6', 1, 0)
# ...
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:10,950 INFO sqlalchemy.engine.Engine [cached since 0.7196s ago] ('ZH_8',)
# 2025-07-09 18:44:10,951 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:10,951 INFO sqlalchemy.engine.Engine [cached since 0.7219s ago] ('ZH_8_C15', '怎', '心 (clef : cœur) + 乍', 'zěn', 'Comment', '怎么样 ? Zěnmeyàng ? Comment ?', 0, '2025-07-09', 'ZH_8')
# 2025-07-09 18:44:10,951 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:10,952 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:10,953 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:10,953 INFO sqlalchemy.engine.Engine [cached since 0.7225s ago] ('ZH_8',)
# 2025-07-09 18:44:10,954 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:10,954 INFO sqlalchemy.engine.Engine [cached since 0.725s ago] ('ZH_8_C16', '做', '亻 (clef : homme) + 故', 'zuò', 'Faire', '你做什么 ? Nǐ zuò shénme ? Que fais-tu ?', 0, '2025-07-09', 'ZH_8')
# 2025-07-09 18:44:10,954 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:10,955 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:10,955 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:10,955 INFO sqlalchemy.engine.Engine [cached since 0.7248s ago] ('ZH_9',)
# 2025-07-09 18:44:10,956 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:10,956 INFO sqlalchemy.engine.Engine [cached since 0.7273s ago] ('ZH_9_C1', '班', '王 (clef : jade) + 6 traits', 'bān', 'Groupe', '上班 shàngbān : Aller au travail', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:10,956 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:10,957 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:10,957 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:10,958 INFO sqlalchemy.engine.Engine [cached since 0.727s ago] ('ZH_9',)
# 2025-07-09 18:44:10,958 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:10,958 INFO sqlalchemy.engine.Engine [cached since 0.7293s ago] ('ZH_9_C2', '车', 'Pictogramme', 'chē', 'Véhicule', '火车 huǒchē : Train', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:10,959 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:10,959 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:10,959 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:10,960 INFO sqlalchemy.engine.Engine [cached since 0.7291s ago] ('ZH_9',)
# 2025-07-09 18:44:10,960 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:10,960 INFO sqlalchemy.engine.Engine [cached since 0.7314s ago] ('ZH_9_C3', '公', '八 (clef : huit) + 2 traits', 'gōng', 'Public', '公交车 gōngjiāochē : Bus', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:10,961 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:10,961 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:10,961 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:10,962 INFO sqlalchemy.engine.Engine [cached since 0.7312s ago] ('ZH_9',)
# 2025-07-09 18:44:10,962 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:10,963 INFO sqlalchemy.engine.Engine [cached since 0.7338s ago] ('ZH_9_C4', '后', '厂 + 口 (clef : bouche)', 'hòu', 'Après/ensuite', '以后 yǐhòu : Après', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:10,963 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:10,964 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:10,964 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:10,964 INFO sqlalchemy.engine.Engine [cached since 0.7335s ago] ('ZH_9',)
# 2025-07-09 18:44:10,964 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:10,964 INFO sqlalchemy.engine.Engine [cached since 0.7356s ago] ('ZH_9_C5', '火', 'Pictogramme', 'huǒ', 'Feu', '火车 huǒchē : Train', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:10,965 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:10,965 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:10,966 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:10,966 INFO sqlalchemy.engine.Engine [cached since 0.7352s ago] ('ZH_9',)
# 2025-07-09 18:44:10,966 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:10,966 INFO sqlalchemy.engine.Engine [cached since 0.7374s ago] ('ZH_9_C6', '交', '亠 (clef : tête) + 4 traits', 'jiāo', 'Échange', '公交车 gōngjiāochē : Bus', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:10,967 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:10,967 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:10,968 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:10,968 INFO sqlalchemy.engine.Engine [cached since 0.7371s ago] ('ZH_9',)
# 2025-07-09 18:44:10,968 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:10,968 INFO sqlalchemy.engine.Engine [cached since 0.7393s ago] ('ZH_9_C7', '开', '廾 (clef : mains) + 1 trait', 'kāi', 'Ouvrir', '开车 kāichē : Conduire', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:10,969 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:10,970 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:10,970 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:10,970 INFO sqlalchemy.engine.Engine [cached since 0.7398s ago] ('ZH_9',)
# 2025-07-09 18:44:10,971 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:10,971 INFO sqlalchemy.engine.Engine [cached since 0.7421s ago] ('ZH_9_C8', '每', '母 (clef : mère) + 2 traits', 'měi', 'Chaque', '每天 měitiān : Tous les jours', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:10,971 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:10,972 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:10,972 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:10,972 INFO sqlalchemy.engine.Engine [cached since 0.7418s ago] ('ZH_9',)
# 2025-07-09 18:44:10,973 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:10,973 INFO sqlalchemy.engine.Engine [cached since 0.744s ago] ('ZH_9_C9', '然', '月 + 犬 + 灬 (clef : feu)', 'rán', 'Cependant', '然后 ránhòu : Ensuite', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:10,973 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:10,974 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:10,974 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:10,975 INFO sqlalchemy.engine.Engine [cached since 0.744s ago] ('ZH_9',)
# 2025-07-09 18:44:10,975 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:10,975 INFO sqlalchemy.engine.Engine [cached since 0.7465s ago] ('ZH_9_C10', '始', '女 (clef : femme) + 台', 'shǐ', 'Débuter', '开始 kāishǐ : Commencer', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:10,976 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:10,977 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:10,977 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:10,977 INFO sqlalchemy.engine.Engine [cached since 0.7464s ago] ('ZH_9',)
# 2025-07-09 18:44:10,978 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:10,978 INFO sqlalchemy.engine.Engine [cached since 0.7489s ago] ('ZH_9_C11', '同', '口 (clef : bouche) + 门', 'tóng', 'Identique', "同意 tóngyì : Être d'accord", 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:10,978 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:10,979 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:10,979 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:10,979 INFO sqlalchemy.engine.Engine [cached since 0.7488s ago] ('ZH_9',)
# 2025-07-09 18:44:10,980 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:10,980 INFO sqlalchemy.engine.Engine [cached since 0.7511s ago] ('ZH_9_C12', '先', '儿 (clef : fils) + 4 traits', 'xiān', 'Premièrement', "你先吃饭吧 nǐ xiān chīfàn ba : Mange d'abord !", 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:10,980 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:10,981 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:10,981 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:10,982 INFO sqlalchemy.engine.Engine [cached since 0.7511s ago] ('ZH_9',)
# 2025-07-09 18:44:10,982 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:10,982 INFO sqlalchemy.engine.Engine [cached since 0.7534s ago] ('ZH_9_C13', '意', '心 (clef : cœur) + 音', 'yì', 'Signification', "同意 tóngyì : Être d'accord", 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:10,983 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:10,983 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:10,983 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:10,984 INFO sqlalchemy.engine.Engine [cached since 0.753s ago] ('ZH_9',)
# 2025-07-09 18:44:10,984 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:10,984 INFO sqlalchemy.engine.Engine [cached since 0.7551s ago] ('ZH_9_C14', '园', '囗 (clef : enceinte) + 元', 'yuán', 'Jardin', '公园 gōngyuán : Parc public', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:10,984 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:10,985 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:10,986 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:10,986 INFO sqlalchemy.engine.Engine [cached since 0.7553s ago] ('ZH_9',)
# 2025-07-09 18:44:10,986 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:10,986 INFO sqlalchemy.engine.Engine [cached since 0.7576s ago] ('ZH_9_C15', '自', '自 (clef : personnel)', 'zì', 'Soi-même', '自行车 zìxíngchē : Vélo', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:10,987 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-09 18:44:10,989 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-09 18:44:10,991 INFO sqlalchemy.engine.Engine SELECT unit.id AS unit_id, unit.title AS unit_title, unit.description AS unit_description, unit.level AS unit_level, unit.score AS unit_score, unit.language_id AS unit_language_id
# FROM unit
# WHERE unit.id = ?
# 2025-07-09 18:44:10,992 INFO sqlalchemy.engine.Engine [cached since 0.7611s ago] ('ZH_9',)
# 2025-07-09 18:44:10,993 INFO sqlalchemy.engine.Engine INSERT INTO calligraphy_character (id, character, components, phonetic, meaning, example_word, score, last_seen, unit_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-07-09 18:44:10,996 INFO sqlalchemy.engine.Engine [cached since 0.7674s ago] ('ZH_9_C16', '坐', '土 (clef : sol) + 从', 'zuò', "S'asseoir", '坐车 zuò chē : Prendre un véhicule', 0, '2025-07-09', 'ZH_9')
# 2025-07-09 18:44:10,998 INFO sqlalchemy.engine.Engine COMMIT
